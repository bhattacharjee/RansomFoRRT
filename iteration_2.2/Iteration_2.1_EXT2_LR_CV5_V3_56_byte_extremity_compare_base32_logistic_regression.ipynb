# %% [markdown]
# ## Modification over the last run
#
# In this run, the extremity size is 56 (as opposed to 128).
#
# Extremities are left unencrypted.

# %% [markdown]
# # Contents
# - ## [Implementation](#mplementation)
#  - ### [List of Files](#list-of-files)
#  - ### [Utility to call gc](#gc)
#  - ### [Selection of Columns](#select-columns)
#  - ### [Function to compare the three selections of columns for a given dataset](#compare-fn)
#  - ### [Load the datasets](#load-dataset)
#  - ### [Select the datasets](#dataset-selection)
#  - ### [Run all combinations of data](#dataset-selection)
# - ## [Results](#results)
#  - ### [Print the raw results](#raw-results)
#  - ### [Sort by the improvement when using Fourier transforms over baseline](#sorted-fourier)
#  - ### [Measure improvement when only webp files are used](#webp-only)
#  - ### [Measure improvement when webp files are not present](#no-webp)
#  - ### [Measure improvement for balanced datasets](#balanced-dataset)
#  - ### [Measure the improvement when all files are used](#full-dataset)
#  - ### [Focus on items where the base metrics performed well](#focus-greater-90)
#  - ### [Correlation of data set and performance]("corr-heatmap")
#  - ### [Average out all the metrics](#mean-fscores)

# %% [markdown]
# ## Implementation <a class="anchor" id="implementation">
#
# [top](#Contents)

# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats

from functools import lru_cache

import gc

import sklearn
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, accuracy_score, recall_score

import matplotlib.pyplot as plt
import glob

import tqdm
from multiprocessing.pool import ThreadPool, Pool

plt.rcParams["figure.figsize"] = (20,20)

# %% [markdown]
# ### List of files <a class="anchor" id="list-of-files">
#
# [top](#Contents)

# %%
# !ls
# Out:
# Iteration_2.1_EXT2_LR_CV5_V3_compare_base32_logistic_regression.ipynb
# expanded.plaintext.base32.csv.gz
# expanded.pyencrypted_v1.b32.csv.gz
# expanded.pyencrypted_v1.csv.gz
# expanded_encrypted_v3.csv.gz
# expanded_encrypted_v3_base32.csv.gz
# plaintext.base32.combined.csv.gz
# plaintext.combined.csv.gz
# plaintext.expanded.csv.gz
# simple-average.pickle
# weighted-results.pickle
# weighted-scaled-results.pickle

# %% [markdown]
# ### Utility to call GC <a class="anchor" id="gc">
#
# [top](#Contents)

# %%
def call_gc():
    for i in range(3):
        for j in range(3):
            gc.collect(j)

# %% [markdown]
# ### Selection of columns <a class="anchor" id="select-columns">
#
# This function is used to select the columns.
# There are three different configurations:
#
#     1. Baseline - statistics like autocorrelation, shannon entropy, chi-square etc. are used
#
#     2. Advanced - More statistics like moments, Tsallis and Renyi entropy, higher moments etc.
#
#     3. Fourier - Some statistics of the Fourier Power Spectrum distribution
#
# [top](#Contents)

# %%
def get_columns(thisdf):
    baseline_columns = [c for c in thisdf.columns if c.startswith('baseline') and "head" not in c and "tail" not in c]
    baseline_columns = [c for c in baseline_columns if "filesize" not in c]
    baseline_columns = [c for c in baseline_columns if "begin" not in c and "end" not in c]

    advanced_columns = [c for c in thisdf.columns if "advanced" in c]
    advanced_columns = [c for c in advanced_columns if "begin" not in c and "end" not in c]
    advanced_columns = [c for c in advanced_columns if "head" not in c and "tail" not in c]
    advanced_columns = [c for c in advanced_columns if "start" not in c]
    advanced_columns_only = list(set(advanced_columns))
    advanced_columns = list(set(advanced_columns + baseline_columns))

    fourier_columns = [c for c in thisdf.columns if "fourier" in c and "value" not in c]
    fourier_columns = [c for c in fourier_columns if "1byte" in c]
    fourier_columns = [c for c in fourier_columns if "begin" not in c and "end" not in c]
    fourier_columns = [c for c in fourier_columns if "head" not in c and "tail" not in c]
    fourier_columns = [c for c in fourier_columns if "start" not in c]
    fourier_columns_only = list(set(fourier_columns))
    fourier_columns = list(set(advanced_columns + fourier_columns))
    
    baseline_and_advanced = list(set(baseline_columns + advanced_columns_only))
    baseline_and_fourier = list(set(baseline_columns + fourier_columns_only))
    advanced_and_fourier = list(set(advanced_columns_only + fourier_columns_only))
    
    return {\
        "baseline": baseline_columns,\
        "advanced-only": advanced_columns_only,\
        "fourier-only": fourier_columns_only,\
        "baseline-and-fourier": baseline_and_fourier,\
        "advanced-and-fourier": advanced_and_fourier,\
        "advanced": advanced_columns,\
        "fourier": fourier_columns,\
    }

# %% [markdown]
# ### Function to compare the three selections of columns for a given dataset <a class="anchor" id="compare-fn">
#
# For the three different sets of measurements described above, compare all the three sets for their f1 score
#
# [top](#Contents)

# %%
USE_ASYNC = False
N_SPLITS=5

def get_kfold_f1_score(name, collist, X, y):
    skf = StratifiedKFold(n_splits=N_SPLITS, random_state=42, shuffle=True)
    f1_scores = []
    precision_scores = []
    recall_scores = []
    accuracy_scores = []
    X = X[collist].to_numpy()
    y = y.to_numpy()
    call_gc()
    for train_idx, test_idx in skf.split(X, y):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]
        lr = LogisticRegression(n_jobs=8, \
                                solver='saga', \
                                random_state=42, \
                                max_iter=1000, \
                                multi_class='ovr')
        estimators = [\
                      ('std,', MinMaxScaler()), \
                      ('LogisticRegression', lr)]
        pipeline = Pipeline(estimators)
        pipeline.fit(X_train, y_train)
        y_pred = pipeline.predict(X_test)
        f1_scores.append(f1_score(y_test, y_pred))
        recall_scores.append(recall_score(y_test, y_pred))
        precision_scores.append(precision_score(y_test, y_pred, zero_division=0))
        accuracy_scores.append(accuracy_score(y_test, y_pred))

    return name, \
            float(np.mean(f1_scores)),\
            float(np.mean(accuracy_scores)),\
            float(np.mean(precision_scores)),\
            float(np.mean(recall_scores)),

def compare_feature_selections_async(X, y):
    columns_dict = get_columns(X)
    ret = dict()
    pool = Pool(3)
    async_results = list()
    for name, collist in columns_dict.items():
        result = pool.apply_async(\
                                  get_kfold_f1_score, \
                                  (name, collist, X, y))
    for result in async_results:
        name, f1 = result.get(timeout=None)
        ret[name] = f1
    return ret

def compare_feature_selections_sync(X, y):
    columns_dict = get_columns(X)
    ret = dict()
    for name, collist in columns_dict.items():
        name, f1, accuracy, precision, recall = \
            get_kfold_f1_score(name, collist, X, y)
        ret[f"{name}-f1_score"] = f1
        ret[f"{name}-accuracy_score"] = accuracy
        ret[f"{name}-precision_score"] = precision
        ret[f"{name}-recall_score"] = recall
    return ret

def compare_feature_selections(X, y):
    if USE_ASYNC:
        return compare_feature_selections_async(X, y)
    else:
        return compare_feature_selections_sync(X, y)

def compare_feature_selections_wrapper(data):
    X = data[[c for c in data.columns if "is_encrypted" != c]]
    y = data["is_encrypted"]
    return compare_feature_selections(X, y)

# %% [markdown]
# ### Load the datasets <a class="anchor" id="load-dataset">
#
# We don't want to load the datasets again and again, so we load them once.
# The LRU cache ensures that the next time this is called, we don't load the datasets again.
#
# [top](#Contents)

# %%
@lru_cache
def load_datasets_once():
    """Load all datasets only once
    
    We want to load the datasets only once. Once loaded
    serve from cache
    """
    datasets = dict()
    for file in glob.glob("*.csv.gz"):
        df = pd.read_csv(file)
        df = df.sample(frac=1).reset_index(drop=True)
        df["is_encrypted"] = 1 if "encr" in file.lower() else 0
        datasets[file] = df
    return datasets

# %% [markdown]
# ### Select the datasets <a class="anchor" id="dataset-selection">
#
# Select the dataset, combine it, shuffle it and return
#
# We used several schemes:
# * Plaintext
#   - The base plaintext dataset of around 50k files
#   - Expanded dataset, where all files that were less than 1500 bytes were expanded by repeating the file
#   - Base32 encoding of
#    - original plaintext
#    - expanded plaintext
# * Encryption : We used two schemes for encruption
#   - v1 : AES 256 encryption of the full file, again two varieties were used
#     - Plain encryption
#     - Encryption followed by base32 encoding
#   - v2 : AES encryption of the file, the first and the last 128 bytes are not encrypted. Of the remaining file, every alternate 16 bytes are encrypted.
#     - Plain encryption
#     - encryption followed by base32 encoding
#
# We select combinations of the above datasets
#
# Furthermore, we add further combinations by including and excluding webp files, and including and excluding non-webp files.
#
# [top](#Contents)

# %%
def get_dataset(\
               exclude_plaintext_nonbase32=False,
               exclude_plaintext_base32=False,
               exclude_encrypted_v1=False,
               exclude_encrypted_v2=False,
               exclude_encrypted_base32=False,
               exclude_encrypted_nonbase32=False,
               exclude_webp=False,
               exclude_nonwebp=False):
    description = {k:v for k,v in locals().items() \
                   if "exclude" in k}
    
    files = glob.glob("*.csv.gz")
    
    
    if exclude_plaintext_nonbase32:
        files = [f for f in files if \
                     "plaintext" not in f.lower() \
                     or "_base32" in f.lower() \
                     or "_b32" in f.lower()]
    if exclude_plaintext_base32:
        files = [f for f in files if\
                    "plaintext" not in f.lower() or \
                    ("base32" not in f.lower() and "b32" not in f.lower())]
    if exclude_encrypted_v1:
        files = [f for f in files if\
                    "_v1" not in f.lower() or "encr" not in f.lower()]
    if exclude_encrypted_v2:
        files = [f for f in files if \
                    "_v3" not in f.lower() or "encr" not in f.lower()]
    if exclude_encrypted_base32:
        files = [ f for f in files if\
                    "encr" not in f or\
                    ("base32" not in f.lower() and "b32" not in f.lower())]
    if exclude_encrypted_nonbase32:
        files = [f for f in files if \
                    "encr" not in f.lower() or \
                    "base32" in f.lower() or "b32" in f.lower()]
        
        
    encrypted_count = len([f for f in files if "encr" in f.lower()])
    non_encrypted_count = len([f for f in files if "encr" not in f.lower()])
    
    if 0 == encrypted_count or 0 == non_encrypted_count or 0 == len(files):
        return description, None, -1, -1
    
    all_dfs = list()
    all_loaded_datasets = load_datasets_once()
    for filename in files:
        all_dfs.append(all_loaded_datasets[filename])
    
    combined_df = pd.concat(all_dfs)
    
    if exclude_webp:
        combined_df = combined_df[\
                        combined_df["extended.extension"] != ".webp"]
    if exclude_nonwebp:
        combined_df = combined_df[\
                        combined_df["extended.extension"] == ".webp"]
        
    if len(combined_df) == 0:
        return description, None, -1, -1
    
        
    encrypt_count = len(combined_df[combined_df["is_encrypted"] == 1])
    nonencrypted_count = len(combined_df[combined_df["is_encrypted"] == 0])

    
    if 0 == len(combined_df) or 0 == encrypt_count or 0 == nonencrypted_count:
        return description, None, -1, -1
    
    return description, combined_df, encrypt_count, nonencrypted_count

# %% [markdown]
# ### Run all combinations of data <a class="anchor" id="dataset-selection">
#
# For all combinations of the datasets, compare the three classes (basic, advanced, and Fourier)
#
# [top](#Contents)

# %%
all_results = []
list_of_arguments = []

# Get all 8-tuple combinations of T/F
list_of_arguments = [(True,), (False,)]
for i in range(7):
    temp = []
    for e in list_of_arguments:
        et = e + (True,)
        temp.append(et)
        et = e + (False,)
        temp.append(et)
    list_of_arguments = temp

     
for a, b, c, k, e, f, g, h in tqdm.tqdm(list_of_arguments):
    desc, df, ec, nec = get_dataset(a, b, c, k, e, f, g, h)
    if df is not None:
        result = compare_feature_selections_wrapper(df)
        call_gc()
        result = {**desc, **result}
        result["n_encrypted"] = ec
        result["n_non_encrypted"] = nec
        result["ratio_encrypt_nonencrypt"] = float(ec) / nec
        all_results.append(result)


df_dict = {k:[] for k in all_results[0]}
for result in all_results:
    for k, v in result.items():
        df_dict[k].append(v)

df = pd.DataFrame(df_dict)
df["best_f1_score"] = \
    df[[c for c in df.columns if "f1_score" in c]].max(axis=1)

df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["improvement_in_fourier"] = \
    df["fourier-f1_score"] - df["baseline-f1_score"]
df = df.sort_values(by="improvement_in_fourier", ascending=False)
# Out:
# 100%|█████████████████████████████████████████████████| 256/256 [9:08:48<00:00, 128.63s/it]

# %% [markdown]
# ## Results <a class="anchor" id="results">
#
# In this section, we present the results
#
# [top](#Contents)

# %% [markdown]
# ### Print the raw results <a class="anchor" id="raw-results">
#
# [top](#Contents)

# %%
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 39                        False                     False
# 41                        False                     False
# 10                        False                      True
# 0                         False                      True
# 27                        False                     False
# 35                        False                     False
# 37                        False                     False
# 30                        False                     False
# 2                         False                      True
# 29                        False                     False
# 33                        False                     False
# 42                        False                     False
# 43                        False                     False
# 6                         False                      True
# 8                         False                      True
# 44                        False                     False
# 34                        False                     False
# 18                        False                      True
# 45                        False                     False
# 40                        False                     False
# 28                        False                     False
# 1                         False                      True
# 31                        False                     False
# 24                        False                      True
# 16                        False                      True
# 32                        False                     False
# 51                        False                     False
# 9                         False                      True
# 36                        False                     False
# 20                        False                      True
# 47                        False                     False
# 26                        False                      True
# 48                        False                     False
# 19                        False                      True
# 7                         False                      True
# 46                        False                     False
# 25                        False                      True
# 15                        False                      True
# 11                        False                      True
# 53                        False                     False
# 38                        False                     False
# 50                        False                     False
# 52                        False                     False
# 49                        False                     False
# 17                        False                      True
# 3                         False                      True
# 5                         False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 22                        False                      True
# 13                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 39                 False                  True                     False
# 41                 False                  True                     False
# 10                 False                  True                      True
# 0                   True                 False                      True
# 27                  True                 False                      True
# 35                  True                 False                     False
# 37                 False                  True                      True
# 30                  True                 False                     False
# 2                   True                 False                      True
# 29                  True                 False                      True
# 33                  True                 False                     False
# 42                 False                  True                     False
# 43                 False                  True                     False
# 6                   True                 False                     False
# 8                   True                 False                     False
# 44                 False                  True                     False
# 34                  True                 False                     False
# 18                 False                 False                      True
# 45                 False                 False                      True
# 40                 False                  True                     False
# 28                  True                 False                      True
# 1                   True                 False                      True
# 31                  True                 False                     False
# 24                 False                 False                     False
# 16                 False                  True                     False
# 32                  True                 False                     False
# 51                 False                 False                     False
# 9                  False                  True                      True
# 36                 False                  True                      True
# 20                 False                 False                      True
# 47                 False                 False                      True
# 26                 False                 False                     False
# 48                 False                 False                     False
# 19                 False                 False                      True
# 7                   True                 False                     False
# 46                 False                 False                      True
# 25                 False                 False                     False
# 15                 False                  True                     False
# 11                 False                  True                      True
# 53                 False                 False                     False
# 38                 False                  True                      True
# 50                 False                 False                     False
# 52                 False                 False                     False
# 49                 False                 False                     False
# 17                 False                  True                     False
# 3                   True                 False                     False
# 5                   True                 False                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 22                 False                 False                     False
# 13                 False                  True                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 39                         True          True            False
# 41                         True         False            False
# 10                        False         False             True
# 0                         False          True            False
# 27                        False          True            False
# 35                        False         False            False
# 37                        False         False             True
# 30                         True          True            False
# 2                         False         False            False
# 29                        False         False            False
# 33                        False          True            False
# 42                        False          True            False
# 43                        False         False             True
# 6                         False          True            False
# 8                         False         False            False
# 44                        False         False            False
# 34                        False         False             True
# 18                        False          True            False
# 45                        False          True            False
# 40                         True         False             True
# 28                        False         False             True
# 1                         False         False             True
# 31                         True         False             True
# 24                        False          True            False
# 16                        False         False             True
# 32                         True         False            False
# 51                        False          True            False
# 9                         False          True            False
# 36                        False          True            False
# 20                        False         False            False
# 47                        False         False            False
# 26                        False         False            False
# 48                         True          True            False
# 19                        False         False             True
# 7                         False         False             True
# 46                        False         False             True
# 25                        False         False             True
# 15                        False          True            False
# 11                        False         False            False
# 53                        False         False            False
# 38                        False         False            False
# 50                         True         False            False
# 52                        False         False             True
# 49                         True         False             True
# 17                        False         False            False
# 3                          True          True            False
# 5                          True         False            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 14                         True         False            False
# 22                         True         False             True
# 47       161706           323412                      0.50       0.816527
# 26       323412           161706                      2.00       0.900382
# 48        98456           196912                      0.50       0.782109
# 19        63250            63250                      1.00       0.678226
# 7         63250            63250                      1.00       0.745170
# 46        63250           126500                      0.50       0.670728
# 25       126500            63250                      2.00       0.830164
# 15        98456            98456                      1.00       0.990237
# 11        80853           161706                      0.50       0.758255
# 53       323412           323412                      1.00       0.736269
# 38        80853           323412                      0.25       0.758114
# 50       161706           323412                      0.50       0.701180
# 52       126500           126500                      1.00       0.644389
# 49        63250           126500                      0.50       0.628754
# 17       161706           161706                      1.00       0.872195
# 3         49228            98456                      0.50       0.998752
# 5         80853           161706                      0.50       0.999178
# 21        98456            98456                      1.00       0.999320
# 23       161706           161706                      1.00       0.999549
# 12        49228            98456                      0.50       0.999838
# 14        80853           161706                      0.50       0.999864
# 22        63250            63250                      1.00       1.000000
# 13        31625            63250                      0.50       1.000000
# 4         31625            63250                      0.50       1.000000
#
#     improvement_in_advanced  improvement_in_fourier
# 39                 0.894038                0.917292
# 41                 0.704594                0.754015
# 10                 0.444636                0.468062
# 0                  0.142598                0.442304
# 27                 0.142220                0.441688
# 35                 0.267929                0.427003
# 37                 0.393671                0.409326
# 30                 0.389506                0.404830
# 2                  0.164017                0.401220
# 29                 0.163772                0.401023
# 33                 0.179223                0.382955
# 42                 0.336049                0.331211
# 43                 0.294621                0.313366
# 6                  0.134056                0.267270
# 8                  0.131996                0.217052
# 44                 0.209553                0.215462
# 34                 0.141768                0.189451
# 18                 0.051481                0.175361
# 45                 0.050329                0.174123
# 40                -0.025179                0.169402
# 28                 0.102784                0.143397
# 1                  0.096788                0.136997
# 31                 0.100029                0.136132
# 24                 0.073503                0.135441
# 16                 0.113070                0.115257
# 32                 0.129120                0.108966
# 51                 0.049293                0.105267
# 9                  0.063527                0.092592
# 36                 0.063398                0.092414
# 20                 0.001762                0.088217
# 47                 0.001268                0.087796
# 26                 0.039952                0.081486
# 48                 0.087761                0.079910
# 19                 0.064103                0.066226
# 7                  0.048857                0.056975
# 46                 0.057616                0.054662
# 25                 0.053817                0.053156
# 15                 0.033100                0.048629
# 11                 0.020317                0.046764
# 53                 0.009800                0.046462
# 38                 0.020129                0.046408
# 50                 0.043309                0.036188
# 52                 0.037207                0.031451
# 49                 0.023767                0.030188
# 17                 0.014736                0.028557
# 3                  0.018928                0.020779
# 5                  0.011787                0.012996
# 21                 0.009873                0.010821
# 23                 0.006141                0.006756
# 12                 0.001934                0.002239
# 14                 0.001179                0.001482
# 22                 0.000000                0.000000
# 13                 0.000000                0.000000
# 4                  0.000000                0.000000
#
# [54 rows x 42 columns]

# %%
df.to_csv("../comparison.csv")

# %%
df = df.sort_values(by="improvement_in_fourier", ascending=False)

# %% [markdown]
# ### Sort by the improvement when using Fourier transforms over baseline <a class="anchor" id="sorted-fourier">
#
# We also take a few other things:
# * Room for improvement (1 - baseline score)
# * How much of the room for improvement was filled by fourier transforms (percentage)
# * Difference between F1 score with advanced and fourier
#
# [top](#Contents)

# %%
df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["room_for_improvement"] = \
    1.0 - df["baseline-f1_score"]
df["fourier_minus_advanced"] = \
    df["fourier-f1_score"] - df["advanced-f1_score"]
df["percentage_of_room_filled"] = \
    df["improvement_in_fourier"] * 100.0 / df["room_for_improvement"]
#df.sort_values(by="fourier_minus_advanced", ascending=False)
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 39                        False                     False
# 41                        False                     False
# 10                        False                      True
# 0                         False                      True
# 27                        False                     False
# 35                        False                     False
# 37                        False                     False
# 30                        False                     False
# 2                         False                      True
# 29                        False                     False
# 33                        False                     False
# 42                        False                     False
# 43                        False                     False
# 6                         False                      True
# 8                         False                      True
# 44                        False                     False
# 34                        False                     False
# 18                        False                      True
# 45                        False                     False
# 40                        False                     False
# 28                        False                     False
# 1                         False                      True
# 31                        False                     False
# 24                        False                      True
# 16                        False                      True
# 32                        False                     False
# 51                        False                     False
# 9                         False                      True
# 36                        False                     False
# 20                        False                      True
# 47                        False                     False
# 26                        False                      True
# 48                        False                     False
# 19                        False                      True
# 7                         False                      True
# 46                        False                     False
# 25                        False                      True
# 15                        False                      True
# 11                        False                      True
# 53                        False                     False
# 38                        False                     False
# 50                        False                     False
# 52                        False                     False
# 49                        False                     False
# 17                        False                      True
# 3                         False                      True
# 5                         False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 22                        False                      True
# 13                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 39                 False                  True                     False
# 41                 False                  True                     False
# 10                 False                  True                      True
# 0                   True                 False                      True
# 27                  True                 False                      True
# 35                  True                 False                     False
# 37                 False                  True                      True
# 30                  True                 False                     False
# 2                   True                 False                      True
# 29                  True                 False                      True
# 33                  True                 False                     False
# 42                 False                  True                     False
# 43                 False                  True                     False
# 6                   True                 False                     False
# 8                   True                 False                     False
# 44                 False                  True                     False
# 34                  True                 False                     False
# 18                 False                 False                      True
# 45                 False                 False                      True
# 40                 False                  True                     False
# 28                  True                 False                      True
# 1                   True                 False                      True
# 31                  True                 False                     False
# 24                 False                 False                     False
# 16                 False                  True                     False
# 32                  True                 False                     False
# 51                 False                 False                     False
# 9                  False                  True                      True
# 36                 False                  True                      True
# 20                 False                 False                      True
# 47                 False                 False                      True
# 26                 False                 False                     False
# 48                 False                 False                     False
# 19                 False                 False                      True
# 7                   True                 False                     False
# 46                 False                 False                      True
# 25                 False                 False                     False
# 15                 False                  True                     False
# 11                 False                  True                      True
# 53                 False                 False                     False
# 38                 False                  True                      True
# 50                 False                 False                     False
# 52                 False                 False                     False
# 49                 False                 False                     False
# 17                 False                  True                     False
# 3                   True                 False                     False
# 5                   True                 False                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 22                 False                 False                     False
# 13                 False                  True                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 39                         True          True            False
# 41                         True         False            False
# 10                        False         False             True
# 0                         False          True            False
# 27                        False          True            False
# 35                        False         False            False
# 37                        False         False             True
# 30                         True          True            False
# 2                         False         False            False
# 29                        False         False            False
# 33                        False          True            False
# 42                        False          True            False
# 43                        False         False             True
# 6                         False          True            False
# 8                         False         False            False
# 44                        False         False            False
# 34                        False         False             True
# 18                        False          True            False
# 45                        False          True            False
# 40                         True         False             True
# 28                        False         False             True
# 1                         False         False             True
# 31                         True         False             True
# 24                        False          True            False
# 16                        False         False             True
# 32                         True         False            False
# 51                        False          True            False
# 9                         False          True            False
# 36                        False          True            False
# 20                        False         False            False
# 47                        False         False            False
# 26                        False         False            False
# 48                         True          True            False
# 19                        False         False             True
# 7                         False         False             True
# 46                        False         False             True
# 25                        False         False             True
# 15                        False          True            False
# 11                        False         False            False
# 53                        False         False            False
# 38                        False         False            False
# 50                         True         False            False
# 52                        False         False             True
# 49                         True         False             True
# 17                        False         False            False
# 3                          True          True            False
# 5                          True         False            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 14                         True         False            False
# 22                         True         False             True
# 13                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 39           0.005335                 0.772747  ...              0.982591
# 41           0.006139                 0.782113  ...              0.878731
# 10           0.160940                 0.677101  ...              0.520000
# 0            0.467677                 0.669267  ...              0.925266
# 27           0.468208                 0.801784  ...              0.925408
# 35           0.000000                 0.666667  ...              0.294170
# 37           0.151492                 0.806476  ...              0.437628
# 30           0.000155                 0.790920  ...              0.336658
# 2            0.298425                 0.664078  ...              0.594288
# 29           0.298728                 0.798466  ...              0.594387
# 33           0.268828                 0.636494  ...              0.595393
# 42           0.589317                 0.761992  ...              0.949165
# 43           0.068422                 0.668511  ...              0.260506
# 6            0.683838                 0.682386  ...              0.958469
# 8            0.638348                 0.715178  ...              0.798783
# 44           0.498821                 0.705983  ...              0.767547
# 34           0.056454                 0.670224  ...              0.149486
# 18           0.776098                 0.741930  ...              0.968351
# 45           0.777201                 0.828709  ...              0.968504
# 40           0.027578                 0.800202  ...              0.116332
# 28           0.215178                 0.813622  ...              0.238261
# 1            0.224638                 0.688559  ...              0.240474
# 31           0.000189                 0.799020  ...              0.076711
# 24           0.838619                 0.775890  ...              0.982358
# 16           0.693719                 0.757636  ...              0.722688
# 32           0.000047                 0.790694  ...              0.060047
# 51           0.738081                 0.700747  ...              0.844022
# 9            0.888060                 0.916829  ...              0.990940
# 36           0.888110                 0.950126  ...              0.990493
# 20           0.728306                 0.654506  ...              0.911469
# 47           0.728731                 0.770091  ...              0.911481
# 26           0.818896                 0.734124  ...              0.952114
# 48           0.694349                 0.751175  ...              0.778480
# 19           0.612000                 0.522158  ...              0.706261
# 7            0.688195                 0.754103  ...              0.620711
# 46           0.613112                 0.680480  ...              0.698593
# 25           0.776346                 0.678092  ...              0.848000
# 15           0.941609                 0.938145  ...              0.995694
# 11           0.711491                 0.772497  ...              0.839598
# 53           0.686759                 0.619484  ...              0.791668
# 19                0.002124                  17.068616
# 7                 0.008118                  18.272658
# 46               -0.002954                  14.128737
# 25               -0.000662                  23.766988
# 15                0.015529                  83.280506
# 11                0.026447                  16.208841
# 53                0.036662                  14.832703
# 38                0.026279                  16.097521
# 50               -0.007121                  10.447440
# 52               -0.005756                   8.006535
# 49                0.006421                   7.519958
# 17                0.013821                  18.263314
# 3                 0.001851                  94.333629
# 5                 0.001209                  94.051563
# 21                0.000948                  94.086300
# 23                0.000614                  93.738519
# 12                0.000304                  90.183010
# 14                0.000303                  90.895529
# 22                0.000000                        NaN
# 13                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [54 rows x 45 columns]

# %% [markdown]
# ### Measure improvement when only webp files are used <a class="anchor" id="webp-only">
#
# We want to measure this alone because in the literature, poor performance in webp files has been mentioned
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == False) & \
   (df["exclude_nonwebp"] == True)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 10                        False                      True
# 37                        False                     False
# 43                        False                     False
# 34                        False                     False
# 40                        False                     False
# 28                        False                     False
# 1                         False                      True
# 31                        False                     False
# 16                        False                      True
# 19                        False                      True
# 7                         False                      True
# 46                        False                     False
# 25                        False                      True
# 52                        False                     False
# 49                        False                     False
# 22                        False                      True
# 13                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 10                 False                  True                      True
# 37                 False                  True                      True
# 43                 False                  True                     False
# 34                  True                 False                     False
# 40                 False                  True                     False
# 28                  True                 False                      True
# 1                   True                 False                      True
# 31                  True                 False                     False
# 16                 False                  True                     False
# 19                 False                 False                      True
# 7                   True                 False                     False
# 46                 False                 False                      True
# 25                 False                 False                     False
# 52                 False                 False                     False
# 49                 False                 False                     False
# 22                 False                 False                     False
# 13                 False                  True                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 10                        False         False             True
# 37                        False         False             True
# 43                        False         False             True
# 34                        False         False             True
# 40                         True         False             True
# 28                        False         False             True
# 1                         False         False             True
# 31                         True         False             True
# 16                        False         False             True
# 19                        False         False             True
# 7                         False         False             True
# 46                        False         False             True
# 25                        False         False             True
# 52                        False         False             True
# 49                         True         False             True
# 22                         True         False             True
# 13                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 10           0.160940                 0.677101  ...              0.520000
# 37           0.151492                 0.806476  ...              0.437628
# 43           0.068422                 0.668511  ...              0.260506
# 34           0.056454                 0.670224  ...              0.149486
# 40           0.027578                 0.800202  ...              0.116332
# 28           0.215178                 0.813622  ...              0.238261
# 1            0.224638                 0.688559  ...              0.240474
# 31           0.000189                 0.799020  ...              0.076711
# 16           0.693719                 0.757636  ...              0.722688
# 19           0.612000                 0.522158  ...              0.706261
# 7            0.688195                 0.754103  ...              0.620711
# 46           0.613112                 0.680480  ...              0.698593
# 25           0.776346                 0.678092  ...              0.848000
# 52           0.607183                 0.523506  ...              0.698316
# 49           0.598566                 0.688221  ...              0.713897
# 22           1.000000                 1.000000  ...              1.000000
# 13           1.000000                 1.000000  ...              1.000000
# 4            1.000000                 1.000000  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 10        31625            63250                      0.50       0.629002
# 37        31625           126500                      0.25       0.560817
# 43        63250           126500                      0.50       0.381788
# 34        63250           126500                      0.50       0.245905
# 40        31625           126500                      0.25       0.196980
# 28        31625           126500                      0.25       0.358575
# 1         31625            63250                      0.50       0.361635
# 31        31625           126500                      0.25       0.136321
# 16        63250            63250                      1.00       0.808976
# 19        63250            63250                      1.00       0.678226
# 7         63250            63250                      1.00       0.745170
# 46        63250           126500                      0.50       0.670728
# 25       126500            63250                      2.00       0.830164
# 52       126500           126500                      1.00       0.644389
# 49        63250           126500                      0.50       0.628754
# 22        63250            63250                      1.00       1.000000
# 13        31625            63250                      0.50       1.000000
# 4         31625            63250                      0.50       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 10                 0.444636                0.468062              0.839060
# 37                 0.393671                0.409326              0.848508
# 43                 0.294621                0.313366              0.931578
# 34                 0.141768                0.189451              0.943546
# 40                -0.025179                0.169402              0.972422
# 28                 0.102784                0.143397              0.784822
# 1                  0.096788                0.136997              0.775362
# 31                 0.100029                0.136132              0.999811
# 16                 0.113070                0.115257              0.306281
# 19                 0.064103                0.066226              0.388000
# 7                  0.048857                0.056975              0.311805
# 46                 0.057616                0.054662              0.386888
# 25                 0.053817                0.053156              0.223654
# 52                 0.037207                0.031451              0.392817
# 49                 0.023767                0.030188              0.401434
# 22                 0.000000                0.000000              0.000000
# 13                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 10                0.023426                  55.784135
# 37                0.015655                  48.240626
# 43                0.018745                  33.638191
# 34                0.047683                  20.078590
# 40                0.194581                  17.420606
# 28                0.040613                  18.271301
# 1                 0.040209                  17.668761
# 31                0.036103                  13.615819
# 16                0.002187                  37.631048
# 19                0.002124                  17.068616
# 7                 0.008118                  18.272658
# 46               -0.002954                  14.128737
# 25               -0.000662                  23.766988
# 52               -0.005756                   8.006535
# 49                0.006421                   7.519958
# 22                0.000000                        NaN
# 13                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [18 rows x 45 columns]

# %% [markdown]
# ### Measure improvement when webp files are not present <a class="anchor" id="no-webp">
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == True) & \
   (df["exclude_nonwebp"] == False)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 39                        False                     False
# 0                         False                      True
# 27                        False                     False
# 30                        False                     False
# 33                        False                     False
# 42                        False                     False
# 6                         False                      True
# 18                        False                      True
# 45                        False                     False
# 24                        False                      True
# 51                        False                     False
# 9                         False                      True
# 36                        False                     False
# 48                        False                     False
# 15                        False                      True
# 3                         False                      True
# 21                        False                      True
# 12                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 39                 False                  True                     False
# 0                   True                 False                      True
# 27                  True                 False                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 42                 False                  True                     False
# 6                   True                 False                     False
# 18                 False                 False                      True
# 45                 False                 False                      True
# 24                 False                 False                     False
# 51                 False                 False                     False
# 9                  False                  True                      True
# 36                 False                  True                      True
# 48                 False                 False                     False
# 15                 False                  True                     False
# 3                   True                 False                     False
# 21                 False                 False                     False
# 12                 False                  True                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 39                         True          True            False
# 0                         False          True            False
# 27                        False          True            False
# 30                         True          True            False
# 33                        False          True            False
# 42                        False          True            False
# 6                         False          True            False
# 18                        False          True            False
# 45                        False          True            False
# 24                        False          True            False
# 51                        False          True            False
# 9                         False          True            False
# 36                        False          True            False
# 48                         True          True            False
# 15                        False          True            False
# 3                          True          True            False
# 21                         True          True            False
# 12                         True          True            False
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 39           0.005335                 0.772747  ...              0.982591
# 0            0.467677                 0.669267  ...              0.925266
# 27           0.468208                 0.801784  ...              0.925408
# 30           0.000155                 0.790920  ...              0.336658
# 33           0.268828                 0.636494  ...              0.595393
# 42           0.589317                 0.761992  ...              0.949165
# 6            0.683838                 0.682386  ...              0.958469
# 18           0.776098                 0.741930  ...              0.968351
# 45           0.777201                 0.828709  ...              0.968504
# 24           0.838619                 0.775890  ...              0.982358
# 51           0.738081                 0.700747  ...              0.844022
# 9            0.888060                 0.916829  ...              0.990940
# 36           0.888110                 0.950126  ...              0.990493
# 48           0.694349                 0.751175  ...              0.778480
# 15           0.941609                 0.938145  ...              0.995694
# 3            0.977973                 0.985171  ...              0.999655
# 21           0.988499                 0.988442  ...              0.999837
# 12           0.997518                 0.998341  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 39        49228           196912                      0.25       0.922627
# 0         49228            98456                      0.50       0.909981
# 27        49228           196912                      0.25       0.909896
# 30        49228           196912                      0.25       0.404985
# 33        98456           196912                      0.50       0.651783
# 42        98456           196912                      0.50       0.925366
# 6         98456            98456                      1.00       0.951108
# 18        98456            98456                      1.00       0.951459
# 45        98456           196912                      0.50       0.951324
# 24       196912            98456                      2.00       0.974060
# 51       196912           196912                      1.00       0.843348
# 9         49228            98456                      0.50       0.980652
# 36        49228           196912                      0.25       0.980524
# 48        98456           196912                      0.50       0.782109
# 15        98456            98456                      1.00       0.990237
# 3         49228            98456                      0.50       0.998752
# 21        98456            98456                      1.00       0.999320
# 12        49228            98456                      0.50       0.999838
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 39                 0.894038                0.917292              0.994665
# 0                  0.142598                0.442304              0.532323
# 27                 0.142220                0.441688              0.531792
# 30                 0.389506                0.404830              0.999845
# 33                 0.179223                0.382955              0.731172
# 42                 0.336049                0.331211              0.410683
# 6                  0.134056                0.267270              0.316162
# 18                 0.051481                0.175361              0.223902
# 45                 0.050329                0.174123              0.222799
# 24                 0.073503                0.135441              0.161381
# 51                 0.049293                0.105267              0.261919
# 9                  0.063527                0.092592              0.111940
# 36                 0.063398                0.092414              0.111890
# 48                 0.087761                0.079910              0.305651
# 15                 0.033100                0.048629              0.058391
# 3                  0.018928                0.020779              0.022027
# 21                 0.009873                0.010821              0.011501
# 12                 0.001934                0.002239              0.002482
#
#     fourier_minus_advanced  percentage_of_room_filled
# 39                0.023254                  92.221247
# 0                 0.299706                  83.089415
# 27                0.299468                  83.056535
# 30                0.015324                  40.489246
# 33                0.203732                  52.375489
# 42               -0.004838                  80.648789
# 6                 0.133214                  84.535732
# 18                0.123880                  78.320592
# 45                0.123794                  78.152447
# 24                0.061938                  83.926040
# 51                0.055974                  40.190534
# 9                 0.029065                  82.715873
# 36                0.029016                  82.593872
# 48               -0.007851                  26.144026
# 15                0.015529                  83.280506
# 3                 0.001851                  94.333629
# 21                0.000948                  94.086300
# 12                0.000304                  90.183010
#
# [18 rows x 45 columns]

# %% [markdown]
# ### Measure improvement for balanced datasets <a class="anchor" id="balanced-dataset">
#
# Most of our dataset selections are not balanced, and we didn't do anything to mitigate
# unablanced datasets. This is because we are measuring the baseline and improvement on the
# same dataset.
#
# However, we will select those instances where the datasets were balanced to see if the
# improvement is still significant in these instances.
#
# [top](#Contents)

# %%
df[df["ratio_encrypt_nonencrypt"] == 1.0]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 6                         False                      True
# 8                         False                      True
# 18                        False                      True
# 16                        False                      True
# 51                        False                     False
# 20                        False                      True
# 19                        False                      True
# 7                         False                      True
# 15                        False                      True
# 53                        False                     False
# 52                        False                     False
# 17                        False                      True
# 21                        False                      True
# 23                        False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 6                   True                 False                     False
# 8                   True                 False                     False
# 18                 False                 False                      True
# 16                 False                  True                     False
# 51                 False                 False                     False
# 20                 False                 False                      True
# 19                 False                 False                      True
# 7                   True                 False                     False
# 15                 False                  True                     False
# 53                 False                 False                     False
# 52                 False                 False                     False
# 17                 False                  True                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 6                         False          True            False
# 8                         False         False            False
# 18                        False          True            False
# 16                        False         False             True
# 51                        False          True            False
# 20                        False         False            False
# 19                        False         False             True
# 7                         False         False             True
# 15                        False          True            False
# 53                        False         False            False
# 52                        False         False             True
# 17                        False         False            False
# 21                         True          True            False
# 23                         True         False            False
# 22                         True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 6            0.683838                 0.682386  ...              0.958469
# 8            0.638348                 0.715178  ...              0.798783
# 18           0.776098                 0.741930  ...              0.968351
# 16           0.693719                 0.757636  ...              0.722688
# 51           0.738081                 0.700747  ...              0.844022
# 20           0.728306                 0.654506  ...              0.911469
# 19           0.612000                 0.522158  ...              0.706261
# 7            0.688195                 0.754103  ...              0.620711
# 15           0.941609                 0.938145  ...              0.995694
# 53           0.686759                 0.619484  ...              0.791668
# 52           0.607183                 0.523506  ...              0.698316
# 17           0.843638                 0.829131  ...              0.918710
# 21           0.988499                 0.988442  ...              0.999837
# 23           0.992793                 0.992771  ...              0.999901
# 22           1.000000                 1.000000  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 6         98456            98456                       1.0       0.951108
# 8        161706           161706                       1.0       0.855400
# 18        98456            98456                       1.0       0.951459
# 16        63250            63250                       1.0       0.808976
# 51       196912           196912                       1.0       0.843348
# 20       161706           161706                       1.0       0.816522
# 19        63250            63250                       1.0       0.678226
# 7         63250            63250                       1.0       0.745170
# 15        98456            98456                       1.0       0.990237
# 53       323412           323412                       1.0       0.736269
# 52       126500           126500                       1.0       0.644389
# 17       161706           161706                       1.0       0.872195
# 21        98456            98456                       1.0       0.999320
# 23       161706           161706                       1.0       0.999549
# 22        63250            63250                       1.0       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 6                  0.134056                0.267270              0.316162
# 8                  0.131996                0.217052              0.361652
# 18                 0.051481                0.175361              0.223902
# 16                 0.113070                0.115257              0.306281
# 51                 0.049293                0.105267              0.261919
# 20                 0.001762                0.088217              0.271694
# 19                 0.064103                0.066226              0.388000
# 7                  0.048857                0.056975              0.311805
# 15                 0.033100                0.048629              0.058391
# 53                 0.009800                0.046462              0.313241
# 52                 0.037207                0.031451              0.392817
# 17                 0.014736                0.028557              0.156362
# 21                 0.009873                0.010821              0.011501
# 23                 0.006141                0.006756              0.007207
# 22                 0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 6                 0.133214                  84.535732
# 8                 0.085056                  60.016756
# 18                0.123880                  78.320592
# 16                0.002187                  37.631048
# 51                0.055974                  40.190534
# 20                0.086455                  32.469144
# 19                0.002124                  17.068616
# 7                 0.008118                  18.272658
# 15                0.015529                  83.280506
# 53                0.036662                  14.832703
# 52               -0.005756                   8.006535
# 17                0.013821                  18.263314
# 21                0.000948                  94.086300
# 23                0.000614                  93.738519
# 22                0.000000                        NaN
#
# [15 rows x 45 columns]

# %% [markdown]
# ### Measure the improvement when all files are used <a class="anchor" id="full-dataset">
#
# In most of our dataset selections, we excluded some data points based on our criteria.
#
# In this, we measure the improvement when we use all data points
#
# [top](#Contents)

# %%
# Measure everything for the full dataset
df2 = df
for colname in df2.columns:
    if "exclude" in colname:
        df2 = df2[df2[colname] == False]
df2
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 53                        False                     False
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 53                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 53                        False         False            False
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 53           0.686759                 0.619484  ...              0.791668
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 53       323412           323412                       1.0       0.736269
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 53                   0.0098                0.046462              0.313241
#
#     fourier_minus_advanced  percentage_of_room_filled
# 53                0.036662                  14.832703
#
# [1 rows x 45 columns]

# %%
df2[[c for c in df2.columns if "baseline" in c or "fourier" in c or "advanced-only" in c]]
# Out:
#     baseline-f1_score  baseline-accuracy_score  baseline-precision_score  \
# 53           0.686759                 0.619484                  0.583583
#
#     baseline-recall_score  advanced-only-f1_score  \
# 53               0.834261                0.697021
#
#     advanced-only-accuracy_score  advanced-only-precision_score  \
# 53                      0.681474                       0.664584
#
#     advanced-only-recall_score  fourier-only-f1_score  \
# 53                    0.732787               0.719788
#
#     fourier-only-accuracy_score  ...  advanced-and-fourier-f1_score  \
# 53                     0.676165  ...                       0.732505
#
#     advanced-and-fourier-accuracy_score  advanced-and-fourier-precision_score  \
# 53                             0.711084                              0.681942
#
#     advanced-and-fourier-recall_score  fourier-f1_score  \
# 53                            0.79117          0.733221
#
#     fourier-accuracy_score  fourier-precision_score  fourier-recall_score  \
# 53                0.711957                 0.682814              0.791668
#
#     improvement_in_fourier  fourier_minus_advanced
# 53                0.046462                0.036662
#
# [1 rows x 26 columns]

# %%
df.to_csv("../comparison_logistic_regression_final.csv")

# %% [markdown]
# ### Focus on items where the base metrics performed well <a class="anchor" id="focus-greater-90">
#
# We see that in all cases, plaintext non-base 32 only is selected. Also we
# see that for encrypted, only base32 is selected and non-base32 excluded.
#
# Fundamentally, what this is measuring is when the plaintext has all files
# but all encrypted content is base-32 encoded.
#
# Typically, base-32 encoding will lead to a reduction of entropy, in many cases
# much less than the original text, and this is what it is measuring.
#
# [top](#Contents)

# %%
df[df["baseline-f1_score"] > 0.9]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 15                        False                      True
# 3                         False                      True
# 5                         False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 22                        False                      True
# 13                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 15                 False                  True                     False
# 3                   True                 False                     False
# 5                   True                 False                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 22                 False                 False                     False
# 13                 False                  True                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 15                        False          True            False
# 3                          True          True            False
# 5                          True         False            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 14                         True         False            False
# 22                         True         False             True
# 13                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 15           0.941609                 0.938145  ...              0.995694
# 3            0.977973                 0.985171  ...              0.999655
# 5            0.986182                 0.990732  ...              0.999790
# 21           0.988499                 0.988442  ...              0.999837
# 23           0.992793                 0.992771  ...              0.999901
# 12           0.997518                 0.998341  ...              1.000000
# 14           0.998370                 0.998912  ...              1.000000
# 22           1.000000                 1.000000  ...              1.000000
# 13           1.000000                 1.000000  ...              1.000000
# 4            1.000000                 1.000000  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 15        98456            98456                       1.0       0.990237
# 3         49228            98456                       0.5       0.998752
# 5         80853           161706                       0.5       0.999178
# 21        98456            98456                       1.0       0.999320
# 23       161706           161706                       1.0       0.999549
# 12        49228            98456                       0.5       0.999838
# 14        80853           161706                       0.5       0.999864
# 22        63250            63250                       1.0       1.000000
# 13        31625            63250                       0.5       1.000000
# 4         31625            63250                       0.5       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 15                 0.033100                0.048629              0.058391
# 3                  0.018928                0.020779              0.022027
# 5                  0.011787                0.012996              0.013818
# 21                 0.009873                0.010821              0.011501
# 23                 0.006141                0.006756              0.007207
# 12                 0.001934                0.002239              0.002482
# 14                 0.001179                0.001482              0.001630
# 22                 0.000000                0.000000              0.000000
# 13                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 15                0.015529                  83.280506
# 3                 0.001851                  94.333629
# 5                 0.001209                  94.051563
# 21                0.000948                  94.086300
# 23                0.000614                  93.738519
# 12                0.000304                  90.183010
# 14                0.000303                  90.895529
# 22                0.000000                        NaN
# 13                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [10 rows x 45 columns]

# %% [markdown]
# ### Correlation of data set and performance <a class="anchor" id="corr-heatmap">
#
# This gives more idea on how data-set selection affects performance.
#
# [top](#Contents)

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,10)
df2 = df[[c for c in df.columns if \
          "precision" not in c and \
          "accuracy" not in c and \
          "recall" not in c]]
sns.heatmap(df2.astype(float).corr(), cmap='coolwarm')
# print(df[df["baseline-f1_score"] > 0.9].astype(float))
_ = plt.xticks(rotation=80)

# %%
df1 = df[["exclude_encrypted_base32", \
          "exclude_encrypted_v2", \
          "exclude_webp", \
          "baseline-f1_score", \
          "advanced-f1_score", \
          "fourier-f1_score"]]
sns.heatmap(df1.astype(float).corr(), cmap='coolwarm')
_ = plt.xticks(rotation=80)

# %% [markdown]
# ### Average out all the metrics <a class="anchor" id="mean-fscores">
#
# To conclude we report the average of the f1-scores and the improvements with all datasets
#
# [top](#Contents)

# %%
df[[c for c in df.columns if ("score" in c or "improvement" in c) and "room" not in c]].mean()
# Out:
# baseline-f1_score                       0.575639
# baseline-accuracy_score                 0.782983
# baseline-precision_score                0.632262
# baseline-recall_score                   0.599188
# advanced-only-f1_score                  0.690579
# advanced-only-accuracy_score            0.835497
# advanced-only-precision_score           0.782579
# advanced-only-recall_score              0.673004
# fourier-only-f1_score                   0.621892
# fourier-only-accuracy_score             0.820463
# fourier-only-precision_score            0.646605
# fourier-only-recall_score               0.632000
# baseline-and-fourier-f1_score           0.674746
# baseline-and-fourier-accuracy_score     0.833900
# baseline-and-fourier-precision_score    0.754836
# baseline-and-fourier-recall_score       0.680397
# advanced-and-fourier-f1_score           0.744864
# advanced-and-fourier-accuracy_score     0.861494
# advanced-and-fourier-precision_score    0.813171
# advanced-and-fourier-recall_score       0.735811
# advanced-f1_score                       0.698041
# advanced-accuracy_score                 0.837670
# advanced-precision_score                0.793993
# advanced-recall_score                   0.682270
# fourier-f1_score                        0.751695
# fourier-accuracy_score                  0.864373
# fourier-precision_score                 0.816463
# fourier-recall_score                    0.743320
# best_f1_score                           0.752745
# improvement_in_advanced                 0.122402
# improvement_in_fourier                  0.176056
# dtype: float64

# %%
df[[c for c in df.columns if \
    ("-and-" in c or \
     "only" in c or \
     "score" in c or \
     "improvement" in c) and "room" not in c]].describe().T
# Out:
#                                       count      mean       std       min  \
# baseline-f1_score                      54.0  0.575639  0.339119  0.000000
# baseline-accuracy_score                54.0  0.782983  0.126251  0.522158
# baseline-precision_score               54.0  0.632262  0.279379  0.000000
# baseline-recall_score                  54.0  0.599188  0.380425  0.000000
# advanced-only-f1_score                 54.0  0.690579  0.266414  0.000000
# advanced-only-accuracy_score           54.0  0.835497  0.107087  0.608273
# advanced-only-precision_score          54.0  0.782579  0.171257  0.000000
# advanced-only-recall_score             54.0  0.673004  0.305336  0.000000
# fourier-only-f1_score                  54.0  0.621892  0.356533  0.000000
# fourier-only-accuracy_score            54.0  0.820463  0.124953  0.516917
# fourier-only-precision_score           54.0  0.646605  0.336231  0.000000
# fourier-only-recall_score              54.0  0.632000  0.372310  0.000000
# baseline-and-fourier-f1_score          54.0  0.674746  0.308606  0.000000
# baseline-and-fourier-accuracy_score    54.0  0.833900  0.121204  0.528379
# baseline-and-fourier-precision_score   54.0  0.754836  0.205405  0.000000
# baseline-and-fourier-recall_score      54.0  0.680397  0.342053  0.000000
# advanced-and-fourier-f1_score          54.0  0.744864  0.249963  0.103562
# advanced-and-fourier-accuracy_score    54.0  0.861494  0.106610  0.602043
# advanced-and-fourier-precision_score   54.0  0.813171  0.144349  0.505359
# advanced-and-fourier-recall_score      54.0  0.735811  0.290258  0.056906
# advanced-f1_score                      54.0  0.698041  0.261979  0.002398
# advanced-accuracy_score                54.0  0.837670  0.106499  0.608486
# advanced-precision_score               54.0  0.793993  0.135656  0.559350
# advanced-recall_score                  54.0  0.682270  0.299820  0.001202
# fourier-f1_score                       54.0  0.751695  0.245833  0.109013
# fourier-accuracy_score                 54.0  0.864373  0.105926  0.604870
# fourier-precision_score                54.0  0.816463  0.143314  0.508177
# fourier-recall_score                   54.0  0.743320  0.286220  0.060047
# best_f1_score                          54.0  0.752745  0.244815  0.129168
# improvement_in_advanced                54.0  0.122402  0.173653 -0.025179
# improvement_in_fourier                 54.0  0.176056  0.194835  0.000000
#
#                                            25%       50%       75%       max
# baseline-f1_score                     0.276227  0.685299  0.833688  1.000000
# baseline-accuracy_score               0.683845  0.771294  0.829026  1.000000
# baseline-precision_score              0.517447  0.616334  0.806211  1.000000
# baseline-recall_score                 0.203941  0.756640  0.925080  1.000000
# advanced-only-f1_score                0.566492  0.726663  0.909296  1.000000
# advanced-only-accuracy_score          0.767000  0.813672  0.932328  1.000000
# advanced-only-precision_score         0.676130  0.778574  0.917053  1.000000
# advanced-only-recall_score            0.458803  0.774977  0.945154  1.000000
# fourier-only-f1_score                 0.512209  0.709880  0.929504  1.000000
# fourier-only-accuracy_score           0.731728  0.800006  0.927526  1.000000
# fourier-only-precision_score          0.522890  0.704402  0.926897  1.000000
# fourier-only-recall_score             0.436974  0.760993  0.955945  1.000000
# baseline-and-fourier-f1_score         0.586842  0.737987  0.933484  1.000000
# baseline-and-fourier-accuracy_score   0.757088  0.817380  0.950603  1.000000
# baseline-and-fourier-precision_score  0.628403  0.753196  0.935348  1.000000
# baseline-and-fourier-recall_score     0.520835  0.808877  0.962757  1.000000
# advanced-and-fourier-f1_score         0.651786  0.802092  0.947350  1.000000
# advanced-and-fourier-accuracy_score   0.787341  0.855609  0.963955  1.000000
# advanced-and-fourier-precision_score  0.685884  0.829139  0.936737  1.000000
# advanced-and-fourier-recall_score     0.598385  0.830601  0.976589  1.000000
# advanced-f1_score                     0.606751  0.731821  0.908934  1.000000
# advanced-accuracy_score               0.773544  0.819725  0.932402  1.000000
# advanced-precision_score              0.675475  0.771211  0.912428  1.000000
# advanced-recall_score                 0.510068  0.775151  0.944650  1.000000
# fourier-f1_score                      0.655781  0.812749  0.951426  1.000000
# fourier-accuracy_score                0.795220  0.861228  0.966502  1.000000
# fourier-precision_score               0.691710  0.836421  0.941683  1.000000
# fourier-recall_score                  0.601723  0.841810  0.978894  1.000000
# best_f1_score                         0.656519  0.812749  0.951426  1.000000
# improvement_in_advanced               0.019228  0.060507  0.142107  0.894038
# improvement_in_fourier                0.046422  0.098929  0.254715  0.917292

# %%
df1 = df[[c for c in df.columns if \
          ("score" in c or "improvement" in c) \
          and "room" not in c]]
columns = ["baseline-f1_score"]
columns += [c for c in df1.columns if "only" in c]
columns += [c for c in df1.columns if "-and-" in c]
columns += [c for c in df1.columns if "only" not in c \
            and "-and-" not in c and "baseline-f1_score" != c]
df1[columns].describe().T
# Out:
#                                       count      mean       std       min  \
# baseline-f1_score                      54.0  0.575639  0.339119  0.000000
# advanced-only-f1_score                 54.0  0.690579  0.266414  0.000000
# advanced-only-accuracy_score           54.0  0.835497  0.107087  0.608273
# advanced-only-precision_score          54.0  0.782579  0.171257  0.000000
# advanced-only-recall_score             54.0  0.673004  0.305336  0.000000
# fourier-only-f1_score                  54.0  0.621892  0.356533  0.000000
# fourier-only-accuracy_score            54.0  0.820463  0.124953  0.516917
# fourier-only-precision_score           54.0  0.646605  0.336231  0.000000
# fourier-only-recall_score              54.0  0.632000  0.372310  0.000000
# baseline-and-fourier-f1_score          54.0  0.674746  0.308606  0.000000
# baseline-and-fourier-accuracy_score    54.0  0.833900  0.121204  0.528379
# baseline-and-fourier-precision_score   54.0  0.754836  0.205405  0.000000
# baseline-and-fourier-recall_score      54.0  0.680397  0.342053  0.000000
# advanced-and-fourier-f1_score          54.0  0.744864  0.249963  0.103562
