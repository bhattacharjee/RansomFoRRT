# %% [markdown]
# Few key observations
# - If both and non-encrypted files are base-32 encoded, accuracy drops really low.
#    * Even in this case, fourier analysis (specifically autocorrelation and mean) provide good discrminators
#    * Renyi's entropy at alpha=infinity gives good discrimination
#    * Overall we see around 13% improvement in F1-score
# - Specifically for webpfiles
#    * We see that higher moments of around 14 gives a good discrimination
#    * Fourier analysis still gives benefits here
# - For webpfiles where both unencrypted and encrypted content are base32 encrypted
#    * Fourier analysis is still beneficial
# - For Non-webp files where plaintext is not base-32 encrypted
#    * Accuracy is decent with just the base parameters, but with fourier analysis, we can close to perfect detection

# %% [markdown]
# # Contents
# - ## [Implementation](#mplementation)
#  - ### [List of Files](#list-of-files)
#  - ### [Utility to call gc](#gc)
#  - ### [Selection of Columns](#select-columns)
#  - ### [Function to compare the three selections of columns for a given dataset](#compare-fn)
#  - ### [Load the datasets](#load-dataset)
#  - ### [Select the datasets](#dataset-selection)
#  - ### [Run all combinations of data](#dataset-selection)
# - ## [Results](#results)
#  - ### [Print the raw results](#raw-results)
#  - ### [Sort by the improvement when using Fourier transforms over baseline](#sorted-fourier)
#  - ### [Measure improvement when only webp files are used](#webp-only)
#  - ### [Measure improvement when webp files are not present](#no-webp)
#  - ### [Measure improvement for balanced datasets](#balanced-dataset)
#  - ### [Measure the improvement when all files are used](#full-dataset)
#  - ### [Focus on items where the base metrics performed well](#focus-greater-90)
#  - ### [Correlation of data set and performance]("corr-heatmap")
#  - ### [Average out all the metrics](#mean-fscores)

# %% [markdown]
# ## Implementation <a class="anchor" id="implementation">
#
# [top](#Contents)

# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats

from functools import lru_cache

import gc

import sklearn
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score, accuracy_score

import matplotlib.pyplot as plt
import glob

import tqdm

plt.rcParams["figure.figsize"] = (20,20)

# %% [markdown]
# ### List of files <a class="anchor" id="list-of-files">
#
# [top](#Contents)

# %%
# !ls
# Out:
# Untitled.ipynb
# expanded.plaintext.base32.csv.gz
# expanded.pyencrypted_v1.b32.csv.gz
# expanded.pyencrypted_v1.csv.gz
# expanded.pyencrypted_v2.base32.csv.gz
# expanded.pyencrypted_v2.csv.gz
# iteration_2.1_compare_base32_alternate_encryption_scheme.ipynb
# iteration_2.1_compare_base32_logistic_regression.ipynb
# plaintext.base32.combined.csv.gz
# plaintext.combined.csv.gz
# plaintext.expanded.csv.gz
# test_iteration_2.1_LR_compare_base32_logistic_regression.ipynb

# %% [markdown]
# ### Utility to call GC <a class="anchor" id="gc">
#
# [top](#Contents)

# %%
def call_gc():
    for i in range(3):
        for j in range(3):
            gc.collect(j)

# %% [markdown]
# ### Selection of columns <a class="anchor" id="select-columns">
#
# This function is used to select the columns.
# There are three different configurations:
#
#     1. Baseline - statistics like autocorrelation, shannon entropy, chi-square etc. are used
#
#     2. Advanced - More statistics like moments, Tsallis and Renyi entropy, higher moments etc.
#
#     3. Fourier - Some statistics of the Fourier Power Spectrum distribution
#
# [top](#Contents)

# %%
def get_columns(thisdf):
    baseline_columns = [c for c in thisdf.columns if c.startswith('baseline') and "head" not in c and "tail" not in c]
    baseline_columns = [c for c in baseline_columns if "filesize" not in c]
    baseline_columns = [c for c in baseline_columns if "begin" not in c and "end" not in c]

    advanced_columns = [c for c in thisdf.columns if "advanced" in c]
    advanced_columns = [c for c in advanced_columns if "begin" not in c and "end" not in c]
    advanced_columns = [c for c in advanced_columns if "head" not in c and "tail" not in c]
    advanced_columns = [c for c in advanced_columns if "start" not in c]
    advanced_columns_only = list(set(advanced_columns))
    advanced_columns = list(set(advanced_columns + baseline_columns))

    fourier_columns = [c for c in thisdf.columns if "fourier" in c and "value" not in c]
    fourier_columns = [c for c in fourier_columns if "1byte" in c]
    fourier_columns = [c for c in fourier_columns if "begin" not in c and "end" not in c]
    fourier_columns = [c for c in fourier_columns if "head" not in c and "tail" not in c]
    fourier_columns = [c for c in fourier_columns if "start" not in c]
    fourier_columns_only = list(set(fourier_columns))
    fourier_columns = list(set(advanced_columns + fourier_columns))
    
    baseline_and_advanced = list(set(baseline_columns + advanced_columns_only))
    baseline_and_fourier = list(set(baseline_columns + fourier_columns_only))
    advanced_and_fourier = list(set(advanced_columns_only + fourier_columns_only))
    
    return {\
        "baseline": baseline_columns,\
        "advanced-only": advanced_columns_only,\
        "fourier-only": fourier_columns_only,\
        "baseline-and-advanced": baseline_and_advanced,\
        "baseline-and-fourier": baseline_and_fourier,\
        "advanced-and-fourier": advanced_and_fourier,\
        "advanced": advanced_columns,\
        "fourier": fourier_columns,\
    }

# %% [markdown]
# ### Function to compare the three selections of columns for a given dataset <a class="anchor" id="compare-fn">
#
# For the three different sets of measurements described above, compare all the three sets for their f1 score
#
# [top](#Contents)

# %%
def compare_feature_selections(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    columns_dict = get_columns(X)
    ret = dict()
    for name, collist in columns_dict.items():
        XX_train, XX_test = X_train[collist], X_test[collist]
        #rfc = RandomForestClassifier(n_jobs=10, random_state=42)
        lr = LogisticRegression(n_jobs=10, random_state=42, max_iter=1000, solver="saga", multi_class="ovr")
        estimators = [('std,', MinMaxScaler()), ('LogisticRegression', lr)]
        pipeline = Pipeline(estimators)
        pipeline.fit(XX_train, y_train)
        y_pred = pipeline.predict(XX_test)
        f1 = f1_score(y_test, y_pred)
        ret[f"{name}-f1_score"] = f1
    return ret

def compare_feature_selections_wrapper(data):
    X = data[[c for c in data.columns if "is_encrypted" != c]]
    y = data["is_encrypted"]
    return compare_feature_selections(X, y)

# %% [markdown]
# ### Load the datasets <a class="anchor" id="load-dataset">
#
# We don't want to load the datasets again and again, so we load them once.
# The LRU cache ensures that the next time this is called, we don't load the datasets again.
#
# [top](#Contents)

# %%
@lru_cache
def load_datasets_once():
    """Load all datasets only once
    
    We want to load the datasets only once. Once loaded
    serve from cache
    """
    datasets = dict()
    for file in glob.glob("*.csv.gz"):
        df = pd.read_csv(file)
        df = df.sample(frac=1).reset_index(drop=True)
        df["is_encrypted"] = 1 if "encr" in file.lower() else 0
        datasets[file] = df
    return datasets

# %% [markdown]
# ### Select the datasets <a class="anchor" id="dataset-selection">
#
# Select the dataset, combine it, shuffle it and return
#
# We used several schemes:
# * Plaintext
#   - The base plaintext dataset of around 50k files
#   - Expanded dataset, where all files that were less than 1500 bytes were expanded by repeating the file
#   - Base32 encoding of
#    - original plaintext
#    - expanded plaintext
# * Encryption : We used two schemes for encruption
#   - v1 : AES 256 encryption of the full file, again two varieties were used
#     - Plain encryption
#     - Encryption followed by base32 encoding
#   - v2 : AES encryption of the file, the first and the last 128 bytes are not encrypted. Of the remaining file, every alternate 16 bytes are encrypted.
#     - Plain encryption
#     - encryption followed by base32 encoding
#
# We select combinations of the above datasets
#
# Furthermore, we add further combinations by including and excluding webp files, and including and excluding non-webp files.
#
# [top](#Contents)

# %%
def get_dataset(\
               exclude_plaintext_nonbase32=False,
               exclude_plaintext_base32=False,
               exclude_encrypted_v1=False,
               exclude_encrypted_v2=False,
               exclude_encrypted_base32=False,
               exclude_encrypted_nonbase32=False,
               exclude_webp=False,
               exclude_nonwebp=False):
    description = {k:v for k,v in locals().items() if "exclude" in k}
    files = glob.glob("*.csv.gz")
    
    
    if exclude_plaintext_nonbase32:
        files = [f for f in files if \
                     "plaintext" not in f \
                     or "_base32" in f \
                     or "_b32" in f]
    if exclude_plaintext_base32:
        files = [f for f in files if\
                    "plaintext" not in f or \
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_v1:
        files = [f for f in files if\
                    "_v1" not in f or "encr" not in f]
    if exclude_encrypted_v2:
        files = [f for f in files if \
                    "_v2" not in f or "encr" not in f]
    if exclude_encrypted_base32:
        files = [ f for f in files if\
                    "encr" not in f or\
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_nonbase32:
        files = [f for f in files if \
                    "encr" not in f or \
                    "base32" in f or "b32" in f]
        
        
    encrypted_count = len([f for f in files if "encr" in f])
    non_encrypted_count = len([f for f in files if "encr" not in f])
    
    if 0 == encrypted_count or 0 == non_encrypted_count or 0 == len(files):
        return description, None, -1, -1
    
    all_dfs = list()
    all_loaded_datasets = load_datasets_once()
    for filename in files:
        all_dfs.append(all_loaded_datasets[filename])
    
    combined_df = pd.concat(all_dfs)
    
    if exclude_webp:
        combined_df = combined_df[combined_df["extended.extension"] != ".webp"]
    if exclude_nonwebp:
        combined_df = combined_df[combined_df["extended.extension"] == ".webp"]
        
    if len(combined_df) == 0:
        return description, None, -1, -1
    
        
    encrypt_count = len(combined_df[combined_df["is_encrypted"] == 1])
    nonencrypted_count = len(combined_df[combined_df["is_encrypted"] == 0])

    
    if 0 == len(combined_df) or 0 == encrypt_count or 0 == nonencrypted_count:
        return description, None, -1, -1
    
    return description, combined_df, encrypt_count, nonencrypted_count

# %% [markdown]
# ### Run all combinations of data <a class="anchor" id="dataset-selection">
#
# For all combinations of the datasets, compare the three classes (basic, advanced, and Fourier)
#
# [top](#Contents)

# %%
all_results = []
list_of_arguments = []
count = 2
for a in [True, False]:
    for b in [True, False]:
        for c in [True, False]:
            for k in [True, False]:
                for e in [True, False]:
                    for f in [True, False]:
                        for g in [True, False]:
                            for h in [True, False]:
                                arguments = (a, b, c, k, e, f, g, h,)
                                list_of_arguments.append(arguments)
                                list_of_arguments = [(True,), (False,)]
"""
# Get all 8-tuple combinations of T/F
list_of_arguments = [(True,), (False,)]
for i in range(7):
    temp = []
    for e in list_of_arguments:
        et = tuple(list(e) + [True])
        temp.append(et)
        et = tuple(list(e) + [False])
        temp.append(et)
    list_of_arguments = temp
"""
                                
for a, b, c, k, e, f, g, h in tqdm.tqdm(list_of_arguments):
    desc, df, ec, nec = get_dataset(a, b, c, k, e, f, g, h)
    if df is not None:
        result = compare_feature_selections_wrapper(df)
        call_gc()
        result = {**desc, **result}
        result["n_encrypted"] = ec
        result["n_non_encrypted"] = nec
        result["ratio_encrypt_nonencrypt"] = float(ec) / nec
        all_results.append(result)


df_dict = {k:[] for k in all_results[0]}
for result in all_results:
    for k, v in result.items():
        df_dict[k].append(v)

df = pd.DataFrame(df_dict)
df["best_f1_score"] = df[[c for c in df.columns if "f1_score" in c]].max(axis=1)

df["improvement_in_advanced"] = df["advanced-f1_score"] - df["baseline-f1_score"]
df["improvement_in_fourier"] = df["fourier-f1_score"] - df["baseline-f1_score"]
df = df.sort_values(by="improvement_in_fourier", ascending=False)
# Out:
# 100%|██████████████████████████████████████████████████| 256/256 [2:08:49<00:00, 30.19s/it]

# %% [markdown]
# ## Results <a class="anchor" id="results">
#
# In this section, we present the results
#
# [top](#Contents)

# %% [markdown]
# ### Print the raw results <a class="anchor" id="raw-results">
#
# [top](#Contents)

# %%
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 39                        False                     False
# 41                        False                     False
# 35                        False                     False
# 10                        False                      True
# 0                         False                      True
# 27                        False                     False
# 2                         False                      True
# 29                        False                     False
# 37                        False                     False
# 30                        False                     False
# 33                        False                     False
# 42                        False                     False
# 43                        False                     False
# 31                        False                     False
# 34                        False                     False
# 6                         False                      True
# 8                         False                      True
# 44                        False                     False
# 18                        False                      True
# 45                        False                     False
# 1                         False                      True
# 28                        False                     False
# 40                        False                     False
# 46                        False                     False
# 19                        False                      True
# 24                        False                      True
# 32                        False                     False
# 52                        False                     False
# 16                        False                      True
# 49                        False                     False
# 51                        False                     False
# 36                        False                     False
# 9                         False                      True
# 20                        False                      True
# 47                        False                     False
# 25                        False                      True
# 26                        False                      True
# 48                        False                     False
# 7                         False                      True
# 15                        False                      True
# 53                        False                     False
# 11                        False                      True
# 38                        False                     False
# 50                        False                     False
# 17                        False                      True
# 3                         False                      True
# 5                         False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 13                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 39                 False                  True                     False
# 41                 False                  True                     False
# 35                  True                 False                     False
# 10                 False                  True                      True
# 0                   True                 False                      True
# 27                  True                 False                      True
# 2                   True                 False                      True
# 29                  True                 False                      True
# 37                 False                  True                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 42                 False                  True                     False
# 43                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 6                   True                 False                     False
# 8                   True                 False                     False
# 44                 False                  True                     False
# 18                 False                 False                      True
# 45                 False                 False                      True
# 1                   True                 False                      True
# 28                  True                 False                      True
# 40                 False                  True                     False
# 46                 False                 False                      True
# 19                 False                 False                      True
# 24                 False                 False                     False
# 32                  True                 False                     False
# 52                 False                 False                     False
# 16                 False                  True                     False
# 49                 False                 False                     False
# 51                 False                 False                     False
# 36                 False                  True                      True
# 9                  False                  True                      True
# 20                 False                 False                      True
# 47                 False                 False                      True
# 25                 False                 False                     False
# 26                 False                 False                     False
# 48                 False                 False                     False
# 7                   True                 False                     False
# 15                 False                  True                     False
# 53                 False                 False                     False
# 11                 False                  True                      True
# 38                 False                  True                      True
# 50                 False                 False                     False
# 17                 False                  True                     False
# 3                   True                 False                     False
# 5                   True                 False                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 13                 False                  True                     False
# 22                 False                 False                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 39                         True          True            False
# 41                         True         False            False
# 35                        False         False            False
# 10                        False         False             True
# 0                         False          True            False
# 27                        False          True            False
# 2                         False         False            False
# 29                        False         False            False
# 37                        False         False             True
# 30                         True          True            False
# 33                        False          True            False
# 42                        False          True            False
# 43                        False         False             True
# 31                         True         False             True
# 34                        False         False             True
# 6                         False          True            False
# 8                         False         False            False
# 44                        False         False            False
# 18                        False          True            False
# 45                        False          True            False
# 1                         False         False             True
# 28                        False         False             True
# 40                         True         False             True
# 46                        False         False             True
# 19                        False         False             True
# 24                        False          True            False
# 32                         True         False            False
# 52                        False         False             True
# 16                        False         False             True
# 49                         True         False             True
# 51                        False          True            False
# 36                        False          True            False
# 9                         False          True            False
# 20                        False         False            False
# 47                        False         False            False
# 25                        False         False             True
# 26                        False         False            False
# 48                         True          True            False
# 7                         False         False             True
# 15                        False          True            False
# 53                        False         False            False
# 11                        False         False            False
# 38                        False         False            False
# 50                         True         False            False
# 17                        False         False            False
# 3                          True          True            False
# 5                          True         False            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 14                         True         False            False
# 13                         True         False             True
# 22                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  advanced-only-f1_score  ...  \
# 39           0.005285                0.897905  ...
# 41           0.006413                0.706439  ...
# 35           0.000000                0.269433  ...
# 10           0.164864                0.549458  ...
# 0            0.465004                0.613573  ...
# 27           0.465277                0.617747  ...
# 2            0.315318                0.476309  ...
# 29           0.317875                0.476212  ...
# 37           0.154430                0.459265  ...
# 30           0.000469                0.355645  ...
# 33           0.265802                0.411502  ...
# 42           0.587848                0.925292  ...
# 43           0.066698                0.294571  ...
# 31           0.039745                0.253637  ...
# 34           0.158018                0.335978  ...
# 6            0.681152                0.815023  ...
# 8            0.638865                0.767833  ...
# 44           0.497529                0.695781  ...
# 18           0.774557                0.826109  ...
# 45           0.775338                0.827055  ...
# 1            0.379174                0.462946  ...
# 28           0.369892                0.450812  ...
# 40           0.025431                0.000000  ...
# 46           0.519709                0.658517  ...
# 19           0.535119                0.669349  ...
# 24           0.837547                0.911319  ...
# 32           0.000284                0.130026  ...
# 52           0.504072                0.632109  ...
# 16           0.689377                0.781671  ...
# 49           0.484722                0.599329  ...
# 51           0.735262                0.782728  ...
# 36           0.885750                0.945169  ...
# 9            0.886445                0.946207  ...
# 20           0.726278                0.716026  ...
# 47           0.727923                0.716911  ...
# 25           0.747222                0.829351  ...
# 26           0.816274                0.849068  ...
# 48           0.695105                0.780030  ...
# 7            0.731911                0.777321  ...
# 15           0.942116                0.972668  ...
# 53           0.682645                0.685332  ...
# 11           0.711538                0.713517  ...
# 38           0.713646                0.715311  ...
# 50           0.645706                0.688567  ...
# 17           0.842971                0.846379  ...
# 3            0.978312                0.996389  ...
# 5            0.986665                0.996886  ...
# 21           0.988923                0.997609  ...
# 23           0.992964                0.998655  ...
# 12           0.997624                0.997423  ...
# 14           0.998315                0.998583  ...
# 13           1.000000                1.000000  ...
# 22           1.000000                1.000000  ...
# 4            1.000000                1.000000  ...
#
#     baseline-and-fourier-f1_score  advanced-and-fourier-f1_score  \
# 39                       0.692893                       0.920643
# 41                       0.380721                       0.751522
# 35                       0.333684                       0.470350
# 10                       0.266720                       0.594873
# 0                        0.863291                       0.892451
# 27                       0.857862                       0.893411
# 2                        0.607756                       0.711173
# 29                       0.608724                       0.711947
# 37                       0.226955                       0.504364
# 30                       0.106065                       0.397884
# 33                       0.622596                       0.642852
# 42                       0.814824                       0.919677
# 43                       0.107992                       0.335859
# 31                       0.099166                       0.329205
# 34                       0.259906                       0.426005
# 6                        0.932037                       0.945949
# 8                        0.803121                       0.860743
# 44                       0.616563                       0.702624
# 18                       0.931659                       0.946790
# 45                       0.927794                       0.945256
# 1                        0.403724                       0.547708
# 28                       0.407509                       0.530801
# 40                       0.025196                       0.167323
# 46                       0.572225                       0.656357
# 19                       0.586546                       0.673244
# 24                       0.963562                       0.971156
# 32                       0.000000                       0.119250
# 52                       0.593992                       0.622034
# 16                       0.704068                       0.788791
# 49                       0.601696                       0.585992
# 51                       0.821493                       0.838021
# 36                       0.965028                       0.979058
# 9                        0.960591                       0.979641
# 20                       0.785533                       0.805650
# 47                       0.786232                       0.806155
# 25                       0.789886                       0.827193
# 26                       0.884393                       0.896663
# 48                       0.741178                       0.771961
# 7                        0.761883                       0.799566
# 15                       0.980623                       0.990008
# 53                       0.734651                       0.726982
# 11                       0.695480                       0.741291
# 38                       0.699586                       0.743097
# 50                       0.670043                       0.673699
# 17                       0.839007                       0.861710
# 3                        0.996345                       0.998046
# 5                        0.997574                       0.998489
# 21                       0.998069                       0.998832
# 23                       0.998852                       0.999531
# 12                       0.999758                       0.999435
# 14                       0.999804                       0.999633
# 13                       1.000000                       1.000000
# 22                       1.000000                       1.000000
# 4                        1.000000                       1.000000
#
#     advanced-f1_score  fourier-f1_score  n_encrypted  n_non_encrypted  \
# 39           0.897677          0.921970        49228           196912
# 41           0.709644          0.757748        80853           323412
# 35           0.282906          0.479211       161706           323412
# 10           0.605160          0.625204        31625            63250
# 0            0.603955          0.904845        49228            98456
# 27           0.609179          0.903290        49228           196912
# 2            0.494802          0.727965        80853           161706
# 29           0.494598          0.729037        80853           323412
# 37           0.544360          0.565256        31625           126500
# 30           0.377727          0.401481        49228           196912
# 33           0.430994          0.647929        98456           196912
# 42           0.925999          0.920261        98456           196912
# 43           0.360384          0.373793        63250           126500
# 31           0.257557          0.335972        31625           126500
# 34           0.348694          0.436661        63250           126500
# 6            0.814477          0.950372        98456            98456
# 8            0.774628          0.866630       161706           161706
# 44           0.704858          0.710491       161706           323412
# 18           0.823374          0.950748        98456            98456
# 45           0.824618          0.949058        98456           196912
# 1            0.479993          0.551115        31625            63250
# 28           0.471486          0.539105        31625           126500
# 40           0.001502          0.194486        31625           126500
# 46           0.664038          0.660138        63250           126500
# 19           0.673061          0.674397        63250            63250
# 24           0.910027          0.972632       196912            98456
# 32           0.134367          0.125655        80853           323412
# 52           0.635520          0.625221       126500           126500
# 16           0.807184          0.806112        63250            63250
# 49           0.602253          0.591671        63250           126500
# 51           0.783902          0.839199       196912           196912
# 36           0.950264          0.980063        49228           196912
# 9            0.949892          0.980640        49228            98456
# 20           0.723825          0.810717       161706           161706
# 47           0.723630          0.811490       161706           323412
# 25           0.833606          0.830144       126500            63250
# 26           0.853370          0.898034       323412           161706
# 48           0.780768          0.773910        98456           196912
# 7            0.781388          0.802003        63250            63250
# 15           0.975385          0.990567        98456            98456
# 53           0.686783          0.728358       323412           323412
# 11           0.730320          0.755586        80853           161706
# 38           0.732295          0.757120        80853           323412
# 50           0.684432          0.674617       161706           323412
# 17           0.856545          0.869962       161706           161706
# 3            0.996955          0.999024        49228            98456
# 5            0.997897          0.999133        80853           161706
# 21           0.998491          0.999275        98456            98456
# 23           0.998951          0.999617       161706           161706
# 12           0.999395          0.999677        49228            98456
# 14           0.999658          0.999853        80853           161706
# 13           1.000000          1.000000        31625            63250
# 22           1.000000          1.000000        63250            63250
# 4            1.000000          1.000000        31625            63250
#
#     ratio_encrypt_nonencrypt  best_f1_score  improvement_in_advanced  \
# 39                      0.25       0.921970                 0.892392
# 41                      0.25       0.757748                 0.703231
# 35                      0.50       0.479211                 0.282906
# 10                      0.50       0.625204                 0.440296
# 0                       0.50       0.904845                 0.138951
# 27                      0.25       0.903290                 0.143902
# 2                       0.50       0.727965                 0.179484
# 29                      0.25       0.729037                 0.176723
# 37                      0.25       0.565256                 0.389930
# 30                      0.25       0.401481                 0.377258
# 33                      0.50       0.647929                 0.165192
# 42                      0.50       0.925999                 0.338151
# 43                      0.50       0.373793                 0.293685
# 31                      0.25       0.335972                 0.217812
# 34                      0.50       0.436661                 0.190676
# 6                       1.00       0.950372                 0.133324
# 8                       1.00       0.866630                 0.135762
# 44                      0.50       0.710491                 0.207329
# 18                      1.00       0.950748                 0.048817
# 45                      0.50       0.949058                 0.049280
# 1                       0.50       0.551115                 0.100818
# 28                      0.25       0.539105                 0.101594
# 40                      0.25       0.194486                -0.023929
# 46                      0.50       0.664038                 0.144328
# 19                      1.00       0.674397                 0.137942
# 24                      2.00       0.972632                 0.072481
# 32                      0.25       0.134367                 0.134083
# 52                      1.00       0.635520                 0.131447
# 16                      1.00       0.807184                 0.117807
# 49                      0.50       0.602253                 0.117531
# 51                      1.00       0.839199                 0.048640
# 36                      0.25       0.980063                 0.064514
# 9                       0.50       0.980640                 0.063447
# 20                      1.00       0.810717                -0.002453
# 47                      0.50       0.811490                -0.004293
# 25                      2.00       0.833606                 0.086385
# 26                      2.00       0.898034                 0.037096
# 48                      0.50       0.780768                 0.085663
# 7                       1.00       0.802003                 0.049476
# 15                      1.00       0.990567                 0.033268
# 53                      1.00       0.734651                 0.004138
# 11                      0.50       0.755586                 0.018781
# 38                      0.25       0.757120                 0.018649
# 50                      0.50       0.688567                 0.038727
# 17                      1.00       0.869962                 0.013574
# 3                       0.50       0.999024                 0.018644
# 5                       0.50       0.999133                 0.011232
# 21                      1.00       0.999275                 0.009569
# 23                      1.00       0.999617                 0.005987
# 12                      0.50       0.999758                 0.001771
# 14                      0.50       0.999853                 0.001343
# 13                      0.50       1.000000                 0.000000
# 22                      1.00       1.000000                 0.000000
# 4                       0.50       1.000000                 0.000000
#
#     improvement_in_fourier
# 39                0.916685
# 41                0.751335
# 35                0.479211
# 10                0.460339
# 0                 0.439841
# 27                0.438013
# 2                 0.412648
# 29                0.411162
# 37                0.410827
# 30                0.401012
# 33                0.382127
# 42                0.332413
# 43                0.307095
# 31                0.296227
# 34                0.278643
# 6                 0.269220
# 8                 0.227765
# 44                0.212962
# 18                0.176191
# 45                0.173721
# 1                 0.171940
# 28                0.169213
# 40                0.169055
# 46                0.140429
# 19                0.139278
# 24                0.135085
# 32                0.125371
# 52                0.121148
# 16                0.116734
# 49                0.106950
# 51                0.103936
# 36                0.094313
# 9                 0.094195
# 20                0.084439
# 47                0.083566
# 25                0.082922
# 26                0.081761
# 48                0.078805
# 7                 0.070092
# 15                0.048451
# 53                0.045713
# 11                0.044048
# 38                0.043474
# 50                0.028911
# 17                0.026991
# 3                 0.020712
# 5                 0.012468
# 21                0.010353
# 23                0.006653
# 12                0.002053
# 14                0.001539
# 13                0.000000
# 22                0.000000
# 4                 0.000000
#
# [54 rows x 22 columns]

# %%
df.to_csv("../comparison.csv")

# %%
df = df.sort_values(by="improvement_in_fourier", ascending=False)

# %% [markdown]
# ### Sort by the improvement when using Fourier transforms over baseline <a class="anchor" id="sorted-fourier">
#
# We also take a few other things:
# * Room for improvement (1 - baseline score)
# * How much of the room for improvement was filled by fourier transforms (percentage)
# * Difference between F1 score with advanced and fourier
#
# [top](#Contents)

# %%
df["improvement_in_advanced"] = df["advanced-f1_score"] - df["baseline-f1_score"]
df["room_for_improvement"] = 1.0 - df["baseline-f1_score"]
df["fourier_minus_advanced"] = df["fourier-f1_score"] - df["advanced-f1_score"]
df["percentage_of_room_filled"] = df["improvement_in_fourier"] * 100.0 / df["room_for_improvement"]
#df.sort_values(by="fourier_minus_advanced", ascending=False)
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 39                        False                     False
# 41                        False                     False
# 35                        False                     False
# 10                        False                      True
# 0                         False                      True
# 27                        False                     False
# 2                         False                      True
# 29                        False                     False
# 37                        False                     False
# 30                        False                     False
# 33                        False                     False
# 42                        False                     False
# 43                        False                     False
# 31                        False                     False
# 34                        False                     False
# 6                         False                      True
# 8                         False                      True
# 44                        False                     False
# 18                        False                      True
# 45                        False                     False
# 1                         False                      True
# 28                        False                     False
# 40                        False                     False
# 46                        False                     False
# 19                        False                      True
# 24                        False                      True
# 32                        False                     False
# 52                        False                     False
# 16                        False                      True
# 49                        False                     False
# 51                        False                     False
# 36                        False                     False
# 9                         False                      True
# 20                        False                      True
# 47                        False                     False
# 25                        False                      True
# 26                        False                      True
# 48                        False                     False
# 7                         False                      True
# 15                        False                      True
# 53                        False                     False
# 11                        False                      True
# 38                        False                     False
# 50                        False                     False
# 17                        False                      True
# 3                         False                      True
# 5                         False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 13                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 39                 False                  True                     False
# 41                 False                  True                     False
# 35                  True                 False                     False
# 10                 False                  True                      True
# 0                   True                 False                      True
# 27                  True                 False                      True
# 2                   True                 False                      True
# 29                  True                 False                      True
# 37                 False                  True                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 42                 False                  True                     False
# 43                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 6                   True                 False                     False
# 8                   True                 False                     False
# 44                 False                  True                     False
# 18                 False                 False                      True
# 45                 False                 False                      True
# 1                   True                 False                      True
# 28                  True                 False                      True
# 40                 False                  True                     False
# 46                 False                 False                      True
# 19                 False                 False                      True
# 24                 False                 False                     False
# 32                  True                 False                     False
# 52                 False                 False                     False
# 16                 False                  True                     False
# 49                 False                 False                     False
# 51                 False                 False                     False
# 36                 False                  True                      True
# 9                  False                  True                      True
# 20                 False                 False                      True
# 47                 False                 False                      True
# 25                 False                 False                     False
# 26                 False                 False                     False
# 48                 False                 False                     False
# 7                   True                 False                     False
# 15                 False                  True                     False
# 53                 False                 False                     False
# 11                 False                  True                      True
# 38                 False                  True                      True
# 50                 False                 False                     False
# 17                 False                  True                     False
# 3                   True                 False                     False
# 5                   True                 False                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 13                 False                  True                     False
# 22                 False                 False                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 39                         True          True            False
# 41                         True         False            False
# 35                        False         False            False
# 10                        False         False             True
# 0                         False          True            False
# 27                        False          True            False
# 2                         False         False            False
# 29                        False         False            False
# 37                        False         False             True
# 30                         True          True            False
# 33                        False          True            False
# 42                        False          True            False
# 43                        False         False             True
# 31                         True         False             True
# 34                        False         False             True
# 6                         False          True            False
# 8                         False         False            False
# 44                        False         False            False
# 18                        False          True            False
# 45                        False          True            False
# 1                         False         False             True
# 28                        False         False             True
# 40                         True         False             True
# 46                        False         False             True
# 19                        False         False             True
# 24                        False          True            False
# 32                         True         False            False
# 52                        False         False             True
# 16                        False         False             True
# 49                         True         False             True
# 51                        False          True            False
# 36                        False          True            False
# 9                         False          True            False
# 20                        False         False            False
# 47                        False         False            False
# 25                        False         False             True
# 26                        False         False            False
# 48                         True          True            False
# 7                         False         False             True
# 15                        False          True            False
# 53                        False         False            False
# 11                        False         False            False
# 38                        False         False            False
# 50                         True         False            False
# 17                        False         False            False
# 3                          True          True            False
# 5                          True         False            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 14                         True         False            False
# 13                         True         False             True
# 22                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  advanced-only-f1_score  ...  fourier-f1_score  \
# 39           0.005285                0.897905  ...          0.921970
# 41           0.006413                0.706439  ...          0.757748
# 35           0.000000                0.269433  ...          0.479211
# 10           0.164864                0.549458  ...          0.625204
# 0            0.465004                0.613573  ...          0.904845
# 27           0.465277                0.617747  ...          0.903290
# 2            0.315318                0.476309  ...          0.727965
# 29           0.317875                0.476212  ...          0.729037
# 37           0.154430                0.459265  ...          0.565256
# 30           0.000469                0.355645  ...          0.401481
# 33           0.265802                0.411502  ...          0.647929
# 42           0.587848                0.925292  ...          0.920261
# 43           0.066698                0.294571  ...          0.373793
# 31           0.039745                0.253637  ...          0.335972
# 34           0.158018                0.335978  ...          0.436661
# 6            0.681152                0.815023  ...          0.950372
# 8            0.638865                0.767833  ...          0.866630
# 44           0.497529                0.695781  ...          0.710491
# 18           0.774557                0.826109  ...          0.950748
# 45           0.775338                0.827055  ...          0.949058
# 1            0.379174                0.462946  ...          0.551115
# 28           0.369892                0.450812  ...          0.539105
# 40           0.025431                0.000000  ...          0.194486
# 46           0.519709                0.658517  ...          0.660138
# 19           0.535119                0.669349  ...          0.674397
# 24           0.837547                0.911319  ...          0.972632
# 32           0.000284                0.130026  ...          0.125655
# 52           0.504072                0.632109  ...          0.625221
# 16           0.689377                0.781671  ...          0.806112
# 49           0.484722                0.599329  ...          0.591671
# 51           0.735262                0.782728  ...          0.839199
# 36           0.885750                0.945169  ...          0.980063
# 9            0.886445                0.946207  ...          0.980640
# 20           0.726278                0.716026  ...          0.810717
# 47           0.727923                0.716911  ...          0.811490
# 25           0.747222                0.829351  ...          0.830144
# 26           0.816274                0.849068  ...          0.898034
# 48           0.695105                0.780030  ...          0.773910
# 7            0.731911                0.777321  ...          0.802003
# 15           0.942116                0.972668  ...          0.990567
# 53           0.682645                0.685332  ...          0.728358
# 11           0.711538                0.713517  ...          0.755586
# 38           0.713646                0.715311  ...          0.757120
# 50           0.645706                0.688567  ...          0.674617
# 17           0.842971                0.846379  ...          0.869962
# 3            0.978312                0.996389  ...          0.999024
# 5            0.986665                0.996886  ...          0.999133
# 21           0.988923                0.997609  ...          0.999275
# 23           0.992964                0.998655  ...          0.999617
# 12           0.997624                0.997423  ...          0.999677
# 14           0.998315                0.998583  ...          0.999853
# 13           1.000000                1.000000  ...          1.000000
# 22           1.000000                1.000000  ...          1.000000
# 4            1.000000                1.000000  ...          1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 39        49228           196912                      0.25       0.921970
# 41        80853           323412                      0.25       0.757748
# 35       161706           323412                      0.50       0.479211
# 10        31625            63250                      0.50       0.625204
# 0         49228            98456                      0.50       0.904845
# 27        49228           196912                      0.25       0.903290
# 2         80853           161706                      0.50       0.727965
# 29        80853           323412                      0.25       0.729037
# 37        31625           126500                      0.25       0.565256
# 30        49228           196912                      0.25       0.401481
# 33        98456           196912                      0.50       0.647929
# 42        98456           196912                      0.50       0.925999
# 43        63250           126500                      0.50       0.373793
# 31        31625           126500                      0.25       0.335972
# 34        63250           126500                      0.50       0.436661
# 6         98456            98456                      1.00       0.950372
# 8        161706           161706                      1.00       0.866630
# 44       161706           323412                      0.50       0.710491
# 18        98456            98456                      1.00       0.950748
# 45        98456           196912                      0.50       0.949058
# 1         31625            63250                      0.50       0.551115
# 28        31625           126500                      0.25       0.539105
# 40        31625           126500                      0.25       0.194486
# 46        63250           126500                      0.50       0.664038
# 19        63250            63250                      1.00       0.674397
# 24       196912            98456                      2.00       0.972632
# 32        80853           323412                      0.25       0.134367
# 52       126500           126500                      1.00       0.635520
# 16        63250            63250                      1.00       0.807184
# 49        63250           126500                      0.50       0.602253
# 51       196912           196912                      1.00       0.839199
# 36        49228           196912                      0.25       0.980063
# 9         49228            98456                      0.50       0.980640
# 20       161706           161706                      1.00       0.810717
# 47       161706           323412                      0.50       0.811490
# 25       126500            63250                      2.00       0.833606
# 26       323412           161706                      2.00       0.898034
# 48        98456           196912                      0.50       0.780768
# 7         63250            63250                      1.00       0.802003
# 15        98456            98456                      1.00       0.990567
# 53       323412           323412                      1.00       0.734651
# 11        80853           161706                      0.50       0.755586
# 38        80853           323412                      0.25       0.757120
# 50       161706           323412                      0.50       0.688567
# 17       161706           161706                      1.00       0.869962
# 3         49228            98456                      0.50       0.999024
# 5         80853           161706                      0.50       0.999133
# 21        98456            98456                      1.00       0.999275
# 23       161706           161706                      1.00       0.999617
# 12        49228            98456                      0.50       0.999758
# 14        80853           161706                      0.50       0.999853
# 13        31625            63250                      0.50       1.000000
# 22        63250            63250                      1.00       1.000000
# 4         31625            63250                      0.50       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 39                 0.892392                0.916685              0.994715
# 41                 0.703231                0.751335              0.993587
# 35                 0.282906                0.479211              1.000000
# 10                 0.440296                0.460339              0.835136
# 0                  0.138951                0.439841              0.534996
# 27                 0.143902                0.438013              0.534723
# 2                  0.179484                0.412648              0.684682
# 29                 0.176723                0.411162              0.682125
# 37                 0.389930                0.410827              0.845570
# 30                 0.377258                0.401012              0.999531
# 33                 0.165192                0.382127              0.734198
# 42                 0.338151                0.332413              0.412152
# 43                 0.293685                0.307095              0.933302
# 31                 0.217812                0.296227              0.960255
# 34                 0.190676                0.278643              0.841982
# 6                  0.133324                0.269220              0.318848
# 8                  0.135762                0.227765              0.361135
# 44                 0.207329                0.212962              0.502471
# 18                 0.048817                0.176191              0.225443
# 45                 0.049280                0.173721              0.224662
# 1                  0.100818                0.171940              0.620826
# 28                 0.101594                0.169213              0.630108
# 40                -0.023929                0.169055              0.974569
# 46                 0.144328                0.140429              0.480291
# 19                 0.137942                0.139278              0.464881
# 24                 0.072481                0.135085              0.162453
# 32                 0.134083                0.125371              0.999716
# 52                 0.131447                0.121148              0.495928
# 16                 0.117807                0.116734              0.310623
# 49                 0.117531                0.106950              0.515278
# 51                 0.048640                0.103936              0.264738
# 36                 0.064514                0.094313              0.114250
# 9                  0.063447                0.094195              0.113555
# 20                -0.002453                0.084439              0.273722
# 47                -0.004293                0.083566              0.272077
# 25                 0.086385                0.082922              0.252778
# 26                 0.037096                0.081761              0.183726
# 48                 0.085663                0.078805              0.304895
# 7                  0.049476                0.070092              0.268089
# 15                 0.033268                0.048451              0.057884
# 53                 0.004138                0.045713              0.317355
# 11                 0.018781                0.044048              0.288462
# 38                 0.018649                0.043474              0.286354
# 50                 0.038727                0.028911              0.354294
# 17                 0.013574                0.026991              0.157029
# 3                  0.018644                0.020712              0.021688
# 5                  0.011232                0.012468              0.013335
# 21                 0.009569                0.010353              0.011077
# 23                 0.005987                0.006653              0.007036
# 12                 0.001771                0.002053              0.002376
# 14                 0.001343                0.001539              0.001685
# 13                 0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 39                0.024293                  92.155503
# 41                0.048104                  75.618442
# 35                0.196305                  47.921085
# 10                0.020044                  55.121495
# 0                 0.300890                  82.213928
# 27                0.294111                  81.914014
# 2                 0.233163                  60.268503
# 29                0.234439                  60.276666
# 37                0.020896                  48.585744
# 30                0.023754                  40.120030
# 33                0.216935                  52.046886
# 42               -0.005739                  80.652924
# 43                0.013410                  32.904139
# 31                0.078416                  30.848816
# 34                0.087967                  33.093750
# 6                 0.135896                  84.435262
# 8                 0.092002                  63.069186
# 44                0.005633                  42.382998
# 18                0.127373                  78.153067
# 45                0.124441                  77.325262
# 1                 0.071122                  27.695430
# 28                0.067619                  26.854606
# 40                0.192984                  17.346644
# 46               -0.003899                  29.238360
# 19                0.001336                  29.959836
# 24                0.062604                  83.153100
# 32               -0.008712                  12.540671
# 52               -0.010299                  24.428626
# 16               -0.001073                  37.580752
# 49               -0.010581                  20.755737
# 51                0.055297                  39.260210
# 36                0.029799                  82.549274
# 9                 0.030748                  82.951002
# 20                0.086892                  30.848415
# 47                0.087860                  30.714263
# 25               -0.003463                  32.804322
# 26                0.044665                  44.501308
# 48               -0.006858                  25.846678
# 7                 0.020615                  26.144975
# 15                0.015183                  83.704131
# 53                0.041575                  14.404424
# 11                0.025267                  15.269943
# 38                0.024826                  15.181959
# 50               -0.009815                   8.160274
# 17                0.013416                  17.188316
# 3                 0.002068                  95.498384
# 5                 0.001236                  93.497481
# 21                0.000784                  93.457780
# 23                0.000666                  94.559129
# 12                0.000282                  86.412774
# 14                0.000196                  91.290946
# 13                0.000000                        NaN
# 22                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [54 rows x 25 columns]

# %% [markdown]
# ### Measure improvement when only webp files are used <a class="anchor" id="webp-only">
#
# We want to measure this alone because in the literature, poor performance in webp files has been mentioned
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == False) & (df["exclude_nonwebp"] == True)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 10                        False                      True
# 37                        False                     False
# 43                        False                     False
# 31                        False                     False
# 34                        False                     False
# 1                         False                      True
# 28                        False                     False
# 40                        False                     False
# 46                        False                     False
# 19                        False                      True
# 52                        False                     False
# 16                        False                      True
# 49                        False                     False
# 25                        False                      True
# 7                         False                      True
# 13                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 10                 False                  True                      True
# 37                 False                  True                      True
# 43                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 1                   True                 False                      True
# 28                  True                 False                      True
# 40                 False                  True                     False
# 46                 False                 False                      True
# 19                 False                 False                      True
# 52                 False                 False                     False
# 16                 False                  True                     False
# 49                 False                 False                     False
# 25                 False                 False                     False
# 7                   True                 False                     False
# 13                 False                  True                     False
# 22                 False                 False                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 10                        False         False             True
# 37                        False         False             True
# 43                        False         False             True
# 31                         True         False             True
# 34                        False         False             True
# 1                         False         False             True
# 28                        False         False             True
# 40                         True         False             True
# 46                        False         False             True
# 19                        False         False             True
# 52                        False         False             True
# 16                        False         False             True
# 49                         True         False             True
# 25                        False         False             True
# 7                         False         False             True
# 13                         True         False             True
# 22                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  advanced-only-f1_score  ...  fourier-f1_score  \
# 10           0.164864                0.549458  ...          0.625204
# 37           0.154430                0.459265  ...          0.565256
# 43           0.066698                0.294571  ...          0.373793
# 31           0.039745                0.253637  ...          0.335972
# 34           0.158018                0.335978  ...          0.436661
# 1            0.379174                0.462946  ...          0.551115
# 28           0.369892                0.450812  ...          0.539105
# 40           0.025431                0.000000  ...          0.194486
# 46           0.519709                0.658517  ...          0.660138
# 19           0.535119                0.669349  ...          0.674397
# 52           0.504072                0.632109  ...          0.625221
# 16           0.689377                0.781671  ...          0.806112
# 49           0.484722                0.599329  ...          0.591671
# 25           0.747222                0.829351  ...          0.830144
# 7            0.731911                0.777321  ...          0.802003
# 13           1.000000                1.000000  ...          1.000000
# 22           1.000000                1.000000  ...          1.000000
# 4            1.000000                1.000000  ...          1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 10        31625            63250                      0.50       0.625204
# 37        31625           126500                      0.25       0.565256
# 43        63250           126500                      0.50       0.373793
# 31        31625           126500                      0.25       0.335972
# 34        63250           126500                      0.50       0.436661
# 1         31625            63250                      0.50       0.551115
# 28        31625           126500                      0.25       0.539105
# 40        31625           126500                      0.25       0.194486
# 46        63250           126500                      0.50       0.664038
# 19        63250            63250                      1.00       0.674397
# 52       126500           126500                      1.00       0.635520
# 16        63250            63250                      1.00       0.807184
# 49        63250           126500                      0.50       0.602253
# 25       126500            63250                      2.00       0.833606
# 7         63250            63250                      1.00       0.802003
# 13        31625            63250                      0.50       1.000000
# 22        63250            63250                      1.00       1.000000
# 4         31625            63250                      0.50       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 10                 0.440296                0.460339              0.835136
# 37                 0.389930                0.410827              0.845570
# 43                 0.293685                0.307095              0.933302
# 31                 0.217812                0.296227              0.960255
# 34                 0.190676                0.278643              0.841982
# 1                  0.100818                0.171940              0.620826
# 28                 0.101594                0.169213              0.630108
# 40                -0.023929                0.169055              0.974569
# 46                 0.144328                0.140429              0.480291
# 19                 0.137942                0.139278              0.464881
# 52                 0.131447                0.121148              0.495928
# 16                 0.117807                0.116734              0.310623
# 49                 0.117531                0.106950              0.515278
# 25                 0.086385                0.082922              0.252778
# 7                  0.049476                0.070092              0.268089
# 13                 0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 10                0.020044                  55.121495
# 37                0.020896                  48.585744
# 43                0.013410                  32.904139
# 31                0.078416                  30.848816
# 34                0.087967                  33.093750
# 1                 0.071122                  27.695430
# 28                0.067619                  26.854606
# 40                0.192984                  17.346644
# 46               -0.003899                  29.238360
# 19                0.001336                  29.959836
# 52               -0.010299                  24.428626
# 16               -0.001073                  37.580752
# 49               -0.010581                  20.755737
# 25               -0.003463                  32.804322
# 7                 0.020615                  26.144975
# 13                0.000000                        NaN
# 22                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [18 rows x 25 columns]

# %% [markdown]
# ### Measure improvement when webp files are not present <a class="anchor" id="no-webp">
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == True) & (df["exclude_nonwebp"] == False)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 39                        False                     False
# 0                         False                      True
# 27                        False                     False
# 30                        False                     False
# 33                        False                     False
# 42                        False                     False
# 6                         False                      True
# 18                        False                      True
# 45                        False                     False
# 24                        False                      True
# 51                        False                     False
# 36                        False                     False
# 9                         False                      True
# 48                        False                     False
# 15                        False                      True
# 3                         False                      True
# 21                        False                      True
# 12                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 39                 False                  True                     False
# 0                   True                 False                      True
# 27                  True                 False                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 42                 False                  True                     False
# 6                   True                 False                     False
# 18                 False                 False                      True
# 45                 False                 False                      True
# 24                 False                 False                     False
# 51                 False                 False                     False
# 36                 False                  True                      True
# 9                  False                  True                      True
# 48                 False                 False                     False
# 15                 False                  True                     False
# 3                   True                 False                     False
# 21                 False                 False                     False
# 12                 False                  True                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 39                         True          True            False
# 0                         False          True            False
# 27                        False          True            False
# 30                         True          True            False
# 33                        False          True            False
# 42                        False          True            False
# 6                         False          True            False
# 18                        False          True            False
# 45                        False          True            False
# 24                        False          True            False
# 51                        False          True            False
# 36                        False          True            False
# 9                         False          True            False
# 48                         True          True            False
# 15                        False          True            False
# 3                          True          True            False
# 21                         True          True            False
# 12                         True          True            False
#
#     baseline-f1_score  advanced-only-f1_score  ...  fourier-f1_score  \
# 39           0.005285                0.897905  ...          0.921970
# 0            0.465004                0.613573  ...          0.904845
# 27           0.465277                0.617747  ...          0.903290
# 30           0.000469                0.355645  ...          0.401481
# 33           0.265802                0.411502  ...          0.647929
# 42           0.587848                0.925292  ...          0.920261
# 6            0.681152                0.815023  ...          0.950372
# 18           0.774557                0.826109  ...          0.950748
# 45           0.775338                0.827055  ...          0.949058
# 24           0.837547                0.911319  ...          0.972632
# 51           0.735262                0.782728  ...          0.839199
# 36           0.885750                0.945169  ...          0.980063
# 9            0.886445                0.946207  ...          0.980640
# 48           0.695105                0.780030  ...          0.773910
# 15           0.942116                0.972668  ...          0.990567
# 3            0.978312                0.996389  ...          0.999024
# 21           0.988923                0.997609  ...          0.999275
# 12           0.997624                0.997423  ...          0.999677
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 39        49228           196912                      0.25       0.921970
# 0         49228            98456                      0.50       0.904845
# 27        49228           196912                      0.25       0.903290
# 30        49228           196912                      0.25       0.401481
# 33        98456           196912                      0.50       0.647929
# 42        98456           196912                      0.50       0.925999
# 6         98456            98456                      1.00       0.950372
# 18        98456            98456                      1.00       0.950748
# 45        98456           196912                      0.50       0.949058
# 24       196912            98456                      2.00       0.972632
# 51       196912           196912                      1.00       0.839199
# 36        49228           196912                      0.25       0.980063
# 9         49228            98456                      0.50       0.980640
# 48        98456           196912                      0.50       0.780768
# 15        98456            98456                      1.00       0.990567
# 3         49228            98456                      0.50       0.999024
# 21        98456            98456                      1.00       0.999275
# 12        49228            98456                      0.50       0.999758
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 39                 0.892392                0.916685              0.994715
# 0                  0.138951                0.439841              0.534996
# 27                 0.143902                0.438013              0.534723
# 30                 0.377258                0.401012              0.999531
# 33                 0.165192                0.382127              0.734198
# 42                 0.338151                0.332413              0.412152
# 6                  0.133324                0.269220              0.318848
# 18                 0.048817                0.176191              0.225443
# 45                 0.049280                0.173721              0.224662
# 24                 0.072481                0.135085              0.162453
# 51                 0.048640                0.103936              0.264738
# 36                 0.064514                0.094313              0.114250
# 9                  0.063447                0.094195              0.113555
# 48                 0.085663                0.078805              0.304895
# 15                 0.033268                0.048451              0.057884
# 3                  0.018644                0.020712              0.021688
# 21                 0.009569                0.010353              0.011077
# 12                 0.001771                0.002053              0.002376
#
#     fourier_minus_advanced  percentage_of_room_filled
# 39                0.024293                  92.155503
# 0                 0.300890                  82.213928
# 27                0.294111                  81.914014
# 30                0.023754                  40.120030
# 33                0.216935                  52.046886
# 42               -0.005739                  80.652924
# 6                 0.135896                  84.435262
# 18                0.127373                  78.153067
# 45                0.124441                  77.325262
# 24                0.062604                  83.153100
# 51                0.055297                  39.260210
# 36                0.029799                  82.549274
# 9                 0.030748                  82.951002
# 48               -0.006858                  25.846678
# 15                0.015183                  83.704131
# 3                 0.002068                  95.498384
# 21                0.000784                  93.457780
# 12                0.000282                  86.412774
#
# [18 rows x 25 columns]

# %% [markdown]
# ### Measure improvement for balanced datasets <a class="anchor" id="balanced-dataset">
#
# Most of our dataset selections are not balanced, and we didn't do anything to mitigate
# unablanced datasets. This is because we are measuring the baseline and improvement on the
# same dataset.
#
# However, we will select those instances where the datasets were balanced to see if the
# improvement is still significant in these instances.
#
# [top](#Contents)

# %%
df[df["ratio_encrypt_nonencrypt"] == 1.0]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 6                         False                      True
# 8                         False                      True
# 18                        False                      True
# 19                        False                      True
# 52                        False                     False
# 16                        False                      True
# 51                        False                     False
# 20                        False                      True
# 7                         False                      True
# 15                        False                      True
# 53                        False                     False
# 17                        False                      True
# 21                        False                      True
# 23                        False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 6                   True                 False                     False
# 8                   True                 False                     False
# 18                 False                 False                      True
# 19                 False                 False                      True
# 52                 False                 False                     False
# 16                 False                  True                     False
# 51                 False                 False                     False
# 20                 False                 False                      True
# 7                   True                 False                     False
# 15                 False                  True                     False
# 53                 False                 False                     False
# 17                 False                  True                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 6                         False          True            False
# 8                         False         False            False
# 18                        False          True            False
# 19                        False         False             True
# 52                        False         False             True
# 16                        False         False             True
# 51                        False          True            False
# 20                        False         False            False
# 7                         False         False             True
# 15                        False          True            False
# 53                        False         False            False
# 17                        False         False            False
# 21                         True          True            False
# 23                         True         False            False
# 22                         True         False             True
#
#     baseline-f1_score  advanced-only-f1_score  ...  fourier-f1_score  \
# 6            0.681152                0.815023  ...          0.950372
# 8            0.638865                0.767833  ...          0.866630
# 18           0.774557                0.826109  ...          0.950748
# 19           0.535119                0.669349  ...          0.674397
# 52           0.504072                0.632109  ...          0.625221
# 16           0.689377                0.781671  ...          0.806112
# 51           0.735262                0.782728  ...          0.839199
# 20           0.726278                0.716026  ...          0.810717
# 7            0.731911                0.777321  ...          0.802003
# 15           0.942116                0.972668  ...          0.990567
# 53           0.682645                0.685332  ...          0.728358
# 17           0.842971                0.846379  ...          0.869962
# 21           0.988923                0.997609  ...          0.999275
# 23           0.992964                0.998655  ...          0.999617
# 22           1.000000                1.000000  ...          1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 6         98456            98456                       1.0       0.950372
# 8        161706           161706                       1.0       0.866630
# 18        98456            98456                       1.0       0.950748
# 19        63250            63250                       1.0       0.674397
# 52       126500           126500                       1.0       0.635520
# 16        63250            63250                       1.0       0.807184
# 51       196912           196912                       1.0       0.839199
# 20       161706           161706                       1.0       0.810717
# 7         63250            63250                       1.0       0.802003
# 15        98456            98456                       1.0       0.990567
# 53       323412           323412                       1.0       0.734651
# 17       161706           161706                       1.0       0.869962
# 21        98456            98456                       1.0       0.999275
# 23       161706           161706                       1.0       0.999617
# 22        63250            63250                       1.0       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 6                  0.133324                0.269220              0.318848
# 8                  0.135762                0.227765              0.361135
# 18                 0.048817                0.176191              0.225443
# 19                 0.137942                0.139278              0.464881
# 52                 0.131447                0.121148              0.495928
# 16                 0.117807                0.116734              0.310623
# 51                 0.048640                0.103936              0.264738
# 20                -0.002453                0.084439              0.273722
# 7                  0.049476                0.070092              0.268089
# 15                 0.033268                0.048451              0.057884
# 53                 0.004138                0.045713              0.317355
# 17                 0.013574                0.026991              0.157029
# 21                 0.009569                0.010353              0.011077
# 23                 0.005987                0.006653              0.007036
# 22                 0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 6                 0.135896                  84.435262
# 8                 0.092002                  63.069186
# 18                0.127373                  78.153067
# 19                0.001336                  29.959836
# 52               -0.010299                  24.428626
# 16               -0.001073                  37.580752
# 51                0.055297                  39.260210
# 20                0.086892                  30.848415
# 7                 0.020615                  26.144975
# 15                0.015183                  83.704131
# 53                0.041575                  14.404424
# 17                0.013416                  17.188316
# 21                0.000784                  93.457780
# 23                0.000666                  94.559129
# 22                0.000000                        NaN
#
# [15 rows x 25 columns]

# %% [markdown]
# ### Measure the improvement when all files are used <a class="anchor" id="full-dataset">
#
# In most of our dataset selections, we excluded some data points based on our criteria.
#
# In this, we measure the improvement when we use all data points
#
# [top](#Contents)

# %%
# Measure everything for the full dataset
df2 = df
for colname in df2.columns:
    if "exclude" in colname:
        df2 = df2[df2[colname] == False]
df2
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 53                        False                     False
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 53                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 53                        False         False            False
#
#     baseline-f1_score  advanced-only-f1_score  ...  fourier-f1_score  \
# 53           0.682645                0.685332  ...          0.728358
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 53       323412           323412                       1.0       0.734651
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 53                 0.004138                0.045713              0.317355
#
#     fourier_minus_advanced  percentage_of_room_filled
# 53                0.041575                  14.404424
#
# [1 rows x 25 columns]

# %%
df.to_csv("../comparison_logistic_regression_final.csv")

# %% [markdown]
# ### Focus on items where the base metrics performed well <a class="anchor" id="focus-greater-90">
#
# We see that in all cases, plaintext non-base 32 only is selected. Also we
# see that for encrypted, only base32 is selected and non-base32 excluded.
#
# Fundamentally, what this is measuring is when the plaintext has all files
# but all encrypted content is base-32 encoded.
#
# Typically, base-32 encoding will lead to a reduction of entropy, in many cases
# much less than the original text, and this is what it is measuring.
#
# [top](#Contents)

# %%
df[df["baseline-f1_score"] > 0.9]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 15                        False                      True
# 3                         False                      True
# 5                         False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 13                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 15                 False                  True                     False
# 3                   True                 False                     False
# 5                   True                 False                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 13                 False                  True                     False
# 22                 False                 False                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 15                        False          True            False
# 3                          True          True            False
# 5                          True         False            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 14                         True         False            False
# 13                         True         False             True
# 22                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  advanced-only-f1_score  ...  fourier-f1_score  \
# 15           0.942116                0.972668  ...          0.990567
# 3            0.978312                0.996389  ...          0.999024
# 5            0.986665                0.996886  ...          0.999133
# 21           0.988923                0.997609  ...          0.999275
# 23           0.992964                0.998655  ...          0.999617
# 12           0.997624                0.997423  ...          0.999677
# 14           0.998315                0.998583  ...          0.999853
# 13           1.000000                1.000000  ...          1.000000
# 22           1.000000                1.000000  ...          1.000000
# 4            1.000000                1.000000  ...          1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 15        98456            98456                       1.0       0.990567
# 3         49228            98456                       0.5       0.999024
# 5         80853           161706                       0.5       0.999133
# 21        98456            98456                       1.0       0.999275
# 23       161706           161706                       1.0       0.999617
# 12        49228            98456                       0.5       0.999758
# 14        80853           161706                       0.5       0.999853
# 13        31625            63250                       0.5       1.000000
# 22        63250            63250                       1.0       1.000000
# 4         31625            63250                       0.5       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 15                 0.033268                0.048451              0.057884
# 3                  0.018644                0.020712              0.021688
# 5                  0.011232                0.012468              0.013335
# 21                 0.009569                0.010353              0.011077
# 23                 0.005987                0.006653              0.007036
# 12                 0.001771                0.002053              0.002376
# 14                 0.001343                0.001539              0.001685
# 13                 0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 15                0.015183                  83.704131
# 3                 0.002068                  95.498384
# 5                 0.001236                  93.497481
# 21                0.000784                  93.457780
# 23                0.000666                  94.559129
# 12                0.000282                  86.412774
# 14                0.000196                  91.290946
# 13                0.000000                        NaN
# 22                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Correlation of data set and performance <a class="anchor" id="corr-heatmap">
#
# This gives more idea on how data-set selection affects performance.
#
# [top](#Contents)

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,10)
sns.heatmap(df.astype(float).corr(), cmap='coolwarm')
# print(df[df["baseline-f1_score"] > 0.9].astype(float))
_ = plt.xticks(rotation=80)

# %%
df1 = df[["exclude_encrypted_base32", "exclude_encrypted_v2", "exclude_webp", "baseline-f1_score", "advanced-f1_score", "fourier-f1_score"]]
sns.heatmap(df1.astype(float).corr(), cmap='coolwarm')
_ = plt.xticks(rotation=80)

# %% [markdown]
# ### Average out all the metrics <a class="anchor" id="mean-fscores">
#
# To conclude we report the average of the f1-scores and the improvements with all datasets
#
# [top](#Contents)

# %%
df[[c for c in df.columns if ("score" in c or "improvement" in c) and "room" not in c]].mean()
# Out:
# baseline-f1_score                 0.577026
# advanced-only-f1_score            0.700388
# fourier-only-f1_score             0.620072
# baseline-and-advanced-f1_score    0.709311
# baseline-and-fourier-f1_score     0.685646
# advanced-and-fourier-f1_score     0.759276
# advanced-f1_score                 0.709311
# fourier-f1_score                  0.766619
# best_f1_score                     0.767933
# improvement_in_advanced           0.132284
# improvement_in_fourier            0.189593
# dtype: float64

# %%
df[[c for c in df.columns if ("score" in c or "improvement" in c) and "room" not in c]].describe()
# Out:
#        baseline-f1_score  advanced-only-f1_score  fourier-only-f1_score  \
# count          54.000000               54.000000              54.000000
# mean            0.577026                0.700388               0.620072
# std             0.329975                0.249429               0.356676
# min             0.000000                0.000000               0.000000
# 25%             0.330879                0.561925               0.494809
# 50%             0.681899                0.716469               0.709234
# 75%             0.832228                0.907965               0.928699
# max             1.000000                1.000000               1.000000
#
#        baseline-and-advanced-f1_score  baseline-and-fourier-f1_score  \
# count                       54.000000                      54.000000
# mean                         0.709311                       0.685646
# std                          0.243008                       0.291938
# min                          0.001502                       0.000000
# 25%                          0.602678                       0.588407
# 50%                          0.731307                       0.751531
# 75%                          0.906940                       0.931942
# max                          1.000000                       1.000000
#
#        advanced-and-fourier-f1_score  advanced-f1_score  fourier-f1_score  \
# count                      54.000000          54.000000         54.000000
# mean                        0.759276           0.709311          0.766619
# std                         0.225656           0.243008          0.220438
# min                         0.119250           0.001502          0.125655
# 25%                         0.646229           0.602678          0.650982
# 50%                         0.802608           0.731307          0.808414
# 75%                         0.946579           0.906940          0.950654
# max                         1.000000           1.000000          1.000000
#
#        best_f1_score  improvement_in_advanced  improvement_in_fourier
# count      54.000000                54.000000               54.000000
# mean        0.767933                 0.132284                0.189593
# std         0.219636                 0.172429                0.193490
# min         0.134367                -0.023929                0.000000
# 25%         0.651956                 0.018645                0.046398
# 50%         0.808951                 0.086024                0.123260
# 75%         0.950654                 0.159976                0.291831
# max         1.000000                 0.892392                0.916685

# %%
df1 = df[[c for c in df.columns if ("score" in c or "improvement" in c) and "room" not in c]]
columns = ["baseline-f1_score"]
columns += [c for c in df1.columns if "only" in c]
columns += [c for c in df1.columns if "-and-" in c]
columns += [c for c in df1.columns if "only" not in c and "-and-" not in c and "baseline-f1_score" != c]
df1[columns].describe()
# Out:
#        baseline-f1_score  advanced-only-f1_score  fourier-only-f1_score  \
# count          54.000000               54.000000              54.000000
# mean            0.577026                0.700388               0.620072
# std             0.329975                0.249429               0.356676
# min             0.000000                0.000000               0.000000
# 25%             0.330879                0.561925               0.494809
# 50%             0.681899                0.716469               0.709234
# 75%             0.832228                0.907965               0.928699
# max             1.000000                1.000000               1.000000
#
#        baseline-and-advanced-f1_score  baseline-and-fourier-f1_score  \
# count                       54.000000                      54.000000
# mean                         0.709311                       0.685646
# std                          0.243008                       0.291938
# min                          0.001502                       0.000000
# 25%                          0.602678                       0.588407
# 50%                          0.731307                       0.751531
# 75%                          0.906940                       0.931942
# max                          1.000000                       1.000000
#
#        advanced-and-fourier-f1_score  advanced-f1_score  fourier-f1_score  \
# count                      54.000000          54.000000         54.000000
# mean                        0.759276           0.709311          0.766619
# std                         0.225656           0.243008          0.220438
# min                         0.119250           0.001502          0.125655
# 25%                         0.646229           0.602678          0.650982
# 50%                         0.802608           0.731307          0.808414
# 75%                         0.946579           0.906940          0.950654
# max                         1.000000           1.000000          1.000000
#
#        best_f1_score  improvement_in_advanced  improvement_in_fourier
# count      54.000000                54.000000               54.000000
# mean        0.767933                 0.132284                0.189593
# std         0.219636                 0.172429                0.193490
# min         0.134367                -0.023929                0.000000
# 25%         0.651956                 0.018645                0.046398
# 50%         0.808951                 0.086024                0.123260
# 75%         0.950654                 0.159976                0.291831
# max         1.000000                 0.892392                0.916685
