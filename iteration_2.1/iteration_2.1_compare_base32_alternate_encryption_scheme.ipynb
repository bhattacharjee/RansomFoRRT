# %% [markdown]
# Few key observations
# - If both and non-encrypted files are base-32 encoded, accuracy drops really low.
#    * Even in this case, fourier analysis (specifically autocorrelation and mean) provide good discrminators
#    * Renyi's entropy at alpha=infinity gives good discrimination
#    * Overall we see around 13% improvement in F1-score
# - Specifically for webpfiles
#    * We see that higher moments of around 14 gives a good discrimination
#    * Fourier analysis still gives benefits here
# - For webpfiles where both unencrypted and encrypted content are base32 encrypted
#    * Fourier analysis is still beneficial
# - For Non-webp files where plaintext is not base-32 encrypted
#    * Accuracy is decent with just the base parameters, but with fourier analysis, we can close to perfect detection

# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats

from functools import lru_cache

import gc

import sklearn
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score, accuracy_score

import matplotlib.pyplot as plt
import glob

plt.rcParams["figure.figsize"] = (20,20)

# %%
# !ls
# Out:
# expanded.plaintext.base32.csv.gz
# expanded.pyencrypted_v1.b32.csv.gz
# expanded.pyencrypted_v1.csv.gz
# expanded.pyencrypted_v2.base32.csv.gz
# expanded.pyencrypted_v2.csv.gz
# iteration_2.010_compare_base32_alternate_encryption_scheme.ipynb
# plaintext.base32.combined.csv.gz
# plaintext.combined.csv.gz
# plaintext.expanded.csv.gz

# %%
def call_gc():
    for i in range(3):
        for j in range(3):
            gc.collect(j)

# %%
def get_columns(thisdf):
    baseline_columns = [c for c in thisdf.columns if c.startswith('baseline') and "head" not in c and "tail" not in c]
    baseline_columns = [c for c in baseline_columns if "filesize" not in c]
    baseline_columns = [c for c in baseline_columns if "begin" not in c and "end" not in c]

    advanced_columns = [c for c in thisdf.columns if "advanced" in c]
    advanced_columns = [c for c in advanced_columns if "begin" not in c and "end" not in c]
    advanced_columns = [c for c in advanced_columns if "head" not in c and "tail" not in c]
    advanced_columns = [c for c in advanced_columns if "start" not in c]
    advanced_columns = list(set(advanced_columns + baseline_columns))

    fourier_columns = [c for c in thisdf.columns if "fourier" in c and "value" not in c]
    fourier_columns = [c for c in fourier_columns if "1byte" in c]
    fourier_columns = [c for c in fourier_columns if "begin" not in c and "end" not in c]
    fourier_columns = [c for c in fourier_columns if "head" not in c and "tail" not in c]
    fourier_columns = [c for c in fourier_columns if "start" not in c]
    fourier_columns = list(set(advanced_columns + fourier_columns))
    
    return {\
        "baseline": baseline_columns,\
        "advanced": advanced_columns,\
        "fourier": fourier_columns,\
    }

# %%
def compare_feature_selections(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    columns_dict = get_columns(X)
    ret = dict()
    for name, collist in columns_dict.items():
        XX_train, XX_test = X_train[collist], X_test[collist]
        rfc = RandomForestClassifier(n_jobs=10, random_state=42)
        estimators = [('std,', MinMaxScaler()), ('RFC', rfc)]
        pipeline = Pipeline(estimators)
        pipeline.fit(XX_train, y_train)
        y_pred = pipeline.predict(XX_test)
        f1 = f1_score(y_test, y_pred)
        ret[f"{name}-f1_score"] = f1
    return ret

def compare_feature_selections_wrapper(data):
    X = data[[c for c in data.columns if "is_encrypted" != c]]
    y = data["is_encrypted"]
    return compare_feature_selections(X, y)

# %%
@lru_cache
def load_datasets_once():
    """Load all datasets only once
    
    We want to load the datasets only once. Once loaded
    serve from cache
    """
    datasets = dict()
    for file in glob.glob("*.csv.gz"):
        df = pd.read_csv(file)
        df = df.sample(frac=1).reset_index(drop=True)
        df["is_encrypted"] = 1 if "encr" in file.lower() else 0
        datasets[file] = df
    return datasets

# %%
def get_dataset(\
               exclude_plaintext_nonbase32=False,
               exclude_plaintext_base32=False,
               exclude_encrypted_v1=False,
               exclude_encrypted_v2=False,
               exclude_encrypted_base32=False,
               exclude_encrypted_nonbase32=False,
               exclude_webp=False,
               exclude_nonwebp=False):
    description = {k:v for k,v in locals().items() if "exclude" in k}
    files = glob.glob("*.csv.gz")
    
    
    if exclude_plaintext_nonbase32:
        files = [f for f in files if \
                     "plaintext" not in f \
                     or "_base32" in f \
                     or "_b32" in f]
    if exclude_plaintext_base32:
        files = [f for f in files if\
                    "plaintext" not in f or \
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_v1:
        files = [f for f in files if\
                    "_v1" not in f or "encr" not in f]
    if exclude_encrypted_v2:
        files = [f for f in files if \
                    "_v2" not in f or "encr" not in f]
    if exclude_encrypted_base32:
        files = [ f for f in files if\
                    "encr" not in f or\
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_nonbase32:
        files = [f for f in files if \
                    "encr" not in f or \
                    "base32" in f or "b32" in f]
        
        
    encrypted_count = len([f for f in files if "encr" in f])
    non_encrypted_count = len([f for f in files if "encr" not in f])
    
    if 0 == encrypted_count or 0 == non_encrypted_count or 0 == len(files):
        return description, None, -1, -1
    
    all_dfs = list()
    all_loaded_datasets = load_datasets_once()
    for filename in files:
        all_dfs.append(all_loaded_datasets[filename])
    
    combined_df = pd.concat(all_dfs)
    
    if exclude_webp:
        combined_df = combined_df[combined_df["extended.extension"] != ".webp"]
    if exclude_nonwebp:
        combined_df = combined_df[combined_df["extended.extension"] == ".webp"]
        
    if len(combined_df) == 0:
        return description, None, -1, -1
    
        
    encrypt_count = len(combined_df[combined_df["is_encrypted"] == 1])
    nonencrypted_count = len(combined_df[combined_df["is_encrypted"] == 0])

    
    if 0 == len(combined_df) or 0 == encrypt_count or 0 == nonencrypted_count:
        return description, None, -1, -1
    
    return description, combined_df, encrypt_count, nonencrypted_count

# %%
all_results = []
count = 2
try:
    for a in [True, False]:
        for b in [True, False]:
            for c in [True, False]:
                for k in [True, False]:
                    for e in [True, False]:
                        for f in [True, False]:
                            for g in [True, False]:
                                for h in [True, False]:
                                    desc, df, ec, nec = get_dataset(a, b, c, k, e, f, g, h)
                                    if df is not None:
                                        result = compare_feature_selections_wrapper(df)
                                        call_gc()
                                        result = {**desc, **result}
                                        result["n_encrypted"] = ec
                                        result["n_non_encrypted"] = nec
                                        result["ratio_encrypt_nonencrypt"] = float(ec) / nec
                                        all_results.append(result)

                                        """
                                        count -= 1
                                        if count == 0:
                                            # A non-standard way to break out of 
                                            # all nested loops
                                            raise Exception("breaking out")
                                        """
except Exception as e:
    print(e)

df_dict = {k:[] for k in all_results[0]}
for result in all_results:
    for k, v in result.items():
        df_dict[k].append(v)

df = pd.DataFrame(df_dict)
df["best_f1_score"] = df[[c for c in df.columns if "f1_score" in c]].max(axis=1)

df["improvement_in_advanced"] = df["advanced-f1_score"] - df["baseline-f1_score"]
df["improvement_in_fourier"] = df["fourier-f1_score"] - df["baseline-f1_score"]
df = df.sort_values(by="improvement_in_fourier", ascending=False)

# %%
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 37                        False                     False
# 10                        False                      True
# 43                        False                     False
# 40                        False                     False
# 31                        False                     False
# 34                        False                     False
# 1                         False                      True
# 32                        False                     False
# 35                        False                     False
# 28                        False                     False
# 2                         False                      True
# 29                        False                     False
# 30                        False                     False
# 33                        False                     False
# 16                        False                      True
# 0                         False                      True
# 27                        False                     False
# 19                        False                      True
# 52                        False                     False
# 49                        False                     False
# 46                        False                     False
# 44                        False                     False
# 38                        False                     False
# 11                        False                      True
# 41                        False                     False
# 53                        False                     False
# 20                        False                      True
# 50                        False                     False
# 8                         False                      True
# 47                        False                     False
# 45                        False                     False
# 6                         False                      True
# 18                        False                      True
# 51                        False                     False
# 48                        False                     False
# 7                         False                      True
# 25                        False                      True
# 17                        False                      True
# 24                        False                      True
# 26                        False                      True
# 3                         False                      True
# 9                         False                      True
# 42                        False                     False
# 39                        False                     False
# 36                        False                     False
# 5                         False                      True
# 15                        False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 4                         False                      True
# 13                        False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 37                 False                  True                      True
# 10                 False                  True                      True
# 43                 False                  True                     False
# 40                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 1                   True                 False                      True
# 32                  True                 False                     False
# 35                  True                 False                     False
# 28                  True                 False                      True
# 2                   True                 False                      True
# 29                  True                 False                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 16                 False                  True                     False
# 0                   True                 False                      True
# 27                  True                 False                      True
# 19                 False                 False                      True
# 52                 False                 False                     False
# 49                 False                 False                     False
# 46                 False                 False                      True
# 44                 False                  True                     False
# 38                 False                  True                      True
# 11                 False                  True                      True
# 41                 False                  True                     False
# 53                 False                 False                     False
# 20                 False                 False                      True
# 50                 False                 False                     False
# 8                   True                 False                     False
# 47                 False                 False                      True
# 45                 False                 False                      True
# 6                   True                 False                     False
# 18                 False                 False                      True
# 51                 False                 False                     False
# 48                 False                 False                     False
# 7                   True                 False                     False
# 25                 False                 False                     False
# 17                 False                  True                     False
# 24                 False                 False                     False
# 26                 False                 False                     False
# 3                   True                 False                     False
# 9                  False                  True                      True
# 42                 False                  True                     False
# 39                 False                  True                     False
# 36                 False                  True                      True
# 5                   True                 False                     False
# 15                 False                  True                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 4                   True                 False                     False
# 13                 False                  True                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 37                        False         False             True
# 10                        False         False             True
# 43                        False         False             True
# 40                         True         False             True
# 31                         True         False             True
# 34                        False         False             True
# 1                         False         False             True
# 32                         True         False            False
# 35                        False         False            False
# 28                        False         False             True
# 2                         False         False            False
# 29                        False         False            False
# 30                         True          True            False
# 33                        False          True            False
# 16                        False         False             True
# 0                         False          True            False
# 27                        False          True            False
# 19                        False         False             True
# 52                        False         False             True
# 49                         True         False             True
# 46                        False         False             True
# 44                        False         False            False
# 38                        False         False            False
# 11                        False         False            False
# 41                         True         False            False
# 53                        False         False            False
# 20                        False         False            False
# 50                         True         False            False
# 8                         False         False            False
# 47                        False         False            False
# 45                        False          True            False
# 6                         False          True            False
# 18                        False          True            False
# 51                        False          True            False
# 48                         True          True            False
# 7                         False         False             True
# 25                        False         False             True
# 17                        False         False            False
# 24                        False          True            False
# 26                        False         False            False
# 3                          True          True            False
# 9                         False          True            False
# 42                        False          True            False
# 39                         True          True            False
# 36                        False          True            False
# 5                          True         False            False
# 15                        False          True            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 14                         True         False            False
# 4                          True         False             True
# 13                         True         False             True
# 22                         True         False             True
#
#     baseline-f1_score  advanced-f1_score  fourier-f1_score  n_encrypted  \
# 37           0.690682           0.872136          0.886821        31625
# 10           0.703183           0.866977          0.883858        31625
# 43           0.656482           0.813560          0.825912        63250
# 40           0.617365           0.773569          0.777615        31625
# 31           0.545348           0.654401          0.680834        31625
# 34           0.623332           0.721805          0.735058        63250
# 1            0.676500           0.775050          0.781492        31625
# 32           0.715513           0.777573          0.819461        80853
# 35           0.768112           0.825482          0.868005       161706
# 28           0.684000           0.776319          0.782407        31625
# 2            0.815457           0.872835          0.911582        80853
# 29           0.816842           0.872115          0.911287        80853
# 30           0.828541           0.876089          0.922745        49228
# 33           0.866051           0.904552          0.956035        98456
# 16           0.857143           0.935900          0.944788        63250
# 0            0.903011           0.936882          0.989274        49228
# 27           0.904989           0.934987          0.989254        49228
# 19           0.791431           0.863164          0.869495        63250
# 52           0.780966           0.842506          0.854287       126500
# 49           0.764474           0.818010          0.834435        63250
# 46           0.797826           0.857816          0.863098        63250
# 44           0.877654           0.931806          0.936889       161706
# 38           0.893869           0.945197          0.952258        80853
# 11           0.894017           0.943061          0.951563        80853
# 41           0.863643           0.918309          0.920652        80853
# 53           0.885429           0.914270          0.933756       323412
# 20           0.900294           0.927762          0.947397       161706
# 50           0.872557           0.902164          0.919120       161706
# 8            0.913086           0.939108          0.957944       161706
# 47           0.903207           0.927912          0.947191       161706
# 45           0.950829           0.968286          0.994547        98456
# 10                 0.163794                0.180675
# 43                 0.157079                0.169431
# 40                 0.156204                0.160250
# 31                 0.109053                0.135486
# 34                 0.098473                0.111726
# 1                  0.098550                0.104992
# 32                 0.062060                0.103948
# 35                 0.057369                0.099893
# 28                 0.092318                0.098407
# 2                  0.057379                0.096125
# 29                 0.055273                0.094445
# 30                 0.047549                0.094204
# 33                 0.038501                0.089984
# 16                 0.078758                0.087645
# 0                  0.033871                0.086263
# 27                 0.029998                0.084265
# 19                 0.071733                0.078064
# 52                 0.061540                0.073321
# 49                 0.053535                0.069961
# 46                 0.059990                0.065272
# 44                 0.054152                0.059235
# 38                 0.051327                0.058389
# 11                 0.049044                0.057546
# 41                 0.054665                0.057009
# 53                 0.028841                0.048327
# 20                 0.027468                0.047103
# 50                 0.029607                0.046563
# 8                  0.026022                0.044858
# 47                 0.024705                0.043984
# 45                 0.017457                0.043719
# 6                  0.017239                0.043529
# 18                 0.016229                0.043227
# 51                 0.018812                0.043120
# 48                 0.022339                0.042353
# 7                  0.038822                0.041998
# 25                 0.030911                0.033919
# 17                 0.024959                0.029536
# 24                 0.008670                0.021997
# 26                 0.012229                0.021621
# 3                  0.002160                0.002160
# 9                  0.001222                0.002077
# 42                 0.001521                0.001926
# 39                 0.001823                0.001907
# 36                 0.001270                0.001516
# 5                  0.001165                0.001165
# 15                 0.000423                0.000826
# 21                 0.000705                0.000705
# 23                 0.000643                0.000643
# 12                 0.000040                0.000040
# 14                 0.000000                0.000000
# 4                  0.000000                0.000000
# 13                 0.000000                0.000000
# 22                 0.000000                0.000000

# %%
df.to_csv("../comparison.csv")

# %%
df = df.sort_values(by="improvement_in_fourier", ascending=False)

# %%
df["improvement_in_advanced"] = df["advanced-f1_score"] - df["baseline-f1_score"]
df["room_for_improvement"] = 1.0 - df["baseline-f1_score"]
df["fourier_minus_advanced"] = df["fourier-f1_score"] - df["advanced-f1_score"]
df["percentage_of_room_filled"] = df["improvement_in_fourier"] * 100.0 / df["room_for_improvement"]
#df.sort_values(by="fourier_minus_advanced", ascending=False)
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 37                        False                     False
# 10                        False                      True
# 43                        False                     False
# 40                        False                     False
# 31                        False                     False
# 34                        False                     False
# 1                         False                      True
# 32                        False                     False
# 35                        False                     False
# 28                        False                     False
# 2                         False                      True
# 29                        False                     False
# 30                        False                     False
# 33                        False                     False
# 16                        False                      True
# 0                         False                      True
# 27                        False                     False
# 19                        False                      True
# 52                        False                     False
# 49                        False                     False
# 46                        False                     False
# 44                        False                     False
# 38                        False                     False
# 11                        False                      True
# 41                        False                     False
# 53                        False                     False
# 20                        False                      True
# 50                        False                     False
# 8                         False                      True
# 47                        False                     False
# 45                        False                     False
# 6                         False                      True
# 18                        False                      True
# 51                        False                     False
# 48                        False                     False
# 7                         False                      True
# 25                        False                      True
# 17                        False                      True
# 24                        False                      True
# 26                        False                      True
# 3                         False                      True
# 9                         False                      True
# 42                        False                     False
# 39                        False                     False
# 36                        False                     False
# 5                         False                      True
# 15                        False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 13                        False                      True
# 14                        False                      True
# 4                         False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 37                 False                  True                      True
# 10                 False                  True                      True
# 43                 False                  True                     False
# 40                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 1                   True                 False                      True
# 32                  True                 False                     False
# 35                  True                 False                     False
# 28                  True                 False                      True
# 2                   True                 False                      True
# 29                  True                 False                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 16                 False                  True                     False
# 0                   True                 False                      True
# 27                  True                 False                      True
# 19                 False                 False                      True
# 52                 False                 False                     False
# 49                 False                 False                     False
# 46                 False                 False                      True
# 44                 False                  True                     False
# 38                 False                  True                      True
# 11                 False                  True                      True
# 41                 False                  True                     False
# 53                 False                 False                     False
# 20                 False                 False                      True
# 50                 False                 False                     False
# 8                   True                 False                     False
# 47                 False                 False                      True
# 45                 False                 False                      True
# 6                   True                 False                     False
# 18                 False                 False                      True
# 51                 False                 False                     False
# 48                 False                 False                     False
# 7                   True                 False                     False
# 25                 False                 False                     False
# 17                 False                  True                     False
# 24                 False                 False                     False
# 26                 False                 False                     False
# 3                   True                 False                     False
# 9                  False                  True                      True
# 42                 False                  True                     False
# 39                 False                  True                     False
# 36                 False                  True                      True
# 5                   True                 False                     False
# 15                 False                  True                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 13                 False                  True                     False
# 14                 False                  True                     False
# 4                   True                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 37                        False         False             True
# 10                        False         False             True
# 43                        False         False             True
# 40                         True         False             True
# 31                         True         False             True
# 34                        False         False             True
# 1                         False         False             True
# 32                         True         False            False
# 35                        False         False            False
# 28                        False         False             True
# 2                         False         False            False
# 29                        False         False            False
# 30                         True          True            False
# 33                        False          True            False
# 16                        False         False             True
# 0                         False          True            False
# 27                        False          True            False
# 19                        False         False             True
# 52                        False         False             True
# 49                         True         False             True
# 46                        False         False             True
# 44                        False         False            False
# 38                        False         False            False
# 11                        False         False            False
# 41                         True         False            False
# 53                        False         False            False
# 20                        False         False            False
# 50                         True         False            False
# 8                         False         False            False
# 47                        False         False            False
# 45                        False          True            False
# 6                         False          True            False
# 18                        False          True            False
# 51                        False          True            False
# 48                         True          True            False
# 7                         False         False             True
# 25                        False         False             True
# 17                        False         False            False
# 24                        False          True            False
# 26                        False         False            False
# 3                          True          True            False
# 9                         False          True            False
# 42                        False          True            False
# 39                         True          True            False
# 36                        False          True            False
# 5                          True         False            False
# 15                        False          True            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 13                         True         False             True
# 14                         True         False            False
# 4                          True         False             True
# 22                         True         False             True
#
# 26                 0.012229                0.021621              0.048246
# 3                  0.002160                0.002160              0.002160
# 9                  0.001222                0.002077              0.002444
# 42                 0.001521                0.001926              0.004878
# 39                 0.001823                0.001907              0.007050
# 36                 0.001270                0.001516              0.002662
# 5                  0.001165                0.001165              0.001240
# 15                 0.000423                0.000826              0.001249
# 21                 0.000705                0.000705              0.000705
# 23                 0.000643                0.000643              0.000643
# 12                 0.000040                0.000040              0.000040
# 13                 0.000000                0.000000              0.000000
# 14                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
#
#     percentage_of_room_filled  fourier_minus_advanced
# 37                  63.410338                0.014686
# 10                  60.870864                0.016881
# 43                  49.322156                0.012352
# 40                  41.880608                0.004046
# 31                  29.800011                0.026434
# 34                  29.661656                0.013253
# 1                   32.455075                0.006442
# 32                  36.538765                0.041888
# 35                  43.078097                0.042524
# 28                  31.141413                0.006088
# 2                   52.088180                0.038747
# 29                  51.564806                0.039172
# 30                  54.942423                0.046655
# 33                  67.177920                0.051483
# 16                  61.351650                0.008888
# 0                   88.941403                0.052393
# 27                  88.690070                0.054268
# 19                  37.428390                0.006331
# 52                  33.474711                0.011781
# 49                  29.704088                0.016425
# 46                  32.284979                0.005282
# 44                  48.415992                0.005083
# 38                  55.016246                0.007062
# 11                  54.297462                0.008502
# 41                  41.808548                0.002343
# 53                  42.180668                0.019486
# 20                  47.242226                0.019635
# 50                  36.536495                0.016956
# 8                   51.611826                0.018836
# 47                  45.441603                0.019280
# 45                  88.910936                0.026261
# 6                   87.738681                0.026290
# 18                  88.616283                0.026998
# 51                  67.743457                0.024309
# 48                  53.419324                0.020014
# 7                   30.140884                0.003176
# 25                  34.310262                0.003009
# 17                  56.086944                0.004578
# 24                  89.457697                0.013327
# 26                  44.813980                0.009392
# 3                  100.000000                0.000000
# 9                   85.011598                0.000855
# 42                  39.479117                0.000405
# 39                  27.055825                0.000084
# 36                  56.945998                0.000245
# 5                   94.001339                0.000000
# 15                  66.135170                0.000403
# 21                 100.000000                0.000000
# 23                 100.000000                0.000000
# 12                 100.000000                0.000000
# 13                        NaN                0.000000
# 14                        NaN                0.000000
# 4                         NaN                0.000000
# 22                        NaN                0.000000

# %%
df[(df["exclude_webp"] == False) & (df["exclude_nonwebp"] == True)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 37                        False                     False
# 10                        False                      True
# 43                        False                     False
# 40                        False                     False
# 31                        False                     False
# 34                        False                     False
# 1                         False                      True
# 28                        False                     False
# 16                        False                      True
# 19                        False                      True
# 52                        False                     False
# 49                        False                     False
# 46                        False                     False
# 7                         False                      True
# 25                        False                      True
# 13                        False                      True
# 4                         False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 37                 False                  True                      True
# 10                 False                  True                      True
# 43                 False                  True                     False
# 40                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 1                   True                 False                      True
# 28                  True                 False                      True
# 16                 False                  True                     False
# 19                 False                 False                      True
# 52                 False                 False                     False
# 49                 False                 False                     False
# 46                 False                 False                      True
# 7                   True                 False                     False
# 25                 False                 False                     False
# 13                 False                  True                     False
# 4                   True                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 37                        False         False             True
# 10                        False         False             True
# 43                        False         False             True
# 40                         True         False             True
# 31                         True         False             True
# 34                        False         False             True
# 1                         False         False             True
# 28                        False         False             True
# 16                        False         False             True
# 19                        False         False             True
# 52                        False         False             True
# 49                         True         False             True
# 46                        False         False             True
# 7                         False         False             True
# 25                        False         False             True
# 13                         True         False             True
# 4                          True         False             True
# 22                         True         False             True
#
#     baseline-f1_score  advanced-f1_score  fourier-f1_score  n_encrypted  \
# 37           0.690682           0.872136          0.886821        31625
# 10           0.703183           0.866977          0.883858        31625
# 43           0.656482           0.813560          0.825912        63250
# 40           0.617365           0.773569          0.777615        31625
# 31           0.545348           0.654401          0.680834        31625
# 34           0.623332           0.721805          0.735058        63250
# 1            0.676500           0.775050          0.781492        31625
# 28           0.684000           0.776319          0.782407        31625
# 16           0.857143           0.935900          0.944788        63250
# 19           0.791431           0.863164          0.869495        63250
# 52           0.780966           0.842506          0.854287       126500
# 49           0.764474           0.818010          0.834435        63250
# 46           0.797826           0.857816          0.863098        63250
# 7            0.860662           0.899484          0.902660        63250
# 25           0.901139           0.932050          0.935059       126500
# 13           1.000000           1.000000          1.000000        31625
# 4            1.000000           1.000000          1.000000        31625
# 22           1.000000           1.000000          1.000000        63250
#
#     n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 37           126500                      0.25       0.886821
# 10            63250                      0.50       0.883858
# 43           126500                      0.50       0.825912
# 40           126500                      0.25       0.777615
# 31           126500                      0.25       0.680834
# 34           126500                      0.50       0.735058
# 1             63250                      0.50       0.781492
# 28           126500                      0.25       0.782407
# 16            63250                      1.00       0.944788
# 19            63250                      1.00       0.869495
# 52           126500                      1.00       0.854287
# 49           126500                      0.50       0.834435
# 46           126500                      0.50       0.863098
# 7             63250                      1.00       0.902660
# 25            63250                      2.00       0.935059
# 13            63250                      0.50       1.000000
# 4             63250                      0.50       1.000000
# 22            63250                      1.00       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 37                 0.181454                0.196140              0.309318
# 10                 0.163794                0.180675              0.296817
# 43                 0.157079                0.169431              0.343518
# 40                 0.156204                0.160250              0.382635
# 31                 0.109053                0.135486              0.454652
# 34                 0.098473                0.111726              0.376668
# 1                  0.098550                0.104992              0.323500
# 28                 0.092318                0.098407              0.316000
# 16                 0.078758                0.087645              0.142857
# 19                 0.071733                0.078064              0.208569
# 52                 0.061540                0.073321              0.219034
# 49                 0.053535                0.069961              0.235526
# 46                 0.059990                0.065272              0.202174
# 7                  0.038822                0.041998              0.139338
# 25                 0.030911                0.033919              0.098861
# 13                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
#
#     percentage_of_room_filled  fourier_minus_advanced
# 37                  63.410338                0.014686
# 10                  60.870864                0.016881
# 43                  49.322156                0.012352
# 40                  41.880608                0.004046
# 31                  29.800011                0.026434
# 34                  29.661656                0.013253
# 1                   32.455075                0.006442
# 28                  31.141413                0.006088
# 16                  61.351650                0.008888
# 19                  37.428390                0.006331
# 52                  33.474711                0.011781
# 49                  29.704088                0.016425
# 46                  32.284979                0.005282
# 7                   30.140884                0.003176
# 25                  34.310262                0.003009
# 13                        NaN                0.000000
# 4                         NaN                0.000000
# 22                        NaN                0.000000

# %%
df[(df["exclude_webp"] == True) & (df["exclude_nonwebp"] == False)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 30                        False                     False
# 33                        False                     False
# 0                         False                      True
# 27                        False                     False
# 45                        False                     False
# 6                         False                      True
# 18                        False                      True
# 51                        False                     False
# 48                        False                     False
# 24                        False                      True
# 3                         False                      True
# 9                         False                      True
# 42                        False                     False
# 39                        False                     False
# 36                        False                     False
# 15                        False                      True
# 21                        False                      True
# 12                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 30                  True                 False                     False
# 33                  True                 False                     False
# 0                   True                 False                      True
# 27                  True                 False                      True
# 45                 False                 False                      True
# 6                   True                 False                     False
# 18                 False                 False                      True
# 51                 False                 False                     False
# 48                 False                 False                     False
# 24                 False                 False                     False
# 3                   True                 False                     False
# 9                  False                  True                      True
# 42                 False                  True                     False
# 39                 False                  True                     False
# 36                 False                  True                      True
# 15                 False                  True                     False
# 21                 False                 False                     False
# 12                 False                  True                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 30                         True          True            False
# 33                        False          True            False
# 0                         False          True            False
# 27                        False          True            False
# 45                        False          True            False
# 6                         False          True            False
# 18                        False          True            False
# 51                        False          True            False
# 48                         True          True            False
# 24                        False          True            False
# 3                          True          True            False
# 9                         False          True            False
# 42                        False          True            False
# 39                         True          True            False
# 36                        False          True            False
# 15                        False          True            False
# 21                         True          True            False
# 12                         True          True            False
#
#     baseline-f1_score  advanced-f1_score  fourier-f1_score  n_encrypted  \
# 30           0.828541           0.876089          0.922745        49228
# 33           0.866051           0.904552          0.956035        98456
# 0            0.903011           0.936882          0.989274        49228
# 27           0.904989           0.934987          0.989254        49228
# 45           0.950829           0.968286          0.994547        98456
# 6            0.950388           0.967627          0.993917        98456
# 18           0.951220           0.967449          0.994447        98456
# 51           0.936347           0.955159          0.979468       196912
# 48           0.920717           0.943055          0.963069        98456
# 24           0.975411           0.984081          0.997408       196912
# 3            0.997840           1.000000          1.000000        49228
# 9            0.997556           0.998779          0.999634        49228
# 42           0.995122           0.996643          0.997048        98456
# 39           0.992950           0.994774          0.994858        49228
# 36           0.997338           0.998608          0.998854        49228
# 15           0.998751           0.999174          0.999577        98456
# 21           0.999295           1.000000          1.000000        98456
# 12           0.999960           1.000000          1.000000        49228
#
#     n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 30           196912                      0.25       0.922745
# 33           196912                      0.50       0.956035
# 0             98456                      0.50       0.989274
# 27           196912                      0.25       0.989254
# 45           196912                      0.50       0.994547
# 6             98456                      1.00       0.993917
# 18            98456                      1.00       0.994447
# 51           196912                      1.00       0.979468
# 48           196912                      0.50       0.963069
# 24            98456                      2.00       0.997408
# 3             98456                      0.50       1.000000
# 9             98456                      0.50       0.999634
# 42           196912                      0.50       0.997048
# 39           196912                      0.25       0.994858
# 36           196912                      0.25       0.998854
# 15            98456                      1.00       0.999577
# 21            98456                      1.00       1.000000
# 12            98456                      0.50       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 30                 0.047549                0.094204              0.171459
# 33                 0.038501                0.089984              0.133949
# 0                  0.033871                0.086263              0.096989
# 27                 0.029998                0.084265              0.095011
# 45                 0.017457                0.043719              0.049171
# 6                  0.017239                0.043529              0.049612
# 18                 0.016229                0.043227              0.048780
# 51                 0.018812                0.043120              0.063653
# 48                 0.022339                0.042353              0.079283
# 24                 0.008670                0.021997              0.024589
# 3                  0.002160                0.002160              0.002160
# 9                  0.001222                0.002077              0.002444
# 42                 0.001521                0.001926              0.004878
# 39                 0.001823                0.001907              0.007050
# 36                 0.001270                0.001516              0.002662
# 15                 0.000423                0.000826              0.001249
# 21                 0.000705                0.000705              0.000705
# 12                 0.000040                0.000040              0.000040
#
#     percentage_of_room_filled  fourier_minus_advanced
# 30                  54.942423                0.046655
# 33                  67.177920                0.051483
# 0                   88.941403                0.052393
# 27                  88.690070                0.054268
# 45                  88.910936                0.026261
# 6                   87.738681                0.026290
# 18                  88.616283                0.026998
# 51                  67.743457                0.024309
# 48                  53.419324                0.020014
# 24                  89.457697                0.013327
# 3                  100.000000                0.000000
# 9                   85.011598                0.000855
# 42                  39.479117                0.000405
# 39                  27.055825                0.000084
# 36                  56.945998                0.000245
# 15                  66.135170                0.000403
# 21                 100.000000                0.000000
# 12                 100.000000                0.000000

# %%
df[df["ratio_encrypt_nonencrypt"] == 1.0]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 16                        False                      True
# 19                        False                      True
# 52                        False                     False
# 53                        False                     False
# 20                        False                      True
# 8                         False                      True
# 6                         False                      True
# 18                        False                      True
# 51                        False                     False
# 7                         False                      True
# 17                        False                      True
# 15                        False                      True
# 21                        False                      True
# 23                        False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 16                 False                  True                     False
# 19                 False                 False                      True
# 52                 False                 False                     False
# 53                 False                 False                     False
# 20                 False                 False                      True
# 8                   True                 False                     False
# 6                   True                 False                     False
# 18                 False                 False                      True
# 51                 False                 False                     False
# 7                   True                 False                     False
# 17                 False                  True                     False
# 15                 False                  True                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 16                        False         False             True
# 19                        False         False             True
# 52                        False         False             True
# 53                        False         False            False
# 20                        False         False            False
# 8                         False         False            False
# 6                         False          True            False
# 18                        False          True            False
# 51                        False          True            False
# 7                         False         False             True
# 17                        False         False            False
# 15                        False          True            False
# 21                         True          True            False
# 23                         True         False            False
# 22                         True         False             True
#
#     baseline-f1_score  advanced-f1_score  fourier-f1_score  n_encrypted  \
# 16           0.857143           0.935900          0.944788        63250
# 19           0.791431           0.863164          0.869495        63250
# 52           0.780966           0.842506          0.854287       126500
# 53           0.885429           0.914270          0.933756       323412
# 20           0.900294           0.927762          0.947397       161706
# 8            0.913086           0.939108          0.957944       161706
# 6            0.950388           0.967627          0.993917        98456
# 18           0.951220           0.967449          0.994447        98456
# 51           0.936347           0.955159          0.979468       196912
# 7            0.860662           0.899484          0.902660        63250
# 17           0.947338           0.972297          0.976875       161706
# 15           0.998751           0.999174          0.999577        98456
# 21           0.999295           1.000000          1.000000        98456
# 23           0.999357           1.000000          1.000000       161706
# 22           1.000000           1.000000          1.000000        63250
#
#     n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 16            63250                       1.0       0.944788
# 19            63250                       1.0       0.869495
# 52           126500                       1.0       0.854287
# 53           323412                       1.0       0.933756
# 20           161706                       1.0       0.947397
# 8            161706                       1.0       0.957944
# 6             98456                       1.0       0.993917
# 18            98456                       1.0       0.994447
# 51           196912                       1.0       0.979468
# 7             63250                       1.0       0.902660
# 17           161706                       1.0       0.976875
# 15            98456                       1.0       0.999577
# 21            98456                       1.0       1.000000
# 23           161706                       1.0       1.000000
# 22            63250                       1.0       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 16                 0.078758                0.087645              0.142857
# 19                 0.071733                0.078064              0.208569
# 52                 0.061540                0.073321              0.219034
# 53                 0.028841                0.048327              0.114571
# 20                 0.027468                0.047103              0.099706
# 8                  0.026022                0.044858              0.086914
# 6                  0.017239                0.043529              0.049612
# 18                 0.016229                0.043227              0.048780
# 51                 0.018812                0.043120              0.063653
# 7                  0.038822                0.041998              0.139338
# 17                 0.024959                0.029536              0.052662
# 15                 0.000423                0.000826              0.001249
# 21                 0.000705                0.000705              0.000705
# 23                 0.000643                0.000643              0.000643
# 22                 0.000000                0.000000              0.000000
#
#     percentage_of_room_filled  fourier_minus_advanced
# 16                  61.351650                0.008888
# 19                  37.428390                0.006331
# 52                  33.474711                0.011781
# 53                  42.180668                0.019486
# 20                  47.242226                0.019635
# 8                   51.611826                0.018836
# 6                   87.738681                0.026290
# 18                  88.616283                0.026998
# 51                  67.743457                0.024309
# 7                   30.140884                0.003176
# 17                  56.086944                0.004578
# 15                  66.135170                0.000403
# 21                 100.000000                0.000000
# 23                 100.000000                0.000000
# 22                        NaN                0.000000
