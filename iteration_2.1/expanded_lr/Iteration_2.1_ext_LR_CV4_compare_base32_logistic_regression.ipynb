# %% [markdown]
# Few key observations
# - If both and non-encrypted files are base-32 encoded, accuracy drops really low.
#    * Even in this case, fourier analysis (specifically autocorrelation and mean) provide good discrminators
#    * Renyi's entropy at alpha=infinity gives good discrimination
#    * Overall we see around 13% improvement in F1-score
# - Specifically for webpfiles
#    * We see that higher moments of around 14 gives a good discrimination
#    * Fourier analysis still gives benefits here
# - For webpfiles where both unencrypted and encrypted content are base32 encrypted
#    * Fourier analysis is still beneficial
# - For Non-webp files where plaintext is not base-32 encrypted
#    * Accuracy is decent with just the base parameters, but with fourier analysis, we can close to perfect detection

# %% [markdown]
# # Contents
# - ## [Implementation](#mplementation)
#  - ### [List of Files](#list-of-files)
#  - ### [Utility to call gc](#gc)
#  - ### [Selection of Columns](#select-columns)
#  - ### [Function to compare the three selections of columns for a given dataset](#compare-fn)
#  - ### [Load the datasets](#load-dataset)
#  - ### [Select the datasets](#dataset-selection)
#  - ### [Run all combinations of data](#dataset-selection)
# - ## [Results](#results)
#  - ### [Print the raw results](#raw-results)
#  - ### [Sort by the improvement when using Fourier transforms over baseline](#sorted-fourier)
#  - ### [Measure improvement when only webp files are used](#webp-only)
#  - ### [Measure improvement when webp files are not present](#no-webp)
#  - ### [Measure improvement for balanced datasets](#balanced-dataset)
#  - ### [Measure the improvement when all files are used](#full-dataset)
#  - ### [Focus on items where the base metrics performed well](#focus-greater-90)
#  - ### [Correlation of data set and performance]("corr-heatmap")
#  - ### [Average out all the metrics](#mean-fscores)

# %% [markdown]
# ## Implementation <a class="anchor" id="implementation">
#
# [top](#Contents)

# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats

from functools import lru_cache

import gc

import sklearn
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import StratifiedKFold

import matplotlib.pyplot as plt
import glob

import tqdm
from multiprocessing.pool import ThreadPool, Pool

plt.rcParams["figure.figsize"] = (20,20)

# %% [markdown]
# ### List of files <a class="anchor" id="list-of-files">
#
# [top](#Contents)

# %%
# !ls
# Out:
# Iteration_2.1_ext_LR_compare_base32_logistic_regression.ipynb
# expanded.plaintext.base32.csv.gz
# expanded.pyencrypted_v1.b32.csv.gz
# expanded.pyencrypted_v1.csv.gz
# expanded.pyencrypted_v2.base32.csv.gz
# expanded.pyencrypted_v2.csv.gz
# iteration_2.1_compare_base32_alternate_encryption_scheme.ipynb
# iteration_2.1_compare_base32_logistic_regression.ipynb
# plaintext.base32.combined.csv.gz
# plaintext.combined.csv.gz
# plaintext.expanded.csv.gz

# %% [markdown]
# ### Utility to call GC <a class="anchor" id="gc">
#
# [top](#Contents)

# %%
def call_gc():
    for i in range(3):
        for j in range(3):
            gc.collect(j)

# %% [markdown]
# ### Selection of columns <a class="anchor" id="select-columns">
#
# This function is used to select the columns.
# There are three different configurations:
#
#     1. Baseline - statistics like autocorrelation, shannon entropy, chi-square etc. are used
#
#     2. Advanced - More statistics like moments, Tsallis and Renyi entropy, higher moments etc.
#
#     3. Fourier - Some statistics of the Fourier Power Spectrum distribution
#
# [top](#Contents)

# %%
def get_columns(thisdf):
    baseline_columns = [c for c in thisdf.columns if c.startswith('baseline') and "head" not in c and "tail" not in c]
    baseline_columns = [c for c in baseline_columns if "filesize" not in c]
    baseline_columns = [c for c in baseline_columns if "begin" not in c and "end" not in c]

    advanced_columns = [c for c in thisdf.columns if "advanced" in c]
    advanced_columns = [c for c in advanced_columns if "begin" not in c and "end" not in c]
    advanced_columns = [c for c in advanced_columns if "head" not in c and "tail" not in c]
    advanced_columns = [c for c in advanced_columns if "start" not in c]
    advanced_columns_only = list(set(advanced_columns))
    advanced_columns = list(set(advanced_columns + baseline_columns))

    fourier_columns = [c for c in thisdf.columns if "fourier" in c and "value" not in c]
    fourier_columns = [c for c in fourier_columns if "1byte" in c]
    fourier_columns = [c for c in fourier_columns if "begin" not in c and "end" not in c]
    fourier_columns = [c for c in fourier_columns if "head" not in c and "tail" not in c]
    fourier_columns = [c for c in fourier_columns if "start" not in c]
    fourier_columns_only = list(set(fourier_columns))
    fourier_columns = list(set(advanced_columns + fourier_columns))
    
    baseline_and_advanced = list(set(baseline_columns + advanced_columns_only))
    baseline_and_fourier = list(set(baseline_columns + fourier_columns_only))
    advanced_and_fourier = list(set(advanced_columns_only + fourier_columns_only))
    
    return {\
        "baseline": baseline_columns,\
        "advanced-only": advanced_columns_only,\
        "fourier-only": fourier_columns_only,\
        "baseline-and-fourier": baseline_and_fourier,\
        "advanced-and-fourier": advanced_and_fourier,\
        "advanced": advanced_columns,\
        "fourier": fourier_columns,\
    }

# %% [markdown]
# ### Function to compare the three selections of columns for a given dataset <a class="anchor" id="compare-fn">
#
# For the three different sets of measurements described above, compare all the three sets for their f1 score
#
# [top](#Contents)

# %%
USE_ASYNC = False

def get_kfold_f1_score(name, collist, X, y):
    skf = StratifiedKFold(n_splits=4, random_state=42, shuffle=True)
    f1_scores = []
    X = X[collist].to_numpy()
    y = y.to_numpy()
    call_gc()
    for train_idx, test_idx in skf.split(X, y):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]
        lr = LogisticRegression(n_jobs=8, \
                                solver='saga', \
                                random_state=42, \
                                max_iter=1000, \
                                multi_class='ovr')
        estimators = [\
                      ('std,', MinMaxScaler()), \
                      ('LogisticRegression', lr)]
        pipeline = Pipeline(estimators)
        pipeline.fit(X_train, y_train)
        y_pred = pipeline.predict(X_test)
        f1 = f1_score(y_test, y_pred)
        f1_scores.append(f1)
    return name, float(np.mean(f1_scores))

def compare_feature_selections_async(X, y):
    columns_dict = get_columns(X)
    ret = dict()
    pool = Pool(3)
    async_results = list()
    for name, collist in columns_dict.items():
        result = pool.apply_async(\
                                  get_kfold_f1_score, \
                                  (name, collist, X, y))
    for result in async_results:
        name, f1 = result.get(timeout=None)
        ret[name] = f1
    return ret

def compare_feature_selections_sync(X, y):
    columns_dict = get_columns(X)
    ret = dict()
    for name, collist in columns_dict.items():
        name, f1 = get_kfold_f1_score(name, collist, X, y)
        ret[name] = f1
    return ret

def compare_feature_selections(X, y):
    if USE_ASYNC:
        return compare_feature_selections_async(X, y)
    else:
        return compare_feature_selections_sync(X, y)

def compare_feature_selections_wrapper(data):
    X = data[[c for c in data.columns if "is_encrypted" != c]]
    y = data["is_encrypted"]
    return compare_feature_selections(X, y)

# %% [markdown]
# ### Load the datasets <a class="anchor" id="load-dataset">
#
# We don't want to load the datasets again and again, so we load them once.
# The LRU cache ensures that the next time this is called, we don't load the datasets again.
#
# [top](#Contents)

# %%
@lru_cache
def load_datasets_once():
    """Load all datasets only once
    
    We want to load the datasets only once. Once loaded
    serve from cache
    """
    datasets = dict()
    for file in glob.glob("*.csv.gz"):
        df = pd.read_csv(file)
        df = df.sample(frac=1).reset_index(drop=True)
        df["is_encrypted"] = 1 if "encr" in file.lower() else 0
        datasets[file] = df
    return datasets

# %% [markdown]
# ### Select the datasets <a class="anchor" id="dataset-selection">
#
# Select the dataset, combine it, shuffle it and return
#
# We used several schemes:
# * Plaintext
#   - The base plaintext dataset of around 50k files
#   - Expanded dataset, where all files that were less than 1500 bytes were expanded by repeating the file
#   - Base32 encoding of
#    - original plaintext
#    - expanded plaintext
# * Encryption : We used two schemes for encruption
#   - v1 : AES 256 encryption of the full file, again two varieties were used
#     - Plain encryption
#     - Encryption followed by base32 encoding
#   - v2 : AES encryption of the file, the first and the last 128 bytes are not encrypted. Of the remaining file, every alternate 16 bytes are encrypted.
#     - Plain encryption
#     - encryption followed by base32 encoding
#
# We select combinations of the above datasets
#
# Furthermore, we add further combinations by including and excluding webp files, and including and excluding non-webp files.
#
# [top](#Contents)

# %%
def get_dataset(\
               exclude_plaintext_nonbase32=False,
               exclude_plaintext_base32=False,
               exclude_encrypted_v1=False,
               exclude_encrypted_v2=False,
               exclude_encrypted_base32=False,
               exclude_encrypted_nonbase32=False,
               exclude_webp=False,
               exclude_nonwebp=False):
    description = {k:v for k,v in locals().items() \
                   if "exclude" in k}
    
    files = glob.glob("*.csv.gz")
    
    
    if exclude_plaintext_nonbase32:
        files = [f for f in files if \
                     "plaintext" not in f \
                     or "_base32" in f \
                     or "_b32" in f]
    if exclude_plaintext_base32:
        files = [f for f in files if\
                    "plaintext" not in f or \
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_v1:
        files = [f for f in files if\
                    "_v1" not in f or "encr" not in f]
    if exclude_encrypted_v2:
        files = [f for f in files if \
                    "_v2" not in f or "encr" not in f]
    if exclude_encrypted_base32:
        files = [ f for f in files if\
                    "encr" not in f or\
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_nonbase32:
        files = [f for f in files if \
                    "encr" not in f or \
                    "base32" in f or "b32" in f]
        
        
    encrypted_count = len([f for f in files if "encr" in f])
    non_encrypted_count = len([f for f in files if "encr" not in f])
    
    if 0 == encrypted_count or 0 == non_encrypted_count or 0 == len(files):
        return description, None, -1, -1
    
    all_dfs = list()
    all_loaded_datasets = load_datasets_once()
    for filename in files:
        all_dfs.append(all_loaded_datasets[filename])
    
    combined_df = pd.concat(all_dfs)
    
    if exclude_webp:
        combined_df = combined_df[\
                        combined_df["extended.extension"] != ".webp"]
    if exclude_nonwebp:
        combined_df = combined_df[\
                        combined_df["extended.extension"] == ".webp"]
        
    if len(combined_df) == 0:
        return description, None, -1, -1
    
        
    encrypt_count = len(combined_df[combined_df["is_encrypted"] == 1])
    nonencrypted_count = len(combined_df[combined_df["is_encrypted"] == 0])

    
    if 0 == len(combined_df) or 0 == encrypt_count or 0 == nonencrypted_count:
        return description, None, -1, -1
    
    return description, combined_df, encrypt_count, nonencrypted_count

# %% [markdown]
# ### Run all combinations of data <a class="anchor" id="dataset-selection">
#
# For all combinations of the datasets, compare the three classes (basic, advanced, and Fourier)
#
# [top](#Contents)

# %%
all_results = []
list_of_arguments = []

# Get all 8-tuple combinations of T/F
list_of_arguments = [(True,), (False,)]
for i in range(7):
    temp = []
    for e in list_of_arguments:
        et = e + (True,)
        temp.append(et)
        et = e + (False,)
        temp.append(et)
    list_of_arguments = temp

                                
for a, b, c, k, e, f, g, h in tqdm.tqdm(list_of_arguments):
    desc, df, ec, nec = get_dataset(a, b, c, k, e, f, g, h)
    if df is not None:
        result = compare_feature_selections_wrapper(df)
        call_gc()
        result = {**desc, **result}
        result["n_encrypted"] = ec
        result["n_non_encrypted"] = nec
        result["ratio_encrypt_nonencrypt"] = float(ec) / nec
        all_results.append(result)


df_dict = {k:[] for k in all_results[0]}
for result in all_results:
    for k, v in result.items():
        df_dict[k].append(v)

df = pd.DataFrame(df_dict)
df["best_f1_score"] = \
    df[[c for c in df.columns if "f1_score" in c]].max(axis=1)

df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["improvement_in_fourier"] = \
    df["fourier-f1_score"] - df["baseline-f1_score"]
df = df.sort_values(by="improvement_in_fourier", ascending=False)
# Out:
# 100%|██████████████████████████████████████████████████| 256/256 [6:41:33<00:00, 94.11s/it]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'advanced-f1_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/z1/hfz3q2b52bx3hb8nh0z1q89c0000gp/T/ipykernel_12970/4246557319.py in <module>
#      49
#      50 df["improvement_in_advanced"] = \
# ---> 51     df["advanced-f1_score"] - df["baseline-f1_score"]
#      52 df["improvement_in_fourier"] = \
#      53     df["fourier-f1_score"] - df["baseline-f1_score"]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'advanced-f1_score'

# %%
df["baseline-f1_score"] = df["baseline"]
df["advanced-f1_score"] = df["advanced"]
df["fourier-f1_score"] = df["fourier"]
df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["improvement_in_fourier"] = \
    df["fourier-f1_score"] - df["baseline-f1_score"]
df["best_f1_score"] = \
    df[[c for c in df.columns if "f1_score" in c]].max(axis=1)
df = df.sort_values(by="improvement_in_fourier", ascending=False)

# %% [markdown]
# ## Results <a class="anchor" id="results">
#
# In this section, we present the results
#
# [top](#Contents)

# %% [markdown]
# ### Print the raw results <a class="anchor" id="raw-results">
#
# [top](#Contents)

# %%
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 39                        False                     False
# 41                        False                     False
# 35                        False                     False
# 10                        False                      True
# 0                         False                      True
# 27                        False                     False
# 2                         False                      True
# 29                        False                     False
# 37                        False                     False
# 30                        False                     False
# 33                        False                     False
# 42                        False                     False
# 43                        False                     False
# 31                        False                     False
# 34                        False                     False
# 6                         False                      True
# 8                         False                      True
# 44                        False                     False
# 18                        False                      True
# 45                        False                     False
# 49                        False                     False
# 28                        False                     False
# 1                         False                      True
# 40                        False                     False
# 19                        False                      True
# 24                        False                      True
# 46                        False                     False
# 32                        False                     False
# 52                        False                     False
# 16                        False                      True
# 51                        False                     False
# 36                        False                     False
# 9                         False                      True
# 20                        False                      True
# 47                        False                     False
# 26                        False                      True
# 25                        False                      True
# 48                        False                     False
# 7                         False                      True
# 15                        False                      True
# 53                        False                     False
# 11                        False                      True
# 38                        False                     False
# 50                        False                     False
# 17                        False                      True
# 3                         False                      True
# 5                         False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 13                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 39                 False                  True                     False
# 41                 False                  True                     False
# 35                  True                 False                     False
# 10                 False                  True                      True
# 0                   True                 False                      True
# 27                  True                 False                      True
# 2                   True                 False                      True
# 29                  True                 False                      True
# 37                 False                  True                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 42                 False                  True                     False
# 43                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 6                   True                 False                     False
# 8                   True                 False                     False
# 44                 False                  True                     False
# 18                 False                 False                      True
# 45                 False                 False                      True
# 49                 False                 False                     False
# 28                  True                 False                      True
# 1                   True                 False                      True
# 40                 False                  True                     False
# 19                 False                 False                      True
# 24                 False                 False                     False
# 46                 False                 False                      True
# 32                  True                 False                     False
# 52                 False                 False                     False
# 16                 False                  True                     False
# 51                 False                 False                     False
# 36                 False                  True                      True
# 9                  False                  True                      True
# 20                 False                 False                      True
# 47                 False                 False                      True
# 26                 False                 False                     False
# 25                 False                 False                     False
# 48                 False                 False                     False
# 7                   True                 False                     False
# 15                 False                  True                     False
# 53                 False                 False                     False
# 11                 False                  True                      True
# 38                 False                  True                      True
# 50                 False                 False                     False
# 17                 False                  True                     False
# 3                   True                 False                     False
# 5                   True                 False                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 13                 False                  True                     False
# 22                 False                 False                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  baseline  \
# 39                         True          True            False  0.004986
# 41                         True         False            False  0.005733
# 35                        False         False            False  0.000000
# 10                        False         False             True  0.159253
# 0                         False          True            False  0.465066
# 27                        False          True            False  0.466437
# 2                         False         False            False  0.315865
# 29                        False         False            False  0.316156
# 37                        False         False             True  0.149850
# 30                         True          True            False  0.000388
# 33                        False          True            False  0.267406
# 42                        False          True            False  0.589132
# 43                        False         False             True  0.067776
# 31                         True         False             True  0.041793
# 34                        False         False             True  0.158457
# 6                         False          True            False  0.682240
# 8                         False         False            False  0.636484
# 44                        False         False            False  0.498257
# 18                        False          True            False  0.774293
# 45                        False          True            False  0.775659
# 49                         True         False             True  0.413314
# 28                        False         False             True  0.367502
# 1                         False         False             True  0.375858
# 40                         True         False             True  0.025529
# 19                        False         False             True  0.534076
# 24                        False          True            False  0.836697
# 46                        False         False             True  0.530060
# 32                         True         False            False  0.000142
# 52                        False         False             True  0.511328
# 16                        False         False             True  0.693357
# 51                        False          True            False  0.736216
# 36                        False          True            False  0.887442
# 9                         False          True            False  0.887421
# 20                        False         False            False  0.727223
# 47                        False         False            False  0.727697
# 26                        False         False            False  0.816075
# 25                        False         False             True  0.750028
# 48                         True          True            False  0.695625
# 7                         False         False             True  0.729485
# 15                        False          True            False  0.941346
# 53                        False         False            False  0.683142
# 11                        False         False            False  0.711549
# 38                        False         False            False  0.711719
# 50                         True         False            False  0.647512
# 17                        False         False            False  0.843565
# 3                          True          True            False  0.977773
# 5                          True         False            False  0.986054
# 21                         True          True            False  0.988342
# 23                         True         False            False  0.992675
# 12                         True          True            False  0.997498
# 14                         True         False            False  0.998352
# 13                         True         False             True  1.000000
# 22                         True         False             True  1.000000
# 4                          True         False             True  1.000000
#
#     advanced-only  ...  ratio_encrypt_nonencrypt  best_f1_score  \
# 39       0.899184  ...                      0.25       0.921026
# 41       0.708283  ...                      0.25       0.759492
# 35       0.268882  ...                      0.50       0.475180
# 10       0.546936  ...                      0.50       0.624884
# 0        0.615602  ...                      0.50       0.905814
# 27       0.615797  ...                      0.25       0.906269
# 2        0.477978  ...                      0.50       0.727771
# 29       0.478416  ...                      0.25       0.727986
# 37       0.447415  ...                      0.25       0.552789
# 30       0.362602  ...                      0.25       0.398779
# 33       0.412205  ...                      0.50       0.645814
# 42       0.924303  ...                      0.50       0.924886
# 43       0.297353  ...                      0.50       0.376270
# 31       0.254694  ...                      0.25       0.340799
# 34       0.337342  ...                      0.50       0.438977
# 6        0.814105  ...                      1.00       0.948696
# 8        0.767752  ...                      1.00       0.865981
# 44       0.699055  ...                      0.50       0.713501
# 18       0.826792  ...                      1.00       0.949509
# 45       0.826792  ...                      0.50       0.949579
# 49       0.595299  ...                      0.50       0.599943
# 28       0.450004  ...                      0.25       0.539555
# 1        0.456372  ...                      0.50       0.545537
# 40       0.000000  ...                      0.25       0.192522
# 19       0.668837  ...                      1.00       0.675753
# 24       0.910652  ...                      2.00       0.972862
# 46       0.659790  ...                      0.50       0.665851
# 32       0.128177  ...                      0.25       0.133882
# 52       0.633194  ...                      1.00       0.635798
# 16       0.778437  ...                      1.00       0.806684
# 51       0.783547  ...                      1.00       0.840526
# 36       0.947095  ...                      0.25       0.980417
# 9        0.946993  ...                      0.50       0.980262
# 20       0.717719  ...                      1.00       0.811413
# 47       0.717660  ...                      0.50       0.811450
# 26       0.849328  ...                      2.00       0.897749
# 25       0.830373  ...                      2.00       0.834103
# 48       0.779529  ...                      0.50       0.779975
# 7        0.777189  ...                      1.00       0.801643
# 48               -0.007394                  25.283184
# 7                 0.020851                  26.674395
# 15                0.015681                  83.108127
# 53                0.041035                  14.384798
# 11                0.025555                  15.638890
# 38                0.025531                  15.566301
# 50               -0.009061                   8.157390
# 17                0.013394                  17.759351
# 3                 0.001901                  94.156435
# 5                 0.001252                  94.017764
# 21                0.000947                  93.644188
# 23                0.000608                  93.543926
# 12                0.000355                  90.261618
# 14                0.000328                  90.623066
# 13                0.000000                        NaN
# 22                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [54 rows x 27 columns]

# %%
df.to_csv("../comparison.csv")

# %%
df = df.sort_values(by="improvement_in_fourier", ascending=False)

# %% [markdown]
# ### Sort by the improvement when using Fourier transforms over baseline <a class="anchor" id="sorted-fourier">
#
# We also take a few other things:
# * Room for improvement (1 - baseline score)
# * How much of the room for improvement was filled by fourier transforms (percentage)
# * Difference between F1 score with advanced and fourier
#
# [top](#Contents)

# %%
df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["room_for_improvement"] = \
    1.0 - df["baseline-f1_score"]
df["fourier_minus_advanced"] = \
    df["fourier-f1_score"] - df["advanced-f1_score"]
df["percentage_of_room_filled"] = \
    df["improvement_in_fourier"] * 100.0 / df["room_for_improvement"]
#df.sort_values(by="fourier_minus_advanced", ascending=False)
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 39                        False                     False
# 41                        False                     False
# 35                        False                     False
# 10                        False                      True
# 0                         False                      True
# 27                        False                     False
# 2                         False                      True
# 29                        False                     False
# 37                        False                     False
# 30                        False                     False
# 33                        False                     False
# 42                        False                     False
# 43                        False                     False
# 31                        False                     False
# 34                        False                     False
# 6                         False                      True
# 8                         False                      True
# 44                        False                     False
# 18                        False                      True
# 45                        False                     False
# 49                        False                     False
# 28                        False                     False
# 1                         False                      True
# 40                        False                     False
# 19                        False                      True
# 24                        False                      True
# 46                        False                     False
# 32                        False                     False
# 52                        False                     False
# 16                        False                      True
# 51                        False                     False
# 36                        False                     False
# 9                         False                      True
# 20                        False                      True
# 47                        False                     False
# 26                        False                      True
# 25                        False                      True
# 48                        False                     False
# 7                         False                      True
# 15                        False                      True
# 53                        False                     False
# 11                        False                      True
# 38                        False                     False
# 50                        False                     False
# 17                        False                      True
# 3                         False                      True
# 5                         False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 13                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 39                 False                  True                     False
# 41                 False                  True                     False
# 35                  True                 False                     False
# 10                 False                  True                      True
# 0                   True                 False                      True
# 27                  True                 False                      True
# 2                   True                 False                      True
# 29                  True                 False                      True
# 37                 False                  True                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 42                 False                  True                     False
# 43                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 6                   True                 False                     False
# 8                   True                 False                     False
# 44                 False                  True                     False
# 18                 False                 False                      True
# 45                 False                 False                      True
# 49                 False                 False                     False
# 28                  True                 False                      True
# 1                   True                 False                      True
# 40                 False                  True                     False
# 19                 False                 False                      True
# 24                 False                 False                     False
# 46                 False                 False                      True
# 32                  True                 False                     False
# 52                 False                 False                     False
# 16                 False                  True                     False
# 51                 False                 False                     False
# 36                 False                  True                      True
# 9                  False                  True                      True
# 20                 False                 False                      True
# 47                 False                 False                      True
# 26                 False                 False                     False
# 25                 False                 False                     False
# 48                 False                 False                     False
# 7                   True                 False                     False
# 15                 False                  True                     False
# 53                 False                 False                     False
# 11                 False                  True                      True
# 38                 False                  True                      True
# 50                 False                 False                     False
# 17                 False                  True                     False
# 3                   True                 False                     False
# 5                   True                 False                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 13                 False                  True                     False
# 22                 False                 False                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  baseline  \
# 39                         True          True            False  0.004986
# 41                         True         False            False  0.005733
# 35                        False         False            False  0.000000
# 10                        False         False             True  0.159253
# 0                         False          True            False  0.465066
# 27                        False          True            False  0.466437
# 2                         False         False            False  0.315865
# 29                        False         False            False  0.316156
# 37                        False         False             True  0.149850
# 30                         True          True            False  0.000388
# 33                        False          True            False  0.267406
# 42                        False          True            False  0.589132
# 43                        False         False             True  0.067776
# 31                         True         False             True  0.041793
# 34                        False         False             True  0.158457
# 6                         False          True            False  0.682240
# 8                         False         False            False  0.636484
# 44                        False         False            False  0.498257
# 18                        False          True            False  0.774293
# 45                        False          True            False  0.775659
# 49                         True         False             True  0.413314
# 28                        False         False             True  0.367502
# 1                         False         False             True  0.375858
# 40                         True         False             True  0.025529
# 19                        False         False             True  0.534076
# 24                        False          True            False  0.836697
# 46                        False         False             True  0.530060
# 32                         True         False            False  0.000142
# 52                        False         False             True  0.511328
# 16                        False         False             True  0.693357
# 51                        False          True            False  0.736216
# 36                        False          True            False  0.887442
# 9                         False          True            False  0.887421
# 20                        False         False            False  0.727223
# 47                        False         False            False  0.727697
# 26                        False         False            False  0.816075
# 25                        False         False             True  0.750028
# 48                         True          True            False  0.695625
# 7                         False         False             True  0.729485
# 15                        False          True            False  0.941346
# 53                        False         False            False  0.683142
# 11                        False         False            False  0.711549
# 38                        False         False            False  0.711719
# 50                         True         False            False  0.647512
# 17                        False         False            False  0.843565
# 3                          True          True            False  0.977773
# 5                          True         False            False  0.986054
# 21                         True          True            False  0.988342
# 23                         True         False            False  0.992675
# 12                         True          True            False  0.997498
# 14                         True         False            False  0.998352
# 13                         True         False             True  1.000000
# 22                         True         False             True  1.000000
# 4                          True         False             True  1.000000
#
#     advanced-only  ...  ratio_encrypt_nonencrypt  best_f1_score  \
# 39       0.899184  ...                      0.25       0.921026
# 41       0.708283  ...                      0.25       0.759492
# 35       0.268882  ...                      0.50       0.475180
# 10       0.546936  ...                      0.50       0.624884
# 0        0.615602  ...                      0.50       0.905814
# 27       0.615797  ...                      0.25       0.906269
# 2        0.477978  ...                      0.50       0.727771
# 23                 0.006244                0.006852              0.007325
# 12                 0.001904                0.002259              0.002502
# 14                 0.001166                0.001494              0.001648
# 13                 0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 39                0.022012                  92.063060
# 41                0.048907                  75.810504
# 35                0.193044                  47.517959
# 10                0.022776                  55.383006
# 0                 0.299960                  82.392956
# 27                0.300286                  82.432978
# 2                 0.229777                  60.208254
# 29                0.230164                  60.222838
# 37                0.015603                  47.396245
# 30                0.017757                  39.854530
# 33                0.215076                  51.653202
# 42               -0.005006                  80.499794
# 43                0.018123                  33.092314
# 31                0.078401                  31.204668
# 34                0.088811                  33.333950
# 6                 0.135264                  83.854372
# 8                 0.091990                  63.132665
# 44                0.005450                  42.899346
# 18                0.125833                  77.629899
# 45                0.125830                  77.524649
# 49               -0.013284                  29.546444
# 28                0.070252                  27.202202
# 1                 0.069122                  27.185913
# 40                0.191132                  17.136773
# 19                0.002669                  30.407878
# 24                0.063016                  83.381681
# 46               -0.005506                  27.723805
# 32               -0.009356                  12.440139
# 52               -0.010788                  23.263433
# 16                0.001812                  36.957376
# 51                0.056014                  39.543676
# 36                0.029108                  82.601540
# 9                 0.029003                  82.467412
# 20                0.087015                  30.864154
# 47                0.087165                  30.757299
# 26                0.043714                  44.405872
# 25               -0.002440                  32.657818
# 48               -0.007394                  25.283184
# 7                 0.020851                  26.674395
# 15                0.015681                  83.108127
# 53                0.041035                  14.384798
# 11                0.025555                  15.638890
# 38                0.025531                  15.566301
# 50               -0.009061                   8.157390
# 17                0.013394                  17.759351
# 3                 0.001901                  94.156435
# 5                 0.001252                  94.017764
# 21                0.000947                  93.644188
# 23                0.000608                  93.543926
# 12                0.000355                  90.261618
# 14                0.000328                  90.623066
# 13                0.000000                        NaN
# 22                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [54 rows x 27 columns]

# %% [markdown]
# ### Measure improvement when only webp files are used <a class="anchor" id="webp-only">
#
# We want to measure this alone because in the literature, poor performance in webp files has been mentioned
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == False) & \
   (df["exclude_nonwebp"] == True)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 10                        False                      True
# 37                        False                     False
# 43                        False                     False
# 31                        False                     False
# 34                        False                     False
# 49                        False                     False
# 28                        False                     False
# 1                         False                      True
# 40                        False                     False
# 19                        False                      True
# 46                        False                     False
# 52                        False                     False
# 16                        False                      True
# 25                        False                      True
# 7                         False                      True
# 13                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 10                 False                  True                      True
# 37                 False                  True                      True
# 43                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 49                 False                 False                     False
# 28                  True                 False                      True
# 1                   True                 False                      True
# 40                 False                  True                     False
# 19                 False                 False                      True
# 46                 False                 False                      True
# 52                 False                 False                     False
# 16                 False                  True                     False
# 25                 False                 False                     False
# 7                   True                 False                     False
# 13                 False                  True                     False
# 22                 False                 False                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  baseline  \
# 10                        False         False             True  0.159253
# 37                        False         False             True  0.149850
# 43                        False         False             True  0.067776
# 31                         True         False             True  0.041793
# 34                        False         False             True  0.158457
# 49                         True         False             True  0.413314
# 28                        False         False             True  0.367502
# 1                         False         False             True  0.375858
# 40                         True         False             True  0.025529
# 19                        False         False             True  0.534076
# 46                        False         False             True  0.530060
# 52                        False         False             True  0.511328
# 16                        False         False             True  0.693357
# 25                        False         False             True  0.750028
# 7                         False         False             True  0.729485
# 13                         True         False             True  1.000000
# 22                         True         False             True  1.000000
# 4                          True         False             True  1.000000
#
#     advanced-only  ...  ratio_encrypt_nonencrypt  best_f1_score  \
# 10       0.546936  ...                      0.50       0.624884
# 37       0.447415  ...                      0.25       0.552789
# 43       0.297353  ...                      0.50       0.376270
# 31       0.254694  ...                      0.25       0.340799
# 34       0.337342  ...                      0.50       0.438977
# 49       0.595299  ...                      0.50       0.599943
# 28       0.450004  ...                      0.25       0.539555
# 1        0.456372  ...                      0.50       0.545537
# 40       0.000000  ...                      0.25       0.192522
# 19       0.668837  ...                      1.00       0.675753
# 46       0.659790  ...                      0.50       0.665851
# 52       0.633194  ...                      1.00       0.635798
# 16       0.778437  ...                      1.00       0.806684
# 25       0.830373  ...                      2.00       0.834103
# 7        0.777189  ...                      1.00       0.801643
# 13       1.000000  ...                      0.50       1.000000
# 22       1.000000  ...                      1.00       1.000000
# 4        1.000000  ...                      0.50       1.000000
#
#     advanced-f1_score  fourier-f1_score  baseline-f1_score  \
# 10           0.602108          0.624884           0.159253
# 37           0.537186          0.552789           0.149850
# 43           0.358147          0.376270           0.067776
# 31           0.262397          0.340799           0.041793
# 34           0.350165          0.438977           0.158457
# 49           0.599943          0.586659           0.413314
# 28           0.469303          0.539555           0.367502
# 1            0.476414          0.545537           0.375858
# 40           0.001390          0.192522           0.025529
# 19           0.673085          0.675753           0.534076
# 46           0.665851          0.660345           0.530060
# 52           0.635798          0.625010           0.511328
# 16           0.804872          0.806684           0.693357
# 25           0.834103          0.831663           0.750028
# 7            0.780791          0.801643           0.729485
# 13           1.000000          1.000000           1.000000
# 22           1.000000          1.000000           1.000000
# 4            1.000000          1.000000           1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 10                 0.442855                0.465631              0.840747
# 37                 0.387336                0.402939              0.850150
# 43                 0.290371                0.308495              0.932224
# 31                 0.220604                0.299005              0.958207
# 34                 0.191708                0.280520              0.841543
# 49                 0.186629                0.173345              0.586686
# 28                 0.101801                0.172053              0.632498
# 1                  0.100556                0.169679              0.624142
# 40                -0.024139                0.166993              0.974471
# 19                 0.139009                0.141678              0.465924
# 46                 0.135791                0.130285              0.469940
# 52                 0.124470                0.113682              0.488672
# 16                 0.111515                0.113327              0.306643
# 25                 0.084075                0.081635              0.249972
# 7                  0.051307                0.072158              0.270515
# 13                 0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 10                0.022776                  55.383006
# 37                0.015603                  47.396245
# 43                0.018123                  33.092314
# 31                0.078401                  31.204668
# 34                0.088811                  33.333950
# 49               -0.013284                  29.546444
# 28                0.070252                  27.202202
# 1                 0.069122                  27.185913
# 40                0.191132                  17.136773
# 19                0.002669                  30.407878
# 46               -0.005506                  27.723805
# 52               -0.010788                  23.263433
# 16                0.001812                  36.957376
# 25               -0.002440                  32.657818
# 7                 0.020851                  26.674395
# 13                0.000000                        NaN
# 22                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [18 rows x 27 columns]

# %% [markdown]
# ### Measure improvement when webp files are not present <a class="anchor" id="no-webp">
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == True) & \
   (df["exclude_nonwebp"] == False)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 39                        False                     False
# 0                         False                      True
# 27                        False                     False
# 30                        False                     False
# 33                        False                     False
# 42                        False                     False
# 6                         False                      True
# 18                        False                      True
# 45                        False                     False
# 24                        False                      True
# 51                        False                     False
# 36                        False                     False
# 9                         False                      True
# 48                        False                     False
# 15                        False                      True
# 3                         False                      True
# 21                        False                      True
# 12                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 39                 False                  True                     False
# 0                   True                 False                      True
# 27                  True                 False                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 42                 False                  True                     False
# 6                   True                 False                     False
# 18                 False                 False                      True
# 45                 False                 False                      True
# 24                 False                 False                     False
# 51                 False                 False                     False
# 36                 False                  True                      True
# 9                  False                  True                      True
# 48                 False                 False                     False
# 15                 False                  True                     False
# 3                   True                 False                     False
# 21                 False                 False                     False
# 12                 False                  True                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  baseline  \
# 39                         True          True            False  0.004986
# 0                         False          True            False  0.465066
# 27                        False          True            False  0.466437
# 30                         True          True            False  0.000388
# 33                        False          True            False  0.267406
# 42                        False          True            False  0.589132
# 6                         False          True            False  0.682240
# 18                        False          True            False  0.774293
# 45                        False          True            False  0.775659
# 24                        False          True            False  0.836697
# 51                        False          True            False  0.736216
# 36                        False          True            False  0.887442
# 9                         False          True            False  0.887421
# 48                         True          True            False  0.695625
# 15                        False          True            False  0.941346
# 3                          True          True            False  0.977773
# 21                         True          True            False  0.988342
# 12                         True          True            False  0.997498
#
#     advanced-only  ...  ratio_encrypt_nonencrypt  best_f1_score  \
# 39       0.899184  ...                      0.25       0.921026
# 0        0.615602  ...                      0.50       0.905814
# 27       0.615797  ...                      0.25       0.906269
# 30       0.362602  ...                      0.25       0.398779
# 33       0.412205  ...                      0.50       0.645814
# 42       0.924303  ...                      0.50       0.924886
# 6        0.814105  ...                      1.00       0.948696
# 18       0.826792  ...                      1.00       0.949509
# 45       0.826792  ...                      0.50       0.949579
# 24       0.910652  ...                      2.00       0.972862
# 51       0.783547  ...                      1.00       0.840526
# 36       0.947095  ...                      0.25       0.980417
# 9        0.946993  ...                      0.50       0.980262
# 48       0.779529  ...                      0.50       0.779975
# 15       0.971432  ...                      1.00       0.990092
# 3        0.995832  ...                      0.50       0.998701
# 21       0.997634  ...                      1.00       0.999259
# 12       0.997801  ...                      0.50       0.999756
#
#     advanced-f1_score  fourier-f1_score  baseline-f1_score  \
# 39           0.899014          0.921026           0.004986
# 0            0.605854          0.905814           0.465066
# 27           0.605983          0.906269           0.466437
# 30           0.381022          0.398779           0.000388
# 33           0.430739          0.645814           0.267406
# 42           0.924886          0.919880           0.589132
# 6            0.813431          0.948696           0.682240
# 18           0.823676          0.949509           0.774293
# 45           0.823748          0.949579           0.775659
# 24           0.909845          0.972862           0.836697
# 51           0.784511          0.840526           0.736216
# 36           0.951309          0.980417           0.887442
# 9            0.951259          0.980262           0.887421
# 48           0.779975          0.772581           0.695625
# 15           0.974411          0.990092           0.941346
# 3            0.996800          0.998701           0.977773
# 21           0.998312          0.999259           0.988342
# 12           0.999401          0.999756           0.997498
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 39                 0.894029                0.916041              0.995014
# 0                  0.140788                0.440748              0.534934
# 27                 0.139546                0.439832              0.533563
# 30                 0.380634                0.398391              0.999612
# 33                 0.163332                0.378408              0.732594
# 42                 0.335754                0.330748              0.410868
# 6                  0.131191                0.266456              0.317760
# 18                 0.049383                0.175216              0.225707
# 45                 0.048089                0.173920              0.224341
# 24                 0.073148                0.136165              0.163303
# 51                 0.048296                0.104310              0.263784
# 36                 0.063867                0.092975              0.112558
# 9                  0.063838                0.092841              0.112579
# 48                 0.084350                0.076956              0.304375
# 15                 0.033066                0.048747              0.058654
# 3                  0.019027                0.020928              0.022227
# 21                 0.009970                0.010917              0.011658
# 12                 0.001904                0.002259              0.002502
#
#     fourier_minus_advanced  percentage_of_room_filled
# 39                0.022012                  92.063060
# 0                 0.299960                  82.392956
# 27                0.300286                  82.432978
# 30                0.017757                  39.854530
# 33                0.215076                  51.653202
# 42               -0.005006                  80.499794
# 6                 0.135264                  83.854372
# 18                0.125833                  77.629899
# 45                0.125830                  77.524649
# 24                0.063016                  83.381681
# 51                0.056014                  39.543676
# 36                0.029108                  82.601540
# 9                 0.029003                  82.467412
# 48               -0.007394                  25.283184
# 15                0.015681                  83.108127
# 3                 0.001901                  94.156435
# 21                0.000947                  93.644188
# 12                0.000355                  90.261618
#
# [18 rows x 27 columns]

# %% [markdown]
# ### Measure improvement for balanced datasets <a class="anchor" id="balanced-dataset">
#
# Most of our dataset selections are not balanced, and we didn't do anything to mitigate
# unablanced datasets. This is because we are measuring the baseline and improvement on the
# same dataset.
#
# However, we will select those instances where the datasets were balanced to see if the
# improvement is still significant in these instances.
#
# [top](#Contents)

# %%
df[df["ratio_encrypt_nonencrypt"] == 1.0]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 6                         False                      True
# 8                         False                      True
# 18                        False                      True
# 19                        False                      True
# 52                        False                     False
# 16                        False                      True
# 51                        False                     False
# 20                        False                      True
# 7                         False                      True
# 15                        False                      True
# 53                        False                     False
# 17                        False                      True
# 21                        False                      True
# 23                        False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 6                   True                 False                     False
# 8                   True                 False                     False
# 18                 False                 False                      True
# 19                 False                 False                      True
# 52                 False                 False                     False
# 16                 False                  True                     False
# 51                 False                 False                     False
# 20                 False                 False                      True
# 7                   True                 False                     False
# 15                 False                  True                     False
# 53                 False                 False                     False
# 17                 False                  True                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  baseline  \
# 6                         False          True            False  0.682240
# 8                         False         False            False  0.636484
# 18                        False          True            False  0.774293
# 19                        False         False             True  0.534076
# 52                        False         False             True  0.511328
# 16                        False         False             True  0.693357
# 51                        False          True            False  0.736216
# 20                        False         False            False  0.727223
# 7                         False         False             True  0.729485
# 15                        False          True            False  0.941346
# 53                        False         False            False  0.683142
# 17                        False         False            False  0.843565
# 21                         True          True            False  0.988342
# 23                         True         False            False  0.992675
# 22                         True         False             True  1.000000
#
#     advanced-only  ...  ratio_encrypt_nonencrypt  best_f1_score  \
# 6        0.814105  ...                       1.0       0.948696
# 8        0.767752  ...                       1.0       0.865981
# 18       0.826792  ...                       1.0       0.949509
# 19       0.668837  ...                       1.0       0.675753
# 52       0.633194  ...                       1.0       0.635798
# 16       0.778437  ...                       1.0       0.806684
# 51       0.783547  ...                       1.0       0.840526
# 20       0.717719  ...                       1.0       0.811413
# 7        0.777189  ...                       1.0       0.801643
# 15       0.971432  ...                       1.0       0.990092
# 53       0.685853  ...                       1.0       0.728721
# 17       0.848298  ...                       1.0       0.871346
# 21       0.997634  ...                       1.0       0.999259
# 23       0.998490  ...                       1.0       0.999527
# 22       1.000000  ...                       1.0       1.000000
#
#     advanced-f1_score  fourier-f1_score  baseline-f1_score  \
# 6            0.813431          0.948696           0.682240
# 8            0.773991          0.865981           0.636484
# 18           0.823676          0.949509           0.774293
# 19           0.673085          0.675753           0.534076
# 52           0.635798          0.625010           0.511328
# 16           0.804872          0.806684           0.693357
# 51           0.784511          0.840526           0.736216
# 20           0.724398          0.811413           0.727223
# 7            0.780791          0.801643           0.729485
# 15           0.974411          0.990092           0.941346
# 53           0.687686          0.728721           0.683142
# 17           0.857953          0.871346           0.843565
# 21           0.998312          0.999259           0.988342
# 23           0.998919          0.999527           0.992675
# 22           1.000000          1.000000           1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 6                  0.131191                0.266456              0.317760
# 8                  0.137508                0.229498              0.363516
# 18                 0.049383                0.175216              0.225707
# 19                 0.139009                0.141678              0.465924
# 52                 0.124470                0.113682              0.488672
# 16                 0.111515                0.113327              0.306643
# 51                 0.048296                0.104310              0.263784
# 20                -0.002825                0.084190              0.272777
# 7                  0.051307                0.072158              0.270515
# 15                 0.033066                0.048747              0.058654
# 53                 0.004544                0.045579              0.316858
# 17                 0.014388                0.027782              0.156435
# 21                 0.009970                0.010917              0.011658
# 23                 0.006244                0.006852              0.007325
# 22                 0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 6                 0.135264                  83.854372
# 8                 0.091990                  63.132665
# 18                0.125833                  77.629899
# 19                0.002669                  30.407878
# 52               -0.010788                  23.263433
# 16                0.001812                  36.957376
# 51                0.056014                  39.543676
# 20                0.087015                  30.864154
# 7                 0.020851                  26.674395
# 15                0.015681                  83.108127
# 53                0.041035                  14.384798
# 17                0.013394                  17.759351
# 21                0.000947                  93.644188
# 23                0.000608                  93.543926
# 22                0.000000                        NaN
#
# [15 rows x 27 columns]

# %% [markdown]
# ### Measure the improvement when all files are used <a class="anchor" id="full-dataset">
#
# In most of our dataset selections, we excluded some data points based on our criteria.
#
# In this, we measure the improvement when we use all data points
#
# [top](#Contents)

# %%
# Measure everything for the full dataset
df2 = df
for colname in df2.columns:
    if "exclude" in colname:
        df2 = df2[df2[colname] == False]
df2
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 53                        False                     False
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 53                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  baseline  \
# 53                        False         False            False  0.683142
#
#     advanced-only  ...  ratio_encrypt_nonencrypt  best_f1_score  \
# 53       0.685853  ...                       1.0       0.728721
#
#     advanced-f1_score  fourier-f1_score  baseline-f1_score  \
# 53           0.687686          0.728721           0.683142
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 53                 0.004544                0.045579              0.316858
#
#     fourier_minus_advanced  percentage_of_room_filled
# 53                0.041035                  14.384798
#
# [1 rows x 27 columns]

# %%
df2[[c for c in df2.columns if "baseline" in c or "fourier" in c or "advanced-only" in c]]
# Out:
#     baseline  advanced-only  fourier-only  baseline-and-fourier  \
# 53  0.683142       0.685853      0.717959              0.734134
#
#     advanced-and-fourier   fourier  fourier-f1_score  baseline-f1_score  \
# 53              0.726914  0.728721          0.728721           0.683142
#
#     improvement_in_fourier  fourier_minus_advanced
# 53                0.045579                0.041035

# %%
df.to_csv("../comparison_logistic_regression_final.csv")

# %% [markdown]
# ### Focus on items where the base metrics performed well <a class="anchor" id="focus-greater-90">
#
# We see that in all cases, plaintext non-base 32 only is selected. Also we
# see that for encrypted, only base32 is selected and non-base32 excluded.
#
# Fundamentally, what this is measuring is when the plaintext has all files
# but all encrypted content is base-32 encoded.
#
# Typically, base-32 encoding will lead to a reduction of entropy, in many cases
# much less than the original text, and this is what it is measuring.
#
# [top](#Contents)

# %%
df[df["baseline-f1_score"] > 0.9]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 15                        False                      True
# 3                         False                      True
# 5                         False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 13                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 15                 False                  True                     False
# 3                   True                 False                     False
# 5                   True                 False                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 13                 False                  True                     False
# 22                 False                 False                     False
# 4                   True                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  baseline  \
# 15                        False          True            False  0.941346
# 3                          True          True            False  0.977773
# 5                          True         False            False  0.986054
# 21                         True          True            False  0.988342
# 23                         True         False            False  0.992675
# 12                         True          True            False  0.997498
# 14                         True         False            False  0.998352
# 13                         True         False             True  1.000000
# 22                         True         False             True  1.000000
# 4                          True         False             True  1.000000
#
#     advanced-only  ...  ratio_encrypt_nonencrypt  best_f1_score  \
# 15       0.971432  ...                       1.0       0.990092
# 3        0.995832  ...                       0.5       0.998701
# 5        0.997120  ...                       0.5       0.999166
# 21       0.997634  ...                       1.0       0.999259
# 23       0.998490  ...                       1.0       0.999527
# 12       0.997801  ...                       0.5       0.999756
# 14       0.998586  ...                       0.5       0.999845
# 13       1.000000  ...                       0.5       1.000000
# 22       1.000000  ...                       1.0       1.000000
# 4        1.000000  ...                       0.5       1.000000
#
#     advanced-f1_score  fourier-f1_score  baseline-f1_score  \
# 15           0.974411          0.990092           0.941346
# 3            0.996800          0.998701           0.977773
# 5            0.997914          0.999166           0.986054
# 21           0.998312          0.999259           0.988342
# 23           0.998919          0.999527           0.992675
# 12           0.999401          0.999756           0.997498
# 14           0.999518          0.999845           0.998352
# 13           1.000000          1.000000           1.000000
# 22           1.000000          1.000000           1.000000
# 4            1.000000          1.000000           1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 15                 0.033066                0.048747              0.058654
# 3                  0.019027                0.020928              0.022227
# 5                  0.011860                0.013112              0.013946
# 21                 0.009970                0.010917              0.011658
# 23                 0.006244                0.006852              0.007325
# 12                 0.001904                0.002259              0.002502
# 14                 0.001166                0.001494              0.001648
# 13                 0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 15                0.015681                  83.108127
# 3                 0.001901                  94.156435
# 5                 0.001252                  94.017764
# 21                0.000947                  93.644188
# 23                0.000608                  93.543926
# 12                0.000355                  90.261618
# 14                0.000328                  90.623066
# 13                0.000000                        NaN
# 22                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [10 rows x 27 columns]

# %% [markdown]
# ### Correlation of data set and performance <a class="anchor" id="corr-heatmap">
#
# This gives more idea on how data-set selection affects performance.
#
# [top](#Contents)

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,10)
sns.heatmap(df.astype(float).corr(), cmap='coolwarm')
# print(df[df["baseline-f1_score"] > 0.9].astype(float))
_ = plt.xticks(rotation=80)

# %%
df1 = df[["exclude_encrypted_base32", \
          "exclude_encrypted_v2", \
          "exclude_webp", \
          "baseline-f1_score", \
          "advanced-f1_score", \
          "fourier-f1_score"]]
sns.heatmap(df1.astype(float).corr(), cmap='coolwarm')
_ = plt.xticks(rotation=80)

# %% [markdown]
# ### Average out all the metrics <a class="anchor" id="mean-fscores">
#
# To conclude we report the average of the f1-scores and the improvements with all datasets
#
# [top](#Contents)

# %%
df[[c for c in df.columns if ("score" in c or "improvement" in c) and "room" not in c]].mean()
# Out:
# best_f1_score              0.767499
# advanced-f1_score          0.709304
# fourier-f1_score           0.766335
# baseline-f1_score          0.575923
# improvement_in_advanced    0.133381
# improvement_in_fourier     0.190412
# dtype: float64

# %%
df[[c for c in df.columns if \
    ("-and-" in c or \
     "only" in c or \
     "score" in c or \
     "improvement" in c) and "room" not in c]].describe()
# Out:
#        advanced-only  fourier-only  baseline-and-fourier  \
# count      54.000000     54.000000             54.000000
# mean        0.700342      0.620494              0.684829
# std         0.249542      0.356663              0.294334
# min         0.000000      0.000000              0.000000
# 25%         0.559027      0.498869              0.592365
# 50%         0.717689      0.708914              0.750733
# 75%         0.907785      0.927135              0.931329
# max         1.000000      1.000000              1.000000
#
#        advanced-and-fourier  best_f1_score  advanced-f1_score  \
# count             54.000000      54.000000          54.000000
# mean               0.759020       0.767499           0.709304
# std                0.226135       0.219977           0.242972
# min                0.116914       0.133882           0.001390
# 25%                0.645165       0.650824           0.600484
# 50%                0.802750       0.809049           0.731083
# 75%                0.945240       0.949561           0.907138
# max                1.000000       1.000000           1.000000
#
#        fourier-f1_score  baseline-f1_score  improvement_in_advanced  \
# count         54.000000          54.000000                54.000000
# mean           0.766335           0.575923                 0.133381
# std            0.220841           0.330680                 0.172839
# min            0.124526           0.000000                -0.024139
# 25%            0.649447           0.328992                 0.019106
# 50%            0.809049           0.682691                 0.084212
# 75%            0.949561           0.831542                 0.177083
# max            1.000000           1.000000                 0.894029
#
#        improvement_in_fourier
# count               54.000000
# mean                 0.190412
# std                  0.193168
# min                  0.000000
# 25%                  0.046371
# 50%                  0.127335
# 75%                  0.294384
# max                  0.916041

# %%
df1 = df[[c for c in df.columns if \
          ("score" in c or "improvement" in c) \
          and "room" not in c]]
columns = ["baseline-f1_score"]
columns += [c for c in df1.columns if "only" in c]
columns += [c for c in df1.columns if "-and-" in c]
columns += [c for c in df1.columns if "only" not in c \
            and "-and-" not in c and "baseline-f1_score" != c]
df1[columns].describe()
# Out:
#        baseline-f1_score  best_f1_score  advanced-f1_score  fourier-f1_score  \
# count          54.000000      54.000000          54.000000         54.000000
# mean            0.575923       0.767499           0.709304          0.766335
# std             0.330680       0.219977           0.242972          0.220841
# min             0.000000       0.133882           0.001390          0.124526
# 25%             0.328992       0.650824           0.600484          0.649447
# 50%             0.682691       0.809049           0.731083          0.809049
# 75%             0.831542       0.949561           0.907138          0.949561
# max             1.000000       1.000000           1.000000          1.000000
#
#        improvement_in_advanced  improvement_in_fourier
# count                54.000000               54.000000
# mean                  0.133381                0.190412
# std                   0.172839                0.193168
# min                  -0.024139                0.000000
# 25%                   0.019106                0.046371
# 50%                   0.084212                0.127335
# 75%                   0.177083                0.294384
# max                   0.894029                0.916041
