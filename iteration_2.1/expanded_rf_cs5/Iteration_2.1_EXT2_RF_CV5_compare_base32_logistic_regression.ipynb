# %% [markdown]
# Few key observations
# - If both and non-encrypted files are base-32 encoded, accuracy drops really low.
#    * Even in this case, fourier analysis (specifically autocorrelation and mean) provide good discrminators
#    * Renyi's entropy at alpha=infinity gives good discrimination
#    * Overall we see around 13% improvement in F1-score
# - Specifically for webpfiles
#    * We see that higher moments of around 14 gives a good discrimination
#    * Fourier analysis still gives benefits here
# - For webpfiles where both unencrypted and encrypted content are base32 encrypted
#    * Fourier analysis is still beneficial
# - For Non-webp files where plaintext is not base-32 encrypted
#    * Accuracy is decent with just the base parameters, but with fourier analysis, we can close to perfect detection

# %% [markdown]
# # Contents
# - ## [Implementation](#mplementation)
#  - ### [List of Files](#list-of-files)
#  - ### [Utility to call gc](#gc)
#  - ### [Selection of Columns](#select-columns)
#  - ### [Function to compare the three selections of columns for a given dataset](#compare-fn)
#  - ### [Load the datasets](#load-dataset)
#  - ### [Select the datasets](#dataset-selection)
#  - ### [Run all combinations of data](#dataset-selection)
# - ## [Results](#results)
#  - ### [Print the raw results](#raw-results)
#  - ### [Sort by the improvement when using Fourier transforms over baseline](#sorted-fourier)
#  - ### [Measure improvement when only webp files are used](#webp-only)
#  - ### [Measure improvement when webp files are not present](#no-webp)
#  - ### [Measure improvement for balanced datasets](#balanced-dataset)
#  - ### [Measure the improvement when all files are used](#full-dataset)
#  - ### [Focus on items where the base metrics performed well](#focus-greater-90)
#  - ### [Correlation of data set and performance]("corr-heatmap")
#  - ### [Average out all the metrics](#mean-fscores)

# %% [markdown]
# ## Implementation <a class="anchor" id="implementation">
#
# [top](#Contents)

# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats

from functools import lru_cache

import gc

import sklearn
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, accuracy_score, recall_score

import matplotlib.pyplot as plt
import glob

import tqdm
from multiprocessing.pool import ThreadPool, Pool

plt.rcParams["figure.figsize"] = (20,20)

# %% [markdown]
# ### List of files <a class="anchor" id="list-of-files">
#
# [top](#Contents)

# %%
# !ls
# Out:
# Iteration_2.1_EXT2_RF_CV5_compare_base32_logistic_regression.ipynb
# expanded.plaintext.base32.csv.gz
# expanded.pyencrypted_v1.b32.csv.gz
# expanded.pyencrypted_v1.csv.gz
# expanded.pyencrypted_v2.base32.csv.gz
# expanded.pyencrypted_v2.csv.gz
# iteration_2.1_compare_base32_alternate_encryption_scheme.ipynb
# iteration_2.1_compare_base32_logistic_regression.ipynb
# plaintext.base32.combined.csv.gz
# plaintext.combined.csv.gz
# plaintext.expanded.csv.gz

# %% [markdown]
# ### Utility to call GC <a class="anchor" id="gc">
#
# [top](#Contents)

# %%
def call_gc():
    for i in range(3):
        for j in range(3):
            gc.collect(j)

# %% [markdown]
# ### Selection of columns <a class="anchor" id="select-columns">
#
# This function is used to select the columns.
# There are three different configurations:
#
#     1. Baseline - statistics like autocorrelation, shannon entropy, chi-square etc. are used
#
#     2. Advanced - More statistics like moments, Tsallis and Renyi entropy, higher moments etc.
#
#     3. Fourier - Some statistics of the Fourier Power Spectrum distribution
#
# [top](#Contents)

# %%
def get_columns(thisdf):
    baseline_columns = [c for c in thisdf.columns if c.startswith('baseline') and "head" not in c and "tail" not in c]
    baseline_columns = [c for c in baseline_columns if "filesize" not in c]
    baseline_columns = [c for c in baseline_columns if "begin" not in c and "end" not in c]

    advanced_columns = [c for c in thisdf.columns if "advanced" in c]
    advanced_columns = [c for c in advanced_columns if "begin" not in c and "end" not in c]
    advanced_columns = [c for c in advanced_columns if "head" not in c and "tail" not in c]
    advanced_columns = [c for c in advanced_columns if "start" not in c]
    advanced_columns_only = list(set(advanced_columns))
    advanced_columns = list(set(advanced_columns + baseline_columns))

    fourier_columns = [c for c in thisdf.columns if "fourier" in c and "value" not in c]
    fourier_columns = [c for c in fourier_columns if "1byte" in c]
    fourier_columns = [c for c in fourier_columns if "begin" not in c and "end" not in c]
    fourier_columns = [c for c in fourier_columns if "head" not in c and "tail" not in c]
    fourier_columns = [c for c in fourier_columns if "start" not in c]
    fourier_columns_only = list(set(fourier_columns))
    fourier_columns = list(set(advanced_columns + fourier_columns))
    
    baseline_and_advanced = list(set(baseline_columns + advanced_columns_only))
    baseline_and_fourier = list(set(baseline_columns + fourier_columns_only))
    advanced_and_fourier = list(set(advanced_columns_only + fourier_columns_only))
    
    return {\
        "baseline": baseline_columns,\
        "advanced-only": advanced_columns_only,\
        "fourier-only": fourier_columns_only,\
        "baseline-and-fourier": baseline_and_fourier,\
        "advanced-and-fourier": advanced_and_fourier,\
        "advanced": advanced_columns,\
        "fourier": fourier_columns,\
    }

# %% [markdown]
# ### Function to compare the three selections of columns for a given dataset <a class="anchor" id="compare-fn">
#
# For the three different sets of measurements described above, compare all the three sets for their f1 score
#
# [top](#Contents)

# %%
USE_ASYNC = False
N_SPLITS=5

def get_kfold_f1_score(name, collist, X, y):
    skf = StratifiedKFold(n_splits=N_SPLITS, random_state=42, shuffle=True)
    f1_scores = []
    precision_scores = []
    recall_scores = []
    accuracy_scores = []
    X = X[collist].to_numpy()
    y = y.to_numpy()
    call_gc()
    for train_idx, test_idx in skf.split(X, y):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]
        rfc = RandomForestClassifier(n_jobs=10, random_state=42)
        estimators = [\
                      ('std,', MinMaxScaler()), \
                      ('RandomForestClassifier', rfc)]
        pipeline = Pipeline(estimators)
        pipeline.fit(X_train, y_train)
        y_pred = pipeline.predict(X_test)
        f1_scores.append(f1_score(y_test, y_pred))
        recall_scores.append(recall_score(y_test, y_pred))
        precision_scores.append(precision_score(y_test, y_pred, zero_division=0))
        accuracy_scores.append(accuracy_score(y_test, y_pred))

    return name, \
            float(np.mean(f1_scores)),\
            float(np.mean(accuracy_scores)),\
            float(np.mean(precision_scores)),\
            float(np.mean(recall_scores)),

def compare_feature_selections_async(X, y):
    columns_dict = get_columns(X)
    ret = dict()
    pool = Pool(3)
    async_results = list()
    for name, collist in columns_dict.items():
        result = pool.apply_async(\
                                  get_kfold_f1_score, \
                                  (name, collist, X, y))
    for result in async_results:
        name, f1 = result.get(timeout=None)
        ret[name] = f1
    return ret

def compare_feature_selections_sync(X, y):
    columns_dict = get_columns(X)
    ret = dict()
    for name, collist in columns_dict.items():
        name, f1, accuracy, precision, recall = \
            get_kfold_f1_score(name, collist, X, y)
        ret[f"{name}-f1_score"] = f1
        ret[f"{name}-accuracy_score"] = accuracy
        ret[f"{name}-precision_score"] = precision
        ret[f"{name}-recall_score"] = recall
    return ret

def compare_feature_selections(X, y):
    if USE_ASYNC:
        return compare_feature_selections_async(X, y)
    else:
        return compare_feature_selections_sync(X, y)

def compare_feature_selections_wrapper(data):
    X = data[[c for c in data.columns if "is_encrypted" != c]]
    y = data["is_encrypted"]
    return compare_feature_selections(X, y)

# %% [markdown]
# ### Load the datasets <a class="anchor" id="load-dataset">
#
# We don't want to load the datasets again and again, so we load them once.
# The LRU cache ensures that the next time this is called, we don't load the datasets again.
#
# [top](#Contents)

# %%
@lru_cache
def load_datasets_once():
    """Load all datasets only once
    
    We want to load the datasets only once. Once loaded
    serve from cache
    """
    datasets = dict()
    for file in glob.glob("*.csv.gz"):
        df = pd.read_csv(file)
        df = df.sample(frac=1).reset_index(drop=True)
        df["is_encrypted"] = 1 if "encr" in file.lower() else 0
        datasets[file] = df
    return datasets

# %% [markdown]
# ### Select the datasets <a class="anchor" id="dataset-selection">
#
# Select the dataset, combine it, shuffle it and return
#
# We used several schemes:
# * Plaintext
#   - The base plaintext dataset of around 50k files
#   - Expanded dataset, where all files that were less than 1500 bytes were expanded by repeating the file
#   - Base32 encoding of
#    - original plaintext
#    - expanded plaintext
# * Encryption : We used two schemes for encruption
#   - v1 : AES 256 encryption of the full file, again two varieties were used
#     - Plain encryption
#     - Encryption followed by base32 encoding
#   - v2 : AES encryption of the file, the first and the last 128 bytes are not encrypted. Of the remaining file, every alternate 16 bytes are encrypted.
#     - Plain encryption
#     - encryption followed by base32 encoding
#
# We select combinations of the above datasets
#
# Furthermore, we add further combinations by including and excluding webp files, and including and excluding non-webp files.
#
# [top](#Contents)

# %%
def get_dataset(\
               exclude_plaintext_nonbase32=False,
               exclude_plaintext_base32=False,
               exclude_encrypted_v1=False,
               exclude_encrypted_v2=False,
               exclude_encrypted_base32=False,
               exclude_encrypted_nonbase32=False,
               exclude_webp=False,
               exclude_nonwebp=False):
    description = {k:v for k,v in locals().items() \
                   if "exclude" in k}
    
    files = glob.glob("*.csv.gz")
    
    
    if exclude_plaintext_nonbase32:
        files = [f for f in files if \
                     "plaintext" not in f \
                     or "_base32" in f \
                     or "_b32" in f]
    if exclude_plaintext_base32:
        files = [f for f in files if\
                    "plaintext" not in f or \
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_v1:
        files = [f for f in files if\
                    "_v1" not in f or "encr" not in f]
    if exclude_encrypted_v2:
        files = [f for f in files if \
                    "_v2" not in f or "encr" not in f]
    if exclude_encrypted_base32:
        files = [ f for f in files if\
                    "encr" not in f or\
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_nonbase32:
        files = [f for f in files if \
                    "encr" not in f or \
                    "base32" in f or "b32" in f]
        
        
    encrypted_count = len([f for f in files if "encr" in f])
    non_encrypted_count = len([f for f in files if "encr" not in f])
    
    if 0 == encrypted_count or 0 == non_encrypted_count or 0 == len(files):
        return description, None, -1, -1
    
    all_dfs = list()
    all_loaded_datasets = load_datasets_once()
    for filename in files:
        all_dfs.append(all_loaded_datasets[filename])
    
    combined_df = pd.concat(all_dfs)
    
    if exclude_webp:
        combined_df = combined_df[\
                        combined_df["extended.extension"] != ".webp"]
    if exclude_nonwebp:
        combined_df = combined_df[\
                        combined_df["extended.extension"] == ".webp"]
        
    if len(combined_df) == 0:
        return description, None, -1, -1
    
        
    encrypt_count = len(combined_df[combined_df["is_encrypted"] == 1])
    nonencrypted_count = len(combined_df[combined_df["is_encrypted"] == 0])

    
    if 0 == len(combined_df) or 0 == encrypt_count or 0 == nonencrypted_count:
        return description, None, -1, -1
    
    return description, combined_df, encrypt_count, nonencrypted_count

# %% [markdown]
# ### Run all combinations of data <a class="anchor" id="dataset-selection">
#
# For all combinations of the datasets, compare the three classes (basic, advanced, and Fourier)
#
# [top](#Contents)

# %%
all_results = []
list_of_arguments = []

# Get all 8-tuple combinations of T/F
list_of_arguments = [(True,), (False,)]
for i in range(7):
    temp = []
    for e in list_of_arguments:
        et = e + (True,)
        temp.append(et)
        et = e + (False,)
        temp.append(et)
    list_of_arguments = temp

     
for a, b, c, k, e, f, g, h in tqdm.tqdm(list_of_arguments):
    desc, df, ec, nec = get_dataset(a, b, c, k, e, f, g, h)
    if df is not None:
        result = compare_feature_selections_wrapper(df)
        call_gc()
        result = {**desc, **result}
        result["n_encrypted"] = ec
        result["n_non_encrypted"] = nec
        result["ratio_encrypt_nonencrypt"] = float(ec) / nec
        all_results.append(result)


df_dict = {k:[] for k in all_results[0]}
for result in all_results:
    for k, v in result.items():
        df_dict[k].append(v)

df = pd.DataFrame(df_dict)
df["best_f1_score"] = \
    df[[c for c in df.columns if "f1_score" in c]].max(axis=1)

df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["improvement_in_fourier"] = \
    df["fourier-f1_score"] - df["baseline-f1_score"]
df = df.sort_values(by="improvement_in_fourier", ascending=False)
# Out:
# 100%|█████████████████████████████████████████████████| 256/256 [8:22:30<00:00, 117.78s/it]

# %% [markdown]
# ## Results <a class="anchor" id="results">
#
# In this section, we present the results
#
# [top](#Contents)

# %% [markdown]
# ### Print the raw results <a class="anchor" id="raw-results">
#
# [top](#Contents)

# %%
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 37                        False                     False
# 10                        False                      True
# 43                        False                     False
# 40                        False                     False
# 31                        False                     False
# 34                        False                     False
# 32                        False                     False
# 35                        False                     False
# 28                        False                     False
# 1                         False                      True
# 29                        False                     False
# 2                         False                      True
# 30                        False                     False
# 33                        False                     False
# 0                         False                      True
# 27                        False                     False
# 16                        False                      True
# 49                        False                     False
# 46                        False                     False
# 52                        False                     False
# 19                        False                      True
# 41                        False                     False
# 44                        False                     False
# 11                        False                      True
# 38                        False                     False
# 50                        False                     False
# 20                        False                      True
# 53                        False                     False
# 8                         False                      True
# 47                        False                     False
# 48                        False                     False
# 51                        False                     False
# 6                         False                      True
# 7                         False                      True
# 45                        False                     False
# 18                        False                      True
# 25                        False                      True
# 17                        False                      True
# 26                        False                      True
# 24                        False                      True
# 39                        False                     False
# 3                         False                      True
# 42                        False                     False
# 36                        False                     False
# 9                         False                      True
# 5                         False                      True
# 15                        False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 13                        False                      True
# 4                         False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 37                 False                  True                      True
# 10                 False                  True                      True
# 43                 False                  True                     False
# 40                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 32                  True                 False                     False
# 35                  True                 False                     False
# 28                  True                 False                      True
# 1                   True                 False                      True
# 29                  True                 False                      True
# 2                   True                 False                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 0                   True                 False                      True
# 27                  True                 False                      True
# 16                 False                  True                     False
# 49                 False                 False                     False
# 46                 False                 False                      True
# 52                 False                 False                     False
# 19                 False                 False                      True
# 41                 False                  True                     False
# 44                 False                  True                     False
# 11                 False                  True                      True
# 38                 False                  True                      True
# 50                 False                 False                     False
# 20                 False                 False                      True
# 53                 False                 False                     False
# 8                   True                 False                     False
# 47                 False                 False                      True
# 48                 False                 False                     False
# 51                 False                 False                     False
# 6                   True                 False                     False
# 7                   True                 False                     False
# 45                 False                 False                      True
# 18                 False                 False                      True
# 25                 False                 False                     False
# 17                 False                  True                     False
# 26                 False                 False                     False
# 24                 False                 False                     False
# 39                 False                  True                     False
# 3                   True                 False                     False
# 42                 False                  True                     False
# 36                 False                  True                      True
# 9                  False                  True                      True
# 5                   True                 False                     False
# 15                 False                  True                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 13                 False                  True                     False
# 4                   True                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 37                        False         False             True
# 10                        False         False             True
# 43                        False         False             True
# 40                         True         False             True
# 31                         True         False             True
# 34                        False         False             True
# 32                         True         False            False
# 35                        False         False            False
# 28                        False         False             True
# 1                         False         False             True
# 29                        False         False            False
# 2                         False         False            False
# 30                         True          True            False
# 33                        False          True            False
# 0                         False          True            False
# 27                        False          True            False
# 16                        False         False             True
# 49                         True         False             True
# 46                        False         False             True
# 52                        False         False             True
# 19                        False         False             True
# 41                         True         False            False
# 44                        False         False            False
# 11                        False         False            False
# 38                        False         False            False
# 50                         True         False            False
# 20                        False         False            False
# 53                        False         False            False
# 8                         False         False            False
# 47                        False         False            False
# 48                         True          True            False
# 51                        False          True            False
# 6                         False          True            False
# 7                         False         False             True
# 45                        False          True            False
# 18                        False          True            False
# 25                        False         False             True
# 17                        False         False            False
# 26                        False         False            False
# 24                        False          True            False
# 39                         True          True            False
# 3                          True          True            False
# 42                        False          True            False
# 36                        False          True            False
# 9                         False          True            False
# 5                          True         False            False
# 15                        False          True            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 14                         True         False            False
# 13                         True         False             True
# 4                          True         False             True
# 22                         True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-f1_score  \
# 37           0.709224                 0.900945  ...          0.891575
# 10           0.713563                 0.837344  ...          0.890656
# 43           0.673574                 0.817744  ...          0.841367
# 40           0.633165                 0.879361  ...          0.786096
# 31           0.570486                 0.868041  ...          0.699117
# 34           0.634183                 0.806340  ...          0.745413
# 32           0.725133                 0.907331  ...          0.826103
# 35           0.776119                 0.870248  ...          0.873108
# 28           0.696362                 0.900009  ...          0.791014
# 1            0.694236                 0.832306  ...          0.788553
# 29           0.824417                 0.937064  ...          0.916108
# 2            0.825324                 0.895613  ...          0.915693
# 30           0.840623                 0.942061  ...          0.929793
# 33           0.874084                 0.922145  ...          0.959957
# 0            0.906860                 0.941111  ...          0.989766
# 27           0.907049                 0.964841  ...          0.989304
# 16           0.868291                 0.878261  ...          0.946992
# 49           0.782918                 0.865486  ...          0.852286
# 46           0.808014                 0.881818  ...          0.875307
# 52           0.796839                 0.811545  ...          0.862600
# 19           0.810004                 0.824490  ...          0.874417
# 41           0.875386                 0.951606  ...          0.930657
# 44           0.889153                 0.928106  ...          0.943872
# 11           0.903524                 0.937277  ...          0.957673
# 38           0.904075                 0.962520  ...          0.956946
# 50           0.882562                 0.924140  ...          0.927541
# 20           0.908785                 0.911126  ...          0.952802
# 53           0.896003                 0.898914  ...          0.939706
# 8            0.916562                 0.920915  ...          0.959570
# 47           0.909485                 0.941198  ...          0.952315
# 48           0.925899                 0.952686  ...          0.966806
# 51           0.940204                 0.942269  ...          0.980983
# 6            0.954134                 0.955376  ...          0.994849
# 7            0.862443                 0.874585  ...          0.903055
# 45           0.954663                 0.970552  ...          0.995134
# 18           0.954649                 0.955813  ...          0.995087
# 25           0.908747                 0.883036  ...          0.939340
# 17           0.951890                 0.952441  ...          0.978496
# 26           0.955389                 0.941297  ...          0.976318
# 24           0.977496                 0.970396  ...          0.997600
# 39           0.993693                 0.997473  ...          0.995499
# 3            0.998221                 0.998815  ...          1.000000
# 42           0.995651                 0.997099  ...          0.997403
# 36           0.997531                 0.999013  ...          0.999228
# 9            0.997592                 0.998395  ...          0.999127
# 5            0.999053                 0.999369  ...          1.000000
# 15           0.998776                 0.998776  ...          0.999645
# 21           0.999192                 0.999193  ...          1.000000
# 23           0.999484                 0.999484  ...          1.000000
# 42                 0.001214                0.001752
# 36                 0.000976                0.001697
# 9                  0.000814                0.001535
# 5                  0.000947                0.000947
# 15                 0.000478                0.000869
# 21                 0.000808                0.000808
# 23                 0.000516                0.000516
# 12                 0.000010                0.000010
# 14                 0.000006                0.000006
# 13                 0.000000                0.000000
# 4                  0.000000                0.000000
# 22                 0.000000                0.000000
#
# [54 rows x 42 columns]

# %%
df.to_csv("../comparison.csv")

# %%
df = df.sort_values(by="improvement_in_fourier", ascending=False)

# %% [markdown]
# ### Sort by the improvement when using Fourier transforms over baseline <a class="anchor" id="sorted-fourier">
#
# We also take a few other things:
# * Room for improvement (1 - baseline score)
# * How much of the room for improvement was filled by fourier transforms (percentage)
# * Difference between F1 score with advanced and fourier
#
# [top](#Contents)

# %%
df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["room_for_improvement"] = \
    1.0 - df["baseline-f1_score"]
df["fourier_minus_advanced"] = \
    df["fourier-f1_score"] - df["advanced-f1_score"]
df["percentage_of_room_filled"] = \
    df["improvement_in_fourier"] * 100.0 / df["room_for_improvement"]
#df.sort_values(by="fourier_minus_advanced", ascending=False)
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 37                        False                     False
# 10                        False                      True
# 43                        False                     False
# 40                        False                     False
# 31                        False                     False
# 34                        False                     False
# 32                        False                     False
# 35                        False                     False
# 28                        False                     False
# 1                         False                      True
# 29                        False                     False
# 2                         False                      True
# 30                        False                     False
# 33                        False                     False
# 0                         False                      True
# 27                        False                     False
# 16                        False                      True
# 49                        False                     False
# 46                        False                     False
# 52                        False                     False
# 19                        False                      True
# 41                        False                     False
# 44                        False                     False
# 11                        False                      True
# 38                        False                     False
# 50                        False                     False
# 20                        False                      True
# 53                        False                     False
# 8                         False                      True
# 47                        False                     False
# 48                        False                     False
# 51                        False                     False
# 6                         False                      True
# 7                         False                      True
# 45                        False                     False
# 18                        False                      True
# 25                        False                      True
# 17                        False                      True
# 26                        False                      True
# 24                        False                      True
# 39                        False                     False
# 3                         False                      True
# 42                        False                     False
# 36                        False                     False
# 9                         False                      True
# 5                         False                      True
# 15                        False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 13                        False                      True
# 4                         False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 37                 False                  True                      True
# 10                 False                  True                      True
# 43                 False                  True                     False
# 40                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 32                  True                 False                     False
# 35                  True                 False                     False
# 28                  True                 False                      True
# 1                   True                 False                      True
# 29                  True                 False                      True
# 2                   True                 False                      True
# 30                  True                 False                     False
# 33                  True                 False                     False
# 0                   True                 False                      True
# 27                  True                 False                      True
# 16                 False                  True                     False
# 49                 False                 False                     False
# 46                 False                 False                      True
# 52                 False                 False                     False
# 19                 False                 False                      True
# 41                 False                  True                     False
# 44                 False                  True                     False
# 11                 False                  True                      True
# 38                 False                  True                      True
# 50                 False                 False                     False
# 20                 False                 False                      True
# 53                 False                 False                     False
# 8                   True                 False                     False
# 47                 False                 False                      True
# 48                 False                 False                     False
# 51                 False                 False                     False
# 6                   True                 False                     False
# 7                   True                 False                     False
# 45                 False                 False                      True
# 18                 False                 False                      True
# 25                 False                 False                     False
# 17                 False                  True                     False
# 26                 False                 False                     False
# 24                 False                 False                     False
# 39                 False                  True                     False
# 3                   True                 False                     False
# 42                 False                  True                     False
# 36                 False                  True                      True
# 9                  False                  True                      True
# 5                   True                 False                     False
# 15                 False                  True                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 13                 False                  True                     False
# 4                   True                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 37                        False         False             True
# 10                        False         False             True
# 43                        False         False             True
# 40                         True         False             True
# 31                         True         False             True
# 34                        False         False             True
# 32                         True         False            False
# 35                        False         False            False
# 28                        False         False             True
# 1                         False         False             True
# 29                        False         False            False
# 2                         False         False            False
# 30                         True          True            False
# 33                        False          True            False
# 0                         False          True            False
# 27                        False          True            False
# 16                        False         False             True
# 49                         True         False             True
# 46                        False         False             True
# 52                        False         False             True
# 19                        False         False             True
# 41                         True         False            False
# 44                        False         False            False
# 11                        False         False            False
# 38                        False         False            False
# 50                         True         False            False
# 20                        False         False            False
# 53                        False         False            False
# 8                         False         False            False
# 47                        False         False            False
# 48                         True          True            False
# 51                        False          True            False
# 6                         False          True            False
# 7                         False         False             True
# 45                        False          True            False
# 18                        False          True            False
# 25                        False         False             True
# 17                        False         False            False
# 26                        False         False            False
# 24                        False          True            False
# 39                         True          True            False
# 3                          True          True            False
# 42                        False          True            False
# 36                        False          True            False
# 9                         False          True            False
# 5                          True         False            False
# 15                        False          True            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 14                         True         False            False
# 13                         True         False             True
# 4                          True         False             True
# 22                         True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 37           0.709224                 0.900945  ...              0.845534
# 10           0.713563                 0.837344  ...              0.845470
# 43           0.673574                 0.817744  ...              0.777439
# 40           0.633165                 0.879361  ...              0.706372
# 31           0.570486                 0.868041  ...              0.566103
# 34           0.634183                 0.806340  ...              0.621518
# 32           0.725133                 0.907331  ...              0.733145
# 35           0.776119                 0.870248  ...              0.799092
# 28           0.696362                 0.900009  ...              0.680316
# 1            0.694236                 0.832306  ...              0.678103
# 29           0.824417                 0.937064  ...              0.862170
# 2            0.825324                 0.895613  ...              0.861230
# 30           0.840623                 0.942061  ...              0.895324
# 33           0.874084                 0.922145  ...              0.938907
# 0            0.906860                 0.941111  ...              0.983383
# 27           0.907049                 0.964841  ...              0.982652
# 16           0.868291                 0.878261  ...              0.923336
# 49           0.782918                 0.865486  ...              0.811968
# 46           0.808014                 0.881818  ...              0.820000
# 4                  0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 37                0.017660                  62.711760
# 10                0.015050                  61.826282
# 43                0.011644                  51.403117
# 40                0.005265                  41.689239
# 31                0.032356                  29.948069
# 34                0.017569                  30.405971
# 32                0.040378                  36.734026
# 35                0.039142                  43.321542
# 28                0.005432                  31.172752
# 1                 0.004395                  30.846467
# 29                0.036960                  52.220531
# 2                 0.037007                  51.735032
# 30                0.043418                  55.948876
# 33                0.047486                  68.198654
# 0                 0.052360                  89.012541
# 27                0.051187                  88.493021
# 16                0.007382                  59.753892
# 49                0.015296                  31.954407
# 46                0.006640                  35.051212
# 52                0.010312                  32.368912
# 19                0.006342                  33.902366
# 41                0.003592                  44.353489
# 44                0.005479                  49.364667
# 11                0.007414                  56.126687
# 38                0.007762                  55.116733
# 50                0.017296                  38.300040
# 20                0.018877                  48.256429
# 53                0.017986                  42.023209
# 8                 0.017103                  51.545381
# 47                0.019022                  47.318871
# 48                0.019988                  55.204108
# 51                0.022172                  68.196693
# 6                 0.025751                  88.769048
# 7                 0.002486                  29.523747
# 45                0.024910                  89.266011
# 18                0.025204                  89.167268
# 25                0.002865                  33.526155
# 17                0.003515                  55.302286
# 26                0.008951                  46.914727
# 24                0.012326                  89.336378
# 39                0.000324                  28.644467
# 3                 0.000000                 100.000000
# 42                0.000538                  40.287041
# 36                0.000721                  68.745143
# 9                 0.000721                  63.740554
# 5                 0.000000                 100.000000
# 15                0.000391                  70.964369
# 21                0.000000                 100.000000
# 23                0.000000                 100.000000
# 12                0.000000                 100.000000
# 14                0.000000                 100.000000
# 13                0.000000                        NaN
# 4                 0.000000                        NaN
# 22                0.000000                        NaN
#
# [54 rows x 45 columns]

# %% [markdown]
# ### Measure improvement when only webp files are used <a class="anchor" id="webp-only">
#
# We want to measure this alone because in the literature, poor performance in webp files has been mentioned
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == False) & \
   (df["exclude_nonwebp"] == True)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 37                        False                     False
# 10                        False                      True
# 43                        False                     False
# 40                        False                     False
# 31                        False                     False
# 34                        False                     False
# 28                        False                     False
# 1                         False                      True
# 16                        False                      True
# 49                        False                     False
# 46                        False                     False
# 52                        False                     False
# 19                        False                      True
# 7                         False                      True
# 25                        False                      True
# 13                        False                      True
# 4                         False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 37                 False                  True                      True
# 10                 False                  True                      True
# 43                 False                  True                     False
# 40                 False                  True                     False
# 31                  True                 False                     False
# 34                  True                 False                     False
# 28                  True                 False                      True
# 1                   True                 False                      True
# 16                 False                  True                     False
# 49                 False                 False                     False
# 46                 False                 False                      True
# 52                 False                 False                     False
# 19                 False                 False                      True
# 7                   True                 False                     False
# 25                 False                 False                     False
# 13                 False                  True                     False
# 4                   True                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 37                        False         False             True
# 10                        False         False             True
# 43                        False         False             True
# 40                         True         False             True
# 31                         True         False             True
# 34                        False         False             True
# 28                        False         False             True
# 1                         False         False             True
# 16                        False         False             True
# 49                         True         False             True
# 46                        False         False             True
# 52                        False         False             True
# 19                        False         False             True
# 7                         False         False             True
# 25                        False         False             True
# 13                         True         False             True
# 4                          True         False             True
# 22                         True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 37           0.709224                 0.900945  ...              0.845534
# 10           0.713563                 0.837344  ...              0.845470
# 43           0.673574                 0.817744  ...              0.777439
# 40           0.633165                 0.879361  ...              0.706372
# 31           0.570486                 0.868041  ...              0.566103
# 34           0.634183                 0.806340  ...              0.621518
# 28           0.696362                 0.900009  ...              0.680316
# 1            0.694236                 0.832306  ...              0.678103
# 16           0.868291                 0.878261  ...              0.923336
# 49           0.782918                 0.865486  ...              0.811968
# 46           0.808014                 0.881818  ...              0.820000
# 52           0.796839                 0.811545  ...              0.814514
# 19           0.810004                 0.824490  ...              0.818656
# 7            0.862443                 0.874585  ...              0.839067
# 25           0.908747                 0.883036  ...              0.909194
# 13           1.000000                 1.000000  ...              1.000000
# 4            1.000000                 1.000000  ...              1.000000
# 22           1.000000                 1.000000  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 37        31625           126500                      0.25       0.891575
# 10        31625            63250                      0.50       0.890656
# 43        63250           126500                      0.50       0.841367
# 40        31625           126500                      0.25       0.786096
# 31        31625           126500                      0.25       0.699117
# 34        63250           126500                      0.50       0.745413
# 28        31625           126500                      0.25       0.791014
# 1         31625            63250                      0.50       0.788645
# 16        63250            63250                      1.00       0.946992
# 49        63250           126500                      0.50       0.852286
# 46        63250           126500                      0.50       0.875307
# 52       126500           126500                      1.00       0.862600
# 19        63250            63250                      1.00       0.874417
# 7         63250            63250                      1.00       0.903055
# 25       126500            63250                      2.00       0.939340
# 13        31625            63250                      0.50       1.000000
# 4         31625            63250                      0.50       1.000000
# 22        63250            63250                      1.00       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 37                 0.164691                0.182351              0.290776
# 10                 0.162043                0.177093              0.286437
# 43                 0.156149                0.167793              0.326426
# 40                 0.147666                0.152931              0.366835
# 31                 0.096275                0.128631              0.429514
# 34                 0.093662                0.111230              0.365817
# 28                 0.089220                0.094652              0.303638
# 1                  0.089922                0.094317              0.305764
# 16                 0.071319                0.078701              0.131709
# 49                 0.054071                0.069367              0.217082
# 46                 0.060654                0.067294              0.191986
# 52                 0.055450                0.065761              0.203161
# 19                 0.058071                0.064413              0.189996
# 7                  0.038126                0.040612              0.137557
# 25                 0.027729                0.030594              0.091253
# 13                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 37                0.017660                  62.711760
# 10                0.015050                  61.826282
# 43                0.011644                  51.403117
# 40                0.005265                  41.689239
# 31                0.032356                  29.948069
# 34                0.017569                  30.405971
# 28                0.005432                  31.172752
# 1                 0.004395                  30.846467
# 16                0.007382                  59.753892
# 49                0.015296                  31.954407
# 46                0.006640                  35.051212
# 52                0.010312                  32.368912
# 19                0.006342                  33.902366
# 7                 0.002486                  29.523747
# 25                0.002865                  33.526155
# 13                0.000000                        NaN
# 4                 0.000000                        NaN
# 22                0.000000                        NaN
#
# [18 rows x 45 columns]

# %% [markdown]
# ### Measure improvement when webp files are not present <a class="anchor" id="no-webp">
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == True) & \
   (df["exclude_nonwebp"] == False)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 30                        False                     False
# 33                        False                     False
# 0                         False                      True
# 27                        False                     False
# 48                        False                     False
# 51                        False                     False
# 6                         False                      True
# 45                        False                     False
# 18                        False                      True
# 24                        False                      True
# 39                        False                     False
# 3                         False                      True
# 42                        False                     False
# 36                        False                     False
# 9                         False                      True
# 15                        False                      True
# 21                        False                      True
# 12                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 30                  True                 False                     False
# 33                  True                 False                     False
# 0                   True                 False                      True
# 27                  True                 False                      True
# 48                 False                 False                     False
# 51                 False                 False                     False
# 6                   True                 False                     False
# 45                 False                 False                      True
# 18                 False                 False                      True
# 24                 False                 False                     False
# 39                 False                  True                     False
# 3                   True                 False                     False
# 42                 False                  True                     False
# 36                 False                  True                      True
# 9                  False                  True                      True
# 15                 False                  True                     False
# 21                 False                 False                     False
# 12                 False                  True                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 30                         True          True            False
# 33                        False          True            False
# 0                         False          True            False
# 27                        False          True            False
# 48                         True          True            False
# 51                        False          True            False
# 6                         False          True            False
# 45                        False          True            False
# 18                        False          True            False
# 24                        False          True            False
# 39                         True          True            False
# 3                          True          True            False
# 42                        False          True            False
# 36                        False          True            False
# 9                         False          True            False
# 15                        False          True            False
# 21                         True          True            False
# 12                         True          True            False
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 30           0.840623                 0.942061  ...              0.895324
# 33           0.874084                 0.922145  ...              0.938907
# 0            0.906860                 0.941111  ...              0.983383
# 27           0.907049                 0.964841  ...              0.982652
# 48           0.925899                 0.952686  ...              0.952425
# 51           0.940204                 0.942269  ...              0.972551
# 6            0.954134                 0.955376  ...              0.991580
# 45           0.954663                 0.970552  ...              0.992789
# 18           0.954649                 0.955813  ...              0.992636
# 24           0.977496                 0.970396  ...              0.996455
# 39           0.993693                 0.997473  ...              0.997501
# 3            0.998221                 0.998815  ...              1.000000
# 42           0.995651                 0.997099  ...              0.998558
# 36           0.997531                 0.999013  ...              0.999553
# 9            0.997592                 0.998395  ...              0.999553
# 15           0.998776                 0.998776  ...              0.999817
# 21           0.999192                 0.999193  ...              1.000000
# 12           0.999990                 0.999993  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 30        49228           196912                      0.25       0.929793
# 33        98456           196912                      0.50       0.959957
# 0         49228            98456                      0.50       0.989766
# 27        49228           196912                      0.25       0.989304
# 48        98456           196912                      0.50       0.966806
# 51       196912           196912                      1.00       0.980983
# 6         98456            98456                      1.00       0.994849
# 45        98456           196912                      0.50       0.995134
# 18        98456            98456                      1.00       0.995087
# 24       196912            98456                      2.00       0.997600
# 39        49228           196912                      0.25       0.995499
# 3         49228            98456                      0.50       1.000000
# 42        98456           196912                      0.50       0.997403
# 36        49228           196912                      0.25       0.999228
# 9         49228            98456                      0.50       0.999127
# 15        98456            98456                      1.00       0.999645
# 21        98456            98456                      1.00       1.000000
# 12        49228            98456                      0.50       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 30                 0.045752                0.089170              0.159377
# 33                 0.038388                0.085873              0.125916
# 0                  0.030546                0.082906              0.093140
# 27                 0.031068                0.082255              0.092951
# 48                 0.020919                0.040907              0.074101
# 51                 0.018607                0.040779              0.059796
# 6                  0.014964                0.040715              0.045866
# 45                 0.015561                0.040471              0.045337
# 18                 0.015234                0.040438              0.045351
# 24                 0.007778                0.020105              0.022504
# 39                 0.001482                0.001807              0.006307
# 3                  0.001779                0.001779              0.001779
# 42                 0.001214                0.001752              0.004349
# 36                 0.000976                0.001697              0.002469
# 9                  0.000814                0.001535              0.002408
# 15                 0.000478                0.000869              0.001224
# 21                 0.000808                0.000808              0.000808
# 12                 0.000010                0.000010              0.000010
#
#     fourier_minus_advanced  percentage_of_room_filled
# 30                0.043418                  55.948876
# 33                0.047486                  68.198654
# 0                 0.052360                  89.012541
# 27                0.051187                  88.493021
# 48                0.019988                  55.204108
# 51                0.022172                  68.196693
# 6                 0.025751                  88.769048
# 45                0.024910                  89.266011
# 18                0.025204                  89.167268
# 24                0.012326                  89.336378
# 39                0.000324                  28.644467
# 3                 0.000000                 100.000000
# 42                0.000538                  40.287041
# 36                0.000721                  68.745143
# 9                 0.000721                  63.740554
# 15                0.000391                  70.964369
# 21                0.000000                 100.000000
# 12                0.000000                 100.000000
#
# [18 rows x 45 columns]

# %% [markdown]
# ### Measure improvement for balanced datasets <a class="anchor" id="balanced-dataset">
#
# Most of our dataset selections are not balanced, and we didn't do anything to mitigate
# unablanced datasets. This is because we are measuring the baseline and improvement on the
# same dataset.
#
# However, we will select those instances where the datasets were balanced to see if the
# improvement is still significant in these instances.
#
# [top](#Contents)

# %%
df[df["ratio_encrypt_nonencrypt"] == 1.0]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 16                        False                      True
# 52                        False                     False
# 19                        False                      True
# 20                        False                      True
# 53                        False                     False
# 8                         False                      True
# 51                        False                     False
# 6                         False                      True
# 7                         False                      True
# 18                        False                      True
# 17                        False                      True
# 15                        False                      True
# 21                        False                      True
# 23                        False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 16                 False                  True                     False
# 52                 False                 False                     False
# 19                 False                 False                      True
# 20                 False                 False                      True
# 53                 False                 False                     False
# 8                   True                 False                     False
# 51                 False                 False                     False
# 6                   True                 False                     False
# 7                   True                 False                     False
# 18                 False                 False                      True
# 17                 False                  True                     False
# 15                 False                  True                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 16                        False         False             True
# 52                        False         False             True
# 19                        False         False             True
# 20                        False         False            False
# 53                        False         False            False
# 8                         False         False            False
# 51                        False          True            False
# 6                         False          True            False
# 7                         False         False             True
# 18                        False          True            False
# 17                        False         False            False
# 15                        False          True            False
# 21                         True          True            False
# 23                         True         False            False
# 22                         True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 16           0.868291                 0.878261  ...              0.923336
# 52           0.796839                 0.811545  ...              0.814514
# 19           0.810004                 0.824490  ...              0.818656
# 20           0.908785                 0.911126  ...              0.938116
# 53           0.896003                 0.898914  ...              0.928237
# 8            0.916562                 0.920915  ...              0.931004
# 51           0.940204                 0.942269  ...              0.972551
# 6            0.954134                 0.955376  ...              0.991580
# 7            0.862443                 0.874585  ...              0.839067
# 18           0.954649                 0.955813  ...              0.992636
# 17           0.951890                 0.952441  ...              0.975319
# 15           0.998776                 0.998776  ...              0.999817
# 21           0.999192                 0.999193  ...              1.000000
# 23           0.999484                 0.999484  ...              1.000000
# 22           1.000000                 1.000000  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 16        63250            63250                       1.0       0.946992
# 52       126500           126500                       1.0       0.862600
# 19        63250            63250                       1.0       0.874417
# 20       161706           161706                       1.0       0.952802
# 53       323412           323412                       1.0       0.939706
# 8        161706           161706                       1.0       0.959570
# 51       196912           196912                       1.0       0.980983
# 6         98456            98456                       1.0       0.994849
# 7         63250            63250                       1.0       0.903055
# 18        98456            98456                       1.0       0.995087
# 17       161706           161706                       1.0       0.978496
# 15        98456            98456                       1.0       0.999645
# 21        98456            98456                       1.0       1.000000
# 23       161706           161706                       1.0       1.000000
# 22        63250            63250                       1.0       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 16                 0.071319                0.078701              0.131709
# 52                 0.055450                0.065761              0.203161
# 19                 0.058071                0.064413              0.189996
# 20                 0.025140                0.044017              0.091215
# 53                 0.025717                0.043703              0.103997
# 8                  0.025906                0.043008              0.083438
# 51                 0.018607                0.040779              0.059796
# 6                  0.014964                0.040715              0.045866
# 7                  0.038126                0.040612              0.137557
# 18                 0.015234                0.040438              0.045351
# 17                 0.023090                0.026606              0.048110
# 15                 0.000478                0.000869              0.001224
# 21                 0.000808                0.000808              0.000808
# 23                 0.000516                0.000516              0.000516
# 22                 0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 16                0.007382                  59.753892
# 52                0.010312                  32.368912
# 19                0.006342                  33.902366
# 20                0.018877                  48.256429
# 53                0.017986                  42.023209
# 8                 0.017103                  51.545381
# 51                0.022172                  68.196693
# 6                 0.025751                  88.769048
# 7                 0.002486                  29.523747
# 18                0.025204                  89.167268
# 17                0.003515                  55.302286
# 15                0.000391                  70.964369
# 21                0.000000                 100.000000
# 23                0.000000                 100.000000
# 22                0.000000                        NaN
#
# [15 rows x 45 columns]

# %% [markdown]
# ### Measure the improvement when all files are used <a class="anchor" id="full-dataset">
#
# In most of our dataset selections, we excluded some data points based on our criteria.
#
# In this, we measure the improvement when we use all data points
#
# [top](#Contents)

# %%
# Measure everything for the full dataset
df2 = df
for colname in df2.columns:
    if "exclude" in colname:
        df2 = df2[df2[colname] == False]
df2
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 53                        False                     False
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 53                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 53                        False         False            False
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 53           0.896003                 0.898914  ...              0.928237
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 53       323412           323412                       1.0       0.939706
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 53                 0.025717                0.043703              0.103997
#
#     fourier_minus_advanced  percentage_of_room_filled
# 53                0.017986                  42.023209
#
# [1 rows x 45 columns]

# %%
df2[[c for c in df2.columns if "baseline" in c or "fourier" in c or "advanced-only" in c]]
# Out:
#     baseline-f1_score  baseline-accuracy_score  baseline-precision_score  \
# 53           0.896003                 0.898914                  0.922575
#
#     baseline-recall_score  advanced-only-f1_score  \
# 53                0.87092                0.904735
#
#     advanced-only-accuracy_score  advanced-only-precision_score  \
# 53                      0.907476                       0.932356
#
#     advanced-only-recall_score  fourier-only-f1_score  \
# 53                    0.878703               0.797437
#
#     fourier-only-accuracy_score  ...  advanced-and-fourier-f1_score  \
# 53                     0.765066  ...                       0.933094
#
#     advanced-and-fourier-accuracy_score  advanced-and-fourier-precision_score  \
# 53                             0.934021                              0.946384
#
#     advanced-and-fourier-recall_score  fourier-f1_score  \
# 53                           0.920173          0.939706
#
#     fourier-accuracy_score  fourier-precision_score  fourier-recall_score  \
# 53                0.940441                 0.951462              0.928237
#
#     improvement_in_fourier  fourier_minus_advanced
# 53                0.043703                0.017986
#
# [1 rows x 26 columns]

# %%
df.to_csv("../comparison_logistic_regression_final.csv")

# %% [markdown]
# ### Focus on items where the base metrics performed well <a class="anchor" id="focus-greater-90">
#
# We see that in all cases, plaintext non-base 32 only is selected. Also we
# see that for encrypted, only base32 is selected and non-base32 excluded.
#
# Fundamentally, what this is measuring is when the plaintext has all files
# but all encrypted content is base-32 encoded.
#
# Typically, base-32 encoding will lead to a reduction of entropy, in many cases
# much less than the original text, and this is what it is measuring.
#
# [top](#Contents)

# %%
df[df["baseline-f1_score"] > 0.9]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 0                         False                      True
# 27                        False                     False
# 11                        False                      True
# 38                        False                     False
# 20                        False                      True
# 8                         False                      True
# 47                        False                     False
# 48                        False                     False
# 51                        False                     False
# 6                         False                      True
# 45                        False                     False
# 18                        False                      True
# 25                        False                      True
# 17                        False                      True
# 26                        False                      True
# 24                        False                      True
# 39                        False                     False
# 3                         False                      True
# 42                        False                     False
# 36                        False                     False
# 9                         False                      True
# 5                         False                      True
# 15                        False                      True
# 21                        False                      True
# 23                        False                      True
# 12                        False                      True
# 14                        False                      True
# 13                        False                      True
# 4                         False                      True
# 22                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 0                   True                 False                      True
# 27                  True                 False                      True
# 11                 False                  True                      True
# 38                 False                  True                      True
# 20                 False                 False                      True
# 8                   True                 False                     False
# 47                 False                 False                      True
# 48                 False                 False                     False
# 51                 False                 False                     False
# 6                   True                 False                     False
# 45                 False                 False                      True
# 18                 False                 False                      True
# 25                 False                 False                     False
# 17                 False                  True                     False
# 26                 False                 False                     False
# 24                 False                 False                     False
# 39                 False                  True                     False
# 3                   True                 False                     False
# 42                 False                  True                     False
# 36                 False                  True                      True
# 9                  False                  True                      True
# 5                   True                 False                     False
# 15                 False                  True                     False
# 21                 False                 False                     False
# 23                 False                 False                     False
# 12                 False                  True                     False
# 14                 False                  True                     False
# 13                 False                  True                     False
# 4                   True                 False                     False
# 22                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 0                         False          True            False
# 27                        False          True            False
# 11                        False         False            False
# 38                        False         False            False
# 20                        False         False            False
# 8                         False         False            False
# 47                        False         False            False
# 48                         True          True            False
# 51                        False          True            False
# 6                         False          True            False
# 45                        False          True            False
# 18                        False          True            False
# 25                        False         False             True
# 17                        False         False            False
# 26                        False         False            False
# 24                        False          True            False
# 39                         True          True            False
# 3                          True          True            False
# 42                        False          True            False
# 36                        False          True            False
# 9                         False          True            False
# 5                          True         False            False
# 15                        False          True            False
# 21                         True          True            False
# 23                         True         False            False
# 12                         True          True            False
# 14                         True         False            False
# 13                         True         False             True
# 4                          True         False             True
# 22                         True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 0            0.906860                 0.941111  ...              0.983383
# 27           0.907049                 0.964841  ...              0.982652
# 11           0.903524                 0.937277  ...              0.951740
# 38           0.904075                 0.962520  ...              0.951121
# 20           0.908785                 0.911126  ...              0.938116
# 8            0.916562                 0.920915  ...              0.931004
# 47           0.909485                 0.941198  ...              0.937714
# 48           0.925899                 0.952686  ...              0.952425
# 51           0.940204                 0.942269  ...              0.972551
# 6            0.954134                 0.955376  ...              0.991580
# 42                 0.001214                0.001752              0.004349
# 36                 0.000976                0.001697              0.002469
# 9                  0.000814                0.001535              0.002408
# 5                  0.000947                0.000947              0.000947
# 15                 0.000478                0.000869              0.001224
# 21                 0.000808                0.000808              0.000808
# 23                 0.000516                0.000516              0.000516
# 12                 0.000010                0.000010              0.000010
# 14                 0.000006                0.000006              0.000006
# 13                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 0                 0.052360                  89.012541
# 27                0.051187                  88.493021
# 11                0.007414                  56.126687
# 38                0.007762                  55.116733
# 20                0.018877                  48.256429
# 8                 0.017103                  51.545381
# 47                0.019022                  47.318871
# 48                0.019988                  55.204108
# 51                0.022172                  68.196693
# 6                 0.025751                  88.769048
# 45                0.024910                  89.266011
# 18                0.025204                  89.167268
# 25                0.002865                  33.526155
# 17                0.003515                  55.302286
# 26                0.008951                  46.914727
# 24                0.012326                  89.336378
# 39                0.000324                  28.644467
# 3                 0.000000                 100.000000
# 42                0.000538                  40.287041
# 36                0.000721                  68.745143
# 9                 0.000721                  63.740554
# 5                 0.000000                 100.000000
# 15                0.000391                  70.964369
# 21                0.000000                 100.000000
# 23                0.000000                 100.000000
# 12                0.000000                 100.000000
# 14                0.000000                 100.000000
# 13                0.000000                        NaN
# 4                 0.000000                        NaN
# 22                0.000000                        NaN
#
# [30 rows x 45 columns]

# %% [markdown]
# ### Correlation of data set and performance <a class="anchor" id="corr-heatmap">
#
# This gives more idea on how data-set selection affects performance.
#
# [top](#Contents)

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,10)
df2 = df[[c for c in df.columns if \
          "precision" not in c and \
          "accuracy" not in c and \
          "recall" not in c]]
sns.heatmap(df2.astype(float).corr(), cmap='coolwarm')
# print(df[df["baseline-f1_score"] > 0.9].astype(float))
_ = plt.xticks(rotation=80)

# %%
df1 = df[["exclude_encrypted_base32", \
          "exclude_encrypted_v2", \
          "exclude_plaintext_base32",\
          "exclude_webp", \
          "baseline-f1_score", \
          "advanced-f1_score", \
          "fourier-f1_score",
          "fourier-only-f1_score",
          "advanced-only-f1_score",
          ]]
sns.heatmap(df1.astype(float).corr(), cmap='coolwarm')
_ = plt.xticks(rotation=80)

# %% [markdown]
# ### Average out all the metrics <a class="anchor" id="mean-fscores">
#
# To conclude we report the average of the f1-scores and the improvements with all datasets
#
# [top](#Contents)

# %%
df[[c for c in df.columns if ("score" in c or "improvement" in c) and "room" not in c]].mean()
# Out:
# baseline-f1_score                       0.880013
# baseline-accuracy_score                 0.930481
# baseline-precision_score                0.939605
# baseline-recall_score                   0.835550
# advanced-only-f1_score                  0.907818
# advanced-only-accuracy_score            0.944956
# advanced-only-precision_score           0.955664
# advanced-only-recall_score              0.869634
# fourier-only-f1_score                   0.734340
# fourier-only-accuracy_score             0.878111
# fourier-only-precision_score            0.874365
# fourier-only-recall_score               0.714305
# baseline-and-fourier-f1_score           0.888630
# baseline-precision_score              0.904797  0.947519  0.991798  1.000000
# baseline-recall_score                 0.741426  0.872262  0.987583  1.000000
# advanced-only-f1_score                0.862454  0.926994  0.982531  1.000000
# advanced-only-accuracy_score          0.914900  0.947379  0.989676  1.000000
# advanced-only-precision_score         0.931267  0.957966  0.989792  1.000000
# advanced-only-recall_score            0.804435  0.895691  0.977320  1.000000
# fourier-only-f1_score                 0.675207  0.834657  0.972472  1.000000
# fourier-only-accuracy_score           0.808489  0.875038  0.978847  1.000000
# fourier-only-precision_score          0.764098  0.920985  0.983257  1.000000
# fourier-only-recall_score             0.516844  0.880595  0.982931  1.000000
# baseline-and-fourier-f1_score         0.842376  0.938457  0.993584  1.000000
# baseline-and-fourier-accuracy_score   0.897714  0.956597  0.995712  1.000000
# baseline-and-fourier-precision_score  0.906193  0.967852  0.996915  1.000000
# baseline-and-fourier-recall_score     0.778506  0.940768  0.996380  1.000000
# advanced-and-fourier-f1_score         0.892823  0.953338  0.995818  1.000000
# advanced-and-fourier-accuracy_score   0.929955  0.967687  0.997133  1.000000
# advanced-and-fourier-precision_score  0.941456  0.976321  0.997868  1.000000
# advanced-and-fourier-recall_score     0.843391  0.935276  0.995838  1.000000
# advanced-f1_score                     0.876376  0.938255  0.992700  1.000000
# advanced-accuracy_score               0.923955  0.958336  0.993566  1.000000
# advanced-precision_score              0.937304  0.968849  0.993913  1.000000
# advanced-recall_score                 0.814889  0.911342  0.992033  1.000000
# fourier-f1_score                      0.894445  0.957309  0.996927  1.000000
# fourier-accuracy_score                0.932670  0.972087  0.997848  1.000000
# fourier-precision_score               0.945084  0.977563  0.997992  1.000000
# fourier-recall_score                  0.845486  0.940265  0.997240  1.000000
# best_f1_score                         0.894445  0.957309  0.996927  1.000000
# improvement_in_advanced               0.003279  0.027706  0.055270  0.164691
# improvement_in_fourier                0.006381  0.043860  0.085132  0.182351

# %%
df1 = df[[c for c in df.columns if \
          ("score" in c or "improvement" in c) \
          and "room" not in c]]
columns = ["baseline-f1_score"]
columns += [c for c in df1.columns if "only" in c]
columns += [c for c in df1.columns if "-and-" in c]
columns += [c for c in df1.columns if "only" not in c \
            and "-and-" not in c and "baseline-f1_score" != c]
df1[columns].describe().T
# Out:
#                                       count      mean       std       min  \
# baseline-f1_score                      54.0  0.880013  0.114956  0.570486
# advanced-only-f1_score                 54.0  0.907818  0.084977  0.636478
# advanced-only-accuracy_score           54.0  0.944956  0.043531  0.840690
# advanced-only-precision_score          54.0  0.955664  0.036919  0.863823
# advanced-only-recall_score             54.0  0.869634  0.120758  0.503874
# fourier-only-f1_score                  54.0  0.734340  0.298946  0.018151
# fourier-only-accuracy_score            54.0  0.878111  0.098882  0.677692
# fourier-only-precision_score           54.0  0.874365  0.125534  0.564108
# fourier-only-recall_score              54.0  0.714305  0.337490  0.009233
# baseline-and-fourier-f1_score          54.0  0.888630  0.131571  0.457295
# baseline-and-fourier-accuracy_score    54.0  0.939137  0.060136  0.790978
# fourier-precision_score               0.945084  0.977563  0.997992  1.000000
# fourier-recall_score                  0.845486  0.940265  0.997240  1.000000
# best_f1_score                         0.894445  0.957309  0.996927  1.000000
# improvement_in_advanced               0.003279  0.027706  0.055270  0.164691
# improvement_in_fourier                0.006381  0.043860  0.085132  0.182351

# %% [markdown]
# # Reporting for the final report <a class="anchor" id="report">
#
# [top](#Contents)

# %%
def regroup(df):
    def get_name(name):
        if "score" not in name.lower():
            return None, None
        feature = name
        measure = None

        measure_map = {
            "f1_score": "F1",
            "accuracy_score": "Accuracy",
            "precision_score": "Precision",
            "recall_score": "Recall"
        }
        featurename_map = {
            "fourier-only-": "Fourier Only",
            "advanced-only-": "Advanced Only",
            "baseline-and-fourier": "Baseline and Fourier",
            "advanced-and-fourier": "Advanced and Fourier",
            "baseline-and-advanced": "Baseline and Advanced",
            "fourier-": "Baseline, Advanced and Fourier",
            "baseline-": "Baseline",
            "advanced-": "Baseline and Advanced",
        }
        for i, j in measure_map.items():
            if i in name:
                measure = j
                break
        for i, j in featurename_map.items():
            if i in name:
                feature = j
                break
        return name, feature, measure

    pd.DataFrame({"Score": df.mean()})
    indices = list(df.mean().index)
    values = df.mean().to_numpy()
    df_acc = pd.DataFrame({"Original":["dummy"], "Feature": ["dummy"], "MeasureName": ["dummy"], "MeasureValue": [0.0]})


    for name, value in zip(indices, values):
        if "score" in name.lower():
            orname, featurename, measurename = get_name(name)
            if featurename is not None:
                tempdf = pd.DataFrame({"Original": [orname], "Feature": [featurename], "MeasureName": [measurename], "MeasureValue": [value]})
                df_acc = pd.concat([df_acc, tempdf]).copy()
    df_acc = df_acc[df_acc["Feature"] != "dummy"]  
    df_acc = df_acc[df_acc["Original"] != "best_f1_score"]
    return df_acc


def regroup_and_pivot(df):
    acc_df = regroup(df)
    acc_df = acc_df[["Feature", "MeasureName", "MeasureValue"]]
    return acc_df.pivot(index="Feature", columns="MeasureName", values="MeasureValue")

# %%
df = pd.read_csv("comparison_logistic_regression_final.csv")
df2 = regroup_and_pivot(df.copy())
print(df2.to_latex())
df2
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.944956 &  0.907818 &   0.955664 &  0.869634 \\
# Advanced and Fourier           &  0.959103 &  0.930944 &   0.967481 &  0.901837 \\
# Baseline                       &  0.930481 &  0.880013 &   0.939605 &  0.835550 \\
# Baseline and Advanced          &  0.952499 &  0.920670 &   0.963147 &  0.886634 \\
# Baseline and Fourier           &  0.939137 &  0.888630 &   0.947858 &  0.853430 \\
# Baseline, Advanced and Fourier &  0.961236 &  0.934905 &   0.969696 &  0.907093 \\
# Fourier Only                   &  0.878111 &  0.734340 &   0.874365 &  0.714305 \\
# \bottomrule
# \end{tabular}
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Advanced Only                   0.944956  0.907818   0.955664  0.869634
# Advanced and Fourier            0.959103  0.930944   0.967481  0.901837
# Baseline                        0.930481  0.880013   0.939605  0.835550
# Baseline and Advanced           0.952499  0.920670   0.963147  0.886634
# Baseline and Fourier            0.939137  0.888630   0.947858  0.853430
# Baseline, Advanced and Fourier  0.961236  0.934905   0.969696  0.907093
# Fourier Only                    0.878111  0.734340   0.874365  0.714305

# %%
df2 = df[(df["exclude_webp"] == 0) & (df["exclude_nonwebp"] == 1) ]
df2 = regroup_and_pivot(df2.copy())
print(df2.to_latex())
df2
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.915112 &  0.853293 &   0.934349 &  0.792184 \\
# Advanced and Fourier           &  0.922660 &  0.867648 &   0.943598 &  0.809628 \\
# Baseline                       &  0.881184 &  0.786780 &   0.896356 &  0.711490 \\
# Baseline and Advanced          &  0.919927 &  0.862616 &   0.940811 &  0.803261 \\
# Baseline and Fourier           &  0.883233 &  0.777226 &   0.915626 &  0.697266 \\
# Baseline, Advanced and Fourier &  0.924665 &  0.871544 &   0.946117 &  0.814310 \\
# Fourier Only                   &  0.810274 &  0.543472 &   0.810364 &  0.504986 \\
# \bottomrule
# \end{tabular}
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Advanced Only                   0.915112  0.853293   0.934349  0.792184
# Advanced and Fourier            0.922660  0.867648   0.943598  0.809628
# Baseline                        0.881184  0.786780   0.896356  0.711490
# Baseline and Advanced           0.919927  0.862616   0.940811  0.803261
# Baseline and Fourier            0.883233  0.777226   0.915626  0.697266
# Baseline, Advanced and Fourier  0.924665  0.871544   0.946117  0.814310
# Fourier Only                    0.810274  0.543472   0.810364  0.504986

# %%
df2 = df[(df["exclude_webp"] == 1) & (df["exclude_nonwebp"] == 0) ]
df2 = regroup_and_pivot(df2.copy())
print(df2.to_latex())
df2
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.971724 &  0.955465 &   0.979503 &  0.933875 \\
# Advanced and Fourier           &  0.991132 &  0.985029 &   0.992465 &  0.978058 \\
# Baseline                       &  0.972556 &  0.956461 &   0.981187 &  0.934501 \\
# Baseline and Advanced          &  0.981003 &  0.970149 &   0.986928 &  0.954709 \\
# Baseline and Fourier           &  0.990470 &  0.984122 &   0.990169 &  0.978490 \\
# Baseline, Advanced and Fourier &  0.992995 &  0.988343 &   0.993957 &  0.982983 \\
# Fourier Only                   &  0.958172 &  0.919927 &   0.955918 &  0.901808 \\
# \bottomrule
# \end{tabular}
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Advanced Only                   0.971724  0.955465   0.979503  0.933875
# Advanced and Fourier            0.991132  0.985029   0.992465  0.978058
# Baseline                        0.972556  0.956461   0.981187  0.934501
# Baseline and Advanced           0.981003  0.970149   0.986928  0.954709
# Baseline and Fourier            0.990470  0.984122   0.990169  0.978490
# Baseline, Advanced and Fourier  0.992995  0.988343   0.993957  0.982983
# Fourier Only                    0.958172  0.919927   0.955918  0.901808

# %%
df2 = df[(df["exclude_webp"] == 0) & (df["exclude_nonwebp"] == 1) ]
df2 = df.copy()
df2 = df2[[c for c in df2.columns if "score" in c]]
df2 = df2.describe().T
df2 = df2["std"]

def get_name(name):
    if "score" not in name.lower():
        return None, None
    feature = name
    measure = None

    measure_map = {
        "f1_score": "F1",
        "accuracy_score": "Accuracy",
        "precision_score": "Precision",
        "recall_score": "Recall"
    }
    featurename_map = {
        "fourier-only-": "Fourier Only",
        "advanced-only-": "Advanced Only",
        "baseline-and-fourier": "Baseline and Fourier",
        "advanced-and-fourier": "Advanced and Fourier",
        "baseline-and-advanced": "Baseline and Advanced",
        "fourier-": "Baseline, Advanced and Fourier",
        "baseline-": "Baseline",
        "advanced-": "Baseline and Advanced",
    }
    for i, j in measure_map.items():
        if i in name:
            measure = j
            break
    for i, j in featurename_map.items():
        if i in name:
            feature = j
            break
    return name, feature, measure


indices = list(df2.index)
values = df2.to_numpy()
df_acc = pd.DataFrame({"Original":["dummy"], "Feature": ["dummy"], "MeasureName": ["dummy"], "MeasureValue": [0.0]})


for name, value in zip(indices, values):
    if "score" in name.lower():
        orname, featurename, measurename = get_name(name)
        if featurename is not None:
            tempdf = pd.DataFrame({"Original": [orname], "Feature": [featurename], "MeasureName": [measurename], "MeasureValue": [value]})
            df_acc = pd.concat([df_acc, tempdf]).copy()
df_acc = df_acc[df_acc["Feature"] != "dummy"]  
df_acc = df_acc[df_acc["Original"] != "best_f1_score"]
df_acc = df_acc[[c for c in df_acc.columns if "Original" != c]]

df_acc = df_acc.pivot(index="Feature", columns="MeasureName", values="MeasureValue")
print(df_acc.to_latex())
df_acc
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.043531 &  0.084977 &   0.036919 &  0.120758 \\
# Advanced and Fourier           &  0.040863 &  0.077458 &   0.032730 &  0.112939 \\
# Baseline                       &  0.057713 &  0.114956 &   0.054548 &  0.155797 \\
# Baseline and Advanced          &  0.040893 &  0.078630 &   0.032483 &  0.114127 \\
# Baseline and Fourier           &  0.060136 &  0.131571 &   0.054135 &  0.182847 \\
# Baseline, Advanced and Fourier &  0.039764 &  0.074468 &   0.030772 &  0.109578 \\
# Fourier Only                   &  0.098882 &  0.298946 &   0.125534 &  0.337490 \\
# \bottomrule
# \end{tabular}
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Advanced Only                   0.043531  0.084977   0.036919  0.120758
# Advanced and Fourier            0.040863  0.077458   0.032730  0.112939
# Baseline                        0.057713  0.114956   0.054548  0.155797
# Baseline and Advanced           0.040893  0.078630   0.032483  0.114127
# Baseline and Fourier            0.060136  0.131571   0.054135  0.182847
# Baseline, Advanced and Fourier  0.039764  0.074468   0.030772  0.109578
# Fourier Only                    0.098882  0.298946   0.125534  0.337490

# %%
df2 = df[(df["exclude_webp"] == 0) & (df["exclude_nonwebp"] == 1) ]
#df2 = df.copy()
df2 = df2[[c for c in df2.columns if "score" in c]]
df2 = df2.describe().T
df2 = df2["std"]

def get_name(name):
    if "score" not in name.lower():
        return None, None
    feature = name
    measure = None

    measure_map = {
        "f1_score": "F1",
        "accuracy_score": "Accuracy",
        "precision_score": "Precision",
        "recall_score": "Recall"
    }
    featurename_map = {
        "fourier-only-": "Fourier Only",
        "advanced-only-": "Advanced Only",
        "baseline-and-fourier": "Baseline and Fourier",
        "advanced-and-fourier": "Advanced and Fourier",
        "baseline-and-advanced": "Baseline and Advanced",
        "fourier-": "Baseline, Advanced and Fourier",
        "baseline-": "Baseline",
        "advanced-": "Baseline and Advanced",
    }
    for i, j in measure_map.items():
        if i in name:
            measure = j
            break
    for i, j in featurename_map.items():
        if i in name:
            feature = j
            break
    return name, feature, measure


indices = list(df2.index)
values = df2.to_numpy()
df_acc = pd.DataFrame({"Original":["dummy"], "Feature": ["dummy"], "MeasureName": ["dummy"], "MeasureValue": [0.0]})


for name, value in zip(indices, values):
    if "score" in name.lower():
        orname, featurename, measurename = get_name(name)
        if featurename is not None:
            tempdf = pd.DataFrame({"Original": [orname], "Feature": [featurename], "MeasureName": [measurename], "MeasureValue": [value]})
            df_acc = pd.concat([df_acc, tempdf]).copy()
df_acc = df_acc[df_acc["Feature"] != "dummy"]  
df_acc = df_acc[df_acc["Original"] != "best_f1_score"]
df_acc = df_acc[[c for c in df_acc.columns if "Original" != c]]

df_acc = df_acc.pivot(index="Feature", columns="MeasureName", values="MeasureValue")
print(df_acc.to_latex())
df_acc
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.048446 &  0.100582 &   0.042906 &  0.140251 \\
# Advanced and Fourier           &  0.044377 &  0.090569 &   0.036402 &  0.130619 \\
# Baseline                       &  0.062108 &  0.132695 &   0.062570 &  0.176662 \\
# Baseline and Advanced          &  0.045279 &  0.092976 &   0.037155 &  0.133081 \\
# Baseline and Fourier           &  0.061962 &  0.156161 &   0.052769 &  0.210129 \\
# Baseline, Advanced and Fourier &  0.043113 &  0.087194 &   0.034476 &  0.127242 \\
# Fourier Only                   &  0.102750 &  0.359471 &   0.136768 &  0.385806 \\
# \bottomrule
# \end{tabular}
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Advanced Only                   0.048446  0.100582   0.042906  0.140251
# Advanced and Fourier            0.044377  0.090569   0.036402  0.130619
# Baseline                        0.062108  0.132695   0.062570  0.176662
# Baseline and Advanced           0.045279  0.092976   0.037155  0.133081
# Baseline and Fourier            0.061962  0.156161   0.052769  0.210129
# Baseline, Advanced and Fourier  0.043113  0.087194   0.034476  0.127242
# Fourier Only                    0.102750  0.359471   0.136768  0.385806
