# %% [markdown]
# Few key observations
# - If both and non-encrypted files are base-32 encoded, accuracy drops really low.
#    * Even in this case, fourier analysis (specifically autocorrelation and mean) provide good discrminators
#    * Renyi's entropy at alpha=infinity gives good discrimination
#    * Overall we see around 13% improvement in F1-score
# - Specifically for webpfiles
#    * We see that higher moments of around 14 gives a good discrimination
#    * Fourier analysis still gives benefits here
# - For webpfiles where both unencrypted and encrypted content are base32 encrypted
#    * Fourier analysis is still beneficial
# - For Non-webp files where plaintext is not base-32 encrypted
#    * Accuracy is decent with just the base parameters, but with fourier analysis, we can close to perfect detection

# %% [markdown]
# # Contents
# - ## [Implementation](#mplementation)
#  - ### [List of Files](#list-of-files)
#  - ### [Utility to call gc](#gc)
#  - ### [Selection of Columns](#select-columns)
#  - ### [Function to compare the three selections of columns for a given dataset](#compare-fn)
#  - ### [Load the datasets](#load-dataset)
#  - ### [Select the datasets](#dataset-selection)
#  - ### [Run all combinations of data](#dataset-selection)
# - ## [Results](#results)
#  - ### [Print the raw results](#raw-results)
#  - ### [Sort by the improvement when using Fourier transforms over baseline](#sorted-fourier)
#  - ### [Measure improvement when only webp files are used](#webp-only)
#  - ### [Measure improvement when webp files are not present](#no-webp)
#  - ### [Measure improvement for balanced datasets](#balanced-dataset)
#  - ### [Measure the improvement when all files are used](#full-dataset)
#  - ### [Focus on items where the base metrics performed well](#focus-greater-90)
#  - ### [Correlation of data set and performance]("corr-heatmap")
#  - ### [Average out all the metrics](#mean-fscores)
#
# - # [Reporting for the final report](#report)

# %% [markdown]
# ## Implementation <a class="anchor" id="implementation">
#
# [top](#Contents)

# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats

from functools import lru_cache

import gc

import sklearn
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, accuracy_score, recall_score

import matplotlib.pyplot as plt
import glob

import tqdm
from multiprocessing.pool import ThreadPool, Pool

plt.rcParams["figure.figsize"] = (20,20)

# %%
# !ls
# Out:
# LR_CS5_DES3.ipynb                     gd.sampled.encrypted.v2.base32.csv.gz
# RF_CS5_DES3.ipynb                     gd.sampled.encrypted.v2.csv.gz
# gd.sampled.encrypted.v1.base32.csv.gz gd.sampled.pt.base32.csv.gz
# gd.sampled.encrypted.v1.csv.gz        gd.sampled.pt.csv.gz

# %% [markdown]
# ### List of files <a class="anchor" id="list-of-files">
#
# [top](#Contents)

# %%
# !ls
# Out:
# LR_CS5_DES3.ipynb                     gd.sampled.encrypted.v2.base32.csv.gz
# RF_CS5_DES3.ipynb                     gd.sampled.encrypted.v2.csv.gz
# gd.sampled.encrypted.v1.base32.csv.gz gd.sampled.pt.base32.csv.gz
# gd.sampled.encrypted.v1.csv.gz        gd.sampled.pt.csv.gz

# %% [markdown]
# ### Utility to call GC <a class="anchor" id="gc">
#
# [top](#Contents)

# %%
def call_gc():
    for i in range(3):
        for j in range(3):
            gc.collect(j)

# %% [markdown]
# ### Selection of columns <a class="anchor" id="select-columns">
#
# This function is used to select the columns.
# There are three different configurations:
#
#     1. Baseline - statistics like autocorrelation, shannon entropy, chi-square etc. are used
#
#     2. Advanced - More statistics like moments, Tsallis and Renyi entropy, higher moments etc.
#
#     3. Fourier - Some statistics of the Fourier Power Spectrum distribution
#
# [top](#Contents)

# %%
def get_columns(thisdf):
    baseline_columns = [c for c in thisdf.columns if c.startswith('baseline') and "head" not in c and "tail" not in c]
    baseline_columns = [c for c in baseline_columns if "filesize" not in c]
    baseline_columns = [c for c in baseline_columns if "begin" not in c and "end" not in c]

    advanced_columns = [c for c in thisdf.columns if "advanced" in c]
    advanced_columns = [c for c in advanced_columns if "begin" not in c and "end" not in c]
    advanced_columns = [c for c in advanced_columns if "head" not in c and "tail" not in c]
    advanced_columns = [c for c in advanced_columns if "start" not in c]
    advanced_columns_only = list(set(advanced_columns))
    advanced_columns = list(set(advanced_columns + baseline_columns))

    fourier_columns = [c for c in thisdf.columns if "fourier" in c and "value" not in c]
    fourier_columns = [c for c in fourier_columns if "1byte" in c]
    fourier_columns = [c for c in fourier_columns if "begin" not in c and "end" not in c]
    fourier_columns = [c for c in fourier_columns if "head" not in c and "tail" not in c]
    fourier_columns = [c for c in fourier_columns if "start" not in c]
    fourier_columns_only = list(set(fourier_columns))
    fourier_columns = list(set(advanced_columns + fourier_columns))
    
    baseline_and_advanced = list(set(baseline_columns + advanced_columns_only))
    baseline_and_fourier = list(set(baseline_columns + fourier_columns_only))
    advanced_and_fourier = list(set(advanced_columns_only + fourier_columns_only))
    
    return {\
        "baseline": baseline_columns,\
        "advanced-only": advanced_columns_only,\
        "fourier-only": fourier_columns_only,\
        "baseline-and-fourier": baseline_and_fourier,\
        "advanced-and-fourier": advanced_and_fourier,\
        "advanced": advanced_columns,\
        "fourier": fourier_columns,\
    }

# %% [markdown]
# ### Function to compare the three selections of columns for a given dataset <a class="anchor" id="compare-fn">
#
# For the three different sets of measurements described above, compare all the three sets for their f1 score
#
# [top](#Contents)

# %%
USE_ASYNC = False
N_SPLITS=5

def get_kfold_f1_score(name, collist, X, y):
    skf = StratifiedKFold(n_splits=N_SPLITS, random_state=42, shuffle=True)
    f1_scores = []
    precision_scores = []
    recall_scores = []
    accuracy_scores = []
    X = X[collist].to_numpy()
    y = y.to_numpy()
    call_gc()
    for train_idx, test_idx in skf.split(X, y):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]
        lr = LogisticRegression(n_jobs=8, \
                                solver='saga', \
                                random_state=42, \
                                max_iter=1000, \
                                multi_class='ovr')
        estimators = [\
                      ('std,', MinMaxScaler()), \
                      ('LogisticRegression', lr)]
        pipeline = Pipeline(estimators)
        pipeline.fit(X_train, y_train)
        y_pred = pipeline.predict(X_test)
        f1_scores.append(f1_score(y_test, y_pred))
        recall_scores.append(recall_score(y_test, y_pred))
        precision_scores.append(precision_score(y_test, y_pred, zero_division=0))
        accuracy_scores.append(accuracy_score(y_test, y_pred))

    return name, \
            float(np.mean(f1_scores)),\
            float(np.mean(accuracy_scores)),\
            float(np.mean(precision_scores)),\
            float(np.mean(recall_scores)),

def compare_feature_selections_async(X, y):
    columns_dict = get_columns(X)
    ret = dict()
    pool = Pool(3)
    async_results = list()
    for name, collist in columns_dict.items():
        result = pool.apply_async(\
                                  get_kfold_f1_score, \
                                  (name, collist, X, y))
    for result in async_results:
        name, f1 = result.get(timeout=None)
        ret[name] = f1
    return ret

def compare_feature_selections_sync(X, y):
    columns_dict = get_columns(X)
    ret = dict()
    for name, collist in columns_dict.items():
        name, f1, accuracy, precision, recall = \
            get_kfold_f1_score(name, collist, X, y)
        ret[f"{name}-f1_score"] = f1
        ret[f"{name}-accuracy_score"] = accuracy
        ret[f"{name}-precision_score"] = precision
        ret[f"{name}-recall_score"] = recall
    return ret

def compare_feature_selections(X, y):
    if USE_ASYNC:
        return compare_feature_selections_async(X, y)
    else:
        return compare_feature_selections_sync(X, y)

def compare_feature_selections_wrapper(data):
    X = data[[c for c in data.columns if "is_encrypted" != c]]
    y = data["is_encrypted"]
    return compare_feature_selections(X, y)

# %% [markdown]
# ### Load the datasets <a class="anchor" id="load-dataset">
#
# We don't want to load the datasets again and again, so we load them once.
# The LRU cache ensures that the next time this is called, we don't load the datasets again.
#
# [top](#Contents)

# %%
@lru_cache
def load_datasets_once():
    """Load all datasets only once
    
    We want to load the datasets only once. Once loaded
    serve from cache
    """
    datasets = dict()
    for file in glob.glob("*.csv.gz"):
        df = pd.read_csv(file)
        df = df.sample(frac=1).reset_index(drop=True)
        df["is_encrypted"] = 1 if "encr" in file.lower() else 0
        datasets[file] = df
    return datasets

# %% [markdown]
# ### Select the datasets <a class="anchor" id="dataset-selection">
#
# Select the dataset, combine it, shuffle it and return
#
# We used several schemes:
# * Plaintext
#   - The base plaintext dataset of around 50k files
#   - Expanded dataset, where all files that were less than 1500 bytes were expanded by repeating the file
#   - Base32 encoding of
#    - original plaintext
#    - expanded plaintext
# * Encryption : We used two schemes for encruption
#   - v1 : AES 256 encryption of the full file, again two varieties were used
#     - Plain encryption
#     - Encryption followed by base32 encoding
#   - v2 : AES encryption of the file, the first and the last 128 bytes are not encrypted. Of the remaining file, every alternate 16 bytes are encrypted.
#     - Plain encryption
#     - encryption followed by base32 encoding
#
# We select combinations of the above datasets
#
# Furthermore, we add further combinations by including and excluding webp files, and including and excluding non-webp files.
#
# [top](#Contents)

# %%
def get_dataset(\
               exclude_plaintext_nonbase32=False,
               exclude_plaintext_base32=False,
               exclude_encrypted_v1=False,
               exclude_encrypted_v2=False,
               exclude_encrypted_base32=False,
               exclude_encrypted_nonbase32=False,
               exclude_webp=False,
               exclude_nonwebp=False):
    description = {k:v for k,v in locals().items() \
                   if "exclude" in k}
    
    files = glob.glob("*.csv.gz")
    
    
    if exclude_plaintext_nonbase32:
        files = [f for f in files if \
                     "plaintext" not in f \
                     or "_base32" in f \
                     or "_b32" in f]
    if exclude_plaintext_base32:
        files = [f for f in files if\
                    "plaintext" not in f or \
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_v1:
        files = [f for f in files if\
                    "_v1" not in f or "encr" not in f]
    if exclude_encrypted_v2:
        files = [f for f in files if \
                    "_v2" not in f or "encr" not in f]
    if exclude_encrypted_base32:
        files = [ f for f in files if\
                    "encr" not in f or\
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_nonbase32:
        files = [f for f in files if \
                    "encr" not in f or \
                    "base32" in f or "b32" in f]
        
        
    encrypted_count = len([f for f in files if "encr" in f])
    non_encrypted_count = len([f for f in files if "encr" not in f])
    
    if 0 == encrypted_count or 0 == non_encrypted_count or 0 == len(files):
        return description, None, -1, -1
    
    all_dfs = list()
    all_loaded_datasets = load_datasets_once()
    for filename in files:
        all_dfs.append(all_loaded_datasets[filename])
    
    combined_df = pd.concat(all_dfs)
    
    if exclude_webp:
        combined_df = combined_df[\
                        combined_df["extended.extension"] != ".webp"]
    if exclude_nonwebp:
        combined_df = combined_df[\
                        combined_df["extended.extension"] == ".webp"]
        
    if len(combined_df) == 0:
        return description, None, -1, -1
    
        
    encrypt_count = len(combined_df[combined_df["is_encrypted"] == 1])
    nonencrypted_count = len(combined_df[combined_df["is_encrypted"] == 0])

    
    if 0 == len(combined_df) or 0 == encrypt_count or 0 == nonencrypted_count:
        return description, None, -1, -1
    
    return description, combined_df, encrypt_count, nonencrypted_count

# %% [markdown]
# ### Run all combinations of data <a class="anchor" id="dataset-selection">
#
# For all combinations of the datasets, compare the three classes (basic, advanced, and Fourier)
#
# [top](#Contents)

# %%
all_results = []
list_of_arguments = []

# Get all 8-tuple combinations of T/F
list_of_arguments = [(True,), (False,)]
for i in range(7):
    temp = []
    for e in list_of_arguments:
        et = e + (True,)
        temp.append(et)
        et = e + (False,)
        temp.append(et)
    list_of_arguments = temp

     
for a, b, c, k, e, f, g, h in tqdm.tqdm(list_of_arguments):
    desc, df, ec, nec = get_dataset(a, b, c, k, e, f, g, h)
    if df is not None:
        result = compare_feature_selections_wrapper(df)
        call_gc()
        result = {**desc, **result}
        result["n_encrypted"] = ec
        result["n_non_encrypted"] = nec
        result["ratio_encrypt_nonencrypt"] = float(ec) / nec
        all_results.append(result)


df_dict = {k:[] for k in all_results[0]}
for result in all_results:
    for k, v in result.items():
        df_dict[k].append(v)

df = pd.DataFrame(df_dict)
df["best_f1_score"] = \
    df[[c for c in df.columns if "f1_score" in c]].max(axis=1)

df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["improvement_in_fourier"] = \
    df["fourier-f1_score"] - df["baseline-f1_score"]
df = df.sort_values(by="improvement_in_fourier", ascending=False)
# Out:
# 100%|████████████████████████████████████████████████| 256/256 [29:52:06<00:00, 420.02s/it]

# %% [markdown]
# ## Results <a class="anchor" id="results">
#
# In this section, we present the results
#
# [top](#Contents)

# %% [markdown]
# ### Print the raw results <a class="anchor" id="raw-results">
#
# [top](#Contents)

# %%
df.T
# Out:
#                                             0          63         18   \
# exclude_plaintext_nonbase32                True       True       True
# exclude_plaintext_base32                   True      False       True
# exclude_encrypted_v1                       True      False      False
# exclude_encrypted_v2                       True      False       True
# exclude_encrypted_base32                   True       True       True
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.869985   0.869985
# baseline-accuracy_score                0.858551   0.858551   0.858551
# baseline-precision_score               0.797796   0.797796   0.797796
# baseline-recall_score                  0.956541   0.956541   0.956541
# advanced-only-f1_score                 0.881373   0.881373   0.881373
# advanced-only-accuracy_score           0.872663   0.872663   0.872663
# advanced-only-precision_score          0.817463   0.817463   0.817463
# advanced-only-recall_score             0.956128   0.956128   0.956128
# fourier-only-f1_score                  0.922184   0.922184   0.922184
# fourier-only-accuracy_score            0.921991   0.921991   0.921991
# fourier-only-precision_score           0.910409   0.910409   0.910409
# fourier-only-recall_score              0.934272   0.934272   0.934272
# baseline-and-fourier-f1_score          0.951364   0.951364   0.951364
# baseline-and-fourier-accuracy_score    0.950719   0.950719   0.950719
# baseline-and-fourier-precision_score   0.929568   0.929568   0.929568
# baseline-and-fourier-recall_score      0.974206   0.974206   0.974206
# advanced-and-fourier-f1_score          0.961981   0.961981   0.961981
# advanced-and-fourier-accuracy_score    0.961747   0.961747   0.961747
# advanced-and-fourier-precision_score   0.946315   0.946315   0.946315
# advanced-and-fourier-recall_score      0.978175   0.978175   0.978175
# advanced-f1_score                      0.884819   0.884819   0.884819
# advanced-accuracy_score                0.876313   0.876313   0.876313
# advanced-precision_score               0.820381   0.820381   0.820381
# advanced-recall_score                  0.960246   0.960246   0.960246
# fourier-f1_score                       0.963817   0.963817   0.963817
# fourier-accuracy_score                  0.96359    0.96359    0.96359
# fourier-precision_score                0.948025   0.948025   0.948025
# fourier-recall_score                   0.980144   0.980144   0.980144
# n_encrypted                               94480      94480      94480
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               0.979209   0.979209   0.979209
# best_f1_score                          0.963817   0.963817   0.963817
# improvement_in_advanced                0.014834   0.014834   0.014834
# improvement_in_fourier                 0.093832   0.093832   0.093832
# room_for_improvement                   0.130015   0.130015   0.130015
# fourier_minus_advanced                 0.078997   0.078997   0.078997
# percentage_of_room_filled             72.170009  72.170009  72.170009
#
#                                             9          72         27   \
# exclude_plaintext_nonbase32                True      False       True
# exclude_plaintext_base32                   True       True       True
# exclude_encrypted_v1                       True       True      False
# exclude_encrypted_v2                      False       True      False
# exclude_encrypted_base32                   True       True       True
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.869985   0.869985
# baseline-accuracy_score                0.858551   0.858551   0.858551
# baseline-precision_score               0.797796   0.797796   0.797796
# baseline-recall_score                  0.956541   0.956541   0.956541
# advanced-only-f1_score                 0.881373   0.881373   0.881373
# advanced-only-accuracy_score           0.872663   0.872663   0.872663
# advanced-only-precision_score          0.817463   0.817463   0.817463
# advanced-only-recall_score             0.956128   0.956128   0.956128
# %% [markdown]
# ### Sort by the improvement when using Fourier transforms over baseline <a class="anchor" id="sorted-fourier">
#
# We also take a few other things:
# * Room for improvement (1 - baseline score)
# * How much of the room for improvement was filled by fourier transforms (percentage)
# * Difference between F1 score with advanced and fourier
#
# [top](#Contents)

# %%
pd.set_option('display.max_columns', None)
df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["room_for_improvement"] = \
    1.0 - df["baseline-f1_score"]
df["fourier_minus_advanced"] = \
    df["fourier-f1_score"] - df["advanced-f1_score"]
df["percentage_of_room_filled"] = \
    df["improvement_in_fourier"] * 100.0 / df["room_for_improvement"]
#df.sort_values(by="fourier_minus_advanced", ascending=False)
df.T
# Out:
#                                             0          63         18   \
# exclude_plaintext_nonbase32                True       True       True
# exclude_plaintext_base32                   True      False       True
# exclude_encrypted_v1                       True      False      False
# exclude_encrypted_v2                       True      False       True
# exclude_encrypted_base32                   True       True       True
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.869985   0.869985
# baseline-accuracy_score                0.858551   0.858551   0.858551
# baseline-precision_score               0.797796   0.797796   0.797796
# baseline-recall_score                  0.956541   0.956541   0.956541
# advanced-only-f1_score                 0.881373   0.881373   0.881373
# advanced-only-accuracy_score           0.872663   0.872663   0.872663
# advanced-only-precision_score          0.817463   0.817463   0.817463
# advanced-only-recall_score             0.956128   0.956128   0.956128
# fourier-only-f1_score                  0.922184   0.922184   0.922184
# fourier-only-accuracy_score            0.921991   0.921991   0.921991
# fourier-only-precision_score           0.910409   0.910409   0.910409
# fourier-only-recall_score              0.934272   0.934272   0.934272
# baseline-and-fourier-f1_score          0.951364   0.951364   0.951364
# baseline-and-fourier-accuracy_score    0.950719   0.950719   0.950719
# baseline-and-fourier-precision_score   0.929568   0.929568   0.929568
# baseline-and-fourier-recall_score      0.974206   0.974206   0.974206
# advanced-and-fourier-f1_score          0.961981   0.961981   0.961981
# advanced-and-fourier-accuracy_score    0.961747   0.961747   0.961747
# advanced-and-fourier-precision_score   0.946315   0.946315   0.946315
# advanced-and-fourier-recall_score      0.978175   0.978175   0.978175
# advanced-f1_score                      0.884819   0.884819   0.884819
# advanced-accuracy_score                0.876313   0.876313   0.876313
# advanced-precision_score               0.820381   0.820381   0.820381
# advanced-recall_score                  0.960246   0.960246   0.960246
# fourier-f1_score                       0.963817   0.963817   0.963817
# fourier-accuracy_score                  0.96359    0.96359    0.96359
# fourier-precision_score                0.948025   0.948025   0.948025
# fourier-recall_score                   0.980144   0.980144   0.980144
# n_encrypted                               94480      94480      94480
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               0.979209   0.979209   0.979209
# best_f1_score                          0.963817   0.963817   0.963817
# improvement_in_advanced                0.014834   0.014834   0.014834
# improvement_in_fourier                 0.093832   0.093832   0.093832
# room_for_improvement                   0.130015   0.130015   0.130015
# fourier_minus_advanced                 0.078997   0.078997   0.078997
# percentage_of_room_filled             72.170009  72.170009  72.170009
#
#                                             9          72         27   \
# exclude_plaintext_nonbase32                True      False       True
# exclude_plaintext_base32                   True       True       True
# exclude_encrypted_v1                       True       True      False
# exclude_encrypted_v2                      False       True      False
# exclude_encrypted_base32                   True       True       True
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.869985   0.869985
# baseline-accuracy_score                0.858551   0.858551   0.858551
# baseline-precision_score               0.797796   0.797796   0.797796
# baseline-recall_score                  0.956541   0.956541   0.956541
# advanced-only-f1_score                 0.881373   0.881373   0.881373
# advanced-only-accuracy_score           0.872663   0.872663   0.872663
# advanced-only-precision_score          0.817463   0.817463   0.817463
# advanced-only-recall_score             0.956128   0.956128   0.956128
# fourier-only-f1_score                  0.922184   0.922184   0.922184
# fourier-only-accuracy_score            0.921991   0.921991   0.921991
# fourier-only-precision_score           0.910409   0.910409   0.910409
# fourier-only-recall_score              0.934272   0.934272   0.934272
# baseline-and-fourier-f1_score          0.951364   0.951364   0.951364
# baseline-and-fourier-accuracy_score    0.950719   0.950719   0.950719
# baseline-and-fourier-precision_score   0.929568   0.929568   0.929568
# baseline-and-fourier-recall_score      0.974206   0.974206   0.974206
# advanced-and-fourier-f1_score          0.961981   0.961981   0.961981
# advanced-and-fourier-accuracy_score    0.961747   0.961747   0.961747
# advanced-and-fourier-precision_score   0.946315   0.946315   0.946315
# advanced-and-fourier-recall_score      0.978175   0.978175   0.978175
# advanced-f1_score                      0.884819   0.884819   0.884819
# advanced-accuracy_score                0.876313   0.876313   0.876313
# advanced-precision_score               0.820381   0.820381   0.820381
# advanced-recall_score                  0.960246   0.960246   0.960246
# fourier-f1_score                       0.963817   0.963817   0.963817
# fourier-accuracy_score                  0.96359    0.96359    0.96359
# fourier-precision_score                0.948025   0.948025   0.948025
# fourier-recall_score                   0.980144   0.980144   0.980144
# n_encrypted                               94480      94480      94480
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               0.979209   0.979209   0.979209
# best_f1_score                          0.963817   0.963817   0.963817
# improvement_in_advanced                0.014834   0.014834   0.014834
# improvement_in_fourier                 0.093832   0.093832   0.093832
# room_for_improvement                   0.130015   0.130015   0.130015
# fourier_minus_advanced                 0.078997   0.078997   0.078997
# percentage_of_room_filled             72.170009  72.170009  72.170009
#
#                                             45         54         36   \
# exclude_plaintext_nonbase32                True       True       True
# exclude_plaintext_base32                  False      False      False
# exclude_encrypted_v1                       True      False       True
# exclude_encrypted_v2                      False       True       True
# exclude_encrypted_base32                   True       True       True
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.869985   0.869985
# baseline-accuracy_score                0.858551   0.858551   0.858551
# baseline-precision_score               0.797796   0.797796   0.797796
# baseline-recall_score                  0.956541   0.956541   0.956541
# advanced-only-f1_score                 0.881373   0.881373   0.881373
# advanced-only-accuracy_score           0.872663   0.872663   0.872663
# best_f1_score                          0.963817   0.963817   0.963817
# improvement_in_advanced                0.014834   0.014834   0.014834
# improvement_in_fourier                 0.093832   0.093832   0.093832
# room_for_improvement                   0.130015   0.130015   0.130015
# fourier_minus_advanced                 0.078997   0.078997   0.078997
# percentage_of_room_filled             72.170009  72.170009  72.170009
#
#                                             135        114        6    \
# exclude_plaintext_nonbase32               False      False       True
# exclude_plaintext_base32                  False      False       True
# exclude_encrypted_v1                      False       True       True
# exclude_encrypted_v2                      False       True       True
# exclude_encrypted_base32                   True      False      False
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.829994   0.829994
# baseline-accuracy_score                0.858551   0.743156   0.743156
# baseline-precision_score               0.797796   0.742399   0.742399
# baseline-recall_score                  0.956541   0.941026   0.941026
# advanced-only-f1_score                 0.881373   0.855868   0.855868
# advanced-only-accuracy_score           0.872663   0.796062   0.796062
# advanced-only-precision_score          0.817463   0.808773   0.808773
# advanced-only-recall_score             0.956128   0.908793   0.908793
# fourier-only-f1_score                  0.922184   0.880394   0.880394
# fourier-only-accuracy_score            0.921991   0.830146   0.830146
# fourier-only-precision_score           0.910409   0.829253   0.829253
# fourier-only-recall_score              0.934272   0.938259   0.938259
# baseline-and-fourier-f1_score          0.951364   0.895625   0.895625
# baseline-and-fourier-accuracy_score    0.950719    0.85284    0.85284
# baseline-and-fourier-precision_score   0.929568   0.849025   0.849025
# baseline-and-fourier-recall_score      0.974206    0.94764    0.94764
# advanced-and-fourier-f1_score          0.961981   0.911776   0.911776
# advanced-and-fourier-accuracy_score    0.961747   0.877695   0.877695
# advanced-and-fourier-precision_score   0.946315   0.877732   0.877732
# advanced-and-fourier-recall_score      0.978175   0.948569   0.948569
# advanced-f1_score                      0.884819    0.86279    0.86279
# advanced-accuracy_score                0.876313   0.805865   0.805865
# advanced-precision_score               0.820381   0.815345   0.815345
# advanced-recall_score                  0.960246   0.916102   0.916102
# fourier-f1_score                       0.963817   0.912106   0.912106
# fourier-accuracy_score                  0.96359   0.878141   0.878141
# fourier-precision_score                0.948025   0.877975   0.877975
# fourier-recall_score                   0.980144      0.949      0.949
# n_encrypted                               94480     192627     192627
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               0.979209   1.996424   1.996424
# best_f1_score                          0.963817   0.912106   0.912106
# improvement_in_advanced                0.014834   0.032796   0.032796
# improvement_in_fourier                 0.093832   0.082112   0.082112
# room_for_improvement                   0.130015   0.170006   0.170006
# fourier_minus_advanced                 0.078997   0.049316   0.049316
# percentage_of_room_filled             72.170009  48.299368  48.299368
#
#                                             141        132        69   \
# exclude_plaintext_nonbase32               False      False       True
# exclude_plaintext_base32                  False      False      False
# exclude_encrypted_v1                      False      False      False
# exclude_encrypted_v2                      False       True      False
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.829994   0.829994   0.829994
# baseline-accuracy_score                0.743156   0.743156   0.743156
# baseline-precision_score               0.742399   0.742399   0.742399
# baseline-recall_score                  0.941026   0.941026   0.941026
# advanced-only-f1_score                 0.855868   0.855868   0.855868
# advanced-only-accuracy_score           0.796062   0.796062   0.796062
# advanced-only-precision_score          0.808773   0.808773   0.808773
# advanced-only-recall_score             0.908793   0.908793   0.908793
# fourier-only-f1_score                  0.880394   0.880394   0.880394
# fourier-only-accuracy_score            0.830146   0.830146   0.830146
# fourier-only-precision_score           0.829253   0.829253   0.829253
# fourier-only-recall_score              0.938259   0.938259   0.938259
# baseline-and-fourier-f1_score          0.895625   0.895625   0.895625
# baseline-and-fourier-accuracy_score     0.85284    0.85284    0.85284
# baseline-and-fourier-precision_score   0.849025   0.849025   0.849025
# baseline-and-fourier-recall_score       0.94764    0.94764    0.94764
# advanced-and-fourier-f1_score          0.911776   0.911776   0.911776
# advanced-and-fourier-accuracy_score    0.877695   0.877695   0.877695
# advanced-and-fourier-precision_score   0.877732   0.877732   0.877732
# advanced-and-fourier-recall_score      0.948569   0.948569   0.948569
# advanced-f1_score                       0.86279    0.86279    0.86279
# advanced-accuracy_score                0.805865   0.805865   0.805865
# advanced-precision_score               0.815345   0.815345   0.815345
# advanced-recall_score                  0.916102   0.916102   0.916102
# fourier-f1_score                       0.912106   0.912106   0.912106
# fourier-accuracy_score                 0.878141   0.878141   0.878141
# fourier-precision_score                0.877975   0.877975   0.877975
# fourier-recall_score                      0.949      0.949      0.949
# n_encrypted                              192627     192627     192627
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.996424   1.996424   1.996424
# best_f1_score                          0.912106   0.912106   0.912106
# improvement_in_advanced                0.032796   0.032796   0.032796
# improvement_in_fourier                 0.082112   0.082112   0.082112
# room_for_improvement                   0.170006   0.170006   0.170006
# fourier_minus_advanced                 0.049316   0.049316   0.049316
# percentage_of_room_filled             48.299368  48.299368  48.299368
#
#                                             51         24         123  \
# exclude_plaintext_nonbase32                True       True      False
# exclude_plaintext_base32                  False       True      False
# exclude_encrypted_v1                       True      False       True
# exclude_encrypted_v2                      False       True      False
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.829994   0.829994   0.829994
# baseline-accuracy_score                0.743156   0.743156   0.743156
# baseline-precision_score               0.742399   0.742399   0.742399
# baseline-recall_score                  0.941026   0.941026   0.941026
# advanced-only-f1_score                 0.855868   0.855868   0.855868
# advanced-only-accuracy_score           0.796062   0.796062   0.796062
# advanced-only-precision_score          0.808773   0.808773   0.808773
# advanced-only-recall_score             0.908793   0.908793   0.908793
# fourier-only-f1_score                  0.880394   0.880394   0.880394
# fourier-only-accuracy_score            0.830146   0.830146   0.830146
# fourier-only-precision_score           0.829253   0.829253   0.829253
# fourier-only-recall_score              0.938259   0.938259   0.938259
# baseline-and-fourier-f1_score          0.895625   0.895625   0.895625
# fourier-accuracy_score                 0.878141   0.878141   0.878141
# fourier-precision_score                0.877975   0.877975   0.877975
# fourier-recall_score                      0.949      0.949      0.949
# n_encrypted                              192627     192627     192627
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.996424   1.996424   1.996424
# best_f1_score                          0.912106   0.912106   0.912106
# improvement_in_advanced                0.032796   0.032796   0.032796
# improvement_in_fourier                 0.082112   0.082112   0.082112
# room_for_improvement                   0.170006   0.170006   0.170006
# fourier_minus_advanced                 0.049316   0.049316   0.049316
# percentage_of_room_filled             48.299368  48.299368  48.299368
#
#                                             33         96         60   \
# exclude_plaintext_nonbase32                True      False       True
# exclude_plaintext_base32                   True       True      False
# exclude_encrypted_v1                      False      False      False
# exclude_encrypted_v2                      False       True       True
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.829994   0.829994   0.829994
# baseline-accuracy_score                0.743156   0.743156   0.743156
# baseline-precision_score               0.742399   0.742399   0.742399
# baseline-recall_score                  0.941026   0.941026   0.941026
# advanced-only-f1_score                 0.855868   0.855868   0.855868
# advanced-only-accuracy_score           0.796062   0.796062   0.796062
# advanced-only-precision_score          0.808773   0.808773   0.808773
# advanced-only-recall_score             0.908793   0.908793   0.908793
# fourier-only-f1_score                  0.880394   0.880394   0.880394
# fourier-only-accuracy_score            0.830146   0.830146   0.830146
# fourier-only-precision_score           0.829253   0.829253   0.829253
# fourier-only-recall_score              0.938259   0.938259   0.938259
# baseline-and-fourier-f1_score          0.895625   0.895625   0.895625
# baseline-and-fourier-accuracy_score     0.85284    0.85284    0.85284
# baseline-and-fourier-precision_score   0.849025   0.849025   0.849025
# baseline-and-fourier-recall_score       0.94764    0.94764    0.94764
# advanced-and-fourier-f1_score          0.911776   0.911776   0.911776
# advanced-and-fourier-accuracy_score    0.877695   0.877695   0.877695
# advanced-and-fourier-precision_score   0.877732   0.877732   0.877732
# advanced-and-fourier-recall_score      0.948569   0.948569   0.948569
# advanced-f1_score                       0.86279    0.86279    0.86279
# advanced-accuracy_score                0.805865   0.805865   0.805865
# advanced-precision_score               0.815345   0.815345   0.815345
# advanced-recall_score                  0.916102   0.916102   0.916102
# fourier-f1_score                       0.912106   0.912106   0.912106
# fourier-accuracy_score                 0.878141   0.878141   0.878141
# fourier-precision_score                0.877975   0.877975   0.877975
# fourier-recall_score                      0.949      0.949      0.949
# n_encrypted                              192627     192627     192627
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.996424   1.996424   1.996424
# best_f1_score                          0.912106   0.912106   0.912106
# improvement_in_advanced                0.032796   0.032796   0.032796
# improvement_in_fourier                 0.082112   0.082112   0.082112
# room_for_improvement                   0.170006   0.170006   0.170006
# fourier_minus_advanced                 0.049316   0.049316   0.049316
# percentage_of_room_filled             48.299368  48.299368  48.299368
#
#                                             78         15         102  \
# exclude_plaintext_nonbase32               False       True      False
# exclude_plaintext_base32                   True       True       True
# exclude_encrypted_v1                       True       True      False
# exclude_encrypted_v2                       True      False      False
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32               False      False       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.829994   0.829994   0.799313
# baseline-accuracy_score                0.743156   0.743156   0.762435
# baseline-precision_score               0.742399   0.742399   0.696261
# baseline-recall_score                  0.941026   0.941026   0.938174
# advanced-only-f1_score                 0.855868   0.855868   0.840008
# advanced-only-accuracy_score           0.796062   0.796062   0.830414
# advanced-only-precision_score          0.808773   0.808773   0.801149
# advanced-only-recall_score             0.908793   0.908793   0.882839
# fourier-only-f1_score                  0.880394   0.880394   0.831248
# fourier-only-accuracy_score            0.830146   0.830146   0.812606
# fourier-only-precision_score           0.829253   0.829253   0.761384
# fourier-only-recall_score              0.938259   0.938259   0.915239
# baseline-and-fourier-f1_score          0.895625   0.895625   0.858423
# baseline-and-fourier-accuracy_score     0.85284    0.85284   0.845453
# baseline-and-fourier-precision_score   0.849025   0.849025   0.797724
# baseline-and-fourier-recall_score       0.94764    0.94764   0.929127
# advanced-and-fourier-f1_score          0.911776   0.911776   0.864532
# advanced-and-fourier-accuracy_score    0.877695   0.877695   0.857105
# advanced-and-fourier-precision_score   0.877732   0.877732   0.828205
# advanced-and-fourier-recall_score      0.948569   0.948569   0.904205
# advanced-f1_score                       0.86279    0.86279   0.849781
# advanced-accuracy_score                0.805865   0.805865   0.841687
# advanced-precision_score               0.815345   0.815345   0.814746
# advanced-recall_score                  0.916102   0.916102   0.887974
# fourier-f1_score                       0.912106   0.912106   0.864926
# fourier-accuracy_score                 0.878141   0.878141   0.857501
# fourier-precision_score                0.877975   0.877975   0.828477
# fourier-recall_score                      0.949      0.949   0.904745
# n_encrypted                              192627     192627      98147
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.996424   1.996424   1.017215
# best_f1_score                          0.912106   0.912106   0.864926
# improvement_in_advanced                0.032796   0.032796   0.050468
# improvement_in_fourier                 0.082112   0.082112   0.065613
# room_for_improvement                   0.170006   0.170006   0.200687
# fourier_minus_advanced                 0.049316   0.049316   0.015145
# percentage_of_room_filled             48.299368  48.299368  32.694335
#
#                                             111        30         57   \
# exclude_plaintext_nonbase32               False       True       True
# exclude_plaintext_base32                  False       True      False
# exclude_encrypted_v1                       True      False      False
# exclude_encrypted_v2                       True      False       True
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32                True       True       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.799313   0.799313   0.799313
# baseline-accuracy_score                0.762435   0.762435   0.762435
# baseline-precision_score               0.696261   0.696261   0.696261
# baseline-recall_score                  0.938174   0.938174   0.938174
# advanced-only-f1_score                 0.840008   0.840008   0.840008
# advanced-only-accuracy_score           0.830414   0.830414   0.830414
# advanced-only-precision_score          0.801149   0.801149   0.801149
# advanced-only-recall_score             0.882839   0.882839   0.882839
# fourier-only-f1_score                  0.831248   0.831248   0.831248
# advanced-f1_score                      0.849781   0.849781   0.849781
# advanced-accuracy_score                0.841687   0.841687   0.841687
# advanced-precision_score               0.814746   0.814746   0.814746
# advanced-recall_score                  0.887974   0.887974   0.887974
# fourier-f1_score                       0.864926   0.864926   0.864926
# fourier-accuracy_score                 0.857501   0.857501   0.857501
# fourier-precision_score                0.828477   0.828477   0.828477
# fourier-recall_score                   0.904745   0.904745   0.904745
# n_encrypted                               98147      98147      98147
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.017215   1.017215   1.017215
# best_f1_score                          0.864926   0.864926   0.864926
# improvement_in_advanced                0.050468   0.050468   0.050468
# improvement_in_fourier                 0.065613   0.065613   0.065613
# room_for_improvement                   0.200687   0.200687   0.200687
# fourier_minus_advanced                 0.015145   0.015145   0.015145
# percentage_of_room_filled             32.694335  32.694335  32.694335
#
#                                             138        75         120  \
# exclude_plaintext_nonbase32               False      False      False
# exclude_plaintext_base32                  False       True      False
# exclude_encrypted_v1                      False       True       True
# exclude_encrypted_v2                      False       True      False
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32                True       True       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.799313   0.799313   0.799313
# baseline-accuracy_score                0.762435   0.762435   0.762435
# baseline-precision_score               0.696261   0.696261   0.696261
# baseline-recall_score                  0.938174   0.938174   0.938174
# advanced-only-f1_score                 0.840008   0.840008   0.840008
# advanced-only-accuracy_score           0.830414   0.830414   0.830414
# advanced-only-precision_score          0.801149   0.801149   0.801149
# advanced-only-recall_score             0.882839   0.882839   0.882839
# fourier-only-f1_score                  0.831248   0.831248   0.831248
# fourier-only-accuracy_score            0.812606   0.812606   0.812606
# fourier-only-precision_score           0.761384   0.761384   0.761384
# fourier-only-recall_score              0.915239   0.915239   0.915239
# baseline-and-fourier-f1_score          0.858423   0.858423   0.858423
# baseline-and-fourier-accuracy_score    0.845453   0.845453   0.845453
# baseline-and-fourier-precision_score   0.797724   0.797724   0.797724
# baseline-and-fourier-recall_score      0.929127   0.929127   0.929127
# advanced-and-fourier-f1_score          0.864532   0.864532   0.864532
# advanced-and-fourier-accuracy_score    0.857105   0.857105   0.857105
# advanced-and-fourier-precision_score   0.828205   0.828205   0.828205
# advanced-and-fourier-recall_score      0.904205   0.904205   0.904205
# advanced-f1_score                      0.849781   0.849781   0.849781
# advanced-accuracy_score                0.841687   0.841687   0.841687
# advanced-precision_score               0.814746   0.814746   0.814746
# advanced-recall_score                  0.887974   0.887974   0.887974
# fourier-f1_score                       0.864926   0.864926   0.864926
# fourier-accuracy_score                 0.857501   0.857501   0.857501
# fourier-precision_score                0.828477   0.828477   0.828477
# fourier-recall_score                   0.904745   0.904745   0.904745
# n_encrypted                               98147      98147      98147
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.017215   1.017215   1.017215
# best_f1_score                          0.864926   0.864926   0.864926
# improvement_in_advanced                0.050468   0.050468   0.050468
# improvement_in_fourier                 0.065613   0.065613   0.065613
# room_for_improvement                   0.200687   0.200687   0.200687
# fourier_minus_advanced                 0.015145   0.015145   0.015145
# percentage_of_room_filled             32.694335  32.694335  32.694335
#
#                                             12         66         93   \
# exclude_plaintext_nonbase32                True       True      False
# exclude_plaintext_base32                   True      False       True
# exclude_encrypted_v1                       True      False      False
# exclude_encrypted_v2                      False      False       True
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32                True       True       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.799313   0.799313   0.799313
# baseline-accuracy_score                0.762435   0.762435   0.762435
# baseline-precision_score               0.696261   0.696261   0.696261
# baseline-recall_score                  0.938174   0.938174   0.938174
# ...
# baseline-and-fourier-recall_score     0.988592  0.988592  0.988592  0.999968
# advanced-and-fourier-f1_score         0.816849  0.816849  0.816849  0.818655
# advanced-and-fourier-accuracy_score   0.702831  0.702831  0.702831  0.775809
# advanced-and-fourier-precision_score  0.698701  0.698701  0.698701  0.695832
# advanced-and-fourier-recall_score     0.983087  0.983087  0.983087  0.994135
# advanced-f1_score                     0.812825  0.812825  0.812825  0.813129
# advanced-accuracy_score               0.693439  0.693439  0.693439  0.766069
# advanced-precision_score              0.690673  0.690673  0.690673  0.685172
# advanced-recall_score                 0.987469  0.987469  0.987469  0.999857
# fourier-f1_score                      0.817108  0.817108  0.817108   0.81846
# fourier-accuracy_score                0.703363  0.703363  0.703363  0.775744
# fourier-precision_score               0.699108  0.699108  0.699108  0.696049
# fourier-recall_score                  0.983031  0.983031  0.983031  0.993118
# n_encrypted                             125524    125524    125524     62919
# n_non_encrypted                          60690     60690     60690     60690
# ratio_encrypt_nonencrypt              2.068281  2.068281  2.068281  1.036728
# best_f1_score                         0.817108  0.817108  0.817108  0.818655
# improvement_in_advanced               0.005617  0.005617  0.005617   0.00076
# improvement_in_fourier                  0.0099    0.0099    0.0099  0.006091
# room_for_improvement                  0.192792  0.192792  0.192792  0.187631
# fourier_minus_advanced                0.004283  0.004283  0.004283  0.005331
# percentage_of_room_filled             5.135153  5.135153  5.135153  3.246159
#
#                                            121       13        76        22   \
# exclude_plaintext_nonbase32              False      True     False      True
# exclude_plaintext_base32                 False      True      True      True
# exclude_encrypted_v1                      True      True      True     False
# exclude_encrypted_v2                     False     False      True      True
# exclude_encrypted_base32                 False     False     False     False
# exclude_encrypted_nonbase32               True      True      True      True
# exclude_webp                             False     False     False     False
# exclude_nonwebp                           True      True      True      True
# baseline-f1_score                     0.812369  0.812369  0.812369  0.812369
# baseline-accuracy_score               0.764863  0.764863  0.764863  0.764863
# baseline-precision_score              0.684027  0.684027  0.684027  0.684027
# baseline-recall_score                      1.0       1.0       1.0       1.0
# advanced-only-f1_score                0.813079  0.813079  0.813079  0.813079
# advanced-only-accuracy_score          0.765996  0.765996  0.765996  0.765996
# advanced-only-precision_score         0.685109  0.685109  0.685109  0.685109
# advanced-only-recall_score            0.999841  0.999841  0.999841  0.999841
# fourier-only-f1_score                 0.815996  0.815996  0.815996  0.815996
# n_encrypted                              62919     62919     62919
# n_non_encrypted                          60690     60690     60690
# ratio_encrypt_nonencrypt              1.036728  1.036728  1.036728
# best_f1_score                         0.818655  0.818655  0.818655
# improvement_in_advanced                0.00076   0.00076   0.00076
# improvement_in_fourier                0.006091  0.006091  0.006091
# room_for_improvement                  0.187631  0.187631  0.187631
# fourier_minus_advanced                0.005331  0.005331  0.005331
# percentage_of_room_filled             3.246159  3.246159  3.246159

# %% [markdown]
# ### Measure improvement when only webp files are used <a class="anchor" id="webp-only">
#
# We want to measure this alone because in the literature, poor performance in webp files has been mentioned
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == False) & \
   (df["exclude_nonwebp"] == True)].T
# Out:
#                                            1         100       37        82   \
# exclude_plaintext_nonbase32               True     False      True     False
# exclude_plaintext_base32                  True      True     False      True
# exclude_encrypted_v1                      True     False      True      True
# exclude_encrypted_v2                      True     False      True     False
# exclude_encrypted_base32                  True      True      True      True
# exclude_encrypted_nonbase32              False     False     False     False
# exclude_webp                             False     False     False     False
# exclude_nonwebp                           True      True      True      True
# baseline-f1_score                     0.802335  0.802335  0.802335  0.802335
# baseline-accuracy_score               0.751953  0.751953  0.751953  0.751953
# baseline-precision_score              0.673816  0.673816  0.673816  0.673816
# baseline-recall_score                 0.991438  0.991438  0.991438  0.991438
# advanced-only-f1_score                0.814118  0.814118  0.814118  0.814118
# advanced-only-accuracy_score          0.771937  0.771937  0.771937  0.771937
# advanced-only-precision_score         0.694469  0.694469  0.694469  0.694469
# advanced-only-recall_score             0.98358   0.98358   0.98358   0.98358
# fourier-only-f1_score                 0.804668  0.804668  0.804668  0.804668
# fourier-only-accuracy_score            0.75424   0.75424   0.75424   0.75424
# fourier-only-precision_score          0.674582  0.674582  0.674582  0.674582
# fourier-only-recall_score             0.996917  0.996917  0.996917  0.996917
# baseline-and-fourier-f1_score         0.799995  0.799995  0.799995  0.799995
# baseline-and-fourier-accuracy_score   0.752066  0.752066  0.752066  0.752066
# baseline-and-fourier-precision_score  0.677515  0.677515  0.677515  0.677515
# baseline-and-fourier-recall_score     0.976535  0.976535  0.976535  0.976535
# advanced-and-fourier-f1_score         0.815768  0.815768  0.815768  0.815768
# advanced-and-fourier-accuracy_score   0.776844  0.776844  0.776844  0.776844
# advanced-and-fourier-precision_score  0.702283  0.702283  0.702283  0.702283
# advanced-and-fourier-recall_score     0.973005  0.973005  0.973005  0.973005
# advanced-f1_score                     0.814306  0.814306  0.814306  0.814306
# advanced-accuracy_score               0.772302  0.772302  0.772302  0.772302
# advanced-precision_score              0.694919  0.694919  0.694919  0.694919
# advanced-recall_score                 0.983228  0.983228  0.983228  0.983228
# fourier-f1_score                      0.816462  0.816462  0.816462  0.816462
# fourier-accuracy_score                0.777866  0.777866  0.777866  0.777866
# fourier-precision_score               0.703296  0.703296  0.703296  0.703296
# fourier-recall_score                  0.973037  0.973037  0.973037  0.973037
# n_encrypted                              62605     62605     62605     62605
# n_non_encrypted                          60690     60690     60690     60690
# percentage_of_room_filled             3.246159  3.246159  3.246159  3.246159

# %% [markdown]
# ### Measure improvement when webp files are not present <a class="anchor" id="no-webp">
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == True) & \
   (df["exclude_nonwebp"] == False)].T
# Out:
#                                             0          63         18   \
# exclude_plaintext_nonbase32                True       True       True
# exclude_plaintext_base32                   True      False       True
# exclude_encrypted_v1                       True      False      False
# exclude_encrypted_v2                       True      False       True
# exclude_encrypted_base32                   True       True       True
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.869985   0.869985
# baseline-accuracy_score                0.858551   0.858551   0.858551
# baseline-precision_score               0.797796   0.797796   0.797796
# baseline-recall_score                  0.956541   0.956541   0.956541
# advanced-only-f1_score                 0.881373   0.881373   0.881373
# advanced-only-accuracy_score           0.872663   0.872663   0.872663
# advanced-only-precision_score          0.817463   0.817463   0.817463
# advanced-only-recall_score             0.956128   0.956128   0.956128
# fourier-only-f1_score                  0.922184   0.922184   0.922184
# fourier-only-accuracy_score            0.921991   0.921991   0.921991
# fourier-only-precision_score           0.910409   0.910409   0.910409
# fourier-only-recall_score              0.934272   0.934272   0.934272
# baseline-and-fourier-f1_score          0.951364   0.951364   0.951364
# baseline-and-fourier-accuracy_score    0.950719   0.950719   0.950719
# baseline-and-fourier-precision_score   0.929568   0.929568   0.929568
# baseline-and-fourier-recall_score      0.974206   0.974206   0.974206
# advanced-and-fourier-f1_score          0.961981   0.961981   0.961981
# advanced-and-fourier-accuracy_score    0.961747   0.961747   0.961747
# advanced-and-fourier-precision_score   0.946315   0.946315   0.946315
# advanced-and-fourier-recall_score      0.978175   0.978175   0.978175
# advanced-f1_score                      0.884819   0.884819   0.884819
# advanced-accuracy_score                0.876313   0.876313   0.876313
# advanced-precision_score               0.820381   0.820381   0.820381
# advanced-recall_score                  0.960246   0.960246   0.960246
# fourier-f1_score                       0.963817   0.963817   0.963817
# fourier-accuracy_score                  0.96359    0.96359    0.96359
# fourier-precision_score                0.948025   0.948025   0.948025
# fourier-recall_score                   0.980144   0.980144   0.980144
# n_encrypted                               94480      94480      94480
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               0.979209   0.979209   0.979209
# best_f1_score                          0.963817   0.963817   0.963817
# improvement_in_advanced                0.014834   0.014834   0.014834
# improvement_in_fourier                 0.093832   0.093832   0.093832
# room_for_improvement                   0.130015   0.130015   0.130015
# fourier_minus_advanced                 0.078997   0.078997   0.078997
# percentage_of_room_filled             72.170009  72.170009  72.170009
#
#                                             9          72         27   \
# exclude_plaintext_nonbase32                True      False       True
# exclude_plaintext_base32                   True       True       True
# exclude_encrypted_v1                       True       True      False
# exclude_encrypted_v2                      False       True      False
# exclude_encrypted_base32                   True       True       True
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.869985   0.869985
# exclude_encrypted_v2                      False       True       True
# exclude_encrypted_base32                   True      False      False
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.829994   0.829994
# baseline-accuracy_score                0.858551   0.743156   0.743156
# baseline-precision_score               0.797796   0.742399   0.742399
# baseline-recall_score                  0.956541   0.941026   0.941026
# advanced-only-f1_score                 0.881373   0.855868   0.855868
# advanced-only-accuracy_score           0.872663   0.796062   0.796062
# advanced-only-precision_score          0.817463   0.808773   0.808773
# advanced-only-recall_score             0.956128   0.908793   0.908793
# fourier-only-f1_score                  0.922184   0.880394   0.880394
# fourier-only-accuracy_score            0.921991   0.830146   0.830146
# fourier-only-precision_score           0.910409   0.829253   0.829253
# fourier-only-recall_score              0.934272   0.938259   0.938259
# baseline-and-fourier-f1_score          0.951364   0.895625   0.895625
# baseline-and-fourier-accuracy_score    0.950719    0.85284    0.85284
# baseline-and-fourier-precision_score   0.929568   0.849025   0.849025
# baseline-and-fourier-recall_score      0.974206    0.94764    0.94764
# advanced-and-fourier-f1_score          0.961981   0.911776   0.911776
# advanced-and-fourier-accuracy_score    0.961747   0.877695   0.877695
# advanced-and-fourier-precision_score   0.946315   0.877732   0.877732
# advanced-and-fourier-recall_score      0.978175   0.948569   0.948569
# advanced-f1_score                      0.884819    0.86279    0.86279
# advanced-accuracy_score                0.876313   0.805865   0.805865
# advanced-precision_score               0.820381   0.815345   0.815345
# advanced-recall_score                  0.960246   0.916102   0.916102
# fourier-f1_score                       0.963817   0.912106   0.912106
# fourier-accuracy_score                  0.96359   0.878141   0.878141
# fourier-precision_score                0.948025   0.877975   0.877975
# fourier-recall_score                   0.980144      0.949      0.949
# n_encrypted                               94480     192627     192627
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               0.979209   1.996424   1.996424
# best_f1_score                          0.963817   0.912106   0.912106
# improvement_in_advanced                0.014834   0.032796   0.032796
# improvement_in_fourier                 0.093832   0.082112   0.082112
# room_for_improvement                   0.130015   0.170006   0.170006
# fourier_minus_advanced                 0.078997   0.049316   0.049316
# percentage_of_room_filled             72.170009  48.299368  48.299368
#
#                                             141        132        69   \
# exclude_plaintext_nonbase32               False      False       True
# exclude_plaintext_base32                  False      False      False
# exclude_encrypted_v1                      False      False      False
# exclude_encrypted_v2                      False       True      False
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.829994   0.829994   0.829994
# baseline-accuracy_score                0.743156   0.743156   0.743156
# baseline-precision_score               0.742399   0.742399   0.742399
# baseline-recall_score                  0.941026   0.941026   0.941026
# advanced-only-f1_score                 0.855868   0.855868   0.855868
# advanced-only-accuracy_score           0.796062   0.796062   0.796062
# advanced-only-precision_score          0.808773   0.808773   0.808773
# advanced-only-recall_score             0.908793   0.908793   0.908793
# fourier-only-f1_score                  0.880394   0.880394   0.880394
# fourier_minus_advanced                 0.049316   0.049316   0.049316
# percentage_of_room_filled             48.299368  48.299368  48.299368
#
#                                             33         96         60   \
# exclude_plaintext_nonbase32                True      False       True
# exclude_plaintext_base32                   True       True      False
# exclude_encrypted_v1                      False      False      False
# exclude_encrypted_v2                      False       True       True
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.829994   0.829994   0.829994
# baseline-accuracy_score                0.743156   0.743156   0.743156
# baseline-precision_score               0.742399   0.742399   0.742399
# baseline-recall_score                  0.941026   0.941026   0.941026
# advanced-only-f1_score                 0.855868   0.855868   0.855868
# advanced-only-accuracy_score           0.796062   0.796062   0.796062
# advanced-only-precision_score          0.808773   0.808773   0.808773
# advanced-only-recall_score             0.908793   0.908793   0.908793
# fourier-only-f1_score                  0.880394   0.880394   0.880394
# fourier-only-accuracy_score            0.830146   0.830146   0.830146
# fourier-only-precision_score           0.829253   0.829253   0.829253
# fourier-only-recall_score              0.938259   0.938259   0.938259
# baseline-and-fourier-f1_score          0.895625   0.895625   0.895625
# baseline-and-fourier-accuracy_score     0.85284    0.85284    0.85284
# baseline-and-fourier-precision_score   0.849025   0.849025   0.849025
# baseline-and-fourier-recall_score       0.94764    0.94764    0.94764
# advanced-and-fourier-f1_score          0.911776   0.911776   0.911776
# advanced-and-fourier-accuracy_score    0.877695   0.877695   0.877695
# advanced-and-fourier-precision_score   0.877732   0.877732   0.877732
# advanced-and-fourier-recall_score      0.948569   0.948569   0.948569
# advanced-f1_score                       0.86279    0.86279    0.86279
# advanced-accuracy_score                0.805865   0.805865   0.805865
# advanced-precision_score               0.815345   0.815345   0.815345
# advanced-recall_score                  0.916102   0.916102   0.916102
# fourier-f1_score                       0.912106   0.912106   0.912106
# fourier-accuracy_score                 0.878141   0.878141   0.878141
# fourier-precision_score                0.877975   0.877975   0.877975
# fourier-recall_score                      0.949      0.949      0.949
# n_encrypted                              192627     192627     192627
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.996424   1.996424   1.996424
# best_f1_score                          0.912106   0.912106   0.912106
# improvement_in_advanced                0.032796   0.032796   0.032796
# improvement_in_fourier                 0.082112   0.082112   0.082112
# room_for_improvement                   0.170006   0.170006   0.170006
# fourier_minus_advanced                 0.049316   0.049316   0.049316
# percentage_of_room_filled             48.299368  48.299368  48.299368
#
#                                             78         15         102  \
# exclude_plaintext_nonbase32               False       True      False
# exclude_plaintext_base32                   True       True       True
# exclude_encrypted_v1                       True       True      False
# exclude_encrypted_v2                       True      False      False
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32               False      False       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.829994   0.829994   0.799313
# baseline-accuracy_score                0.743156   0.743156   0.762435
# baseline-precision_score               0.742399   0.742399   0.696261
# baseline-recall_score                  0.941026   0.941026   0.938174
# ratio_encrypt_nonencrypt               1.017215   1.017215   1.017215
# best_f1_score                          0.864926   0.864926   0.864926
# improvement_in_advanced                0.050468   0.050468   0.050468
# improvement_in_fourier                 0.065613   0.065613   0.065613
# room_for_improvement                   0.200687   0.200687   0.200687
# fourier_minus_advanced                 0.015145   0.015145   0.015145
# percentage_of_room_filled             32.694335  32.694335  32.694335
#
#                                             138        75         120  \
# exclude_plaintext_nonbase32               False      False      False
# exclude_plaintext_base32                  False       True      False
# exclude_encrypted_v1                      False       True       True
# exclude_encrypted_v2                      False       True      False
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32                True       True       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.799313   0.799313   0.799313
# baseline-accuracy_score                0.762435   0.762435   0.762435
# baseline-precision_score               0.696261   0.696261   0.696261
# baseline-recall_score                  0.938174   0.938174   0.938174
# advanced-only-f1_score                 0.840008   0.840008   0.840008
# advanced-only-accuracy_score           0.830414   0.830414   0.830414
# advanced-only-precision_score          0.801149   0.801149   0.801149
# advanced-only-recall_score             0.882839   0.882839   0.882839
# fourier-only-f1_score                  0.831248   0.831248   0.831248
# fourier-only-accuracy_score            0.812606   0.812606   0.812606
# fourier-only-precision_score           0.761384   0.761384   0.761384
# fourier-only-recall_score              0.915239   0.915239   0.915239
# baseline-and-fourier-f1_score          0.858423   0.858423   0.858423
# baseline-and-fourier-accuracy_score    0.845453   0.845453   0.845453
# baseline-and-fourier-precision_score   0.797724   0.797724   0.797724
# baseline-and-fourier-recall_score      0.929127   0.929127   0.929127
# advanced-and-fourier-f1_score          0.864532   0.864532   0.864532
# advanced-and-fourier-accuracy_score    0.857105   0.857105   0.857105
# advanced-and-fourier-precision_score   0.828205   0.828205   0.828205
# advanced-and-fourier-recall_score      0.904205   0.904205   0.904205
# advanced-f1_score                      0.849781   0.849781   0.849781
# advanced-accuracy_score                0.841687   0.841687   0.841687
# advanced-precision_score               0.814746   0.814746   0.814746
# advanced-recall_score                  0.887974   0.887974   0.887974
# fourier-f1_score                       0.864926   0.864926   0.864926
# fourier-accuracy_score                 0.857501   0.857501   0.857501
# fourier-precision_score                0.828477   0.828477   0.828477
# fourier-recall_score                   0.904745   0.904745   0.904745
# n_encrypted                               98147      98147      98147
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.017215   1.017215   1.017215
# best_f1_score                          0.864926   0.864926   0.864926
# improvement_in_advanced                0.050468   0.050468   0.050468
# improvement_in_fourier                 0.065613   0.065613   0.065613
# room_for_improvement                   0.200687   0.200687   0.200687
# fourier_minus_advanced                 0.015145   0.015145   0.015145
# percentage_of_room_filled             32.694335  32.694335  32.694335
#
#                                             12         66         93   \
# exclude_plaintext_nonbase32                True       True      False
# exclude_plaintext_base32                   True      False       True
# exclude_encrypted_v1                       True      False      False
# exclude_encrypted_v2                      False      False       True
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32                True       True       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.799313   0.799313   0.799313
# baseline-accuracy_score                0.762435   0.762435   0.762435
# baseline-precision_score               0.696261   0.696261   0.696261
# baseline-recall_score                  0.938174   0.938174   0.938174
# advanced-only-f1_score                 0.840008   0.840008   0.840008
# advanced-only-accuracy_score           0.830414   0.830414   0.830414
# advanced-only-precision_score          0.801149   0.801149   0.801149
# advanced-only-recall_score             0.882839   0.882839   0.882839
# fourier-only-f1_score                  0.831248   0.831248   0.831248
# fourier-only-accuracy_score            0.812606   0.812606   0.812606
# fourier-only-precision_score           0.761384   0.761384   0.761384
# fourier-only-recall_score              0.915239   0.915239   0.915239
# baseline-and-fourier-f1_score          0.858423   0.858423   0.858423
# baseline-and-fourier-accuracy_score    0.845453   0.845453   0.845453
# baseline-and-fourier-precision_score   0.797724   0.797724   0.797724
# baseline-and-fourier-recall_score      0.929127   0.929127   0.929127
# advanced-and-fourier-f1_score          0.864532   0.864532   0.864532
# advanced-and-fourier-accuracy_score    0.857105   0.857105   0.857105
# advanced-and-fourier-precision_score   0.828205   0.828205   0.828205
# advanced-and-fourier-recall_score      0.904205   0.904205   0.904205
# advanced-f1_score                      0.849781   0.849781   0.849781
# advanced-accuracy_score                0.841687   0.841687   0.841687
# advanced-precision_score               0.814746   0.814746   0.814746
# advanced-recall_score                  0.887974   0.887974   0.887974
# fourier-f1_score                       0.864926   0.864926   0.864926
# fourier-accuracy_score                 0.857501   0.857501   0.857501
# fourier-precision_score                0.828477   0.828477   0.828477
# fourier-recall_score                   0.904745   0.904745   0.904745
# n_encrypted                               98147      98147      98147
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.017215   1.017215   1.017215
# best_f1_score                          0.864926   0.864926   0.864926
# improvement_in_advanced                0.050468   0.050468   0.050468
# improvement_in_fourier                 0.065613   0.065613   0.065613
# room_for_improvement                   0.200687   0.200687   0.200687
# fourier_minus_advanced                 0.015145   0.015145   0.015145
# percentage_of_room_filled             32.694335  32.694335  32.694335
#
#                                             84         48         39
# exclude_plaintext_nonbase32               False       True       True
# exclude_plaintext_base32                   True      False      False
# exclude_encrypted_v1                       True       True       True
# exclude_encrypted_v2                      False      False       True
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32                True       True       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.799313   0.799313   0.799313
# baseline-accuracy_score                0.762435   0.762435   0.762435
# baseline-precision_score               0.696261   0.696261   0.696261
# baseline-recall_score                  0.938174   0.938174   0.938174
# advanced-only-f1_score                 0.840008   0.840008   0.840008
# advanced-only-accuracy_score           0.830414   0.830414   0.830414
# advanced-only-precision_score          0.801149   0.801149   0.801149
# advanced-only-recall_score             0.882839   0.882839   0.882839
# fourier-only-f1_score                  0.831248   0.831248   0.831248
# fourier-only-accuracy_score            0.812606   0.812606   0.812606
# fourier-only-precision_score           0.761384   0.761384   0.761384
# fourier-only-recall_score              0.915239   0.915239   0.915239
# baseline-and-fourier-f1_score          0.858423   0.858423   0.858423
# baseline-and-fourier-accuracy_score    0.845453   0.845453   0.845453
# baseline-and-fourier-precision_score   0.797724   0.797724   0.797724
# baseline-and-fourier-recall_score      0.929127   0.929127   0.929127
# advanced-and-fourier-f1_score          0.864532   0.864532   0.864532
# advanced-and-fourier-accuracy_score    0.857105   0.857105   0.857105
# advanced-and-fourier-precision_score   0.828205   0.828205   0.828205
# advanced-and-fourier-recall_score      0.904205   0.904205   0.904205
# advanced-f1_score                      0.849781   0.849781   0.849781
# advanced-accuracy_score                0.841687   0.841687   0.841687
# advanced-precision_score               0.814746   0.814746   0.814746
# advanced-recall_score                  0.887974   0.887974   0.887974
# fourier-f1_score                       0.864926   0.864926   0.864926
# fourier-accuracy_score                 0.857501   0.857501   0.857501
# fourier-precision_score                0.828477   0.828477   0.828477
# fourier-recall_score                   0.904745   0.904745   0.904745
# n_encrypted                               98147      98147      98147
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.017215   1.017215   1.017215
# best_f1_score                          0.864926   0.864926   0.864926
# improvement_in_advanced                0.050468   0.050468   0.050468
# improvement_in_fourier                 0.065613   0.065613   0.065613
# room_for_improvement                   0.200687   0.200687   0.200687
# fourier_minus_advanced                 0.015145   0.015145   0.015145
# percentage_of_room_filled             32.694335  32.694335  32.694335

# %% [markdown]
# ### Measure improvement for balanced datasets <a class="anchor" id="balanced-dataset">
#
# Most of our dataset selections are not balanced, and we didn't do anything to mitigate
# unablanced datasets. This is because we are measuring the baseline and improvement on the
# same dataset.
#
# However, we will select those instances where the datasets were balanced to see if the
# improvement is still significant in these instances.
#
# [top](#Contents)

# %%
df[(df["ratio_encrypt_nonencrypt"] > 0.9) & (df["ratio_encrypt_nonencrypt"] < 1.1)].T
# Out:
#                                             0          63         18   \
# exclude_plaintext_nonbase32                True       True       True
# exclude_plaintext_base32                   True      False       True
# exclude_encrypted_v1                       True      False      False
# exclude_encrypted_v2                       True      False       True
# exclude_encrypted_base32                   True       True       True
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.869985   0.869985
# baseline-accuracy_score                0.858551   0.858551   0.858551
# baseline-precision_score               0.797796   0.797796   0.797796
# baseline-recall_score                  0.956541   0.956541   0.956541
# advanced-only-f1_score                 0.881373   0.881373   0.881373
# advanced-only-accuracy_score           0.872663   0.872663   0.872663
# advanced-only-precision_score          0.817463   0.817463   0.817463
# advanced-only-recall_score             0.956128   0.956128   0.956128
# fourier-only-f1_score                  0.922184   0.922184   0.922184
# fourier-only-accuracy_score            0.921991   0.921991   0.921991
# fourier-only-precision_score           0.910409   0.910409   0.910409
# fourier-only-recall_score              0.934272   0.934272   0.934272
# baseline-and-fourier-f1_score          0.951364   0.951364   0.951364
# baseline-and-fourier-accuracy_score    0.950719   0.950719   0.950719
# baseline-and-fourier-precision_score   0.929568   0.929568   0.929568
# baseline-and-fourier-recall_score      0.974206   0.974206   0.974206
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               0.979209   0.979209   0.979209
# best_f1_score                          0.963817   0.963817   0.963817
# improvement_in_advanced                0.014834   0.014834   0.014834
# improvement_in_fourier                 0.093832   0.093832   0.093832
# room_for_improvement                   0.130015   0.130015   0.130015
# fourier_minus_advanced                 0.078997   0.078997   0.078997
# percentage_of_room_filled             72.170009  72.170009  72.170009
#
#                                             45         54         36   \
# exclude_plaintext_nonbase32                True       True       True
# exclude_plaintext_base32                  False      False      False
# exclude_encrypted_v1                       True      False       True
# exclude_encrypted_v2                      False       True       True
# exclude_encrypted_base32                   True       True       True
# exclude_encrypted_nonbase32               False      False      False
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.869985   0.869985   0.869985
# baseline-accuracy_score                0.858551   0.858551   0.858551
# baseline-precision_score               0.797796   0.797796   0.797796
# baseline-recall_score                  0.956541   0.956541   0.956541
# advanced-only-f1_score                 0.881373   0.881373   0.881373
# advanced-only-accuracy_score           0.872663   0.872663   0.872663
# advanced-only-precision_score          0.817463   0.817463   0.817463
# advanced-only-recall_score             0.956128   0.956128   0.956128
# fourier-only-f1_score                  0.922184   0.922184   0.922184
# fourier-only-accuracy_score            0.921991   0.921991   0.921991
# fourier-only-precision_score           0.910409   0.910409   0.910409
# fourier-only-recall_score              0.934272   0.934272   0.934272
# baseline-and-fourier-f1_score          0.951364   0.951364   0.951364
# baseline-and-fourier-accuracy_score    0.950719   0.950719   0.950719
# baseline-and-fourier-precision_score   0.929568   0.929568   0.929568
# baseline-and-fourier-recall_score      0.974206   0.974206   0.974206
# advanced-and-fourier-f1_score          0.961981   0.961981   0.961981
# advanced-and-fourier-accuracy_score    0.961747   0.961747   0.961747
# advanced-and-fourier-precision_score   0.946315   0.946315   0.946315
# advanced-and-fourier-recall_score      0.978175   0.978175   0.978175
# advanced-f1_score                      0.884819   0.884819   0.884819
# advanced-accuracy_score                0.876313   0.876313   0.876313
# advanced-precision_score               0.820381   0.820381   0.820381
# advanced-recall_score                  0.960246   0.960246   0.960246
# fourier-f1_score                       0.963817   0.963817   0.963817
# fourier-accuracy_score                  0.96359    0.96359    0.96359
# fourier-precision_score                0.948025   0.948025   0.948025
# fourier-recall_score                   0.980144   0.980144   0.980144
# n_encrypted                               94480      94480      94480
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               0.979209   0.979209   0.979209
# best_f1_score                          0.963817   0.963817   0.963817
# improvement_in_advanced                0.014834   0.014834   0.014834
# improvement_in_fourier                 0.093832   0.093832   0.093832
# room_for_improvement                   0.130015   0.130015   0.130015
# fourier_minus_advanced                 0.078997   0.078997   0.078997
# percentage_of_room_filled             72.170009  72.170009  72.170009
#
#                                             81         90         99   \
# exclude_plaintext_nonbase32               False      False      False
# exclude_plaintext_base32                   True       True       True
# exclude_encrypted_v1                       True      False      False
# exclude_encrypted_v2                      False       True      False
# exclude_encrypted_base32                   True       True       True
# exclude_encrypted_nonbase32               False      False      False
# advanced-recall_score                  0.960246   0.887974   0.887974
# fourier-f1_score                       0.963817   0.864926   0.864926
# fourier-accuracy_score                  0.96359   0.857501   0.857501
# fourier-precision_score                0.948025   0.828477   0.828477
# fourier-recall_score                   0.980144   0.904745   0.904745
# n_encrypted                               94480      98147      98147
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               0.979209   1.017215   1.017215
# best_f1_score                          0.963817   0.864926   0.864926
# improvement_in_advanced                0.014834   0.050468   0.050468
# improvement_in_fourier                 0.093832   0.065613   0.065613
# room_for_improvement                   0.130015   0.200687   0.200687
# fourier_minus_advanced                 0.078997   0.015145   0.015145
# percentage_of_room_filled             72.170009  32.694335  32.694335
#
#                                             30         57         3    \
# exclude_plaintext_nonbase32                True       True       True
# exclude_plaintext_base32                   True      False       True
# exclude_encrypted_v1                      False      False       True
# exclude_encrypted_v2                      False       True       True
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32                True       True       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.799313   0.799313   0.799313
# baseline-accuracy_score                0.762435   0.762435   0.762435
# baseline-precision_score               0.696261   0.696261   0.696261
# baseline-recall_score                  0.938174   0.938174   0.938174
# advanced-only-f1_score                 0.840008   0.840008   0.840008
# advanced-only-accuracy_score           0.830414   0.830414   0.830414
# advanced-only-precision_score          0.801149   0.801149   0.801149
# advanced-only-recall_score             0.882839   0.882839   0.882839
# fourier-only-f1_score                  0.831248   0.831248   0.831248
# fourier-only-accuracy_score            0.812606   0.812606   0.812606
# fourier-only-precision_score           0.761384   0.761384   0.761384
# fourier-only-recall_score              0.915239   0.915239   0.915239
# baseline-and-fourier-f1_score          0.858423   0.858423   0.858423
# baseline-and-fourier-accuracy_score    0.845453   0.845453   0.845453
# baseline-and-fourier-precision_score   0.797724   0.797724   0.797724
# baseline-and-fourier-recall_score      0.929127   0.929127   0.929127
# advanced-and-fourier-f1_score          0.864532   0.864532   0.864532
# advanced-and-fourier-accuracy_score    0.857105   0.857105   0.857105
# advanced-and-fourier-precision_score   0.828205   0.828205   0.828205
# advanced-and-fourier-recall_score      0.904205   0.904205   0.904205
# advanced-f1_score                      0.849781   0.849781   0.849781
# advanced-accuracy_score                0.841687   0.841687   0.841687
# advanced-precision_score               0.814746   0.814746   0.814746
# advanced-recall_score                  0.887974   0.887974   0.887974
# fourier-f1_score                       0.864926   0.864926   0.864926
# fourier-accuracy_score                 0.857501   0.857501   0.857501
# fourier-precision_score                0.828477   0.828477   0.828477
# fourier-recall_score                   0.904745   0.904745   0.904745
# n_encrypted                               98147      98147      98147
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.017215   1.017215   1.017215
# best_f1_score                          0.864926   0.864926   0.864926
# improvement_in_advanced                0.050468   0.050468   0.050468
# improvement_in_fourier                 0.065613   0.065613   0.065613
# room_for_improvement                   0.200687   0.200687   0.200687
# fourier_minus_advanced                 0.015145   0.015145   0.015145
# percentage_of_room_filled             32.694335  32.694335  32.694335
#
#                                             129        21         138  \
# exclude_plaintext_nonbase32               False       True      False
# exclude_plaintext_base32                  False       True      False
# exclude_encrypted_v1                      False      False      False
# exclude_encrypted_v2                       True       True      False
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32                True       True       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.799313   0.799313   0.799313
# baseline-accuracy_score                0.762435   0.762435   0.762435
# baseline-precision_score               0.696261   0.696261   0.696261
# baseline-recall_score                  0.938174   0.938174   0.938174
# advanced-only-f1_score                 0.840008   0.840008   0.840008
# advanced-only-accuracy_score           0.830414   0.830414   0.830414
# advanced-only-precision_score          0.801149   0.801149   0.801149
# advanced-only-recall_score             0.882839   0.882839   0.882839
# fourier-only-f1_score                  0.831248   0.831248   0.831248
# fourier-only-accuracy_score            0.812606   0.812606   0.812606
# fourier-only-precision_score           0.761384   0.761384   0.761384
# fourier-only-recall_score              0.915239   0.915239   0.915239
# baseline-and-fourier-f1_score          0.858423   0.858423   0.858423
# baseline-and-fourier-accuracy_score    0.845453   0.845453   0.845453
# baseline-and-fourier-precision_score   0.797724   0.797724   0.797724
# baseline-and-fourier-recall_score      0.929127   0.929127   0.929127
# advanced-and-fourier-f1_score          0.864532   0.864532   0.864532
# advanced-and-fourier-accuracy_score    0.857105   0.857105   0.857105
# advanced-and-fourier-precision_score   0.828205   0.828205   0.828205
# advanced-and-fourier-recall_score      0.904205   0.904205   0.904205
# advanced-f1_score                      0.849781   0.849781   0.849781
# advanced-accuracy_score                0.841687   0.841687   0.841687
# advanced-precision_score               0.814746   0.814746   0.814746
# advanced-recall_score                  0.887974   0.887974   0.887974
# fourier-f1_score                       0.864926   0.864926   0.864926
# fourier-accuracy_score                 0.857501   0.857501   0.857501
# fourier-precision_score                0.828477   0.828477   0.828477
# fourier-recall_score                   0.904745   0.904745   0.904745
# n_encrypted                               98147      98147      98147
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.017215   1.017215   1.017215
# best_f1_score                          0.864926   0.864926   0.864926
# improvement_in_advanced                0.050468   0.050468   0.050468
# improvement_in_fourier                 0.065613   0.065613   0.065613
# room_for_improvement                   0.200687   0.200687   0.200687
# fourier_minus_advanced                 0.015145   0.015145   0.015145
# percentage_of_room_filled             32.694335  32.694335  32.694335
#
#                                             75         120        12   \
# exclude_plaintext_nonbase32               False      False       True
# exclude_plaintext_base32                   True      False       True
# exclude_encrypted_v1                       True       True       True
# exclude_encrypted_v2                       True      False      False
# exclude_encrypted_base32                  False      False      False
# exclude_encrypted_nonbase32                True       True       True
# exclude_webp                               True       True       True
# exclude_nonwebp                           False      False      False
# baseline-f1_score                      0.799313   0.799313   0.799313
# baseline-accuracy_score                0.762435   0.762435   0.762435
# baseline-precision_score               0.696261   0.696261   0.696261
# baseline-recall_score                  0.938174   0.938174   0.938174
# advanced-only-f1_score                 0.840008   0.840008   0.840008
# advanced-only-accuracy_score           0.830414   0.830414   0.830414
# advanced-and-fourier-precision_score   0.828205   0.828205   0.828205
# advanced-and-fourier-recall_score      0.904205   0.904205   0.904205
# advanced-f1_score                      0.849781   0.849781   0.849781
# advanced-accuracy_score                0.841687   0.841687   0.841687
# advanced-precision_score               0.814746   0.814746   0.814746
# advanced-recall_score                  0.887974   0.887974   0.887974
# fourier-f1_score                       0.864926   0.864926   0.864926
# fourier-accuracy_score                 0.857501   0.857501   0.857501
# fourier-precision_score                0.828477   0.828477   0.828477
# fourier-recall_score                   0.904745   0.904745   0.904745
# n_encrypted                               98147      98147      98147
# n_non_encrypted                           96486      96486      96486
# ratio_encrypt_nonencrypt               1.017215   1.017215   1.017215
# best_f1_score                          0.864926   0.864926   0.864926
# improvement_in_advanced                0.050468   0.050468   0.050468
# improvement_in_fourier                 0.065613   0.065613   0.065613
# room_for_improvement                   0.200687   0.200687   0.200687
# fourier_minus_advanced                 0.015145   0.015145   0.015145
# percentage_of_room_filled             32.694335  32.694335  32.694335
#
#                                             48         39        11   \
# exclude_plaintext_nonbase32                True       True      True
# exclude_plaintext_base32                  False      False      True
# exclude_encrypted_v1                       True       True      True
# exclude_encrypted_v2                      False       True     False
# exclude_encrypted_base32                  False      False      True
# exclude_encrypted_nonbase32                True       True     False
# exclude_webp                               True       True     False
# exclude_nonwebp                           False      False     False
# baseline-f1_score                      0.799313   0.799313  0.841811
# baseline-accuracy_score                0.762435   0.762435  0.816436
# baseline-precision_score               0.696261   0.696261  0.739415
# baseline-recall_score                  0.938174   0.938174  0.977127
# advanced-only-f1_score                 0.840008   0.840008  0.853431
# advanced-only-accuracy_score           0.830414   0.830414  0.828557
# advanced-only-precision_score          0.801149   0.801149  0.745141
# advanced-only-recall_score             0.882839   0.882839  0.998549
# fourier-only-f1_score                  0.831248   0.831248  0.861742
# fourier-only-accuracy_score            0.812606   0.812606  0.848161
# fourier-only-precision_score           0.761384   0.761384   0.79081
# fourier-only-recall_score              0.915239   0.915239  0.946653
# baseline-and-fourier-f1_score          0.858423   0.858423  0.881419
# baseline-and-fourier-accuracy_score    0.845453   0.845453  0.868657
# baseline-and-fourier-precision_score   0.797724   0.797724  0.803176
# baseline-and-fourier-recall_score      0.929127   0.929127  0.976554
# advanced-and-fourier-f1_score          0.864532   0.864532  0.890352
# advanced-and-fourier-accuracy_score    0.857105   0.857105  0.879963
# advanced-and-fourier-precision_score   0.828205   0.828205  0.819248
# advanced-and-fourier-recall_score      0.904205   0.904205  0.974975
# advanced-f1_score                      0.849781   0.849781  0.853768
# advanced-accuracy_score                0.841687   0.841687  0.829756
# advanced-precision_score               0.814746   0.814746  0.748077
# advanced-recall_score                  0.887974   0.887974  0.994239
# fourier-f1_score                       0.864926   0.864926  0.893109
# fourier-accuracy_score                 0.857501   0.857501  0.882868
# fourier-precision_score                0.828477   0.828477  0.821117
# fourier-recall_score                   0.904745   0.904745  0.978941
# n_encrypted                               98147      98147    157085
# n_non_encrypted                           96486      96486    157176
# ratio_encrypt_nonencrypt               1.017215   1.017215  0.999421
#                                            2         20        83        101  \
# exclude_plaintext_nonbase32               True      True     False     False
# exclude_plaintext_base32                  True      True      True      True
# exclude_encrypted_v1                      True     False      True     False
# exclude_encrypted_v2                      True      True     False     False
# exclude_encrypted_base32                  True      True      True      True
# exclude_encrypted_nonbase32              False     False     False     False
# exclude_webp                             False     False     False     False
# exclude_nonwebp                          False     False     False     False
# baseline-f1_score                     0.841811  0.841811  0.841811  0.841811
# baseline-accuracy_score               0.816436  0.816436  0.816436  0.816436
# baseline-precision_score              0.739415  0.739415  0.739415  0.739415
# baseline-recall_score                 0.977127  0.977127  0.977127  0.977127
# advanced-only-f1_score                0.853431  0.853431  0.853431  0.853431
# advanced-only-accuracy_score          0.828557  0.828557  0.828557  0.828557
# advanced-only-precision_score         0.745141  0.745141  0.745141  0.745141
# advanced-only-recall_score            0.998549  0.998549  0.998549  0.998549
# fourier-only-f1_score                 0.861742  0.861742  0.861742  0.861742
# fourier-only-accuracy_score           0.848161  0.848161  0.848161  0.848161
# fourier-only-precision_score           0.79081   0.79081   0.79081   0.79081
# fourier-only-recall_score             0.946653  0.946653  0.946653  0.946653
# baseline-and-fourier-f1_score         0.881419  0.881419  0.881419  0.881419
# baseline-and-fourier-accuracy_score   0.868657  0.868657  0.868657  0.868657
# baseline-and-fourier-precision_score  0.803176  0.803176  0.803176  0.803176
# baseline-and-fourier-recall_score     0.976554  0.976554  0.976554  0.976554
# advanced-and-fourier-f1_score         0.890352  0.890352  0.890352  0.890352
# advanced-and-fourier-accuracy_score   0.879963  0.879963  0.879963  0.879963
# advanced-and-fourier-precision_score  0.819248  0.819248  0.819248  0.819248
# advanced-and-fourier-recall_score     0.974975  0.974975  0.974975  0.974975
# advanced-f1_score                     0.853768  0.853768  0.853768  0.853768
# advanced-accuracy_score               0.829756  0.829756  0.829756  0.829756
# advanced-precision_score              0.748077  0.748077  0.748077  0.748077
# advanced-recall_score                 0.994239  0.994239  0.994239  0.994239
# fourier-f1_score                      0.893109  0.893109  0.893109  0.893109
# fourier-accuracy_score                0.882868  0.882868  0.882868  0.882868
# fourier-precision_score               0.821117  0.821117  0.821117  0.821117
# fourier-recall_score                  0.978941  0.978941  0.978941  0.978941
# n_encrypted                             157085    157085    157085    157085
# n_non_encrypted                         157176    157176    157176    157176
# ratio_encrypt_nonencrypt              0.999421  0.999421  0.999421  0.999421
# best_f1_score                         0.893109  0.893109  0.893109  0.893109
# improvement_in_advanced               0.011956  0.011956  0.011956  0.011956
# improvement_in_fourier                0.051298  0.051298  0.051298  0.051298
# room_for_improvement                  0.158189  0.158189  0.158189  0.158189
# fourier_minus_advanced                0.039341  0.039341  0.039341  0.039341
# percentage_of_room_filled             32.42828  32.42828  32.42828  32.42828
#
#                                            92        119       29        110  \
# exclude_plaintext_nonbase32              False     False      True     False
# exclude_plaintext_base32                  True     False      True     False
# exclude_encrypted_v1                     False      True     False      True
# exclude_encrypted_v2                      True     False     False      True
# exclude_encrypted_base32                  True      True      True      True
# exclude_encrypted_nonbase32              False     False     False     False
# advanced-only-f1_score                0.813079  0.813079  0.813079  0.813079
# advanced-only-accuracy_score          0.765996  0.765996  0.765996  0.765996
# advanced-only-precision_score         0.685109  0.685109  0.685109  0.685109
# advanced-only-recall_score            0.999841  0.999841  0.999841  0.999841
# fourier-only-f1_score                 0.815996  0.815996  0.815996  0.815996
# fourier-only-accuracy_score           0.770446  0.770446  0.770446  0.770446
# fourier-only-precision_score          0.689209  0.689209  0.689209  0.689209
# fourier-only-recall_score             0.999952  0.999952  0.999952  0.999952
# baseline-and-fourier-f1_score          0.81647   0.81647   0.81647   0.81647
# baseline-and-fourier-accuracy_score   0.771166  0.771166  0.771166  0.771166
# baseline-and-fourier-precision_score  0.689878  0.689878  0.689878  0.689878
# baseline-and-fourier-recall_score     0.999968  0.999968  0.999968  0.999968
# advanced-and-fourier-f1_score         0.818655  0.818655  0.818655  0.818655
# advanced-and-fourier-accuracy_score   0.775809  0.775809  0.775809  0.775809
# advanced-and-fourier-precision_score  0.695832  0.695832  0.695832  0.695832
# advanced-and-fourier-recall_score     0.994135  0.994135  0.994135  0.994135
# advanced-f1_score                     0.813129  0.813129  0.813129  0.813129
# advanced-accuracy_score               0.766069  0.766069  0.766069  0.766069
# advanced-precision_score              0.685172  0.685172  0.685172  0.685172
# advanced-recall_score                 0.999857  0.999857  0.999857  0.999857
# fourier-f1_score                       0.81846   0.81846   0.81846   0.81846
# fourier-accuracy_score                0.775744  0.775744  0.775744  0.775744
# fourier-precision_score               0.696049  0.696049  0.696049  0.696049
# fourier-recall_score                  0.993118  0.993118  0.993118  0.993118
# n_encrypted                              62919     62919     62919     62919
# n_non_encrypted                          60690     60690     60690     60690
# ratio_encrypt_nonencrypt              1.036728  1.036728  1.036728  1.036728
# best_f1_score                         0.818655  0.818655  0.818655  0.818655
# improvement_in_advanced                0.00076   0.00076   0.00076   0.00076
# improvement_in_fourier                0.006091  0.006091  0.006091  0.006091
# room_for_improvement                  0.187631  0.187631  0.187631  0.187631
# fourier_minus_advanced                0.005331  0.005331  0.005331  0.005331
# percentage_of_room_filled             3.246159  3.246159  3.246159  3.246159

# %%
df["ratio_encrypt_nonencrypt"].unique()
# Out:
# array([0.97920942, 1.99642435, 1.01721493, 2.02417036, 0.99942103,
#        1.02474933, 1.0315538 , 2.06828143, 1.03672763])

# %% [markdown]
# ### Measure the improvement when all files are used <a class="anchor" id="full-dataset">
#
# In most of our dataset selections, we excluded some data points based on our criteria.
#
# In this, we measure the improvement when we use all data points
#
# [top](#Contents)

# %%
# Measure everything for the full dataset
df2 = df
for colname in df2.columns:
    if "exclude" in colname:
        df2 = df2[df2[colname] == False]
df2
# Out:
#      exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 143                        False                     False
#
#      exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 143                 False                 False                     False
#
#      exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 143                        False         False            False
#
#      baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 143           0.815903                 0.711251  ...              0.967437
#
#      n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 143       318151           157176                   2.02417       0.868787
#
#      improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 143                 0.031823                0.052884              0.184097
#
#      fourier_minus_advanced  percentage_of_room_filled
# 143                0.021062                  28.726274
#
# [1 rows x 45 columns]

# %%
df2[[c for c in df2.columns if "baseline" in c or "fourier" in c or "advanced-only" in c]].T
# Out:
#                                            143
# baseline-f1_score                     0.815903
# baseline-accuracy_score               0.711251
# baseline-precision_score              0.711640
# baseline-recall_score                 0.955964
# advanced-only-f1_score                0.844044
# advanced-only-accuracy_score          0.756713
# advanced-only-precision_score         0.739179
# advanced-only-recall_score            0.983583
# fourier-only-f1_score                 0.849267
# fourier-only-accuracy_score           0.773983
# fourier-only-precision_score          0.767018
# fourier-only-recall_score             0.951275
# baseline-and-fourier-f1_score         0.858954
# baseline-and-fourier-accuracy_score   0.788687
# baseline-and-fourier-precision_score  0.776296
# baseline-and-fourier-recall_score     0.961314
# advanced-and-fourier-f1_score         0.868474
# advanced-and-fourier-accuracy_score   0.803897
# advanced-and-fourier-precision_score  0.787976
# advanced-and-fourier-recall_score     0.967292
# fourier-f1_score                      0.868787
# fourier-accuracy_score                0.804406
# fourier-precision_score               0.788396
# fourier-recall_score                  0.967437
# improvement_in_fourier                0.052884
# fourier_minus_advanced                0.021062

# %%
df.to_csv("../LR_comparison_logistic_regression_final.csv")

# %% [markdown]
# ### Focus on items where the base metrics performed well <a class="anchor" id="focus-greater-90">
#
# We see that in all cases, plaintext non-base 32 only is selected. Also we
# see that for encrypted, only base32 is selected and non-base32 excluded.
#
# Fundamentally, what this is measuring is when the plaintext has all files
# but all encrypted content is base-32 encoded.
#
# Typically, base-32 encoding will lead to a reduction of entropy, in many cases
# much less than the original text, and this is what it is measuring.
#
# [top](#Contents)

# %%
df[df["baseline-f1_score"] > 0.9]
# Out:
# Empty DataFrame
# Columns: [exclude_plaintext_nonbase32, exclude_plaintext_base32, exclude_encrypted_v1, exclude_encrypted_v2, exclude_encrypted_base32, exclude_encrypted_nonbase32, exclude_webp, exclude_nonwebp, baseline-f1_score, baseline-accuracy_score, baseline-precision_score, baseline-recall_score, advanced-only-f1_score, advanced-only-accuracy_score, advanced-only-precision_score, advanced-only-recall_score, fourier-only-f1_score, fourier-only-accuracy_score, fourier-only-precision_score, fourier-only-recall_score, baseline-and-fourier-f1_score, baseline-and-fourier-accuracy_score, baseline-and-fourier-precision_score, baseline-and-fourier-recall_score, advanced-and-fourier-f1_score, advanced-and-fourier-accuracy_score, advanced-and-fourier-precision_score, advanced-and-fourier-recall_score, advanced-f1_score, advanced-accuracy_score, advanced-precision_score, advanced-recall_score, fourier-f1_score, fourier-accuracy_score, fourier-precision_score, fourier-recall_score, n_encrypted, n_non_encrypted, ratio_encrypt_nonencrypt, best_f1_score, improvement_in_advanced, improvement_in_fourier, room_for_improvement, fourier_minus_advanced, percentage_of_room_filled]
# Index: []
#
# [0 rows x 45 columns]

# %% [markdown]
# ### Correlation of data set and performance <a class="anchor" id="corr-heatmap">
#
# This gives more idea on how data-set selection affects performance.
#
# [top](#Contents)

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,10)
df2 = df[[c for c in df.columns if \
          "precision" not in c and \
          "accuracy" not in c and \
          "recall" not in c]]
sns.heatmap(df2.astype(float).corr(), cmap='coolwarm')
# print(df[df["baseline-f1_score"] > 0.9].astype(float))
_ = plt.xticks(rotation=80)

# %%
df1 = df[["exclude_encrypted_base32", \
          "exclude_encrypted_v2", \
          "exclude_webp", \
          "baseline-f1_score", \
          "advanced-f1_score", \
          "fourier-f1_score"]]
sns.heatmap(df1.astype(float).corr(), cmap='coolwarm')
_ = plt.xticks(rotation=80)

# %%
df1 = df[["exclude_encrypted_base32", \
          "exclude_encrypted_v2", \
          "exclude_plaintext_base32",\
          "exclude_webp", \
          "baseline-f1_score", \
          "advanced-f1_score", \
          "fourier-f1_score",
          "fourier-only-f1_score",
          "advanced-only-f1_score",
          "improvement_in_fourier",
          "improvement_in_advanced",
          "fourier_minus_advanced"
          ]]
sns.heatmap(df1.astype(float).corr(), cmap='coolwarm')
_ = plt.xticks(rotation=80)

# %%
cols = [c for c in df.columns if "improve" in c or "minus" in c or "exclude" in c]
df1 = df[cols]
sns.heatmap(df1.astype(float).corr(), cmap='coolwarm')
_ = plt.xticks(rotation=80)

# %%
df1 = df[["exclude_encrypted_base32", \
          "exclude_encrypted_v2", \
          "exclude_plaintext_base32",\
          "exclude_webp", \
          "baseline-f1_score", \
          "advanced-f1_score", \
          "fourier-f1_score",
          "fourier-only-f1_score",
          "advanced-only-f1_score",
          ]]
sns.heatmap(df1.astype(float).corr(), cmap='coolwarm')
_ = plt.xticks(rotation=80)

# %% [markdown]
# ### Average out all the metrics <a class="anchor" id="mean-fscores">
#
# To conclude we report the average of the f1-scores and the improvements with all datasets
#
# [top](#Contents)

# %%
df[[c for c in df.columns if ("score" in c or "improvement" in c) and "room" not in c]].mean()
# Out:
# baseline-f1_score                       0.820384
# baseline-accuracy_score                 0.761149
# baseline-precision_score                0.712656
# baseline-recall_score                   0.969040
# advanced-only-f1_score                  0.838543
# advanced-only-accuracy_score            0.791496
# advanced-only-precision_score           0.747503
# advanced-only-recall_score              0.960246
# fourier-only-f1_score                   0.844455
# fourier-only-accuracy_score             0.799342
# fourier-only-precision_score            0.759997
# fourier-only-recall_score               0.957614
# baseline-and-fourier-f1_score           0.857171
# baseline-and-fourier-accuracy_score     0.815050
# baseline-and-fourier-precision_score    0.773712
# baseline-and-fourier-recall_score       0.967551
# advanced-and-fourier-f1_score           0.866200
# advanced-and-fourier-accuracy_score     0.829093
# advanced-and-fourier-precision_score    0.790879
# advanced-and-fourier-recall_score       0.964272
# advanced-f1_score                       0.841875
# advanced-accuracy_score                 0.796065
# advanced-precision_score                0.752103
# advanced-recall_score                   0.961508
# fourier-f1_score                        0.866911
# fourier-accuracy_score                  0.829909
# fourier-precision_score                 0.791466
# fourier-recall_score                    0.965094
# best_f1_score                           0.866933
# improvement_in_advanced                 0.021490
# improvement_in_fourier                  0.046527
# dtype: float64

# %%
df[[c for c in df.columns if \
    ("-and-" in c or \
     "only" in c or \
     "score" in c or \
     "improvement" in c) and "room" not in c]].describe().T
# Out:
#                                       count      mean       std       min  \
# baseline-f1_score                     144.0  0.820384  0.021910  0.799313
# baseline-accuracy_score               144.0  0.761149  0.050001  0.678193
# baseline-precision_score              144.0  0.712656  0.038379  0.673816
# baseline-recall_score                 144.0  0.969040  0.022606  0.938174
# advanced-only-f1_score                144.0  0.838543  0.022046  0.812621
# advanced-only-accuracy_score          144.0  0.791496  0.049258  0.693138
# advanced-only-precision_score         144.0  0.747503  0.049108  0.685109
# advanced-only-recall_score            144.0  0.960246  0.039355  0.882839
# fourier-only-f1_score                 144.0  0.844455  0.036336  0.804668
# fourier-only-accuracy_score           144.0  0.799342  0.062787  0.684589
# fourier-only-precision_score          144.0  0.759997  0.072870  0.674582
# fourier-only-recall_score             144.0  0.957614  0.030422  0.915239
# baseline-and-fourier-f1_score         144.0  0.857171  0.045354  0.799995
# baseline-and-fourier-accuracy_score   144.0  0.815050  0.072589  0.685271
# baseline-and-fourier-precision_score  144.0  0.773712  0.079133  0.677515
# baseline-and-fourier-recall_score     144.0  0.967551  0.020605  0.929127
# advanced-and-fourier-f1_score         144.0  0.866200  0.046632  0.815768
# advanced-and-fourier-accuracy_score   144.0  0.829093  0.071341  0.702831
# advanced-and-fourier-precision_score  144.0  0.790879  0.082035  0.695832
# advanced-and-fourier-recall_score     144.0  0.964272  0.024986  0.904205
# advanced-f1_score                     144.0  0.841875  0.023575  0.812825
# advanced-accuracy_score               144.0  0.796065  0.050855  0.693439
# advanced-precision_score              144.0  0.752103  0.051987  0.685172
# advanced-recall_score                 144.0  0.961508  0.036363  0.887974
# fourier-f1_score                      144.0  0.866911  0.047163  0.816462
# fourier-accuracy_score                144.0  0.829909  0.071810  0.703363
# fourier-precision_score               144.0  0.791466  0.082347  0.696049
# fourier-recall_score                  144.0  0.965094  0.024966  0.904745
# best_f1_score                         144.0  0.866933  0.047140  0.816462
# improvement_in_advanced               144.0  0.021490  0.015397  0.000760
# improvement_in_fourier                144.0  0.046527  0.029864  0.006091
#
#                                            25%       50%       75%       max
# baseline-f1_score                     0.804540  0.812369  0.829994  0.869985
# baseline-accuracy_score               0.743156  0.762435  0.764863  0.858551
# baseline-precision_score              0.684027  0.696261  0.739415  0.797796
# baseline-recall_score                 0.955964  0.961674  0.991438  1.000000
# advanced-only-f1_score                0.814118  0.840008  0.853431  0.881373
# advanced-only-accuracy_score          0.765996  0.796062  0.828557  0.872663
# advanced-only-precision_score         0.694469  0.745141  0.801149  0.817463
# advanced-only-recall_score            0.941794  0.983580  0.987110  0.999841
# fourier-only-f1_score                 0.815996  0.831248  0.861742  0.922184
# fourier-only-accuracy_score           0.770446  0.797912  0.830146  0.921991
# fourier-only-precision_score          0.689209  0.761384  0.790810  0.910409
# fourier-only-recall_score             0.937616  0.946653  0.996917  0.999952
# baseline-and-fourier-f1_score         0.816470  0.858423  0.881419  0.951364
# baseline-and-fourier-accuracy_score   0.771166  0.820589  0.852840  0.950719
# baseline-and-fourier-precision_score  0.689878  0.776296  0.803176  0.929568
# baseline-and-fourier-recall_score     0.954025  0.974206  0.976554  0.999968
# advanced-and-fourier-f1_score         0.818655  0.864532  0.890352  0.961981
# advanced-and-fourier-accuracy_score   0.776844  0.825944  0.877695  0.961747
# advanced-and-fourier-precision_score  0.702283  0.787976  0.828205  0.946315
# advanced-and-fourier-recall_score     0.955006  0.973005  0.978175  0.994135
# advanced-f1_score                     0.814306  0.847726  0.853768  0.884819
# advanced-accuracy_score               0.766069  0.805865  0.829756  0.876313
# advanced-precision_score              0.694919  0.748077  0.814746  0.820381
# advanced-recall_score                 0.944085  0.980371  0.987469  0.999857
# fourier-f1_score                      0.818460  0.864926  0.893109  0.963817
# fourier-accuracy_score                0.777866  0.825702  0.878141  0.963590
# fourier-precision_score               0.703296  0.788396  0.828477  0.948025
# fourier-recall_score                  0.956391  0.973037  0.980144  0.993118
# best_f1_score                         0.818655  0.864926  0.893109  0.963817
# improvement_in_advanced               0.011956  0.014834  0.032796  0.050468
# improvement_in_fourier                0.014127  0.051298  0.065613  0.093832

# %%
df1 = df[[c for c in df.columns if \
          ("score" in c or "improvement" in c) \
          and "room" not in c]]
columns = ["baseline-f1_score"]
columns += [c for c in df1.columns if "only" in c]
columns += [c for c in df1.columns if "-and-" in c]
columns += [c for c in df1.columns if "only" not in c \
            and "-and-" not in c and "baseline-f1_score" != c]
df1[columns].describe().T
# Out:
#                                       count      mean       std       min  \
# baseline-f1_score                     144.0  0.820384  0.021910  0.799313
# advanced-only-f1_score                144.0  0.838543  0.022046  0.812621
# advanced-only-accuracy_score          144.0  0.791496  0.049258  0.693138
# advanced-only-precision_score         144.0  0.747503  0.049108  0.685109
# advanced-only-recall_score            144.0  0.960246  0.039355  0.882839
# fourier-only-f1_score                 144.0  0.844455  0.036336  0.804668
# fourier-only-accuracy_score           144.0  0.799342  0.062787  0.684589
# fourier-only-precision_score          144.0  0.759997  0.072870  0.674582
# fourier-only-recall_score             144.0  0.957614  0.030422  0.915239
# baseline-and-fourier-f1_score         144.0  0.857171  0.045354  0.799995
# baseline-and-fourier-accuracy_score   144.0  0.815050  0.072589  0.685271
# baseline-and-fourier-precision_score  144.0  0.773712  0.079133  0.677515
# baseline-and-fourier-recall_score     144.0  0.967551  0.020605  0.929127
# advanced-and-fourier-f1_score         144.0  0.866200  0.046632  0.815768
# advanced-and-fourier-accuracy_score   144.0  0.829093  0.071341  0.702831
# advanced-and-fourier-precision_score  144.0  0.790879  0.082035  0.695832
# advanced-and-fourier-recall_score     144.0  0.964272  0.024986  0.904205
# baseline-accuracy_score               144.0  0.761149  0.050001  0.678193
# baseline-precision_score              144.0  0.712656  0.038379  0.673816
# baseline-recall_score                 144.0  0.969040  0.022606  0.938174
# advanced-f1_score                     144.0  0.841875  0.023575  0.812825
# advanced-accuracy_score               144.0  0.796065  0.050855  0.693439
# advanced-precision_score              144.0  0.752103  0.051987  0.685172
# advanced-recall_score                 144.0  0.961508  0.036363  0.887974
# fourier-f1_score                      144.0  0.866911  0.047163  0.816462
# fourier-accuracy_score                144.0  0.829909  0.071810  0.703363
# fourier-precision_score               144.0  0.791466  0.082347  0.696049
# fourier-recall_score                  144.0  0.965094  0.024966  0.904745
# best_f1_score                         144.0  0.866933  0.047140  0.816462
# improvement_in_advanced               144.0  0.021490  0.015397  0.000760
# improvement_in_fourier                144.0  0.046527  0.029864  0.006091
#
#                                            25%       50%       75%       max
# baseline-f1_score                     0.804540  0.812369  0.829994  0.869985
# advanced-only-f1_score                0.814118  0.840008  0.853431  0.881373
# advanced-only-accuracy_score          0.765996  0.796062  0.828557  0.872663
# advanced-only-precision_score         0.694469  0.745141  0.801149  0.817463
# advanced-only-recall_score            0.941794  0.983580  0.987110  0.999841
# fourier-only-f1_score                 0.815996  0.831248  0.861742  0.922184
# fourier-only-accuracy_score           0.770446  0.797912  0.830146  0.921991
# fourier-only-precision_score          0.689209  0.761384  0.790810  0.910409
# fourier-only-recall_score             0.937616  0.946653  0.996917  0.999952
# baseline-and-fourier-f1_score         0.816470  0.858423  0.881419  0.951364
# baseline-and-fourier-accuracy_score   0.771166  0.820589  0.852840  0.950719
# baseline-and-fourier-precision_score  0.689878  0.776296  0.803176  0.929568
# baseline-and-fourier-recall_score     0.954025  0.974206  0.976554  0.999968
# advanced-and-fourier-f1_score         0.818655  0.864532  0.890352  0.961981
# advanced-and-fourier-accuracy_score   0.776844  0.825944  0.877695  0.961747
# advanced-and-fourier-precision_score  0.702283  0.787976  0.828205  0.946315
# advanced-and-fourier-recall_score     0.955006  0.973005  0.978175  0.994135
# baseline-accuracy_score               0.743156  0.762435  0.764863  0.858551
# baseline-precision_score              0.684027  0.696261  0.739415  0.797796
# baseline-recall_score                 0.955964  0.961674  0.991438  1.000000
# advanced-f1_score                     0.814306  0.847726  0.853768  0.884819
# advanced-accuracy_score               0.766069  0.805865  0.829756  0.876313
# advanced-precision_score              0.694919  0.748077  0.814746  0.820381
# advanced-recall_score                 0.944085  0.980371  0.987469  0.999857
# fourier-f1_score                      0.818460  0.864926  0.893109  0.963817
# fourier-accuracy_score                0.777866  0.825702  0.878141  0.963590
# fourier-precision_score               0.703296  0.788396  0.828477  0.948025
# fourier-recall_score                  0.956391  0.973037  0.980144  0.993118
# best_f1_score                         0.818655  0.864926  0.893109  0.963817
# improvement_in_advanced               0.011956  0.014834  0.032796  0.050468
# improvement_in_fourier                0.014127  0.051298  0.065613  0.093832

# %%
# Full score


def regroup(df):
    def get_name(name):
        if "score" not in name.lower():
            return None, None
        feature = name
        measure = None

        measure_map = {
            "f1_score": "F1",
            "accuracy_score": "Accuracy",
            "precision_score": "Precision",
            "recall_score": "Recall"
        }
        featurename_map = {
            "fourier-only-": "Fourier Only",
            "advanced-only-": "Advanced Only",
            "baseline-and-fourier": "Baseline and Fourier",
            "advanced-and-fourier": "Advanced and Fourier",
            "baseline-and-advanced": "Baseline and Advanced",
            "fourier-": "Baseline, Advanced and Fourier",
            "baseline-": "Baseline",
            "advanced-": "Baseline and Advanced",
        }
        for i, j in measure_map.items():
            if i in name:
                measure = j
                break
        for i, j in featurename_map.items():
            if i in name:
                feature = j
                break
        return name, feature, measure

    pd.DataFrame({"Score": df.mean()})
    indices = list(df.mean().index)
    values = df.mean().to_numpy()
    df_acc = pd.DataFrame({"Original":["dummy"], "Feature": ["dummy"], "MeasureName": ["dummy"], "MeasureValue": [0.0]})


    for name, value in zip(indices, values):
        if "score" in name.lower():
            orname, featurename, measurename = get_name(name)
            if featurename is not None:
                tempdf = pd.DataFrame({"Original": [orname], "Feature": [featurename], "MeasureName": [measurename], "MeasureValue": [value]})
                df_acc = pd.concat([df_acc, tempdf]).copy()
    df_acc = df_acc[df_acc["Feature"] != "dummy"]  
    df_acc = df_acc[df_acc["Original"] != "best_f1_score"]
    return df_acc



def regroup_and_pivot(df):
    acc_df = regroup(df)
    acc_df = acc_df[["Feature", "MeasureName", "MeasureValue"]]
    return acc_df.pivot(index="Feature", columns="MeasureName", values="MeasureValue")

# %%
print(regroup_and_pivot(df).to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.791496 &  0.838543 &   0.747503 &  0.960246 \\
# Advanced and Fourier           &  0.829093 &  0.866200 &   0.790879 &  0.964272 \\
# Baseline                       &  0.761149 &  0.820384 &   0.712656 &  0.969040 \\
# Baseline and Advanced          &  0.796065 &  0.841875 &   0.752103 &  0.961508 \\
# Baseline and Fourier           &  0.815050 &  0.857171 &   0.773712 &  0.967551 \\
# Baseline, Advanced and Fourier &  0.829909 &  0.866911 &   0.791466 &  0.965094 \\
# Fourier Only                   &  0.799342 &  0.844455 &   0.759997 &  0.957614 \\
# \bottomrule
# \end{tabular}

# %%
regroup_and_pivot(df).sort_values(by="F1")
# Out:
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Baseline                        0.761149  0.820384   0.712656  0.969040
# Advanced Only                   0.791496  0.838543   0.747503  0.960246
# Baseline and Advanced           0.796065  0.841875   0.752103  0.961508
# Fourier Only                    0.799342  0.844455   0.759997  0.957614
# Baseline and Fourier            0.815050  0.857171   0.773712  0.967551
# Advanced and Fourier            0.829093  0.866200   0.790879  0.964272
# Baseline, Advanced and Fourier  0.829909  0.866911   0.791466  0.965094

# %%
regroup_and_pivot(df)[['F1', 'Precision', 'Recall']]
# Out:
# MeasureName                           F1  Precision    Recall
# Feature
# Advanced Only                   0.838543   0.747503  0.960246
# Advanced and Fourier            0.866200   0.790879  0.964272
# Baseline                        0.820384   0.712656  0.969040
# Baseline and Advanced           0.841875   0.752103  0.961508
# Baseline and Fourier            0.857171   0.773712  0.967551
# Baseline, Advanced and Fourier  0.866911   0.791466  0.965094
# Fourier Only                    0.844455   0.759997  0.957614

# %%
print(regroup_and_pivot(df)[['F1', 'Precision', 'Recall']].to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# MeasureName &        F1 &  Precision &    Recall \\
# Feature                        &           &            &           \\
# \midrule
# Advanced Only                  &  0.838543 &   0.747503 &  0.960246 \\
# Advanced and Fourier           &  0.866200 &   0.790879 &  0.964272 \\
# Baseline                       &  0.820384 &   0.712656 &  0.969040 \\
# Baseline and Advanced          &  0.841875 &   0.752103 &  0.961508 \\
# Baseline and Fourier           &  0.857171 &   0.773712 &  0.967551 \\
# Baseline, Advanced and Fourier &  0.866911 &   0.791466 &  0.965094 \\
# Fourier Only                   &  0.844455 &   0.759997 &  0.957614 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Reporting for the final report <a class="anchor" id="report">
#
# [top](#Contents)

# %%
def regroup(df):
    def get_name(name):
        if "score" not in name.lower():
            return None, None
        feature = name
        measure = None

        measure_map = {
            "f1_score": "F1",
            "accuracy_score": "Accuracy",
            "precision_score": "Precision",
            "recall_score": "Recall"
        }
        featurename_map = {
            "fourier-only-": "Fourier Only",
            "advanced-only-": "Advanced Only",
            "baseline-and-fourier": "Baseline and Fourier",
            "advanced-and-fourier": "Advanced and Fourier",
            "baseline-and-advanced": "Baseline and Advanced",
            "fourier-": "Baseline, Advanced and Fourier",
            "baseline-": "Baseline",
            "advanced-": "Baseline and Advanced",
        }
        for i, j in measure_map.items():
            if i in name:
                measure = j
                break
        for i, j in featurename_map.items():
            if i in name:
                feature = j
                break
        return name, feature, measure

    pd.DataFrame({"Score": df.mean()})
    indices = list(df.mean().index)
    values = df.mean().to_numpy()
    df_acc = pd.DataFrame({"Original":["dummy"], "Feature": ["dummy"], "MeasureName": ["dummy"], "MeasureValue": [0.0]})


    for name, value in zip(indices, values):
        if "score" in name.lower():
            orname, featurename, measurename = get_name(name)
            if featurename is not None:
                tempdf = pd.DataFrame({"Original": [orname], "Feature": [featurename], "MeasureName": [measurename], "MeasureValue": [value]})
                df_acc = pd.concat([df_acc, tempdf]).copy()
    df_acc = df_acc[df_acc["Feature"] != "dummy"]  
    df_acc = df_acc[df_acc["Original"] != "best_f1_score"]
    return df_acc

# %%
# Full score

def regroup_and_pivot(df):
    acc_df = regroup(df)
    acc_df = acc_df[["Feature", "MeasureName", "MeasureValue"]]
    return acc_df.pivot(index="Feature", columns="MeasureName", values="MeasureValue")

# %%
newdf = regroup_and_pivot(df)

# %%
print(newdf.to_latex())
newdf.sort_values(by="F1")
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.791496 &  0.838543 &   0.747503 &  0.960246 \\
# Advanced and Fourier           &  0.829093 &  0.866200 &   0.790879 &  0.964272 \\
# Baseline                       &  0.761149 &  0.820384 &   0.712656 &  0.969040 \\
# Baseline and Advanced          &  0.796065 &  0.841875 &   0.752103 &  0.961508 \\
# Baseline and Fourier           &  0.815050 &  0.857171 &   0.773712 &  0.967551 \\
# Baseline, Advanced and Fourier &  0.829909 &  0.866911 &   0.791466 &  0.965094 \\
# Fourier Only                   &  0.799342 &  0.844455 &   0.759997 &  0.957614 \\
# \bottomrule
# \end{tabular}
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Baseline                        0.761149  0.820384   0.712656  0.969040
# Advanced Only                   0.791496  0.838543   0.747503  0.960246
# Baseline and Advanced           0.796065  0.841875   0.752103  0.961508
# Fourier Only                    0.799342  0.844455   0.759997  0.957614
# Baseline and Fourier            0.815050  0.857171   0.773712  0.967551
# Advanced and Fourier            0.829093  0.866200   0.790879  0.964272
# Baseline, Advanced and Fourier  0.829909  0.866911   0.791466  0.965094

# %%
 df2 = df[(df["exclude_webp"] == 0) & (df["exclude_nonwebp"] == 1) ]

# %%
df2 = regroup_and_pivot(df2)
print(df2.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.743690 &  0.813273 &   0.690044 &  0.990177 \\
# Advanced and Fourier           &  0.751828 &  0.817090 &   0.698938 &  0.983409 \\
# Baseline                       &  0.731670 &  0.807304 &   0.678283 &  0.996952 \\
# Baseline and Advanced          &  0.743937 &  0.813420 &   0.690255 &  0.990185 \\
# Baseline and Fourier           &  0.736167 &  0.808478 &   0.683992 &  0.988365 \\
# Baseline, Advanced and Fourier &  0.752324 &  0.817343 &   0.699484 &  0.983062 \\
# Fourier Only                   &  0.736425 &  0.810271 &   0.681814 &  0.998404 \\
# \bottomrule
# \end{tabular}

# %%
df2 = df[(df["exclude_webp"] == 1) & (df["exclude_nonwebp"] == 0) ]
df2 = regroup_and_pivot(df2)
print(df2.to_latex())
df2.sort_values(by="F1")
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.833047 &  0.859083 &   0.809128 &  0.915920 \\
# Advanced and Fourier           &  0.898849 &  0.912763 &   0.884084 &  0.943650 \\
# Baseline                       &  0.788047 &  0.833097 &   0.745485 &  0.945247 \\
# Baseline and Advanced          &  0.841288 &  0.865797 &   0.816824 &  0.921441 \\
# Baseline and Fourier           &  0.883004 &  0.901804 &   0.858772 &  0.950324 \\
# Baseline, Advanced and Fourier &  0.899744 &  0.913616 &   0.884826 &  0.944630 \\
# Fourier Only                   &  0.854915 &  0.877942 &   0.833682 &  0.929257 \\
# \bottomrule
# \end{tabular}
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Baseline                        0.788047  0.833097   0.745485  0.945247
# Advanced Only                   0.833047  0.859083   0.809128  0.915920
# Baseline and Advanced           0.841288  0.865797   0.816824  0.921441
# Fourier Only                    0.854915  0.877942   0.833682  0.929257
# Baseline and Fourier            0.883004  0.901804   0.858772  0.950324
# Advanced and Fourier            0.898849  0.912763   0.884084  0.943650
# Baseline, Advanced and Fourier  0.899744  0.913616   0.884826  0.944630

# %%
df2 = df[(df["exclude_webp"] == 0) & (df["exclude_nonwebp"] == 1) ]
df2 = df.copy()
df2 = df2[[c for c in df2.columns if "score" in c]]
df2 = df2.describe().T
df2 = df2["std"]

def get_name(name):
    if "score" not in name.lower():
        return None, None
    feature = name
    measure = None

    measure_map = {
        "f1_score": "F1",
        "accuracy_score": "Accuracy",
        "precision_score": "Precision",
        "recall_score": "Recall"
    }
    featurename_map = {
        "fourier-only-": "Fourier Only",
        "advanced-only-": "Advanced Only",
        "baseline-and-fourier": "Baseline and Fourier",
        "advanced-and-fourier": "Advanced and Fourier",
        "baseline-and-advanced": "Baseline and Advanced",
        "fourier-": "Baseline, Advanced and Fourier",
        "baseline-": "Baseline",
        "advanced-": "Baseline and Advanced",
    }
    for i, j in measure_map.items():
        if i in name:
            measure = j
            break
    for i, j in featurename_map.items():
        if i in name:
            feature = j
            break
    return name, feature, measure


indices = list(df2.index)
values = df2.to_numpy()
df_acc = pd.DataFrame({"Original":["dummy"], "Feature": ["dummy"], "MeasureName": ["dummy"], "MeasureValue": [0.0]})


for name, value in zip(indices, values):
    if "score" in name.lower():
        orname, featurename, measurename = get_name(name)
        if featurename is not None:
            tempdf = pd.DataFrame({"Original": [orname], "Feature": [featurename], "MeasureName": [measurename], "MeasureValue": [value]})
            df_acc = pd.concat([df_acc, tempdf]).copy()
df_acc = df_acc[df_acc["Feature"] != "dummy"]  
df_acc = df_acc[df_acc["Original"] != "best_f1_score"]
df_acc = df_acc[[c for c in df_acc.columns if "Original" != c]]

df_acc = df_acc.pivot(index="Feature", columns="MeasureName", values="MeasureValue")
print(df_acc.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.049258 &  0.022046 &   0.049108 &  0.039355 \\
# Advanced and Fourier           &  0.071341 &  0.046632 &   0.082035 &  0.024986 \\
# Baseline                       &  0.050001 &  0.021910 &   0.038379 &  0.022606 \\
# Baseline and Advanced          &  0.050855 &  0.023575 &   0.051987 &  0.036363 \\
# Baseline and Fourier           &  0.072589 &  0.045354 &   0.079133 &  0.020605 \\
# Baseline, Advanced and Fourier &  0.071810 &  0.047163 &   0.082347 &  0.024966 \\
# Fourier Only                   &  0.062787 &  0.036336 &   0.072870 &  0.030422 \\
# \bottomrule
# \end{tabular}

# %%
df_acc.sort_values(by="F1")
# Out:
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Baseline                        0.050001  0.021910   0.038379  0.022606
# Advanced Only                   0.049258  0.022046   0.049108  0.039355
# Baseline and Advanced           0.050855  0.023575   0.051987  0.036363
# Fourier Only                    0.062787  0.036336   0.072870  0.030422
# Baseline and Fourier            0.072589  0.045354   0.079133  0.020605
# Advanced and Fourier            0.071341  0.046632   0.082035  0.024986
# Baseline, Advanced and Fourier  0.071810  0.047163   0.082347  0.024966

# %%
df.to_csv("LR_SAMPLED_CS5_FINAL.csv")
