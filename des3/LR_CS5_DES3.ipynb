# %% [markdown]
# Few key observations
# - If both and non-encrypted files are base-32 encoded, accuracy drops really low.
#    * Even in this case, fourier analysis (specifically autocorrelation and mean) provide good discrminators
#    * Renyi's entropy at alpha=infinity gives good discrimination
#    * Overall we see around 13% improvement in F1-score
# - Specifically for webpfiles
#    * We see that higher moments of around 14 gives a good discrimination
#    * Fourier analysis still gives benefits here
# - For webpfiles where both unencrypted and encrypted content are base32 encrypted
#    * Fourier analysis is still beneficial
# - For Non-webp files where plaintext is not base-32 encrypted
#    * Accuracy is decent with just the base parameters, but with fourier analysis, we can close to perfect detection

# %% [markdown]
# # Contents
# - ## [Implementation](#mplementation)
#  - ### [List of Files](#list-of-files)
#  - ### [Utility to call gc](#gc)
#  - ### [Selection of Columns](#select-columns)
#  - ### [Function to compare the three selections of columns for a given dataset](#compare-fn)
#  - ### [Load the datasets](#load-dataset)
#  - ### [Select the datasets](#dataset-selection)
#  - ### [Run all combinations of data](#dataset-selection)
# - ## [Results](#results)
#  - ### [Print the raw results](#raw-results)
#  - ### [Sort by the improvement when using Fourier transforms over baseline](#sorted-fourier)
#  - ### [Measure improvement when only webp files are used](#webp-only)
#  - ### [Measure improvement when webp files are not present](#no-webp)
#  - ### [Measure improvement for balanced datasets](#balanced-dataset)
#  - ### [Measure the improvement when all files are used](#full-dataset)
#  - ### [Focus on items where the base metrics performed well](#focus-greater-90)
#  - ### [Correlation of data set and performance]("corr-heatmap")
#  - ### [Average out all the metrics](#mean-fscores)
#
# - # [Reporting for the final report](#report)

# %% [markdown]
# ## Implementation <a class="anchor" id="implementation">
#
# [top](#Contents)

# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats

from functools import lru_cache

import gc

import sklearn
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, accuracy_score, recall_score

import matplotlib.pyplot as plt
import glob

import tqdm
from multiprocessing.pool import ThreadPool, Pool

plt.rcParams["figure.figsize"] = (20,20)

# %%
# !ls
# Out:
# LR_CS5_DES3.ipynb                     expanded.plaintext.base32.csv.gz
# RF_CS5_DES3.ipynb                     plaintext.base32.combined.csv.gz
# encrypted.expanded.base32.des3.csv.gz plaintext.combined.csv.gz
# encrypted.expanded.des3.csv.gz        plaintext.expanded.csv.gz

# %% [markdown]
# ### List of files <a class="anchor" id="list-of-files">
#
# [top](#Contents)

# %%
# !ls
# Out:
# LR_CS5_DES3.ipynb                     expanded.plaintext.base32.csv.gz
# RF_CS5_DES3.ipynb                     plaintext.base32.combined.csv.gz
# encrypted.expanded.base32.des3.csv.gz plaintext.combined.csv.gz
# encrypted.expanded.des3.csv.gz        plaintext.expanded.csv.gz

# %% [markdown]
# ### Utility to call GC <a class="anchor" id="gc">
#
# [top](#Contents)

# %%
def call_gc():
    for i in range(3):
        for j in range(3):
            gc.collect(j)

# %% [markdown]
# ### Selection of columns <a class="anchor" id="select-columns">
#
# This function is used to select the columns.
# There are three different configurations:
#
#     1. Baseline - statistics like autocorrelation, shannon entropy, chi-square etc. are used
#
#     2. Advanced - More statistics like moments, Tsallis and Renyi entropy, higher moments etc.
#
#     3. Fourier - Some statistics of the Fourier Power Spectrum distribution
#
# [top](#Contents)

# %%
def get_columns(thisdf):
    baseline_columns = [c for c in thisdf.columns if c.startswith('baseline') and "head" not in c and "tail" not in c]
    baseline_columns = [c for c in baseline_columns if "filesize" not in c]
    baseline_columns = [c for c in baseline_columns if "begin" not in c and "end" not in c]

    advanced_columns = [c for c in thisdf.columns if "advanced" in c]
    advanced_columns = [c for c in advanced_columns if "begin" not in c and "end" not in c]
    advanced_columns = [c for c in advanced_columns if "head" not in c and "tail" not in c]
    advanced_columns = [c for c in advanced_columns if "start" not in c]
    advanced_columns_only = list(set(advanced_columns))
    advanced_columns = list(set(advanced_columns + baseline_columns))

    fourier_columns = [c for c in thisdf.columns if "fourier" in c and "value" not in c]
    fourier_columns = [c for c in fourier_columns if "1byte" in c]
    fourier_columns = [c for c in fourier_columns if "begin" not in c and "end" not in c]
    fourier_columns = [c for c in fourier_columns if "head" not in c and "tail" not in c]
    fourier_columns = [c for c in fourier_columns if "start" not in c]
    fourier_columns_only = list(set(fourier_columns))
    fourier_columns = list(set(advanced_columns + fourier_columns))
    
    baseline_and_advanced = list(set(baseline_columns + advanced_columns_only))
    baseline_and_fourier = list(set(baseline_columns + fourier_columns_only))
    advanced_and_fourier = list(set(advanced_columns_only + fourier_columns_only))
    
    return {\
        "baseline": baseline_columns,\
        "advanced-only": advanced_columns_only,\
        "fourier-only": fourier_columns_only,\
        "baseline-and-fourier": baseline_and_fourier,\
        "advanced-and-fourier": advanced_and_fourier,\
        "advanced": advanced_columns,\
        "fourier": fourier_columns,\
    }

# %% [markdown]
# ### Function to compare the three selections of columns for a given dataset <a class="anchor" id="compare-fn">
#
# For the three different sets of measurements described above, compare all the three sets for their f1 score
#
# [top](#Contents)

# %%
USE_ASYNC = False
N_SPLITS=5

def get_kfold_f1_score(name, collist, X, y):
    skf = StratifiedKFold(n_splits=N_SPLITS, random_state=42, shuffle=True)
    f1_scores = []
    precision_scores = []
    recall_scores = []
    accuracy_scores = []
    X = X[collist].to_numpy()
    y = y.to_numpy()
    call_gc()
    for train_idx, test_idx in skf.split(X, y):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]
        lr = LogisticRegression(n_jobs=8, \
                                solver='saga', \
                                random_state=42, \
                                max_iter=1000, \
                                multi_class='ovr')
        estimators = [\
                      ('std,', MinMaxScaler()), \
                      ('LogisticRegression', lr)]
        pipeline = Pipeline(estimators)
        pipeline.fit(X_train, y_train)
        y_pred = pipeline.predict(X_test)
        f1_scores.append(f1_score(y_test, y_pred))
        recall_scores.append(recall_score(y_test, y_pred))
        precision_scores.append(precision_score(y_test, y_pred, zero_division=0))
        accuracy_scores.append(accuracy_score(y_test, y_pred))

    return name, \
            float(np.mean(f1_scores)),\
            float(np.mean(accuracy_scores)),\
            float(np.mean(precision_scores)),\
            float(np.mean(recall_scores)),

def compare_feature_selections_async(X, y):
    columns_dict = get_columns(X)
    ret = dict()
    pool = Pool(3)
    async_results = list()
    for name, collist in columns_dict.items():
        result = pool.apply_async(\
                                  get_kfold_f1_score, \
                                  (name, collist, X, y))
    for result in async_results:
        name, f1 = result.get(timeout=None)
        ret[name] = f1
    return ret

def compare_feature_selections_sync(X, y):
    columns_dict = get_columns(X)
    ret = dict()
    for name, collist in columns_dict.items():
        name, f1, accuracy, precision, recall = \
            get_kfold_f1_score(name, collist, X, y)
        ret[f"{name}-f1_score"] = f1
        ret[f"{name}-accuracy_score"] = accuracy
        ret[f"{name}-precision_score"] = precision
        ret[f"{name}-recall_score"] = recall
    return ret

def compare_feature_selections(X, y):
    if USE_ASYNC:
        return compare_feature_selections_async(X, y)
    else:
        return compare_feature_selections_sync(X, y)

def compare_feature_selections_wrapper(data):
    X = data[[c for c in data.columns if "is_encrypted" != c]]
    y = data["is_encrypted"]
    return compare_feature_selections(X, y)

# %% [markdown]
# ### Load the datasets <a class="anchor" id="load-dataset">
#
# We don't want to load the datasets again and again, so we load them once.
# The LRU cache ensures that the next time this is called, we don't load the datasets again.
#
# [top](#Contents)

# %%
@lru_cache
def load_datasets_once():
    """Load all datasets only once
    
    We want to load the datasets only once. Once loaded
    serve from cache
    """
    datasets = dict()
    for file in glob.glob("*.csv.gz"):
        df = pd.read_csv(file)
        df = df.sample(frac=1).reset_index(drop=True)
        df["is_encrypted"] = 1 if "encr" in file.lower() else 0
        datasets[file] = df
    return datasets

# %% [markdown]
# ### Select the datasets <a class="anchor" id="dataset-selection">
#
# Select the dataset, combine it, shuffle it and return
#
# We used several schemes:
# * Plaintext
#   - The base plaintext dataset of around 50k files
#   - Expanded dataset, where all files that were less than 1500 bytes were expanded by repeating the file
#   - Base32 encoding of
#    - original plaintext
#    - expanded plaintext
# * Encryption : We used two schemes for encruption
#   - v1 : AES 256 encryption of the full file, again two varieties were used
#     - Plain encryption
#     - Encryption followed by base32 encoding
#   - v2 : AES encryption of the file, the first and the last 128 bytes are not encrypted. Of the remaining file, every alternate 16 bytes are encrypted.
#     - Plain encryption
#     - encryption followed by base32 encoding
#
# We select combinations of the above datasets
#
# Furthermore, we add further combinations by including and excluding webp files, and including and excluding non-webp files.
#
# [top](#Contents)

# %%
def get_dataset(\
               exclude_plaintext_nonbase32=False,
               exclude_plaintext_base32=False,
               exclude_encrypted_v1=False,
               exclude_encrypted_v2=False,
               exclude_encrypted_base32=False,
               exclude_encrypted_nonbase32=False,
               exclude_webp=False,
               exclude_nonwebp=False):
    description = {k:v for k,v in locals().items() \
                   if "exclude" in k}
    
    files = glob.glob("*.csv.gz")
    
    
    if exclude_plaintext_nonbase32:
        files = [f for f in files if \
                     "plaintext" not in f \
                     or "_base32" in f \
                     or "_b32" in f]
    if exclude_plaintext_base32:
        files = [f for f in files if\
                    "plaintext" not in f or \
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_v1:
        files = [f for f in files if\
                    "_v1" not in f or "encr" not in f]
    if exclude_encrypted_v2:
        files = [f for f in files if \
                    "_v2" not in f or "encr" not in f]
    if exclude_encrypted_base32:
        files = [ f for f in files if\
                    "encr" not in f or\
                    ("base32" not in f and "b32" not in f)]
    if exclude_encrypted_nonbase32:
        files = [f for f in files if \
                    "encr" not in f or \
                    "base32" in f or "b32" in f]
        
        
    encrypted_count = len([f for f in files if "encr" in f])
    non_encrypted_count = len([f for f in files if "encr" not in f])
    
    if 0 == encrypted_count or 0 == non_encrypted_count or 0 == len(files):
        return description, None, -1, -1
    
    all_dfs = list()
    all_loaded_datasets = load_datasets_once()
    for filename in files:
        all_dfs.append(all_loaded_datasets[filename])
    
    combined_df = pd.concat(all_dfs)
    
    if exclude_webp:
        combined_df = combined_df[\
                        combined_df["extended.extension"] != ".webp"]
    if exclude_nonwebp:
        combined_df = combined_df[\
                        combined_df["extended.extension"] == ".webp"]
        
    if len(combined_df) == 0:
        return description, None, -1, -1
    
        
    encrypt_count = len(combined_df[combined_df["is_encrypted"] == 1])
    nonencrypted_count = len(combined_df[combined_df["is_encrypted"] == 0])

    
    if 0 == len(combined_df) or 0 == encrypt_count or 0 == nonencrypted_count:
        return description, None, -1, -1
    
    return description, combined_df, encrypt_count, nonencrypted_count

# %% [markdown]
# ### Run all combinations of data <a class="anchor" id="dataset-selection">
#
# For all combinations of the datasets, compare the three classes (basic, advanced, and Fourier)
#
# [top](#Contents)

# %%
all_results = []
list_of_arguments = []

# Get all 8-tuple combinations of T/F
list_of_arguments = [(True,), (False,)]
for i in range(7):
    temp = []
    for e in list_of_arguments:
        et = e + (True,)
        temp.append(et)
        et = e + (False,)
        temp.append(et)
    list_of_arguments = temp

     
for a, b, c, k, e, f, g, h in tqdm.tqdm(list_of_arguments):
    desc, df, ec, nec = get_dataset(a, b, c, k, e, f, g, h)
    if df is not None:
        result = compare_feature_selections_wrapper(df)
        call_gc()
        result = {**desc, **result}
        result["n_encrypted"] = ec
        result["n_non_encrypted"] = nec
        result["ratio_encrypt_nonencrypt"] = float(ec) / nec
        all_results.append(result)


df_dict = {k:[] for k in all_results[0]}
for result in all_results:
    for k, v in result.items():
        df_dict[k].append(v)

df = pd.DataFrame(df_dict)
df["best_f1_score"] = \
    df[[c for c in df.columns if "f1_score" in c]].max(axis=1)

df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["improvement_in_fourier"] = \
    df["fourier-f1_score"] - df["baseline-f1_score"]
df = df.sort_values(by="improvement_in_fourier", ascending=False)
# Out:
# 100%|████████████████████████████████████████████████| 256/256 [10:37:57<00:00, 149.52s/it]

# %% [markdown]
# ## Results <a class="anchor" id="results">
#
# In this section, we present the results
#
# [top](#Contents)

# %% [markdown]
# ### Print the raw results <a class="anchor" id="raw-results">
#
# [top](#Contents)

# %%
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 48                        False                     False
# 39                        False                     False
# 66                        False                     False
# 57                        False                     False
# 59                        False                     False
# ..                          ...                       ...
# 14                        False                      True
# 13                        False                      True
# 31                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 48                  True                 False                     False
# 39                  True                  True                     False
# 66                 False                 False                     False
# 57                 False                  True                     False
# 59                 False                  True                     False
# ..                   ...                   ...                       ...
# 14                  True                 False                     False
# 13                  True                 False                     False
# 31                 False                 False                     False
# 22                 False                  True                     False
# 4                   True                  True                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 48                         True          True            False
# 39                         True          True            False
# 66                         True          True            False
# 57                         True          True            False
# 59                         True         False            False
# ..                          ...           ...              ...
# 14                         True         False            False
# 13                         True         False             True
# 31                         True         False             True
# 22                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-f1_score  \
# 48           0.004519                 0.772605  ...          0.922326
# 39           0.004519                 0.772605  ...          0.922326
# 66           0.004519                 0.772605  ...          0.922326
# 57           0.004519                 0.772605  ...          0.922326
# 59           0.006091                 0.782051  ...          0.760109
# ..                ...                      ...  ...               ...
# 14           0.998376                 0.998916  ...          0.999858
# 13           1.000000                 1.000000  ...          1.000000
# 31           1.000000                 1.000000  ...          1.000000
# 22           1.000000                 1.000000  ...          1.000000
# 4            1.000000                 1.000000  ...          1.000000
#
#     fourier-accuracy_score  fourier-precision_score  fourier-recall_score  \
# 48                0.966909                 0.869269              0.982287
# 39                0.966909                 0.869269              0.982287
# 66                0.966909                 0.869269              0.982287
# 57                0.966909                 0.869269              0.982287
# 59                0.889043                 0.669592              0.878928
# ..                     ...                      ...                   ...
# 14                0.999905                 0.999716              1.000000
# 13                1.000000                 1.000000              1.000000
# 31                1.000000                 1.000000              1.000000
# 22                1.000000                 1.000000              1.000000
# 4                 1.000000                 1.000000              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 48        49228           196912                      0.25       0.922326
# 39        49228           196912                      0.25       0.922326
# 66        49228           196912                      0.25       0.922326
# 57        49228           196912                      0.25       0.922326
# 59        80853           323412                      0.25       0.760109
# ..          ...              ...                       ...            ...
# 14        80853           161706                      0.50       0.999858
# 13        31625            63250                      0.50       1.000000
# 31        31625            63250                      0.50       1.000000
# 22        31625            63250                      0.50       1.000000
# 4         31625            63250                      0.50       1.000000
#
#     improvement_in_advanced  improvement_in_fourier
# 48                 0.895236                0.917807
# 39                 0.895236                0.917807
# 66                 0.895236                0.917807
# 57                 0.895236                0.917807
# 59                 0.704378                0.754018
# ..                      ...                     ...
# 14                 0.001160                0.001482
# 13                 0.000000                0.000000
# 31                 0.000000                0.000000
# 22                 0.000000                0.000000
# 4                  0.000000                0.000000
#
# [72 rows x 42 columns]

# %%
df.to_csv("../LR_comparison.csv")

# %%
# df = pd.read_csv("comparison_logistic_regression_final.csv")
df = df.sort_values(by="improvement_in_fourier", ascending=False)

# %% [markdown]
# ### Sort by the improvement when using Fourier transforms over baseline <a class="anchor" id="sorted-fourier">
#
# We also take a few other things:
# * Room for improvement (1 - baseline score)
# * How much of the room for improvement was filled by fourier transforms (percentage)
# * Difference between F1 score with advanced and fourier
#
# [top](#Contents)

# %%
df["improvement_in_advanced"] = \
    df["advanced-f1_score"] - df["baseline-f1_score"]
df["room_for_improvement"] = \
    1.0 - df["baseline-f1_score"]
df["fourier_minus_advanced"] = \
    df["fourier-f1_score"] - df["advanced-f1_score"]
df["percentage_of_room_filled"] = \
    df["improvement_in_fourier"] * 100.0 / df["room_for_improvement"]
#df.sort_values(by="fourier_minus_advanced", ascending=False)
df
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 48                        False                     False
# 57                        False                     False
# 39                        False                     False
# 66                        False                     False
# 59                        False                     False
# ..                          ...                       ...
# 14                        False                      True
# 13                        False                      True
# 31                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 48                  True                 False                     False
# 57                 False                  True                     False
# 39                  True                  True                     False
# 66                 False                 False                     False
# 59                 False                  True                     False
# ..                   ...                   ...                       ...
# 14                  True                 False                     False
# 13                  True                 False                     False
# 31                 False                 False                     False
# 22                 False                  True                     False
# 4                   True                  True                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 48                         True          True            False
# 57                         True          True            False
# 39                         True          True            False
# 66                         True          True            False
# 59                         True         False            False
# ..                          ...           ...              ...
# 14                         True         False            False
# 13                         True         False             True
# 31                         True         False             True
# 22                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 48           0.004519                 0.772605  ...              0.982287
# 57           0.004519                 0.772605  ...              0.982287
# 39           0.004519                 0.772605  ...              0.982287
# 66           0.004519                 0.772605  ...              0.982287
# 59           0.006091                 0.782051  ...              0.878928
# ..                ...                      ...  ...                   ...
# 14           0.998376                 0.998916  ...              1.000000
# 13           1.000000                 1.000000  ...              1.000000
# 31           1.000000                 1.000000  ...              1.000000
# 22           1.000000                 1.000000  ...              1.000000
# 4            1.000000                 1.000000  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 48        49228           196912                      0.25       0.922326
# 57        49228           196912                      0.25       0.922326
# 39        49228           196912                      0.25       0.922326
# 66        49228           196912                      0.25       0.922326
# 59        80853           323412                      0.25       0.760109
# ..          ...              ...                       ...            ...
# 14        80853           161706                      0.50       0.999858
# 13        31625            63250                      0.50       1.000000
# 31        31625            63250                      0.50       1.000000
# 22        31625            63250                      0.50       1.000000
# 4         31625            63250                      0.50       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 48                 0.895236                0.917807              0.995481
# 57                 0.895236                0.917807              0.995481
# 39                 0.895236                0.917807              0.995481
# 66                 0.895236                0.917807              0.995481
# 59                 0.704378                0.754018              0.993909
# ..                      ...                     ...                   ...
# 14                 0.001160                0.001482              0.001624
# 13                 0.000000                0.000000              0.000000
# 31                 0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 48                0.022570                  92.197292
# 57                0.022570                  92.197292
# 39                0.022570                  92.197292
# 66                0.022570                  92.197292
# 59                0.049639                  75.863886
# ..                     ...                        ...
# 14                0.000321                  91.241969
# 13                0.000000                        NaN
# 31                0.000000                        NaN
# 22                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [72 rows x 45 columns]

# %% [markdown]
# ### Measure improvement when only webp files are used <a class="anchor" id="webp-only">
#
# We want to measure this alone because in the literature, poor performance in webp files has been mentioned
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == False) & \
   (df["exclude_nonwebp"] == True)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 1                         False                      True
# 10                        False                      True
# 28                        False                      True
# 19                        False                      True
# 55                        False                     False
# 37                        False                     False
# 46                        False                     False
# 64                        False                     False
# 43                        False                     False
# 61                        False                     False
# 52                        False                     False
# 70                        False                     False
# 40                        False                     False
# 67                        False                     False
# 49                        False                     False
# 58                        False                     False
# 25                        False                      True
# 16                        False                      True
# 7                         False                      True
# 34                        False                      True
# 13                        False                      True
# 31                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 1                   True                  True                      True
# 10                  True                 False                      True
# 28                 False                 False                      True
# 19                 False                  True                      True
# 55                 False                  True                      True
# 37                  True                  True                      True
# 46                  True                 False                      True
# 64                 False                 False                      True
# 43                  True                  True                     False
# 61                 False                  True                     False
# 52                  True                 False                     False
# 70                 False                 False                     False
# 40                  True                  True                     False
# 67                 False                 False                     False
# 49                  True                 False                     False
# 58                 False                  True                     False
# 25                 False                  True                     False
# 16                  True                 False                     False
# 7                   True                  True                     False
# 34                 False                 False                     False
# 13                  True                 False                     False
# 31                 False                 False                     False
# 22                 False                  True                     False
# 4                   True                  True                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 1                         False         False             True
# 10                        False         False             True
# 28                        False         False             True
# 19                        False         False             True
# 55                        False         False             True
# 37                        False         False             True
# 46                        False         False             True
# 64                        False         False             True
# 43                        False         False             True
# 61                        False         False             True
# 52                        False         False             True
# 70                        False         False             True
# 40                         True         False             True
# 67                         True         False             True
# 49                         True         False             True
# 58                         True         False             True
# 25                        False         False             True
# 16                        False         False             True
# 7                         False         False             True
# 34                        False         False             True
# 13                         True         False             True
# 31                         True         False             True
# 22                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 1            0.159871                 0.676986  ...              0.524711
# 10           0.159871                 0.676986  ...              0.524711
# 28           0.159871                 0.676986  ...              0.524711
# 19           0.159871                 0.676986  ...              0.524711
# 55           0.147403                 0.806071  ...              0.434024
# 37           0.147403                 0.806071  ...              0.434024
# 46           0.147403                 0.806071  ...              0.434024
# 64           0.147403                 0.806071  ...              0.434024
# 43           0.067840                 0.668401  ...              0.259146
# 61           0.067840                 0.668401  ...              0.259146
# 52           0.067840                 0.668401  ...              0.259146
# 70           0.067840                 0.668401  ...              0.259146
# 40           0.028719                 0.800253  ...              0.116522
# 67           0.028719                 0.800253  ...              0.116522
# 49           0.028719                 0.800253  ...              0.116522
# 58           0.028719                 0.800253  ...              0.116522
# 25           0.693130                 0.757257  ...              0.721850
# 16           0.693130                 0.757257  ...              0.721850
# 7            0.693130                 0.757257  ...              0.721850
# 34           0.693130                 0.757257  ...              0.721850
# 13           1.000000                 1.000000  ...              1.000000
# 31           1.000000                 1.000000  ...              1.000000
# 22           1.000000                 1.000000  ...              1.000000
# 4            1.000000                 1.000000  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 1         31625            63250                      0.50       0.632427
# 10        31625            63250                      0.50       0.632427
# 28        31625            63250                      0.50       0.632427
# 19        31625            63250                      0.50       0.632427
# 55        31625           126500                      0.25       0.557553
# 37        31625           126500                      0.25       0.557553
# 46        31625           126500                      0.25       0.557553
# 64        31625           126500                      0.25       0.557553
# 43        63250           126500                      0.50       0.380412
# 61        63250           126500                      0.50       0.380412
# 52        63250           126500                      0.50       0.380412
# 70        63250           126500                      0.50       0.380412
# 40        31625           126500                      0.25       0.197208
# 67        31625           126500                      0.25       0.197208
# 49        31625           126500                      0.25       0.197208
# 58        31625           126500                      0.25       0.197208
# 25        63250            63250                      1.00       0.808417
# 16        63250            63250                      1.00       0.808417
# 7         63250            63250                      1.00       0.808417
# 34        63250            63250                      1.00       0.808417
# 13        31625            63250                      0.50       1.000000
# 31        31625            63250                      0.50       1.000000
# 22        31625            63250                      0.50       1.000000
# 4         31625            63250                      0.50       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 1                  0.446146                0.472556              0.840129
# 10                 0.446146                0.472556              0.840129
# 28                 0.446146                0.472556              0.840129
# 19                 0.446146                0.472556              0.840129
# 55                 0.397292                0.410151              0.852597
# 37                 0.397292                0.410151              0.852597
# 46                 0.397292                0.410151              0.852597
# 64                 0.397292                0.410151              0.852597
# 43                 0.293911                0.312572              0.932160
# 61                 0.293911                0.312572              0.932160
# 52                 0.293911                0.312572              0.932160
# 70                 0.293911                0.312572              0.932160
# 40                -0.025376                0.168488              0.971281
# 67                -0.025376                0.168488              0.971281
# 49                -0.025376                0.168488              0.971281
# 58                -0.025376                0.168488              0.971281
# 25                 0.113394                0.115287              0.306870
# 16                 0.113394                0.115287              0.306870
# 7                  0.113394                0.115287              0.306870
# 34                 0.113394                0.115287              0.306870
# 13                 0.000000                0.000000              0.000000
# 31                 0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 1                 0.026410                  56.248039
# 10                0.026410                  56.248039
# 28                0.026410                  56.248039
# 19                0.026410                  56.248039
# 55                0.012859                  48.106002
# 37                0.012859                  48.106002
# 46                0.012859                  48.106002
# 64                0.012859                  48.106002
# 43                0.018661                  33.531992
# 61                0.018661                  33.531992
# 52                0.018661                  33.531992
# 70                0.018661                  33.531992
# 40                0.193864                  17.347014
# 67                0.193864                  17.347014
# 49                0.193864                  17.347014
# 58                0.193864                  17.347014
# 25                0.001893                  37.568626
# 16                0.001893                  37.568626
# 7                 0.001893                  37.568626
# 34                0.001893                  37.568626
# 13                0.000000                        NaN
# 31                0.000000                        NaN
# 22                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [24 rows x 45 columns]

# %% [markdown]
# ### Measure improvement when webp files are not present <a class="anchor" id="no-webp">
#
# [top](#Contents)

# %%
df[(df["exclude_webp"] == True) & \
   (df["exclude_nonwebp"] == False)]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 48                        False                     False
# 57                        False                     False
# 39                        False                     False
# 66                        False                     False
# 51                        False                     False
# 60                        False                     False
# 69                        False                     False
# 42                        False                     False
# 9                         False                      True
# 18                        False                      True
# 0                         False                      True
# 27                        False                      True
# 63                        False                     False
# 45                        False                     False
# 36                        False                     False
# 54                        False                     False
# 15                        False                      True
# 24                        False                      True
# 6                         False                      True
# 33                        False                      True
# 21                        False                      True
# 3                         False                      True
# 12                        False                      True
# 30                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 48                  True                 False                     False
# 57                 False                  True                     False
# 39                  True                  True                     False
# 66                 False                 False                     False
# 51                  True                 False                     False
# 60                 False                  True                     False
# 69                 False                 False                     False
# 42                  True                  True                     False
# 9                   True                 False                      True
# 18                 False                  True                      True
# 0                   True                  True                      True
# 27                 False                 False                      True
# 63                 False                 False                      True
# 45                  True                 False                      True
# 36                  True                  True                      True
# 54                 False                  True                      True
# 15                  True                 False                     False
# 24                 False                  True                     False
# 6                   True                  True                     False
# 33                 False                 False                     False
# 21                 False                  True                     False
# 3                   True                  True                     False
# 12                  True                 False                     False
# 30                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 48                         True          True            False
# 57                         True          True            False
# 39                         True          True            False
# 66                         True          True            False
# 51                        False          True            False
# 60                        False          True            False
# 69                        False          True            False
# 42                        False          True            False
# 9                         False          True            False
# 18                        False          True            False
# 0                         False          True            False
# 27                        False          True            False
# 63                        False          True            False
# 45                        False          True            False
# 36                        False          True            False
# 54                        False          True            False
# 15                        False          True            False
# 24                        False          True            False
# 6                         False          True            False
# 33                        False          True            False
# 21                         True          True            False
# 3                          True          True            False
# 12                         True          True            False
# 30                         True          True            False
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 48           0.004519                 0.772605  ...              0.982287
# 57           0.004519                 0.772605  ...              0.982287
# 39           0.004519                 0.772605  ...              0.982287
# 66           0.004519                 0.772605  ...              0.982287
# 51           0.589049                 0.761833  ...              0.949663
# 60           0.589049                 0.761833  ...              0.949663
# 69           0.589049                 0.761833  ...              0.949663
# 42           0.589049                 0.761833  ...              0.949663
# 9            0.888290                 0.917012  ...              0.990737
# 18           0.888290                 0.917012  ...              0.990737
# 0            0.888290                 0.917012  ...              0.990737
# 27           0.888290                 0.917012  ...              0.990737
# 63           0.888222                 0.950171  ...              0.990392
# 45           0.888222                 0.950171  ...              0.990392
# 36           0.888222                 0.950171  ...              0.990392
# 54           0.888222                 0.950171  ...              0.990392
# 15           0.941553                 0.938089  ...              0.995714
# 24           0.941553                 0.938089  ...              0.995714
# 6            0.941553                 0.938089  ...              0.995714
# 33           0.941553                 0.938089  ...              0.995714
# 21           0.997518                 0.998341  ...              1.000000
# 3            0.997518                 0.998341  ...              1.000000
# 12           0.997518                 0.998341  ...              1.000000
# 30           0.997518                 0.998341  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 48        49228           196912                      0.25       0.922326
# 57        49228           196912                      0.25       0.922326
# 39        49228           196912                      0.25       0.922326
# 66        49228           196912                      0.25       0.922326
# 51        98456           196912                      0.50       0.925409
# 60        98456           196912                      0.50       0.925409
# 69        98456           196912                      0.50       0.925409
# 42        98456           196912                      0.50       0.925409
# 9         49228            98456                      0.50       0.980441
# 18        49228            98456                      0.50       0.980441
# 0         49228            98456                      0.50       0.980441
# 27        49228            98456                      0.50       0.980441
# 63        49228           196912                      0.25       0.980364
# 45        49228           196912                      0.25       0.980364
# 36        49228           196912                      0.25       0.980364
# 54        49228           196912                      0.25       0.980364
# 15        98456            98456                      1.00       0.990202
# 24        98456            98456                      1.00       0.990202
# 6         98456            98456                      1.00       0.990202
# 33        98456            98456                      1.00       0.990202
# 21        49228            98456                      0.50       0.999838
# 3         49228            98456                      0.50       0.999838
# 12        49228            98456                      0.50       0.999838
# 30        49228            98456                      0.50       0.999838
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 48                 0.895236                0.917807              0.995481
# 57                 0.895236                0.917807              0.995481
# 39                 0.895236                0.917807              0.995481
# 66                 0.895236                0.917807              0.995481
# 51                 0.336360                0.331756              0.410951
# 60                 0.336360                0.331756              0.410951
# 69                 0.336360                0.331756              0.410951
# 42                 0.336360                0.331756              0.410951
# 9                  0.063464                0.092151              0.111710
# 18                 0.063464                0.092151              0.111710
# 0                  0.063464                0.092151              0.111710
# 27                 0.063464                0.092151              0.111710
# 63                 0.063596                0.092142              0.111778
# 45                 0.063596                0.092142              0.111778
# 36                 0.063596                0.092142              0.111778
# 54                 0.063596                0.092142              0.111778
# 15                 0.033059                0.048649              0.058447
# 24                 0.033059                0.048649              0.058447
# 6                  0.033059                0.048649              0.058447
# 33                 0.033059                0.048649              0.058447
# 21                 0.001883                0.002238              0.002482
# 3                  0.001883                0.002238              0.002482
# 12                 0.001883                0.002238              0.002482
# 30                 0.001883                0.002238              0.002482
#
#     fourier_minus_advanced  percentage_of_room_filled
# 48                0.022570                  92.197292
# 57                0.022570                  92.197292
# 39                0.022570                  92.197292
# 66                0.022570                  92.197292
# 51               -0.004604                  80.728871
# 60               -0.004604                  80.728871
# 69               -0.004604                  80.728871
# 42               -0.004604                  80.728871
# 9                 0.028686                  82.491123
# 18                0.028686                  82.491123
# 0                 0.028686                  82.491123
# 27                0.028686                  82.491123
# 63                0.028546                  82.433198
# 45                0.028546                  82.433198
# 36                0.028546                  82.433198
# 54                0.028546                  82.433198
# 15                0.015590                  83.236802
# 24                0.015590                  83.236802
# 6                 0.015590                  83.236802
# 33                0.015590                  83.236802
# 21                0.000355                  90.181916
# 3                 0.000355                  90.181916
# 12                0.000355                  90.181916
# 30                0.000355                  90.181916
#
# [24 rows x 45 columns]

# %% [markdown]
# ### Measure improvement for balanced datasets <a class="anchor" id="balanced-dataset">
#
# Most of our dataset selections are not balanced, and we didn't do anything to mitigate
# unablanced datasets. This is because we are measuring the baseline and improvement on the
# same dataset.
#
# However, we will select those instances where the datasets were balanced to see if the
# improvement is still significant in these instances.
#
# [top](#Contents)

# %%
df[df["ratio_encrypt_nonencrypt"] == 1.0]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 25                        False                      True
# 16                        False                      True
# 7                         False                      True
# 34                        False                      True
# 15                        False                      True
# 24                        False                      True
# 6                         False                      True
# 33                        False                      True
# 8                         False                      True
# 35                        False                      True
# 17                        False                      True
# 26                        False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 25                 False                  True                     False
# 16                  True                 False                     False
# 7                   True                  True                     False
# 34                 False                 False                     False
# 15                  True                 False                     False
# 24                 False                  True                     False
# 6                   True                  True                     False
# 33                 False                 False                     False
# 8                   True                  True                     False
# 35                 False                 False                     False
# 17                  True                 False                     False
# 26                 False                  True                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 25                        False         False             True
# 16                        False         False             True
# 7                         False         False             True
# 34                        False         False             True
# 15                        False          True            False
# 24                        False          True            False
# 6                         False          True            False
# 33                        False          True            False
# 8                         False         False            False
# 35                        False         False            False
# 17                        False         False            False
# 26                        False         False            False
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 25           0.693130                 0.757257  ...              0.721850
# 16           0.693130                 0.757257  ...              0.721850
# 7            0.693130                 0.757257  ...              0.721850
# 34           0.693130                 0.757257  ...              0.721850
# 15           0.941553                 0.938089  ...              0.995714
# 24           0.941553                 0.938089  ...              0.995714
# 6            0.941553                 0.938089  ...              0.995714
# 33           0.941553                 0.938089  ...              0.995714
# 8            0.844329                 0.829706  ...              0.918488
# 35           0.844329                 0.829706  ...              0.918488
# 17           0.844329                 0.829706  ...              0.918488
# 26           0.844329                 0.829706  ...              0.918488
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 25        63250            63250                       1.0       0.808417
# 16        63250            63250                       1.0       0.808417
# 7         63250            63250                       1.0       0.808417
# 34        63250            63250                       1.0       0.808417
# 15        98456            98456                       1.0       0.990202
# 24        98456            98456                       1.0       0.990202
# 6         98456            98456                       1.0       0.990202
# 33        98456            98456                       1.0       0.990202
# 8        161706           161706                       1.0       0.872064
# 35       161706           161706                       1.0       0.872064
# 17       161706           161706                       1.0       0.872064
# 26       161706           161706                       1.0       0.872064
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 25                 0.113394                0.115287              0.306870
# 16                 0.113394                0.115287              0.306870
# 7                  0.113394                0.115287              0.306870
# 34                 0.113394                0.115287              0.306870
# 15                 0.033059                0.048649              0.058447
# 24                 0.033059                0.048649              0.058447
# 6                  0.033059                0.048649              0.058447
# 33                 0.033059                0.048649              0.058447
# 8                  0.014101                0.027735              0.155671
# 35                 0.014101                0.027735              0.155671
# 17                 0.014101                0.027735              0.155671
# 26                 0.014101                0.027735              0.155671
#
#     fourier_minus_advanced  percentage_of_room_filled
# 25                0.001893                  37.568626
# 16                0.001893                  37.568626
# 7                 0.001893                  37.568626
# 34                0.001893                  37.568626
# 15                0.015590                  83.236802
# 24                0.015590                  83.236802
# 6                 0.015590                  83.236802
# 33                0.015590                  83.236802
# 8                 0.013633                  17.816291
# 35                0.013633                  17.816291
# 17                0.013633                  17.816291
# 26                0.013633                  17.816291
#
# [12 rows x 45 columns]

# %% [markdown]
# ### Measure the improvement when all files are used <a class="anchor" id="full-dataset">
#
# In most of our dataset selections, we excluded some data points based on our criteria.
#
# In this, we measure the improvement when we use all data points
#
# [top](#Contents)

# %%
# Measure everything for the full dataset
df2 = df
for colname in df2.columns:
    if "exclude" in colname:
        df2 = df2[df2[colname] == False]
df2
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 71                        False                     False
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 71                 False                 False                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 71                        False         False            False
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 71           0.499595                 0.706436  ...              0.766706
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 71       161706           323412                       0.5       0.713696
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 71                 0.208228                0.214101              0.500405
#
#     fourier_minus_advanced  percentage_of_room_filled
# 71                0.005872                  42.785525
#
# [1 rows x 45 columns]

# %%
df2[[c for c in df2.columns if "baseline" in c or "fourier" in c or "advanced-only" in c]]
# Out:
#     baseline-f1_score  baseline-accuracy_score  baseline-precision_score  \
# 71           0.499595                 0.706436                  0.578499
#
#     baseline-recall_score  advanced-only-f1_score  \
# 71               0.439637                0.698571
#
#     advanced-only-accuracy_score  advanced-only-precision_score  \
# 71                      0.787932                       0.663779
#
#     advanced-only-recall_score  fourier-only-f1_score  \
# 71                    0.737221               0.520592
#
#     fourier-only-accuracy_score  ...  advanced-and-fourier-f1_score  \
# 71                     0.712029  ...                       0.705276
#
#     advanced-and-fourier-accuracy_score  advanced-and-fourier-precision_score  \
# 71                             0.789781                              0.662019
#
#     advanced-and-fourier-recall_score  fourier-f1_score  \
# 71                           0.754592          0.713696
#
#     fourier-accuracy_score  fourier-precision_score  fourier-recall_score  \
# 71                0.794957                 0.667549              0.766706
#
#     improvement_in_fourier  fourier_minus_advanced
# 71                0.214101                0.005872
#
# [1 rows x 26 columns]

# %%
df.to_csv("../LR_comparison_logistic_regression_final.csv")

# %% [markdown]
# ### Focus on items where the base metrics performed well <a class="anchor" id="focus-greater-90">
#
# We see that in all cases, plaintext non-base 32 only is selected. Also we
# see that for encrypted, only base32 is selected and non-base32 excluded.
#
# Fundamentally, what this is measuring is when the plaintext has all files
# but all encrypted content is base-32 encoded.
#
# Typically, base-32 encoding will lead to a reduction of entropy, in many cases
# much less than the original text, and this is what it is measuring.
#
# [top](#Contents)

# %%
df[df["baseline-f1_score"] > 0.9]
# Out:
#     exclude_plaintext_nonbase32  exclude_plaintext_base32  \
# 15                        False                      True
# 24                        False                      True
# 6                         False                      True
# 33                        False                      True
# 21                        False                      True
# 3                         False                      True
# 12                        False                      True
# 30                        False                      True
# 32                        False                      True
# 23                        False                      True
# 5                         False                      True
# 14                        False                      True
# 13                        False                      True
# 31                        False                      True
# 22                        False                      True
# 4                         False                      True
#
#     exclude_encrypted_v1  exclude_encrypted_v2  exclude_encrypted_base32  \
# 15                  True                 False                     False
# 24                 False                  True                     False
# 6                   True                  True                     False
# 33                 False                 False                     False
# 21                 False                  True                     False
# 3                   True                  True                     False
# 12                  True                 False                     False
# 30                 False                 False                     False
# 32                 False                 False                     False
# 23                 False                  True                     False
# 5                   True                  True                     False
# 14                  True                 False                     False
# 13                  True                 False                     False
# 31                 False                 False                     False
# 22                 False                  True                     False
# 4                   True                  True                     False
#
#     exclude_encrypted_nonbase32  exclude_webp  exclude_nonwebp  \
# 15                        False          True            False
# 24                        False          True            False
# 6                         False          True            False
# 33                        False          True            False
# 21                         True          True            False
# 3                          True          True            False
# 12                         True          True            False
# 30                         True          True            False
# 32                         True         False            False
# 23                         True         False            False
# 5                          True         False            False
# 14                         True         False            False
# 13                         True         False             True
# 31                         True         False             True
# 22                         True         False             True
# 4                          True         False             True
#
#     baseline-f1_score  baseline-accuracy_score  ...  fourier-recall_score  \
# 15           0.941553                 0.938089  ...              0.995714
# 24           0.941553                 0.938089  ...              0.995714
# 6            0.941553                 0.938089  ...              0.995714
# 33           0.941553                 0.938089  ...              0.995714
# 21           0.997518                 0.998341  ...              1.000000
# 3            0.997518                 0.998341  ...              1.000000
# 12           0.997518                 0.998341  ...              1.000000
# 30           0.997518                 0.998341  ...              1.000000
# 32           0.998376                 0.998916  ...              1.000000
# 23           0.998376                 0.998916  ...              1.000000
# 5            0.998376                 0.998916  ...              1.000000
# 14           0.998376                 0.998916  ...              1.000000
# 13           1.000000                 1.000000  ...              1.000000
# 31           1.000000                 1.000000  ...              1.000000
# 22           1.000000                 1.000000  ...              1.000000
# 4            1.000000                 1.000000  ...              1.000000
#
#     n_encrypted  n_non_encrypted  ratio_encrypt_nonencrypt  best_f1_score  \
# 15        98456            98456                       1.0       0.990202
# 24        98456            98456                       1.0       0.990202
# 6         98456            98456                       1.0       0.990202
# 33        98456            98456                       1.0       0.990202
# 21        49228            98456                       0.5       0.999838
# 3         49228            98456                       0.5       0.999838
# 12        49228            98456                       0.5       0.999838
# 30        49228            98456                       0.5       0.999838
# 32        80853           161706                       0.5       0.999858
# 23        80853           161706                       0.5       0.999858
# 5         80853           161706                       0.5       0.999858
# 14        80853           161706                       0.5       0.999858
# 13        31625            63250                       0.5       1.000000
# 31        31625            63250                       0.5       1.000000
# 22        31625            63250                       0.5       1.000000
# 4         31625            63250                       0.5       1.000000
#
#     improvement_in_advanced  improvement_in_fourier  room_for_improvement  \
# 15                 0.033059                0.048649              0.058447
# 24                 0.033059                0.048649              0.058447
# 6                  0.033059                0.048649              0.058447
# 33                 0.033059                0.048649              0.058447
# 21                 0.001883                0.002238              0.002482
# 3                  0.001883                0.002238              0.002482
# 12                 0.001883                0.002238              0.002482
# 30                 0.001883                0.002238              0.002482
# 32                 0.001160                0.001482              0.001624
# 23                 0.001160                0.001482              0.001624
# 5                  0.001160                0.001482              0.001624
# 14                 0.001160                0.001482              0.001624
# 13                 0.000000                0.000000              0.000000
# 31                 0.000000                0.000000              0.000000
# 22                 0.000000                0.000000              0.000000
# 4                  0.000000                0.000000              0.000000
#
#     fourier_minus_advanced  percentage_of_room_filled
# 15                0.015590                  83.236802
# 24                0.015590                  83.236802
# 6                 0.015590                  83.236802
# 33                0.015590                  83.236802
# 21                0.000355                  90.181916
# 3                 0.000355                  90.181916
# 12                0.000355                  90.181916
# 30                0.000355                  90.181916
# 32                0.000321                  91.241969
# 23                0.000321                  91.241969
# 5                 0.000321                  91.241969
# 14                0.000321                  91.241969
# 13                0.000000                        NaN
# 31                0.000000                        NaN
# 22                0.000000                        NaN
# 4                 0.000000                        NaN
#
# [16 rows x 45 columns]

# %% [markdown]
# ### Correlation of data set and performance <a class="anchor" id="corr-heatmap">
#
# This gives more idea on how data-set selection affects performance.
#
# [top](#Contents)

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,10)
df2 = df[[c for c in df.columns if \
          "precision" not in c and \
          "accuracy" not in c and \
          "recall" not in c]]
sns.heatmap(df2.astype(float).corr(), cmap='coolwarm')
# print(df[df["baseline-f1_score"] > 0.9].astype(float))
_ = plt.xticks(rotation=80)

# %%
df1 = df[["exclude_encrypted_base32", \
          "exclude_encrypted_v2", \
          "exclude_webp", \
          "baseline-f1_score", \
          "advanced-f1_score", \
          "fourier-f1_score"]]
sns.heatmap(df1.astype(float).corr(), cmap='coolwarm')
_ = plt.xticks(rotation=80)

# %% [markdown]
# ### Average out all the metrics <a class="anchor" id="mean-fscores">
#
# To conclude we report the average of the f1-scores and the improvements with all datasets
#
# [top](#Contents)

# %%
df[[c for c in df.columns if ("score" in c or "improvement" in c) and "room" not in c]].mean()
# Out:
# baseline-f1_score                       0.565491
# baseline-accuracy_score                 0.833384
# baseline-precision_score                0.669154
# baseline-recall_score                   0.573262
# advanced-only-f1_score                  0.747656
# advanced-only-accuracy_score            0.883549
# advanced-only-precision_score           0.785304
# advanced-only-recall_score              0.744651
# fourier-only-f1_score                   0.588228
# fourier-only-accuracy_score             0.843263
# fourier-only-precision_score            0.620431
# fourier-only-recall_score               0.589351
# baseline-and-fourier-f1_score           0.666723
# baseline-and-fourier-accuracy_score     0.857964
# baseline-and-fourier-precision_score    0.766824
# baseline-and-fourier-recall_score       0.665729
# advanced-and-fourier-f1_score           0.777817
# advanced-and-fourier-accuracy_score     0.893699
# advanced-and-fourier-precision_score    0.836229
# advanced-and-fourier-recall_score       0.773731
# advanced-f1_score                       0.764719
# advanced-accuracy_score                 0.889773
# advanced-precision_score                0.830693
# advanced-recall_score                   0.764500
# fourier-f1_score                        0.790602
# fourier-accuracy_score                  0.897840
# fourier-precision_score                 0.838211
# fourier-recall_score                    0.789240
# best_f1_score                           0.790862
# improvement_in_advanced                 0.199228
# improvement_in_fourier                  0.225111
# dtype: float64

# %%
df[[c for c in df.columns if \
    ("-and-" in c or \
     "only" in c or \
     "score" in c or \
     "improvement" in c) and "room" not in c]].describe().T
# Out:
#                                       count      mean       std       min  \
# baseline-f1_score                      72.0  0.565491  0.379570  0.004519
# baseline-accuracy_score                72.0  0.833384  0.107579  0.668401
# baseline-precision_score               72.0  0.669154  0.279160  0.018209
# baseline-recall_score                  72.0  0.573262  0.416899  0.002580
# advanced-only-f1_score                 72.0  0.747656  0.267655  0.000000
# advanced-only-accuracy_score           72.0  0.883549  0.093117  0.701639
# advanced-only-precision_score          72.0  0.785304  0.230291  0.000000
# advanced-only-recall_score             72.0  0.744651  0.299445  0.000000
# fourier-only-f1_score                  72.0  0.588228  0.389288  0.000000
# fourier-only-accuracy_score            72.0  0.843263  0.114170  0.666055
# fourier-only-precision_score           72.0  0.620431  0.373126  0.000000
# fourier-only-recall_score              72.0  0.589351  0.399653  0.000000
# baseline-and-fourier-f1_score          72.0  0.666723  0.320593  0.029549
# baseline-and-fourier-accuracy_score    72.0  0.857964  0.107168  0.674456
# baseline-and-fourier-precision_score   72.0  0.766824  0.172079  0.517712
# baseline-and-fourier-recall_score      72.0  0.665729  0.358140  0.015209
# advanced-and-fourier-f1_score          72.0  0.777817  0.237264  0.167379
# advanced-and-fourier-accuracy_score    72.0  0.893699  0.091198  0.711831
# advanced-and-fourier-precision_score   72.0  0.836229  0.133909  0.630723
# advanced-and-fourier-recall_score      72.0  0.773731  0.282244  0.096506
# advanced-f1_score                      72.0  0.764719  0.255444  0.003344
# advanced-accuracy_score                72.0  0.889773  0.088339  0.717154
# advanced-precision_score               72.0  0.830693  0.126226  0.646524
# advanced-recall_score                  72.0  0.764500  0.284597  0.001676
# fourier-f1_score                       72.0  0.790602  0.224331  0.197208
# fourier-accuracy_score                 72.0  0.897840  0.087946  0.718619
# fourier-precision_score                72.0  0.838211  0.131140  0.641751
# fourier-recall_score                   72.0  0.789240  0.268991  0.116522
# best_f1_score                          72.0  0.790862  0.224488  0.197208
# improvement_in_advanced                72.0  0.199228  0.260720 -0.025376
# improvement_in_fourier                 72.0  0.225111  0.261074  0.000000
#
#                                            25%       50%       75%       max
# baseline-f1_score                     0.147403  0.702618  0.888290  1.000000
# baseline-accuracy_score               0.761833  0.803162  0.938089  1.000000
# baseline-precision_score              0.578499  0.655049  0.891689  1.000000
# baseline-recall_score                 0.083826  0.695418  0.989864  1.000000
# advanced-only-f1_score                0.698571  0.814133  0.947099  1.000000
# advanced-only-accuracy_score          0.800000  0.872837  0.971180  1.000000
# advanced-only-precision_score         0.663779  0.831845  0.932576  1.000000
# advanced-only-recall_score            0.676016  0.836605  0.962257  1.000000
# fourier-only-f1_score                 0.056574  0.651472  0.954970  1.000000
# fourier-only-accuracy_score           0.749779  0.820684  0.968986  1.000000
# fourier-only-precision_score          0.485711  0.665576  0.955591  1.000000
# fourier-only-recall_score             0.030040  0.670108  0.983688  1.000000
# baseline-and-fourier-f1_score         0.377072  0.705462  0.964416  1.000000
# baseline-and-fourier-accuracy_score   0.779736  0.846502  0.979895  1.000000
# baseline-and-fourier-precision_score  0.620682  0.694887  0.938510  1.000000
# baseline-and-fourier-recall_score     0.275772  0.792750  0.991793  1.000000
# advanced-and-fourier-f1_score         0.705276  0.826980  0.979752  1.000000
# advanced-and-fourier-accuracy_score   0.811563  0.886556  0.989579  1.000000
# advanced-and-fourier-precision_score  0.681796  0.846998  0.969567  1.000000
# advanced-and-fourier-recall_score     0.690893  0.886034  0.990270  1.000000
# advanced-f1_score                     0.707824  0.832477  0.951818  1.000000
# advanced-accuracy_score               0.803916  0.876900  0.974410  1.000000
# advanced-precision_score              0.703127  0.835127  0.937025  1.000000
# advanced-recall_score                 0.720743  0.852167  0.967518  1.000000
# fourier-f1_score                      0.713696  0.840240  0.980441  1.000000
# fourier-accuracy_score                0.821087  0.890870  0.990148  1.000000
# fourier-precision_score               0.690933  0.849689  0.970539  1.000000
# fourier-recall_score                  0.721850  0.898708  0.990737  1.000000
# best_f1_score                         0.713696  0.840240  0.980441  1.000000
# improvement_in_advanced               0.014101  0.063530  0.336360  0.895236
# improvement_in_fourier                0.045330  0.103719  0.331756  0.917807

# %%
df1 = df[[c for c in df.columns if \
          ("score" in c or "improvement" in c) \
          and "room" not in c]]
columns = ["baseline-f1_score"]
columns += [c for c in df1.columns if "only" in c]
columns += [c for c in df1.columns if "-and-" in c]
columns += [c for c in df1.columns if "only" not in c \
            and "-and-" not in c and "baseline-f1_score" != c]
df1[columns].describe().T
# Out:
#                                       count      mean       std       min  \
# baseline-f1_score                      72.0  0.565491  0.379570  0.004519
# advanced-only-f1_score                 72.0  0.747656  0.267655  0.000000
# advanced-only-accuracy_score           72.0  0.883549  0.093117  0.701639
# advanced-only-precision_score          72.0  0.785304  0.230291  0.000000
# advanced-only-recall_score             72.0  0.744651  0.299445  0.000000
# fourier-only-f1_score                  72.0  0.588228  0.389288  0.000000
# fourier-only-accuracy_score            72.0  0.843263  0.114170  0.666055
# fourier-only-precision_score           72.0  0.620431  0.373126  0.000000
# fourier-only-recall_score              72.0  0.589351  0.399653  0.000000
# baseline-and-fourier-f1_score          72.0  0.666723  0.320593  0.029549
# baseline-and-fourier-accuracy_score    72.0  0.857964  0.107168  0.674456
# baseline-and-fourier-precision_score   72.0  0.766824  0.172079  0.517712
# baseline-and-fourier-recall_score      72.0  0.665729  0.358140  0.015209
# advanced-and-fourier-f1_score          72.0  0.777817  0.237264  0.167379
# advanced-and-fourier-accuracy_score    72.0  0.893699  0.091198  0.711831
# advanced-and-fourier-precision_score   72.0  0.836229  0.133909  0.630723
# advanced-and-fourier-recall_score      72.0  0.773731  0.282244  0.096506
# baseline-accuracy_score                72.0  0.833384  0.107579  0.668401
# baseline-precision_score               72.0  0.669154  0.279160  0.018209
# baseline-recall_score                  72.0  0.573262  0.416899  0.002580
# advanced-f1_score                      72.0  0.764719  0.255444  0.003344
# advanced-accuracy_score                72.0  0.889773  0.088339  0.717154
# advanced-precision_score               72.0  0.830693  0.126226  0.646524
# advanced-recall_score                  72.0  0.764500  0.284597  0.001676
# fourier-f1_score                       72.0  0.790602  0.224331  0.197208
# fourier-accuracy_score                 72.0  0.897840  0.087946  0.718619
# fourier-precision_score                72.0  0.838211  0.131140  0.641751
# fourier-recall_score                   72.0  0.789240  0.268991  0.116522
# best_f1_score                          72.0  0.790862  0.224488  0.197208
# improvement_in_advanced                72.0  0.199228  0.260720 -0.025376
# improvement_in_fourier                 72.0  0.225111  0.261074  0.000000
#
#                                            25%       50%       75%       max
# baseline-f1_score                     0.147403  0.702618  0.888290  1.000000
# advanced-only-f1_score                0.698571  0.814133  0.947099  1.000000
# advanced-only-accuracy_score          0.800000  0.872837  0.971180  1.000000
# advanced-only-precision_score         0.663779  0.831845  0.932576  1.000000
# advanced-only-recall_score            0.676016  0.836605  0.962257  1.000000
# fourier-only-f1_score                 0.056574  0.651472  0.954970  1.000000
# fourier-only-accuracy_score           0.749779  0.820684  0.968986  1.000000
# fourier-only-precision_score          0.485711  0.665576  0.955591  1.000000
# fourier-only-recall_score             0.030040  0.670108  0.983688  1.000000
# baseline-and-fourier-f1_score         0.377072  0.705462  0.964416  1.000000
# baseline-and-fourier-accuracy_score   0.779736  0.846502  0.979895  1.000000
# baseline-and-fourier-precision_score  0.620682  0.694887  0.938510  1.000000
# baseline-and-fourier-recall_score     0.275772  0.792750  0.991793  1.000000
# advanced-and-fourier-f1_score         0.705276  0.826980  0.979752  1.000000
# advanced-and-fourier-accuracy_score   0.811563  0.886556  0.989579  1.000000
# advanced-and-fourier-precision_score  0.681796  0.846998  0.969567  1.000000
# advanced-and-fourier-recall_score     0.690893  0.886034  0.990270  1.000000
# baseline-accuracy_score               0.761833  0.803162  0.938089  1.000000
# baseline-precision_score              0.578499  0.655049  0.891689  1.000000
# baseline-recall_score                 0.083826  0.695418  0.989864  1.000000
# advanced-f1_score                     0.707824  0.832477  0.951818  1.000000
# advanced-accuracy_score               0.803916  0.876900  0.974410  1.000000
# advanced-precision_score              0.703127  0.835127  0.937025  1.000000
# advanced-recall_score                 0.720743  0.852167  0.967518  1.000000
# fourier-f1_score                      0.713696  0.840240  0.980441  1.000000
# fourier-accuracy_score                0.821087  0.890870  0.990148  1.000000
# fourier-precision_score               0.690933  0.849689  0.970539  1.000000
# fourier-recall_score                  0.721850  0.898708  0.990737  1.000000
# best_f1_score                         0.713696  0.840240  0.980441  1.000000
# improvement_in_advanced               0.014101  0.063530  0.336360  0.895236
# improvement_in_fourier                0.045330  0.103719  0.331756  0.917807

# %%
print(regroup_and_pivot(df).to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.883549 &  0.747656 &   0.785304 &  0.744651 \\
# Advanced and Fourier           &  0.893699 &  0.777817 &   0.836229 &  0.773731 \\
# Baseline                       &  0.833384 &  0.565491 &   0.669154 &  0.573262 \\
# Baseline and Advanced          &  0.889773 &  0.764719 &   0.830693 &  0.764500 \\
# Baseline and Fourier           &  0.857964 &  0.666723 &   0.766824 &  0.665729 \\
# Baseline, Advanced and Fourier &  0.897840 &  0.790602 &   0.838211 &  0.789240 \\
# Fourier Only                   &  0.843263 &  0.588228 &   0.620431 &  0.589351 \\
# \bottomrule
# \end{tabular}

# %%
regroup_and_pivot(df)
# Out:
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Advanced Only                   0.883549  0.747656   0.785304  0.744651
# Advanced and Fourier            0.893699  0.777817   0.836229  0.773731
# Baseline                        0.833384  0.565491   0.669154  0.573262
# Baseline and Advanced           0.889773  0.764719   0.830693  0.764500
# Baseline and Fourier            0.857964  0.666723   0.766824  0.665729
# Baseline, Advanced and Fourier  0.897840  0.790602   0.838211  0.789240
# Fourier Only                    0.843263  0.588228   0.620431  0.589351

# %%
regroup_and_pivot(df)[['F1', 'Precision', 'Recall']]
# Out:
# MeasureName                           F1  Precision    Recall
# Feature
# Advanced Only                   0.747656   0.785304  0.744651
# Advanced and Fourier            0.777817   0.836229  0.773731
# Baseline                        0.565491   0.669154  0.573262
# Baseline and Advanced           0.764719   0.830693  0.764500
# Baseline and Fourier            0.666723   0.766824  0.665729
# Baseline, Advanced and Fourier  0.790602   0.838211  0.789240
# Fourier Only                    0.588228   0.620431  0.589351

# %%
print(regroup_and_pivot(df)[['F1', 'Precision', 'Recall']].to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# MeasureName &        F1 &  Precision &    Recall \\
# Feature                        &           &            &           \\
# \midrule
# Advanced Only                  &  0.747656 &   0.785304 &  0.744651 \\
# Advanced and Fourier           &  0.777817 &   0.836229 &  0.773731 \\
# Baseline                       &  0.565491 &   0.669154 &  0.573262 \\
# Baseline and Advanced          &  0.764719 &   0.830693 &  0.764500 \\
# Baseline and Fourier           &  0.666723 &   0.766824 &  0.665729 \\
# Baseline, Advanced and Fourier &  0.790602 &   0.838211 &  0.789240 \\
# Fourier Only                   &  0.588228 &   0.620431 &  0.589351 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Reporting for the final report <a class="anchor" id="report">
#
# [top](#Contents)

# %%
def regroup(df):
    def get_name(name):
        if "score" not in name.lower():
            return None, None
        feature = name
        measure = None

        measure_map = {
            "f1_score": "F1",
            "accuracy_score": "Accuracy",
            "precision_score": "Precision",
            "recall_score": "Recall"
        }
        featurename_map = {
            "fourier-only-": "Fourier Only",
            "advanced-only-": "Advanced Only",
            "baseline-and-fourier": "Baseline and Fourier",
            "advanced-and-fourier": "Advanced and Fourier",
            "baseline-and-advanced": "Baseline and Advanced",
            "fourier-": "Baseline, Advanced and Fourier",
            "baseline-": "Baseline",
            "advanced-": "Baseline and Advanced",
        }
        for i, j in measure_map.items():
            if i in name:
                measure = j
                break
        for i, j in featurename_map.items():
            if i in name:
                feature = j
                break
        return name, feature, measure

    pd.DataFrame({"Score": df.mean()})
    indices = list(df.mean().index)
    values = df.mean().to_numpy()
    df_acc = pd.DataFrame({"Original":["dummy"], "Feature": ["dummy"], "MeasureName": ["dummy"], "MeasureValue": [0.0]})


    for name, value in zip(indices, values):
        if "score" in name.lower():
            orname, featurename, measurename = get_name(name)
            if featurename is not None:
                tempdf = pd.DataFrame({"Original": [orname], "Feature": [featurename], "MeasureName": [measurename], "MeasureValue": [value]})
                df_acc = pd.concat([df_acc, tempdf]).copy()
    df_acc = df_acc[df_acc["Feature"] != "dummy"]  
    df_acc = df_acc[df_acc["Original"] != "best_f1_score"]
    return df_acc

# %%
# Full score

def regroup_and_pivot(df):
    acc_df = regroup(df)
    acc_df = acc_df[["Feature", "MeasureName", "MeasureValue"]]
    return acc_df.pivot(index="Feature", columns="MeasureName", values="MeasureValue")

# %%
newdf = regroup_and_pivot(df)

# %%
print(newdf.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.883549 &  0.747656 &   0.785304 &  0.744651 \\
# Advanced and Fourier           &  0.893699 &  0.777817 &   0.836229 &  0.773731 \\
# Baseline                       &  0.833384 &  0.565491 &   0.669154 &  0.573262 \\
# Baseline and Advanced          &  0.889773 &  0.764719 &   0.830693 &  0.764500 \\
# Baseline and Fourier           &  0.857964 &  0.666723 &   0.766824 &  0.665729 \\
# Baseline, Advanced and Fourier &  0.897840 &  0.790602 &   0.838211 &  0.789240 \\
# Fourier Only                   &  0.843263 &  0.588228 &   0.620431 &  0.589351 \\
# \bottomrule
# \end{tabular}

# %%
 df2 = df[(df["exclude_webp"] == 0) & (df["exclude_nonwebp"] == 1) ]

# %%
df2 = regroup_and_pivot(df2)
print(df2.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.820014 &  0.514959 &   0.687472 &  0.438256 \\
# Advanced and Fourier           &  0.829505 &  0.567358 &   0.808919 &  0.477138 \\
# Baseline                       &  0.784828 &  0.349494 &   0.702409 &  0.295889 \\
# Baseline and Advanced          &  0.831111 &  0.553722 &   0.814769 &  0.480751 \\
# Baseline and Fourier           &  0.789849 &  0.389645 &   0.718973 &  0.325576 \\
# Baseline, Advanced and Fourier &  0.836140 &  0.596003 &   0.808499 &  0.509375 \\
# Fourier Only                   &  0.780417 &  0.287514 &   0.412620 &  0.255781 \\
# \bottomrule
# \end{tabular}

# %%
df2 = df[(df["exclude_webp"] == 1) & (df["exclude_nonwebp"] == 0) ]
df2 = regroup_and_pivot(df2)
print(df2.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.969691 &  0.948030 &   0.928952 &  0.968563 \\
# Advanced and Fourier           &  0.979817 &  0.964972 &   0.947339 &  0.984089 \\
# Baseline                       &  0.889675 &  0.718192 &   0.701567 &  0.748609 \\
# Baseline and Advanced          &  0.971299 &  0.950458 &   0.931090 &  0.971327 \\
# Baseline and Fourier           &  0.943996 &  0.903223 &   0.866998 &  0.946665 \\
# Baseline, Advanced and Fourier &  0.980222 &  0.965649 &   0.948014 &  0.984799 \\
# Fourier Only                   &  0.934651 &  0.883864 &   0.854524 &  0.916909 \\
# \bottomrule
# \end{tabular}

# %%
df2 = df[(df["exclude_webp"] == 0) & (df["exclude_nonwebp"] == 1) ]
df2 = df.copy()
df2 = df2[[c for c in df2.columns if "score" in c]]
df2 = df2.describe().T
df2 = df2["std"]

def get_name(name):
    if "score" not in name.lower():
        return None, None
    feature = name
    measure = None

    measure_map = {
        "f1_score": "F1",
        "accuracy_score": "Accuracy",
        "precision_score": "Precision",
        "recall_score": "Recall"
    }
    featurename_map = {
        "fourier-only-": "Fourier Only",
        "advanced-only-": "Advanced Only",
        "baseline-and-fourier": "Baseline and Fourier",
        "advanced-and-fourier": "Advanced and Fourier",
        "baseline-and-advanced": "Baseline and Advanced",
        "fourier-": "Baseline, Advanced and Fourier",
        "baseline-": "Baseline",
        "advanced-": "Baseline and Advanced",
    }
    for i, j in measure_map.items():
        if i in name:
            measure = j
            break
    for i, j in featurename_map.items():
        if i in name:
            feature = j
            break
    return name, feature, measure


indices = list(df2.index)
values = df2.to_numpy()
df_acc = pd.DataFrame({"Original":["dummy"], "Feature": ["dummy"], "MeasureName": ["dummy"], "MeasureValue": [0.0]})


for name, value in zip(indices, values):
    if "score" in name.lower():
        orname, featurename, measurename = get_name(name)
        if featurename is not None:
            tempdf = pd.DataFrame({"Original": [orname], "Feature": [featurename], "MeasureName": [measurename], "MeasureValue": [value]})
            df_acc = pd.concat([df_acc, tempdf]).copy()
df_acc = df_acc[df_acc["Feature"] != "dummy"]  
df_acc = df_acc[df_acc["Original"] != "best_f1_score"]
df_acc = df_acc[[c for c in df_acc.columns if "Original" != c]]

df_acc = df_acc.pivot(index="Feature", columns="MeasureName", values="MeasureValue")
print(df_acc.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# MeasureName &  Accuracy &        F1 &  Precision &    Recall \\
# Feature                        &           &           &            &           \\
# \midrule
# Advanced Only                  &  0.093117 &  0.267655 &   0.230291 &  0.299445 \\
# Advanced and Fourier           &  0.091198 &  0.237264 &   0.133909 &  0.282244 \\
# Baseline                       &  0.107579 &  0.379570 &   0.279160 &  0.416899 \\
# Baseline and Advanced          &  0.088339 &  0.255444 &   0.126226 &  0.284597 \\
# Baseline and Fourier           &  0.107168 &  0.320593 &   0.172079 &  0.358140 \\
# Baseline, Advanced and Fourier &  0.087946 &  0.224331 &   0.131140 &  0.268991 \\
# Fourier Only                   &  0.114170 &  0.389288 &   0.373126 &  0.399653 \\
# \bottomrule
# \end{tabular}

# %%
df_acc
# Out:
# MeasureName                     Accuracy        F1  Precision    Recall
# Feature
# Advanced Only                   0.093117  0.267655   0.230291  0.299445
# Advanced and Fourier            0.091198  0.237264   0.133909  0.282244
# Baseline                        0.107579  0.379570   0.279160  0.416899
# Baseline and Advanced           0.088339  0.255444   0.126226  0.284597
# Baseline and Fourier            0.107168  0.320593   0.172079  0.358140
# Baseline, Advanced and Fourier  0.087946  0.224331   0.131140  0.268991
# Fourier Only                    0.114170  0.389288   0.373126  0.399653

# %%
df.to_csv("../LR_DES3_CS5_FINAL.csv")
