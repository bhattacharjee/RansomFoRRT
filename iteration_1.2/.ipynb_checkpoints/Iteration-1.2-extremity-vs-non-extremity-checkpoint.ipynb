# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

import sklearn
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, recall_score, precision_score
from sklearn.metrics import f1_score

# %% [markdown]
# # REFER THIS FOR GRAPHS FOR ITERATION 1

# %%
ENCRYPTED_DIRECTORY = "data/govdocs_encrypted"
PLAINTEXT_DIRECTORY = "data/govdocs_plaintext"

# %%
def load_data(directory):
    dataframes = list()
    for f in glob.glob(f"{directory}/**.csv.gz"):
        df = pd.read_csv(f)
        dataframes.append(df)
    return pd.concat(dataframes)

df_plaintext = load_data(PLAINTEXT_DIRECTORY)
df_plaintext["is_encrypted"] = 0
df_encrypted = load_data(ENCRYPTED_DIRECTORY)
df_encrypted["is_encrypted"] = 1

master_df = pd.concat([df_plaintext, df_encrypted])

# Filter out only webp
# master_df = master_df[master_df['extended.extension'] != '.webp']
print("only webp: ", master_df.shape)

# Filter out files which are larger than 4k
#master_df = master_df[master_df['baseline.filesize'] > 4096]
print("greater than 4096: ", master_df.shape)

# Shuffle
master_df = master_df.sample(frac=1).reset_index(drop=True)

# fill Nan with 0
master_df['baseline.chisquare_end'] = master_df['baseline.chisquare_end'].fillna(0.0)
master_df.dropna(inplace=True)
master_df = master_df.copy()

baseline_columns = [c for c in master_df.columns if "baseline" in c.lower() and "filesize" not in c.lower()]
advanced_columns = [c for c in master_df.columns if "kurtosis" in c.lower() or "skew" in c.lower()]
# Out:
# /var/folders/z1/hfz3q2b52bx3hb8nh0z1q89c0000gp/T/ipykernel_28513/3076509417.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_plaintext["is_encrypted"] = 0
# /var/folders/z1/hfz3q2b52bx3hb8nh0z1q89c0000gp/T/ipykernel_28513/3076509417.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_encrypted["is_encrypted"] = 1
# only webp:  (160507, 528)
# greater than 4096:  (160507, 528)

# %%
#columns_to_consider = [c for c in master_df.columns]
#columns_to_consider = [c for c in master_df.columns if c.startswith("baseline")]
#columns_to_consider.append('is_encrypted')
columns_to_consider = [c for c in master_df.columns if c != 'extended.extension']


interesting_df = master_df[columns_to_consider]

X = interesting_df[[c for c in interesting_df.columns if c.startswith('baseline')]]
X = interesting_df[[c for c in interesting_df.columns if c != 'is_encrypted']]
X = X[[c for c in X.columns if c != 'is_encrypted']]
X = X[baseline_columns + advanced_columns]

# get rid of tail and head metrics
X = X[[c for c in X.columns if "begin" not in c and "head" not in c]]
X = X[[c for c in X.columns if "tail" not in c and "end" not in c]]

X = X[[c for c in X.columns if "kurtosis" not in c and "skew" not in c]]

y = interesting_df['is_encrypted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# ---------------------------------------------------------------

rfc = RandomForestClassifier(n_jobs=-1)
estimators = [('std,', MinMaxScaler()), ('LogisticRegressor', LogisticRegression(n_jobs=10, max_iter=1000))]
pipeline = Pipeline(estimators)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print(f"Precision : {precision}")
print(f"Recall    : {recall}")
print(f"Accuracy  : {accuracy}")
print(f"F1-score  : {f1}")

df_json = {
    "Extremities_Measured_Separately": [],
    "Algorithm": [],
    "Accuracy": [],
    "Precision": [],
    "Recall": [],
    "F1": []
}

df_json["Extremities_Measured_Separately"].append("NO")
df_json["Algorithm"].append("Logistic Regression")
df_json["Accuracy"].append(accuracy)
df_json["Precision"].append(precision)
df_json["Recall"].append(recall)
df_json["F1"].append(f1)
# Out:
# Precision : 0.6121311774915502
# Recall    : 0.9033432191965489
# Accuracy  : 0.668293008956022
# F1-score  : 0.72975769126055

# %% [markdown]
# ## Now try the same thing with extremity measurements separately

# %%
columns_to_consider = [c for c in master_df.columns if c != 'extended.extension']

interesting_df = master_df[columns_to_consider]

X = interesting_df[[c for c in interesting_df.columns if c.startswith('baseline')]]
X = interesting_df[[c for c in interesting_df.columns if c != 'is_encrypted']]
X = X[baseline_columns + advanced_columns]

X = X[[c for c in X.columns if c != 'is_encrypted']]

# get rid of tail and head metrics
# X = X[[c for c in X.columns if "begin" not in c and "head" not in c]]
# X = X[[c for c in X.columns if "tail" not in c and "end" not in c]]

X = X[[c for c in X.columns if "kurtosis" not in c and "skew" not in c]]

y = interesting_df['is_encrypted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

rfc = RandomForestClassifier(n_jobs=-1)
estimators = [('std,', MinMaxScaler()), ('LogisticRegressor', LogisticRegression(n_jobs=10,  max_iter=1000))]
pipeline = Pipeline(estimators)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print(f"Precision : {precision}")
print(f"Recall    : {recall}")
print(f"Accuracy  : {accuracy}")
print(f"F1-score  : {f1}")


df_json["Extremities_Measured_Separately"].append("YES")
df_json["Algorithm"].append("Logistic Regression")
df_json["Accuracy"].append(accuracy)
df_json["Precision"].append(precision)
df_json["Recall"].append(recall)
df_json["F1"].append(f1)
# Out:
# Precision : 0.7263593380614657
# Recall    : 0.8283904017255325
# Accuracy  : 0.7601924876353429
# F1-score  : 0.7740269555359617

# %%
#columns_to_consider = [c for c in master_df.columns]
#columns_to_consider = [c for c in master_df.columns if c.startswith("baseline")]
#columns_to_consider.append('is_encrypted')
columns_to_consider = [c for c in master_df.columns if c != 'extended.extension']


interesting_df = master_df[columns_to_consider]

X = interesting_df[[c for c in interesting_df.columns if c.startswith('baseline')]]
X = interesting_df[[c for c in interesting_df.columns if c != 'is_encrypted']]
X = X[baseline_columns + advanced_columns]

X = X[[c for c in X.columns if c != 'is_encrypted']]

# get rid of tail and head metrics
X = X[[c for c in X.columns if "begin" not in c and "head" not in c]]
X = X[[c for c in X.columns if "tail" not in c and "end" not in c]]

X = X[[c for c in X.columns if "kurtosis" not in c and "skew" not in c]]

y = interesting_df['is_encrypted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# -----------------------------------


rfc = RandomForestClassifier(n_jobs=-1)
estimators = [('std,', MinMaxScaler()), ('RFC', rfc)]
pipeline = Pipeline(estimators)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print(f"Precision : {precision}")
print(f"Recall    : {recall}")
print(f"Accuracy  : {accuracy}")
print(f"F1-score  : {f1}")

df_json["Extremities_Measured_Separately"].append("NO")
df_json["Algorithm"].append("Random Forest")
df_json["Accuracy"].append(accuracy)
df_json["Precision"].append(precision)
df_json["Recall"].append(recall)
df_json["F1"].append(f1)
# Out:
# Precision : 0.6354396277247122
# Recall    : 0.6995146939875977
# Accuracy  : 0.6520518647239674
# F1-score  : 0.6659394250513346

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (6,5)

columns = np.array([c for c in X_train.columns])
sort_array = np.argsort(rfc.feature_importances_)[::-1]
df = pd.DataFrame({"Feature": X_train.columns[sort_array], "Importance": rfc.feature_importances_[sort_array]})

def get_type(x):
    return "Advanced" if "advanced" in x.lower() else "Baseline"

df["Type"] = df["Feature"].map(get_type)
      
#plt.barh(X_train.columns[sort_array], rfc.feature_importances_[sort_array])
sns.barplot(y="Feature", x="Importance", hue="Type", data=df, palette="bright", dodge=False)
# Out:
# <AxesSubplot:xlabel='Importance', ylabel='Feature'>

# %%
#columns_to_consider = [c for c in master_df.columns]
#columns_to_consider = [c for c in master_df.columns if c.startswith("baseline")]
#columns_to_consider.append('is_encrypted')
columns_to_consider = [c for c in master_df.columns if c != 'extended.extension']


interesting_df = master_df[columns_to_consider]

X = interesting_df[[c for c in interesting_df.columns if c.startswith('baseline')]]
X = interesting_df[[c for c in interesting_df.columns if c != 'is_encrypted']]
X = X[baseline_columns + advanced_columns]


X = X[[c for c in X.columns if c != 'is_encrypted']]

# get rid of tail and head metrics
#X = X[[c for c in X.columns if "begin" not in c and "head" not in c]]
#X = X[[c for c in X.columns if "tail" not in c and "end" not in c]]

X = X[[c for c in X.columns if "kurtosis" not in c and "skew" not in c]]

y = interesting_df['is_encrypted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# -----------------------------------


rfc = RandomForestClassifier(n_jobs=-1)
estimators = [('std,', MinMaxScaler()), ('RFC', rfc)]
pipeline = Pipeline(estimators)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print(f"Precision : {precision}")
print(f"Recall    : {recall}")
print(f"Accuracy  : {accuracy}")
print(f"F1-score  : {f1}")

df_json["Extremities_Measured_Separately"].append("YES")
df_json["Algorithm"].append("Random Forest")
df_json["Accuracy"].append(accuracy)
df_json["Precision"].append(precision)
df_json["Recall"].append(recall)
df_json["F1"].append(f1)
# Out:
# Precision : 0.7527162701141521
# Recall    : 0.7377999460771097
# Accuracy  : 0.7498329100387648
# F1-score  : 0.7451834706242767

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (6,5)

columns = np.array([c for c in X_train.columns])
sort_array = np.argsort(rfc.feature_importances_)[::-1]
df = pd.DataFrame({"Feature": X_train.columns[sort_array], "Importance": rfc.feature_importances_[sort_array]})

def get_type(x):
    return "Advanced" if "advanced" in x.lower() else "Baseline"

df["Type"] = df["Feature"].map(get_type)
      
#plt.barh(X_train.columns[sort_array], rfc.feature_importances_[sort_array])
sns.barplot(y="Feature", x="Importance", hue="Type", data=df, palette="bright", dodge=False)
# Out:
# <AxesSubplot:xlabel='Importance', ylabel='Feature'>

# %%
df = pd.DataFrame(df_json)

# %%
df
# Out:
#   Extremities_Measured_Separately            Algorithm  Accuracy  Precision  \
# 0                              NO  Logistic Regression  0.668293   0.612131
# 1                             YES  Logistic Regression  0.760192   0.726359
# 2                              NO        Random Forest  0.652052   0.635440
# 3                             YES        Random Forest  0.749833   0.752716
#
#      Recall        F1
# 0  0.903343  0.729758
# 1  0.828390  0.774027
# 2  0.699515  0.665939
# 3  0.737800  0.745183

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lllrrrr}
# \toprule
# {} & Extremities\_Measured\_Separately &            Algorithm &  Accuracy &  Precision &    Recall &        F1 \\
# \midrule
# 0 &                              NO &  Logistic Regression &  0.668293 &   0.612131 &  0.903343 &  0.729758 \\
# 1 &                             YES &  Logistic Regression &  0.760192 &   0.726359 &  0.828390 &  0.774027 \\
# 2 &                              NO &        Random Forest &  0.652052 &   0.635440 &  0.699515 &  0.665939 \\
# 3 &                             YES &        Random Forest &  0.749833 &   0.752716 &  0.737800 &  0.745183 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Now add kurtosis and skew to the same thing and measure again

# %%
#columns_to_consider = [c for c in master_df.columns]
#columns_to_consider = [c for c in master_df.columns if c.startswith("baseline")]
#columns_to_consider.append('is_encrypted')
columns_to_consider = [c for c in master_df.columns if c != 'extended.extension']


interesting_df = master_df[columns_to_consider]

X = interesting_df[[c for c in interesting_df.columns if c.startswith('baseline')]]
X = interesting_df[[c for c in interesting_df.columns if c != 'is_encrypted']]
X = X[baseline_columns + advanced_columns]


X = X[[c for c in X.columns if c != 'is_encrypted']]

# get rid of tail and head metrics
X = X[[c for c in X.columns if "begin" not in c and "head" not in c]]
X = X[[c for c in X.columns if "tail" not in c and "end" not in c]]

# X = X[[c for c in X.columns if "kurtosis" not in c and "skew" not in c]]

y = interesting_df['is_encrypted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# ---------------------------------------------------------------

rfc = RandomForestClassifier(n_jobs=-1)
estimators = [('std,', MinMaxScaler()), ('LogisticRegressor', LogisticRegression(n_jobs=10, max_iter=1000))]
pipeline = Pipeline(estimators)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print(f"Precision : {precision}")
print(f"Recall    : {recall}")
print(f"Accuracy  : {accuracy}")
print(f"F1-score  : {f1}")

df_json2 = {
    "Extremities_Measured_Separately": [],
    "Algorithm": [],
    "Accuracy": [],
    "Precision": [],
    "Recall": [],
    "F1": []
}

df_json2["Extremities_Measured_Separately"].append("NO")
df_json2["Algorithm"].append("Logistic Regression")
df_json2["Accuracy"].append(accuracy)
df_json2["Precision"].append(precision)
df_json2["Recall"].append(recall)
df_json2["F1"].append(f1)
# Out:
# Precision : 0.6124108938036922
# Recall    : 0.9033432191965489
# Accuracy  : 0.6686271888784922
# F1-score  : 0.7299564270152505

# %%
#columns_to_consider = [c for c in master_df.columns]
#columns_to_consider = [c for c in master_df.columns if c.startswith("baseline")]
#columns_to_consider.append('is_encrypted')
columns_to_consider = [c for c in master_df.columns if c != 'extended.extension']


interesting_df = master_df[columns_to_consider]

X = interesting_df[[c for c in interesting_df.columns if c.startswith('baseline')]]
X = interesting_df[[c for c in interesting_df.columns if c != 'is_encrypted']]
X = X[baseline_columns + advanced_columns]


X = X[[c for c in X.columns if c != 'is_encrypted']]

# get rid of tail and head metrics
# X = X[[c for c in X.columns if "begin" not in c and "head" not in c]]
# X = X[[c for c in X.columns if "tail" not in c and "end" not in c]]

# X = X[[c for c in X.columns if "kurtosis" not in c and "skew" not in c]]

y = interesting_df['is_encrypted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# ---------------------------------------------------------------

rfc = RandomForestClassifier(n_jobs=-1)
estimators = [('std,', MinMaxScaler()), ('LogisticRegressor', LogisticRegression(n_jobs=10, max_iter=1000))]
#estimators = [('std,', MinMaxScaler()), ('RFC', rfc)]
pipeline = Pipeline(estimators)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print(f"Precision : {precision}")
print(f"Recall    : {recall}")
print(f"Accuracy  : {accuracy}")
print(f"F1-score  : {f1}")


df_json2["Extremities_Measured_Separately"].append("YES")
df_json2["Algorithm"].append("Logistic Regression")
df_json2["Accuracy"].append(accuracy)
df_json2["Precision"].append(precision)
df_json2["Recall"].append(recall)
df_json2["F1"].append(f1)
# Out:
# Precision : 0.7365110089523349
# Recall    : 0.8207063898624967
# Accuracy  : 0.765539366394867
# F1-score  : 0.7763325682223924

# %%
#columns_to_consider = [c for c in master_df.columns]
#columns_to_consider = [c for c in master_df.columns if c.startswith("baseline")]
#columns_to_consider.append('is_encrypted')
columns_to_consider = [c for c in master_df.columns if c != 'extended.extension']


interesting_df = master_df[columns_to_consider]

X = interesting_df[[c for c in interesting_df.columns if c.startswith('baseline')]]
X = interesting_df[[c for c in interesting_df.columns if c != 'is_encrypted']]
X = X[baseline_columns + advanced_columns]
X = X[[c for c in X.columns if c != 'is_encrypted']]

# get rid of tail and head metrics
X = X[[c for c in X.columns if "begin" not in c and "head" not in c]]
X = X[[c for c in X.columns if "tail" not in c and "end" not in c]]

# X = X[[c for c in X.columns if "kurtosis" not in c and "skew" not in c]]

y = interesting_df['is_encrypted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# ---------------------------------------------------------------

rfc = RandomForestClassifier(n_jobs=-1)
#estimators = [('std,', MinMaxScaler()), ('LogisticRegressor', LogisticRegression(n_jobs=10, max_iter=1000))]
estimators = [('std,', MinMaxScaler()), ('RFC', rfc)]
pipeline = Pipeline(estimators)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print(f"Precision : {precision}")
print(f"Recall    : {recall}")
print(f"Accuracy  : {accuracy}")
print(f"F1-score  : {f1}")

df_json2["Extremities_Measured_Separately"].append("NO")
df_json2["Algorithm"].append("Random Forest")
df_json2["Accuracy"].append(accuracy)
df_json2["Precision"].append(precision)
df_json2["Recall"].append(recall)
df_json2["F1"].append(f1)
# Out:
# Precision : 0.6319143819143819
# Recall    : 0.7084119708816392
# Accuracy  : 0.6508488170030745
# F1-score  : 0.6679801703317656

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (6,5)

columns = np.array([c for c in X_train.columns])
sort_array = np.argsort(rfc.feature_importances_)[::-1]
df = pd.DataFrame({"Feature": X_train.columns[sort_array], "Importance": rfc.feature_importances_[sort_array]})

def get_type(x):
    return "Advanced" if "advanced" in x.lower() else "Baseline"

df["Type"] = df["Feature"].map(get_type)
      
#plt.barh(X_train.columns[sort_array], rfc.feature_importances_[sort_array])
sns.barplot(y="Feature", x="Importance", hue="Type", data=df, palette="bright", dodge=False)
# Out:
# <AxesSubplot:xlabel='Importance', ylabel='Feature'>

# %%
#columns_to_consider = [c for c in master_df.columns]
#columns_to_consider = [c for c in master_df.columns if c.startswith("baseline")]
#columns_to_consider.append('is_encrypted')
columns_to_consider = [c for c in master_df.columns if c != 'extended.extension']


interesting_df = master_df[columns_to_consider]

X = interesting_df[[c for c in interesting_df.columns if c.startswith('baseline')]]
X = interesting_df[[c for c in interesting_df.columns if c != 'is_encrypted']]
X = X[baseline_columns + advanced_columns]

X = X[[c for c in X.columns if c != 'is_encrypted']]

# get rid of tail and head metrics
# X = X[[c for c in X.columns if "begin" not in c and "head" not in c]]
# X = X[[c for c in X.columns if "tail" not in c and "end" not in c]]

# X = X[[c for c in X.columns if "kurtosis" not in c and "skew" not in c]]

y = interesting_df['is_encrypted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# ---------------------------------------------------------------

rfc = RandomForestClassifier(n_jobs=-1)
#estimators = [('std,', MinMaxScaler()), ('LogisticRegressor', LogisticRegression(n_jobs=10, max_iter=1000))]
estimators = [('std,', MinMaxScaler()), ('RFC', rfc)]
pipeline = Pipeline(estimators)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print(f"Precision : {precision}")
print(f"Recall    : {recall}")
print(f"Accuracy  : {accuracy}")
print(f"F1-score  : {f1}")

df_json2["Extremities_Measured_Separately"].append("YES")
df_json2["Algorithm"].append("Random Forest")
df_json2["Accuracy"].append(accuracy)
df_json2["Precision"].append(precision)
df_json2["Recall"].append(recall)
df_json2["F1"].append(f1)
# Out:
# Precision : 0.754017305315204
# Recall    : 0.7400916689134538
# Accuracy  : 0.7514369736666221
# F1-score  : 0.7469895911286482

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (6,5)

columns = np.array([c for c in X_train.columns])
sort_array = np.argsort(rfc.feature_importances_)[::-1]
df = pd.DataFrame({"Feature": X_train.columns[sort_array], "Importance": rfc.feature_importances_[sort_array]})

def get_type(x):
    return "Advanced" if "advanced" in x.lower() else "Baseline"

df["Type"] = df["Feature"].map(get_type)
      
#plt.barh(X_train.columns[sort_array], rfc.feature_importances_[sort_array])
sns.barplot(y="Feature", x="Importance", hue="Type", data=df, palette="bright", dodge=False)
# Out:
# <AxesSubplot:xlabel='Importance', ylabel='Feature'>

# %%
df2 = pd.DataFrame(df_json2)
df2
# Out:
#   Extremities_Measured_Separately            Algorithm  Accuracy  Precision  \
# 0                              NO  Logistic Regression  0.668627   0.612411
# 1                             YES  Logistic Regression  0.765539   0.736511
# 2                              NO        Random Forest  0.650849   0.631914
# 3                             YES        Random Forest  0.751437   0.754017
#
#      Recall        F1
# 0  0.903343  0.729956
# 1  0.820706  0.776333
# 2  0.708412  0.667980
# 3  0.740092  0.746990

# %%
print(df2.to_latex())
# Out:
# \begin{tabular}{lllrrrr}
# \toprule
# {} & Extremities\_Measured\_Separately &            Algorithm &  Accuracy &  Precision &    Recall &        F1 \\
# \midrule
# 0 &                              NO &  Logistic Regression &  0.668627 &   0.612411 &  0.903343 &  0.729956 \\
# 1 &                             YES &  Logistic Regression &  0.765539 &   0.736511 &  0.820706 &  0.776333 \\
# 2 &                              NO &        Random Forest &  0.650849 &   0.631914 &  0.708412 &  0.667980 \\
# 3 &                             YES &        Random Forest &  0.751437 &   0.754017 &  0.740092 &  0.746990 \\
# \bottomrule
# \end{tabular}

# %%
df
# Out:
#                            Feature  Importance      Type
# 0                advanced.skew_end    0.020297  Advanced
# 1            advanced.kurtosis_end    0.020418  Advanced
# 2           advanced.kurtosis_full    0.022887  Advanced
# 3               advanced.skew_full    0.023995  Advanced
# 4           baseline.montecarlo_pi    0.024262  Baseline
# 5          baseline.chisquare_full    0.028986  Baseline
# 6              advanced.skew_begin    0.032261  Advanced
# 7          advanced.kurtosis_begin    0.034743  Advanced
# 8           baseline.chisquare_end    0.040194  Baseline
# 9         baseline.shannon_entropy    0.041312  Baseline
# 10    baseline.autocorrelation_end    0.042884  Baseline
# 11   baseline.autocorrelation_full    0.063667  Baseline
# 12   baseline.tail_shannon_entropy    0.071773  Baseline
# 13        baseline.chisquare_begin    0.116142  Baseline
# 14  baseline.autocorrelation_begin    0.159750  Baseline
# 15   baseline.head_shannon_entropy    0.256429  Baseline

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llrl}
# \toprule
# {} &                         Feature &  Importance &      Type \\
# \midrule
# 0  &               advanced.skew\_end &    0.020297 &  Advanced \\
# 1  &           advanced.kurtosis\_end &    0.020418 &  Advanced \\
# 2  &          advanced.kurtosis\_full &    0.022887 &  Advanced \\
# 3  &              advanced.skew\_full &    0.023995 &  Advanced \\
# 4  &          baseline.montecarlo\_pi &    0.024262 &  Baseline \\
# 5  &         baseline.chisquare\_full &    0.028986 &  Baseline \\
# 6  &             advanced.skew\_begin &    0.032261 &  Advanced \\
# 7  &         advanced.kurtosis\_begin &    0.034743 &  Advanced \\
# 8  &          baseline.chisquare\_end &    0.040194 &  Baseline \\
# 9  &        baseline.shannon\_entropy &    0.041312 &  Baseline \\
# 10 &    baseline.autocorrelation\_end &    0.042884 &  Baseline \\
# 11 &   baseline.autocorrelation\_full &    0.063667 &  Baseline \\
# 12 &   baseline.tail\_shannon\_entropy &    0.071773 &  Baseline \\
# 13 &        baseline.chisquare\_begin &    0.116142 &  Baseline \\
# 14 &  baseline.autocorrelation\_begin &    0.159750 &  Baseline \\
# 15 &   baseline.head\_shannon\_entropy &    0.256429 &  Baseline \\
# \bottomrule
# \end{tabular}

# %%
df2.describe().T
# Out:
#            count      mean       std       min       25%       50%       75%  \
# Accuracy     4.0  0.709113  0.057761  0.650849  0.664183  0.710032  0.754963
# Precision    4.0  0.683713  0.071874  0.612411  0.627039  0.684213  0.740888
# Recall       4.0  0.793138  0.087364  0.708412  0.732172  0.780399  0.841366
# F1           4.0  0.730315  0.045758  0.667980  0.714462  0.738473  0.754325
#
#                 max
# Accuracy   0.765539
# Precision  0.754017
# Recall     0.903343
# F1         0.776333

# %%
df.describe().T
# Out:
#             count    mean       std       min       25%       50%       75%  \
# Importance   16.0  0.0625  0.064413  0.020297  0.024195  0.037469  0.065694
#
#                  max
# Importance  0.256429

# %%
df3 = pd.DataFrame({"With Skew and Kurtosis (averages)": df2.mean(), "Without Skew and Kurtosis (averages)": df.mean()}).T
# Out:
# /var/folders/z1/hfz3q2b52bx3hb8nh0z1q89c0000gp/T/ipykernel_28513/3964534304.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df3 = pd.DataFrame({"With Skew and Kurtosis (averages)": df2.mean(), "Without Skew and Kurtosis (averages)": df.mean()}).T

# %%
df3
# Out:
#                                       Accuracy        F1  Importance  \
# With Skew and Kurtosis (averages)     0.709113  0.730315         NaN
# Without Skew and Kurtosis (averages)       NaN       NaN      0.0625
#
#                                       Precision    Recall
# With Skew and Kurtosis (averages)      0.683713  0.793138
# Without Skew and Kurtosis (averages)        NaN       NaN

# %%
print(df3.to_latex())
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Accuracy &        F1 &  Importance &  Precision &    Recall \\
# \midrule
# With Skew and Kurtosis (averages)    &  0.709113 &  0.730315 &         NaN &   0.683713 &  0.793138 \\
# Without Skew and Kurtosis (averages) &       NaN &       NaN &      0.0625 &        NaN &       NaN \\
# \bottomrule
# \end{tabular}

# %%
df.to_csv("extremity-compared-without-kurtosis.csv")
df2.to_csv("extremity-compared-with-kurtosis.csv")
df3.to_csv("with-and-without-kurtosis.csv")

# %%
df["Kurtosis and Skew Used"] = 0
df2["Kurtosis and Skew Used"] = 1

# %%
df_final = pd.concat([df, df2])

# %%
df_final["Extremities Measured Separately"] = df_final["Extremities_Measured_Separately"]
df_final = df_final.drop("Extremities_Measured_Separately", axis=1)

# %%
df_final = df_final.reset_index()

# %%
print(df_final.to_latex())
# Out:
# \begin{tabular}{lrlrlrlrrrrl}
# \toprule
# {} &  index &                         Feature &  Importance &      Type &  Kurtosis and Skew Used &            Algorithm &  Accuracy &  Precision &    Recall &        F1 & Extremities Measured Separately \\
# \midrule
# 0  &      0 &               advanced.skew\_end &    0.020297 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 1  &      1 &           advanced.kurtosis\_end &    0.020418 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 2  &      2 &          advanced.kurtosis\_full &    0.022887 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 3  &      3 &              advanced.skew\_full &    0.023995 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 4  &      4 &          baseline.montecarlo\_pi &    0.024262 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 5  &      5 &         baseline.chisquare\_full &    0.028986 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 6  &      6 &             advanced.skew\_begin &    0.032261 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 7  &      7 &         advanced.kurtosis\_begin &    0.034743 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 8  &      8 &          baseline.chisquare\_end &    0.040194 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 9  &      9 &        baseline.shannon\_entropy &    0.041312 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 10 &     10 &    baseline.autocorrelation\_end &    0.042884 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 11 &     11 &   baseline.autocorrelation\_full &    0.063667 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 12 &     12 &   baseline.tail\_shannon\_entropy &    0.071773 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 13 &     13 &        baseline.chisquare\_begin &    0.116142 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 14 &     14 &  baseline.autocorrelation\_begin &    0.159750 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 15 &     15 &   baseline.head\_shannon\_entropy &    0.256429 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 16 &      0 &                             NaN &         NaN &       NaN &                       1 &  Logistic Regression &  0.668627 &   0.612411 &  0.903343 &  0.729956 &                              NO \\
# 17 &      1 &                             NaN &         NaN &       NaN &                       1 &  Logistic Regression &  0.765539 &   0.736511 &  0.820706 &  0.776333 &                             YES \\
# 18 &      2 &                             NaN &         NaN &       NaN &                       1 &        Random Forest &  0.650849 &   0.631914 &  0.708412 &  0.667980 &                              NO \\
# 19 &      3 &                             NaN &         NaN &       NaN &                       1 &        Random Forest &  0.751437 &   0.754017 &  0.740092 &  0.746990 &                             YES \\
# \bottomrule
# \end{tabular}

# %%
df_final = df_final.drop("index", axis=1)

# %%
df_final
# Out:
#                            Feature  Importance      Type  \
# 0                advanced.skew_end    0.020297  Advanced
# 1            advanced.kurtosis_end    0.020418  Advanced
# 2           advanced.kurtosis_full    0.022887  Advanced
# 3               advanced.skew_full    0.023995  Advanced
# 4           baseline.montecarlo_pi    0.024262  Baseline
# 5          baseline.chisquare_full    0.028986  Baseline
# 6              advanced.skew_begin    0.032261  Advanced
# 7          advanced.kurtosis_begin    0.034743  Advanced
# 8           baseline.chisquare_end    0.040194  Baseline
# 9         baseline.shannon_entropy    0.041312  Baseline
# 10    baseline.autocorrelation_end    0.042884  Baseline
# 11   baseline.autocorrelation_full    0.063667  Baseline
# 12   baseline.tail_shannon_entropy    0.071773  Baseline
# 13        baseline.chisquare_begin    0.116142  Baseline
# 14  baseline.autocorrelation_begin    0.159750  Baseline
# 15   baseline.head_shannon_entropy    0.256429  Baseline
# 16                             NaN         NaN       NaN
# 17                             NaN         NaN       NaN
# 18                             NaN         NaN       NaN
# 19                             NaN         NaN       NaN
#
#     Kurtosis and Skew Used            Algorithm  Accuracy  Precision  \
# 0                        0                  NaN       NaN        NaN
# 1                        0                  NaN       NaN        NaN
# 2                        0                  NaN       NaN        NaN
# 3                        0                  NaN       NaN        NaN
# 4                        0                  NaN       NaN        NaN
# 5                        0                  NaN       NaN        NaN
# 6                        0                  NaN       NaN        NaN
# 7                        0                  NaN       NaN        NaN
# 8                        0                  NaN       NaN        NaN
# 9                        0                  NaN       NaN        NaN
# 10                       0                  NaN       NaN        NaN
# 11                       0                  NaN       NaN        NaN
# 12                       0                  NaN       NaN        NaN
# 13                       0                  NaN       NaN        NaN
# 14                       0                  NaN       NaN        NaN
# 15                       0                  NaN       NaN        NaN
# 16                       1  Logistic Regression  0.668627   0.612411
# 17                       1  Logistic Regression  0.765539   0.736511
# 18                       1        Random Forest  0.650849   0.631914
# 19                       1        Random Forest  0.751437   0.754017
#
#       Recall        F1 Extremities Measured Separately
# 0        NaN       NaN                             NaN
# 1        NaN       NaN                             NaN
# 2        NaN       NaN                             NaN
# 3        NaN       NaN                             NaN
# 4        NaN       NaN                             NaN
# 5        NaN       NaN                             NaN
# 6        NaN       NaN                             NaN
# 7        NaN       NaN                             NaN
# 8        NaN       NaN                             NaN
# 9        NaN       NaN                             NaN
# 10       NaN       NaN                             NaN
# 11       NaN       NaN                             NaN
# 12       NaN       NaN                             NaN
# 13       NaN       NaN                             NaN
# 14       NaN       NaN                             NaN
# 15       NaN       NaN                             NaN
# 16  0.903343  0.729956                              NO
# 17  0.820706  0.776333                             YES
# 18  0.708412  0.667980                              NO
# 19  0.740092  0.746990                             YES

# %%
print(df_final.to_latex())
# Out:
# \begin{tabular}{llrlrlrrrrl}
# \toprule
# {} &                         Feature &  Importance &      Type &  Kurtosis and Skew Used &            Algorithm &  Accuracy &  Precision &    Recall &        F1 & Extremities Measured Separately \\
# \midrule
# 0  &               advanced.skew\_end &    0.020297 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 1  &           advanced.kurtosis\_end &    0.020418 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 2  &          advanced.kurtosis\_full &    0.022887 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 3  &              advanced.skew\_full &    0.023995 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 4  &          baseline.montecarlo\_pi &    0.024262 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 5  &         baseline.chisquare\_full &    0.028986 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 6  &             advanced.skew\_begin &    0.032261 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 7  &         advanced.kurtosis\_begin &    0.034743 &  Advanced &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 8  &          baseline.chisquare\_end &    0.040194 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 9  &        baseline.shannon\_entropy &    0.041312 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 10 &    baseline.autocorrelation\_end &    0.042884 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 11 &   baseline.autocorrelation\_full &    0.063667 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 12 &   baseline.tail\_shannon\_entropy &    0.071773 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 13 &        baseline.chisquare\_begin &    0.116142 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 14 &  baseline.autocorrelation\_begin &    0.159750 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 15 &   baseline.head\_shannon\_entropy &    0.256429 &  Baseline &                       0 &                  NaN &       NaN &        NaN &       NaN &       NaN &                             NaN \\
# 16 &                             NaN &         NaN &       NaN &                       1 &  Logistic Regression &  0.668627 &   0.612411 &  0.903343 &  0.729956 &                              NO \\
# 17 &                             NaN &         NaN &       NaN &                       1 &  Logistic Regression &  0.765539 &   0.736511 &  0.820706 &  0.776333 &                             YES \\
# 18 &                             NaN &         NaN &       NaN &                       1 &        Random Forest &  0.650849 &   0.631914 &  0.708412 &  0.667980 &                              NO \\
# 19 &                             NaN &         NaN &       NaN &                       1 &        Random Forest &  0.751437 &   0.754017 &  0.740092 &  0.746990 &                             YES \\
# \bottomrule
# \end{tabular}

# %%
df_final.to_csv("extremity-kurtosis-skew-measured.csv")

# %%
df_final[df_final["Algorithm"] == "Logistic Regression"]
# Out:
#    Feature  Importance Type  Kurtosis and Skew Used            Algorithm  \
# 16     NaN         NaN  NaN                       1  Logistic Regression
# 17     NaN         NaN  NaN                       1  Logistic Regression
#
#     Accuracy  Precision    Recall        F1 Extremities Measured Separately
# 16  0.668627   0.612411  0.903343  0.729956                              NO
# 17  0.765539   0.736511  0.820706  0.776333                             YES

# %%
df_final[df_final["Algorithm"] != "Logistic Regression"]
# Out:
#                            Feature  Importance      Type  \
# 0                advanced.skew_end    0.020297  Advanced
# 1            advanced.kurtosis_end    0.020418  Advanced
# 2           advanced.kurtosis_full    0.022887  Advanced
# 3               advanced.skew_full    0.023995  Advanced
# 4           baseline.montecarlo_pi    0.024262  Baseline
# 5          baseline.chisquare_full    0.028986  Baseline
# 6              advanced.skew_begin    0.032261  Advanced
# 7          advanced.kurtosis_begin    0.034743  Advanced
# 8           baseline.chisquare_end    0.040194  Baseline
# 9         baseline.shannon_entropy    0.041312  Baseline
# 10    baseline.autocorrelation_end    0.042884  Baseline
# 11   baseline.autocorrelation_full    0.063667  Baseline
# 12   baseline.tail_shannon_entropy    0.071773  Baseline
# 13        baseline.chisquare_begin    0.116142  Baseline
# 14  baseline.autocorrelation_begin    0.159750  Baseline
# 15   baseline.head_shannon_entropy    0.256429  Baseline
# 18                             NaN         NaN       NaN
# 19                             NaN         NaN       NaN
#
#     Kurtosis and Skew Used      Algorithm  Accuracy  Precision    Recall  \
# 0                        0            NaN       NaN        NaN       NaN
# 1                        0            NaN       NaN        NaN       NaN
# 2                        0            NaN       NaN        NaN       NaN
# 3                        0            NaN       NaN        NaN       NaN
# 4                        0            NaN       NaN        NaN       NaN
# 5                        0            NaN       NaN        NaN       NaN
# 6                        0            NaN       NaN        NaN       NaN
# 7                        0            NaN       NaN        NaN       NaN
# 8                        0            NaN       NaN        NaN       NaN
# 9                        0            NaN       NaN        NaN       NaN
# 10                       0            NaN       NaN        NaN       NaN
# 11                       0            NaN       NaN        NaN       NaN
# 12                       0            NaN       NaN        NaN       NaN
# 13                       0            NaN       NaN        NaN       NaN
# 14                       0            NaN       NaN        NaN       NaN
# 15                       0            NaN       NaN        NaN       NaN
# 18                       1  Random Forest  0.650849   0.631914  0.708412
# 19                       1  Random Forest  0.751437   0.754017  0.740092
#
#          F1 Extremities Measured Separately
# 0       NaN                             NaN
# 1       NaN                             NaN
# 2       NaN                             NaN
# 3       NaN                             NaN
# 4       NaN                             NaN
# 5       NaN                             NaN
# 6       NaN                             NaN
# 7       NaN                             NaN
# 8       NaN                             NaN
# 9       NaN                             NaN
# 10      NaN                             NaN
# 11      NaN                             NaN
# 12      NaN                             NaN
# 13      NaN                             NaN
# 14      NaN                             NaN
# 15      NaN                             NaN
# 18  0.66798                              NO
# 19  0.74699                             YES

# %%
baseline_columns = [c for c in master_df.columns if "baseline" in c.lower() and "filesize" not in c.lower()]
advanced_columns = [c for c in master_df.columns if "kurtosis" in c.lower() or "skew" in c.lower()]
